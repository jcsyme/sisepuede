# %%
import os, os.path
import numpy as np
import pandas as pd
#from model_attributes import *
import model_attributes as ma
import model_afolu as mafl
import model_ippu as mi
import model_circular_economy as mc
import model_electricity as ml
import model_energy as me
import model_socioeconomic as se
import setup_analysis as sa
import sisepuede_data_api as api
import support_classes as sc
import support_functions as sf
import sql_utilities as su
import importlib
import time
import warnings
import matplotlib.pyplot as plt
from typing import Union
import inspect
import ingestion as ing
import logging
from sisepuede_file_structure import *
# Out:
# /Users/jsyme/Documents/Projects/git_jbus/lac_decarbonization/python/model_attributes.py:2550: UserWarning: Invalid subsector attribute 'key_varreqs_partial'. Valid return type values are:'pycategory_primary', 'abv_subsector', 'sector', 'abv_sector', 'key_varreqs_all'
#   warnings.warn(f"Invalid subsector attribute '{return_type}'. Valid return type values are:{valid_rts}")
# /Users/jsyme/Documents/Projects/git_jbus/lac_decarbonization/python/model_attributes.py:2307: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for desig, df in df_by_designation:

# %%
df_test = pd.read_csv("/Users/jsyme/Desktop/athena_test_ecuador.csv")

# %%
def generate_schema_from_df(
    df_in: pd.DataFrame,
    dict_fields_to_dtype_sql: Union[Dict[str, Union[str, type]], None] = None,
    field_type_object_default: str = "string",
    float_as_double: bool = False,
    sep: str = ",\n",
) -> str:
    """
    Generate an SQL schema from a data frame. For use in automating table
        setup in remote SQL or SQL-like databases.
    
    Returns a two-ple of the following form:
    
        (schema_out, fields_out)
 
 
    Function Arguments
    ------------------
    - df_in: input data frame
    
    Keyword Arguments
    -----------------
    - dict_fields_to_dtype_sql: dictionary mapping fields to specific SQL data 
        types; keys are fields and dtypes are SQL data types.
        * If None, infers from DataFrame dtype
    - field_type_object_default: default data type for fields specified as 
        object (any valid SQL data type)
    - sep: string separator to use in schema (", " or "\n, ", should always have
        a comma)
    """
    # initialize fields, schema out, and fields that were successfully pushed to the schema
    fields = list(df_in.columns)
    schema_out = []
    fields_out = []
    
    # some data type dictionaries that are used
    dict_dtypes = df_in.dtypes.to_dict()
    dict_dtypes_to_sql_types = {
        "string": "STRING",
        "o": "STRING", 
        "float64": "FLOAT",
        "int64": "INTEGER",
    }
    dict_fields_to_dtype_sql = (
        dict_fields_to_dtype_sql
        if isinstance(dict_fields_to_dtype_sql, dict)
        else {}
    )
    
    for i, field in enumerate(fields):
        
        # try getting sql data type from external dictionary; otherwise, pull from pandas datatype
        dtype_sql = dict_fields_to_dtype_sql.get(field)
        if dtype_sql is None:
            dtype_sql = dict_dtypes.get(field)
            dtype_sql = (
                dict_dtypes_to_sql_types.get(dtype_sql.name, "STRING")
                if dtype_sql is not None
                else None
            )
        
        # skip if failed
        if dtype_sql is None:
            continue
            
        # otherwise, build schema
        schema_out.append(f"{field} {dtype_sql}")
        fields_out.append(field)
    
    schema_out = str(sep).join(schema_out)
    
    return schema_out, fields_out

        
tup = generate_schema_from_df(df_test)

table_name = "MODEL_OUTPUT_HASHIDHERE"
loc_s3 = "s3://rand-sisepuede/database/sisepuede_run_2023-06-22T18;27;35.313318/MODEL_OUTPUT/"
    
query_create_table = f"CREATE EXTERNAL TABLE IF NOT EXISTS {table_name}"
query_create_table = f"{query_create_table} (\n{tup[0]}\n)"   

# add row format
appends_ordered = [
    "ROW FORMAT SERDE",
    "WITH SERDEPROPERTIES",
    "STORED AS",
    "LOCATION",
    # TBLPROPERTIES follows everything else; see https://docs.aws.amazon.com/athena/latest/ug/vpc-flow-logs.html for example
    "TBLPROPERTIES"
]

# some components to keep
dict_query_components = {
    "LOCATION": f"'{loc_s3}'",
    "ROW FORMAT SERDE": "'org.apache.hadoop.hive.serde2.OpenCSVSerde'",
    "STORED AS": "TEXTFILE",
    "TBLPROPERTIES": "(\"skip.header.line.count\"=\"1\")",
    "WITH SERDEPROPERTIES": f"""(
       'separatorChar' = ',',
       'quoteChar' = '"',
       'escapeChar' = '\\'
        )
    """,
}

for k in appends_ordered:
    v = dict_query_components.get(k)
    query_create_table = f"{query_create_table}\n{k} {v}"

query_create_table = f"{query_create_table};"
print(query_create_table)
# Out:
# CREATE EXTERNAL TABLE IF NOT EXISTS MODEL_OUTPUT_HASHIDHERE (
# primary_id INTEGER,
# region STRING,
# time_period INTEGER,
# area_agrc_crops_bevs_and_spices FLOAT,
# area_agrc_crops_cereals FLOAT,
# area_agrc_crops_fibers FLOAT,
# area_agrc_crops_fruits FLOAT,
# area_agrc_crops_herbs_and_other_perennial_crops FLOAT,
# area_agrc_crops_nuts FLOAT,
# area_agrc_crops_other_annual FLOAT,
# area_agrc_crops_other_woody_perennial FLOAT,
# area_agrc_crops_pulses FLOAT,
# area_agrc_crops_rice FLOAT,
# area_agrc_crops_sugar_cane FLOAT,
# area_agrc_crops_tubers FLOAT,
# area_agrc_crops_vegetables_and_vines FLOAT,
# area_lndu_conversion_from_croplands FLOAT,
# area_lndu_conversion_from_forests_mangroves FLOAT,
# area_lndu_conversion_from_forests_primary FLOAT,
# area_lndu_conversion_from_forests_secondary FLOAT,
# area_lndu_conversion_from_grasslands FLOAT,
# area_lndu_conversion_from_other FLOAT,
# area_lndu_conversion_from_settlements FLOAT,
# area_lndu_conversion_from_wetlands FLOAT,
# ...

# %%
# primary id is INTEGER
# FLOAT for outhers
2**15
# Out:
# 32768

# %%
df_tmp = pd.DataFrame({"this": ["a", "b", "c"]})
df_tmp.dtypes
# Out:
# this    object
# dtype: object

# %%
dict_dtypes = df_test.dtypes.to_dict()
dict_dtypes.get("primary_id").name
# Out:
# 'int64'

# %% [markdown]
# # Check output fields to facilitate schema build on the fly

# %%
import sqlalchemy
import sql_utilities as squ
import setup_analysis as sa

engine = sqlalchemy.create_engine(f"sqlite:///{fp}")
fp = "/Users/jsyme/Documents/Projects/git_jbus/lac_decarbonization/out/sisepuede_run_2023-07-05T02;43;25.818306/sisepuede_run_2023-07-05T02;43;25.818306_output_database.sqlite"

# %%
engine.table_names()
# Out:
# /var/folders/8m/3ll2cn6d1hdcs6gjqxr2jx5d2hffc9/T/ipykernel_6259/4162273999.py:1: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   engine.table_names()
# ['ANALYSIS_METADATA',
#  'ATTRIBUTE_DESIGN',
#  'ATTRIBUTE_PRIMARY',
#  'ATTRIBUTE_STRATEGY',
#  'MODEL_BASE_INPUT_DATABASE',
#  'MODEL_OUTPUT']

# %%
df_all_out = squ.sql_table_to_df(
    engine,
    "MODEL_OUTPUT",
)

# %%
set(sa.model_attributes.all_variables_output) - set(df_all_out.columns)
# Out:
# {'net_imports_agrc_bevs_and_spices_tonne',
#  'net_imports_agrc_cereals_tonne',
#  'net_imports_agrc_fibers_tonne',
#  'net_imports_agrc_fruits_tonne',
#  'net_imports_agrc_herbs_and_other_perennial_crops_tonne',
#  'net_imports_agrc_nuts_tonne',
#  'net_imports_agrc_other_annual_tonne',
#  'net_imports_agrc_other_woody_perennial_tonne',
#  'net_imports_agrc_pulses_tonne',
#  'net_imports_agrc_rice_tonne',
#  'net_imports_agrc_sugar_cane_tonne',
#  'net_imports_agrc_tubers_tonne',
#  'net_imports_agrc_vegetables_and_vines_tonne',
#  'net_imports_change_lvst_buffalo',
#  'net_imports_change_lvst_cattle_dairy',
#  'net_imports_change_lvst_cattle_nondairy',
#  'net_imports_change_lvst_chickens',
#  'net_imports_change_lvst_goats',
#  'net_imports_change_lvst_horses',
#  'net_imports_change_lvst_mules',
#  'net_imports_change_lvst_pigs',
#  'net_imports_change_lvst_sheep',
#  'population_gnrl_total'}

# %%
set(sa.model_attributes.all_variables_output) - set(df_all_out.columns)

# %%
# EST

# 26 countries * 6 strategies * 1000 futures * 1/30 = 26*200

# %%
#5200 hrs
import argparse

parser = argparse.ArgumentParser(description = "test")

# %%
parser = argparse.ArgumentParser(
    description = "Run SISEPUEDE models from the command line."
)

##  REQUIRED ARGUMENTS

# regions to run
msg_hlp_regions = f"""
Comma-delimited list of regions or ISO codes to run. Required argument. To
    run all available regions, set to ALLREGIONS
"""
parser.add_argument(
    "--regions",
    help = msg_hlp_regions,
)


##  OPTIONAL ARGUMENTS/FLAGS

# optional flag to *exclude* electricity model 
msg_hlp_models = f"""
Exclude the fuel production (NemoMod) model from runs. 
"""
parser.add_argument(
    "--exclude-fuel-production",
    help = msg_hlp_models,
    action = "store_false",
    default = "All"
)
# Out:
# _StoreFalseAction(option_strings=['--exclude-fuel-production'], dest='exclude_fuel_production', nargs=0, const=False, default='All', type=None, choices=None, required=False, help='\nExclude the fuel production (NemoMod) model from runs. \n', metavar=None)

# %% [markdown]
# # AWS builds

# %%
import boto3

# %%
command = "ipykernel_launcher.py --regions"
parser.parse_args(command)
# Out:
# usage: ipykernel_launcher.py [-h] [--regions REGIONS]
#                              [--exclude-fuel-production]
# ipykernel_launcher.py: error: unrecognized arguments: i p y k e r n e l _ l a u n c h e r . p y   - - r e g i o n s
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2

# %% [markdown]
# # Build launch management script

# %%
def setup_logger(
    namespace: str, 
    fn_out: Union[str, None] = None,
    format_str: Union[str, None] = None,
) -> None:
    """
    Function Arguments
    ------------------
    
    Keyword Arguments
    -----------------
    - fn_out: file name for logger. If none, writes to current directory
    - format_str: optional logger format string to specify
    """
    
    # check formatting string and output filename
    format_str = (
        "%(asctime)s - %(levelname)s - %(message)s"
        if not isinstance(format_str, str)
        else format_str
    )
    
    fn_out = (
        os.path.join(os.getcwd(), "log.log")
        if not isinstance(fn_out, str)
        else fn_out
    )
    
    
    # configure
    if fn_out is not None:
        logging.basicConfig(
            filename = fn_out,
            filemode = "w",
            format = format_str,
            level = logging.DEBUG
        )
    else:
        logging.basicConfig(
            format = format_str,
            level = logging.DEBUG
        )
        
    logger = logging.getLogger(namespace)
    
    # create console handler and set level to debug
    ch = logging.StreamHandler()
    ch.setLevel(logging.DEBUG)
    # create formatter
    formatter = logging.Formatter(format_str)
    # add formatter to ch
    ch.setFormatter(formatter)
    # add ch to logger
    logger.addHandler(ch)

    return logger

logger_aws = setup_logger(__name__, os.path.join(os.getcwd(), "log_aws_launch.log"))

# %%
import sisepuede as ssp
importlib.reload(ssp)
sisepuede = ssp.SISEPUEDE(
    "demo",
    initialize_as_dummy = True,
    logger = logger_aws,
)
# Out:
# /Users/jsyme/Documents/Projects/git_jbus/lac_decarbonization/python/support_functions.py:1576: UserWarning: Warning passed from optional_log: Successfully initialized Analysis ID 'sisepuede_run_2023-07-09T22:20:19.022306'.
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/lac_decarbonization/python/support_functions.py:1576: UserWarning: Warning passed from optional_log: Verification of SISEPUEDE directory structure completed successfully with 0 errors..
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/lac_decarbonization/python/model_attributes.py:2550: UserWarning: Invalid subsector attribute 'key_varreqs_partial'. Valid return type values are:'pycategory_primary', 'abv_subsector', 'sector', 'abv_sector', 'key_varreqs_all'
#   warnings.warn(f"Invalid subsector attribute '{return_type}'. Valid return type values are:{valid_rts}")
# ...

# %%
import importlib
import aws_manager as am
importlib.reload(sc)
importlib.reload(am)
importlib.reload(sf)

fp_template_shell = "/Users/jsyme/Documents/Projects/git_jbus/sisepuede_launcher/sisepuede_exec.sh"
fp_template_ud = "/Users/jsyme/Documents/Projects/git_jbus/sisepuede_launcher/userdata_template.txt"
file_yaml = "/Users/jsyme/Documents/Projects/git_jbus/sisepuede_launcher/config.yaml"

fs = sisepuede.file_struct
analysis_id = sisepuede.id

aws_manager = am.AWSManager(
    fs,
    file_yaml,
    fp_template_shell,
    fp_template_ud,
)


"""
aws_manager.build_user_data_echo_from_keyvals(
    fs.model_attributes.dim_strategy_id,
    [0, 1014, 5001, 5004, 5006, 5008],
    "strategies",
    dir_instance = "/home/ec2-user"
)
""";

dict_scenario_combinations = {
    fs.model_attributes.dim_design_id: [0],#[0, 1014, 5001, 5004, 5006, 5008],
    fs.model_attributes.dim_strategy_id: [5008],#[0, 1014, 5001, 5004, 5006, 5008],
    fs.model_attributes.dim_region: ["brazil"],
    fs.model_attributes.dim_future_id: [0],#list(range(59, 65)),
    "random_seed": 67830,
    "id": f"\"{analysis_id}\"",
}

user_data = aws_manager.build_user_data(dict_scenario_combinations, instance_launch_index = 4)

with open("/Users/jsyme/Desktop/user_data.txt", "w+") as fl:
    fl.write(user_data)

# %%
#print(user_data)
sisepuede.database.db.dict_iterative_database_tables
# Out:
# {'ANALYSIS_METADATA': <iterative_database.IterativeDatabaseTable at 0x13347a790>,
#  'ATTRIBUTE_DESIGN': <iterative_database.IterativeDatabaseTable at 0x1333b7e10>,
#  'ATTRIBUTE_LHC_SAMPLES_EXOGENOUS_UNCERTAINTIES': <iterative_database.IterativeDatabaseTable at 0x125347190>,
#  'ATTRIBUTE_LHC_SAMPLES_LEVER_EFFECTS': <iterative_database.IterativeDatabaseTable at 0x133553010>,
#  'ATTRIBUTE_PRIMARY': <iterative_database.IterativeDatabaseTable at 0x1335d0210>,
#  'ATTRIBUTE_STRATEGY': <iterative_database.IterativeDatabaseTable at 0x13335db10>,
#  'MODEL_BASE_INPUT_DATABASE': <iterative_database.IterativeDatabaseTable at 0x13335ff50>,
#  'MODEL_INPUT': <iterative_database.IterativeDatabaseTable at 0x1333b1650>,
#  'MODEL_OUTPUT': <iterative_database.IterativeDatabaseTable at 0x1333b0350>}

# %%
importlib.reload(ma)
importlib.reload(sa)
sa.model_attributes.configuration.get("save_inputs")
# Out:
# /Users/jsyme/Documents/Projects/git_jbus/lac_decarbonization/python/model_attributes.py:2567: UserWarning: Invalid subsector attribute 'key_varreqs_partial'. Valid return type values are:'pycategory_primary', 'abv_subsector', 'sector', 'abv_sector', 'key_varreqs_all'
#
# /Users/jsyme/Documents/Projects/git_jbus/lac_decarbonization/python/model_attributes.py:2324: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   Get attribute column from an attribute table ordered the same as key
# False

# %%
importlib.reload(am)

aws_manager = am.AWSManager(
    fs,
    file_yaml,
    fp_template_shell,
    fp_template_ud,
)
# Out:
# TMP
# aws_access_key_id:	ASIA55V3I4L2DI6IVF6H
# TMP
# aws_secret_access_key:	OYEmi0EbVi6RKt8wsG7bh6/58J26d7YGTgyfXELR

# %%
buckets = aws_manager.client_s3.list_buckets()
buckets
# Out:
# {'ResponseMetadata': {'RequestId': '63C9EFFBA34T3EW5',
#   'HostId': 'sNrRXn4mgk2rEeBZl3VAzFRCrjDO9jIaaAWJiyL8Tw1/LEezJ6ebcXxZu+y7G3AlR+T6Txdvvs8=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'sNrRXn4mgk2rEeBZl3VAzFRCrjDO9jIaaAWJiyL8Tw1/LEezJ6ebcXxZu+y7G3AlR+T6Txdvvs8=',
#    'x-amz-request-id': '63C9EFFBA34T3EW5',
#    'date': 'Mon, 10 Jul 2023 17:02:46 GMT',
#    'content-type': 'application/xml',
#    'transfer-encoding': 'chunked',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'Buckets': [{'Name': 'cf-templates-vcnecy8xis7x-us-east-2',
#    'CreationDate': datetime.datetime(2021, 11, 8, 23, 12, 23, tzinfo=tzutc())},
#   {'Name': 'cf-templates-vcnecy8xis7x-us-west-2',
#    'CreationDate': datetime.datetime(2021, 11, 12, 17, 25, tzinfo=tzutc())},
#   {'Name': 'config-bucket-957096714996-us-west-2',
#    'CreationDate': datetime.datetime(2023, 3, 20, 20, 15, 32, tzinfo=tzutc())},
#   {'Name': 'databricks-workspace-stack-lambdazipsbucket-1m7k2rfka4mr',
# ...

# %%
def format_tags_for_ec2(#self,
    dict_tags: Dict[str, Any],
) -> Union[List[Dict[str, Any]], None]:
    """
    Transform configuration tags as a list of dictionaries for 
        upload with client_ec2.run_instances()
    """
    
    if not isinstance(dict_tags, dict):
        return None
    
    
    tags_out = []
    
    for k, v in dict_tags.items():
        tags_out.append(
            {
                "Key": k,
                "Value": v
            }
        )
        
    return tags_out
        



# EC2
ami = aws_manager.config.get("aws_ec2.image")
instance_type = aws_manager.config.get("aws_ec2.instance_type")

# general
security_group = aws_manager.config.get("aws_general.security_group")
subnet = aws_manager.config.get("aws_general.subnet")


list_tag_dicts = format_tags_for_ec2(aws_manager.config.get("aws_general.tag"))

# %%
instance_type = "t3.large"

# %%
aws_manager.client_ec2.run_instances(
    ImageId = ami,
    MinCount = 1,
    MaxCount = 1,
    SecurityGroupIds = [security_group],
    InstanceType = instance_type,
    SubnetId = subnet,
    TagSpecifications = [{
        "ResourceType": "instance",
        "Tags": list_tag_dicts
    }],
    #IamInstanceProfile = {"Name": iam_role},
    UserData = user_data.encode("ascii")
)
# Out:
# {'Groups': [],
#  'Instances': [{'AmiLaunchIndex': 0,
#    'ImageId': 'ami-0943f2aa08fb8cb17',
#    'InstanceId': 'i-08bef8d816fdc1560',
#    'InstanceType': 't3.large',
#    'LaunchTime': datetime.datetime(2023, 7, 10, 17, 28, 36, tzinfo=tzutc()),
#    'Monitoring': {'State': 'disabled'},
#    'Placement': {'AvailabilityZone': 'us-west-2c',
#     'GroupName': '',
#     'Tenancy': 'default'},
#    'PrivateDnsName': 'ip-10-28-132-227.us-west-2.compute.internal',
#    'PrivateIpAddress': '10.28.132.227',
#    'ProductCodes': [],
#    'PublicDnsName': '',
#    'State': {'Code': 0, 'Name': 'pending'},
#    'StateTransitionReason': '',
#    'SubnetId': 'subnet-03cb6d543a8c17c0c',
#    'VpcId': 'vpc-016d7bc9457b9eea8',
#    'Architecture': 'x86_64',
#    'BlockDeviceMappings': [],
#    'ClientToken': '7e47f9ad-01f0-43af-8ef1-12bab8d38431',
#    'EbsOptimized': False,
#    'EnaSupport': True,
#    'Hypervisor': 'xen',
# ...

# %%
#b3_session = boto3.Session(profile_name = "default")
sts = aws_manager.b3_session.client("sts")


#response = sts.assume_role(
#    RoleArn = "arn:aws:iam::957096714996:role/amazon-linux-jsyme",
#    RoleSessionName = "launch_sisepuede"
#)
#"arn:aws:iam::957096714996:role/amazon-linux-jsyme"

# %%
sts.get_caller_identity()
#aws_access_key_id = aws_manager.config.get("aws_config.aws_access_key_id"),
#aws_secret_access_key = aws_manager.config.get("aws_config.aws_secret_access_key"),
#aws_session_token = aws_manager.config.get("aws_config.aws_session_token"),
#aws_region = aws_manager.config.get("aws_config.region"),
#profile_name = aws_manager.config.get("aws_config.profile_name")
# Out:
# {'UserId': 'AROA55V3I4L2JNWNQSXQ3:jsyme@pardeerand.edu',
#  'Account': '957096714996',
#  'Arn': 'arn:aws:sts::957096714996:assumed-role/AWSReservedSSO_AWSPowerUserAccess-inn-devlab_96528f53dd75521b/jsyme@pardeerand.edu',
#  'ResponseMetadata': {'RequestId': '8b2b98ac-4d8b-4fc6-89f1-cdfca5c92cc0',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '8b2b98ac-4d8b-4fc6-89f1-cdfca5c92cc0',
#    'content-type': 'text/xml',
#    'content-length': '508',
#    'date': 'Mon, 10 Jul 2023 16:29:36 GMT'},
#   'RetryAttempts': 0}}

# %%
dir(sts)
# Out:
# ['_PY_TO_OP_NAME',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_cache',
#  '_client_config',
#  '_convert_to_request_dict',
#  '_emit_api_params',
#  '_endpoint',
#  '_exceptions',
#  '_exceptions_factory',
#  '_get_waiter_config',
#  '_load_exceptions',
#  '_loader',
#  '_make_api_call',
#  '_make_request',
#  '_register_handlers',
#  '_request_signer',
#  '_resolve_endpoint_ruleset',
#  '_response_parser',
#  '_ruleset_resolver',
#  '_serializer',
#  '_service_model',
#  '_user_agent_creator',
#  'assume_role',
#  'assume_role_with_saml',
# ...

# %%
import boto3
# ?boto3.Session
# Out:
# Init signature:
# boto3.Session(
#     aws_access_key_id=None,
#     aws_secret_access_key=None,
#     aws_session_token=None,
#     region_name=None,
#     botocore_session=None,
#     profile_name=None,
# )
# Docstring:
# A session stores configuration state and allows you to create service
# clients and resources.
#
# :type aws_access_key_id: string
# :param aws_access_key_id: AWS access key ID
# :type aws_secret_access_key: string
# :param aws_secret_access_key: AWS secret access key
# :type aws_session_token: string
# :param aws_session_token: AWS temporary session token
# :type region_name: string
# :param region_name: Default region when creating new connections
# :type botocore_session: botocore.session.Session
# :param botocore_session: Use this Botocore session instead of creating
#                          a new default one.
# :type profile_name: string
# :param profile_name: The name of a profile to use. If not given, then
# ...

# %%
#dir(sisepuede.experimental_manager.primary_key_database)
def _initialize_aws(#self,
    profile_name: str = "default",
) -> None:
    """
    Initialize AWS session components. Sets the following properties:
        
        * self.b3_session
        * self.client_athena
        * self.client_ec2
        * self.client_s3
        * self.resource_s3
    
    Function Arguments
    ------------------

    Keyword Arguments
    -----------------
    - profile_name: passed to boto3.Session as profile_name
    """
    
    ##  GET AWS KEYS
    
    aws_access_key_id = aws_manager.config.get("aws_config.aws_access_key_id")
    aws_secret_access_key = aws_manager.config.get("aws_config.aws_secret_access_key")
    aws_session_token = aws_manager.config.get("aws_config.aws_session_token")
    aws_region = aws_manager.config.get("aws_config.region")
    
    # set all to None to rely on config defaults
    any_none_imples_all_none = [aws_access_key_id, aws_secret_access_key, aws_session_token]
    if any([(x is None) for x in any_none_imples_all_none]):
        aws_access_key_id = None
        aws_secret_access_key = None
        aws_session_token = None
        
        
    ##  INITIALIZE boto3 SESSION
    
    b3_session = boto3.Session(
        aws_access_key_id = aws_access_key_id,
        aws_secret_access_key = aws_secret_access_key,
        aws_session_token = aws_session_token,
        aws_region = aws_region,
        profile_name = "default",
    )
    
    #get clients and resources
    client_athena = boto3.client("athena")
    client_ec2 = boto3.client("ec2")
    client_s3 = boto3.client("s3")
    resource_s3 = b3_session.resource("s3")
    
    
    ##  SET PROPERTIES
    """
    self.athena = athena
    self.b3_session = b3_session
    self.ec2 = ec2
    self.s3 = s3
    """;

# %%
# ?boto3.Session(
# Out:
# Init signature:
# boto3.Session(
#     aws_access_key_id=None,
#     aws_secret_access_key=None,
#     aws_session_token=None,
#     region_name=None,
#     botocore_session=None,
#     profile_name=None,
# )
# Docstring:
# A session stores configuration state and allows you to create service
# clients and resources.
#
# :type aws_access_key_id: string
# :param aws_access_key_id: AWS access key ID
# :type aws_secret_access_key: string
# :param aws_secret_access_key: AWS secret access key
# :type aws_session_token: string
# :param aws_session_token: AWS temporary session token
# :type region_name: string
# :param region_name: Default region when creating new connections
# :type botocore_session: botocore.session.Session
# :param botocore_session: Use this Botocore session instead of creating
#                          a new default one.
# :type profile_name: string
# :param profile_name: The name of a profile to use. If not given, then
# ...
