# %%
import define_transformations_afolu as dta
import define_transformations_circular_economy as dtc
import define_transformations_energy as dte
import define_transformations_ippu as dti
import define_transformations_integrated as dtr

import os, os.path
import numpy as np
import pandas as pd
#from model_attributes import *
import model_attributes as ma
import model_afolu as mafl
import model_ippu as mi
import model_circular_economy as mc
import model_electricity as ml
import model_energy as me
import model_socioeconomic as se
import setup_analysis as sa
import sisepuede_data_api as api
import sisepuede_models as sm
import support_classes as sc
import support_functions as sf
import importlib
import time
import warnings
import matplotlib.pyplot as plt
from typing import Union
import inspect
import ingestion as ing
import logging
from sisepuede_file_structure import *
import transformations_base_afolu as tba
import transformations_base_circular_economy as tbc
import transformations_base_energy as tbe
import transformations_base_general as tbg
import transformations_base_ippu as tbi


importlib.reload(ma)
importlib.reload(sa)
importlib.reload(sf)
importlib.reload(mafl)
importlib.reload(mc)
importlib.reload(mi)
importlib.reload(me)
importlib.reload(se)
importlib.reload(tbc)
importlib.reload(tbe)


import sisepuede as ssp


def _setup_logger(namespace: str, fn_out: Union[str, None] = None) -> None:
    global logger
    
    format_str = "%(asctime)s - %(levelname)s - %(message)s"
    # configure
    if fn_out is not None:
        logging.basicConfig(
            filename = fn_out,
            filemode = "w",
            format = format_str,
            level = logging.DEBUG
        )
    else:
        logging.basicConfig(
            format = format_str,
            level = logging.DEBUG
        )
        
    logger = logging.getLogger(namespace)
    # create console handler and set level to debug
    ch = logging.StreamHandler()
    ch.setLevel(logging.DEBUG)
    # create formatter
    formatter = logging.Formatter(format_str)
    # add formatter to ch
    ch.setFormatter(formatter)
    # add ch to logger
    logger.addHandler(ch)

    return logger

_setup_logger(__name__, os.path.join(os.getcwd(), "log_build_sisepuede_transformations.log"))
# Out:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:2635: UserWarning: Invalid subsector attribute 'key_varreqs_partial'. Valid return type values are:'pycategory_primary', 'abv_subsector', 'sector', 'abv_sector', 'key_varreqs_all'
#   warnings.warn(f"Invalid subsector attribute '{return_type}'. Valid return type values are:{valid_rts}")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:2392: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for desig, df in df_by_designation:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:2635: UserWarning: Invalid subsector attribute 'key_varreqs_partial'. Valid return type values are:'pycategory_primary', 'abv_subsector', 'sector', 'abv_sector', 'key_varreqs_all'
#   warnings.warn(f"Invalid subsector attribute '{return_type}'. Valid return type values are:{valid_rts}")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:2392: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for desig, df in df_by_designation:
# <Logger __main__ (DEBUG)>

# %% [markdown]
# # Use the TransformationsIntegrated class to build input templates
#
# - allows to specify any strategies/regions for which to build templates
#
# - writes in-line to Excel templates
#
# - for all strategies, about 5-min per (can and will improve this runtime)
#
# - use `transformations_integrated.build_strategies_to_templates()` to build (docstring included with `?`)
#
#
# **NOTE**: The `TransformationsIntegrated` class will instantiate a new SISEPUEDE AnalysisID, but the id does not correspond with a directory or any model runs. Ignore it

# %% [markdown]
# # NOTE TO JAMES:
# - FIX ERROR WHERE transformations_integrated CANNOT INSTANTIATE A TEMPLATE IF IT DOESN'T EXIST
# - Should be able to initialize a template with base_input_database_demo or input_template

# %%
importlib.reload(sf)
importlib.reload(tba)
importlib.reload(dta)
importlib.reload(dtr)

regions_lac = [
    "argentina",
    "bahamas",
    "barbados",
    "belize",
    "bolivia",
    "brazil",
    "chile",
    "colombia",
    "costa_rica",
    "dominican_republic",
    "ecuador",
    "el_salvador",
    "guatemala",
    "guyana",
    "haiti",
    "honduras",
    "jamaica",
    "mexico",
    "nicaragua",
    "panama",
    "paraguay",
    "peru",
    "suriname",
    "trinidad_and_tobago",
    "uruguay",
    "venezuela"
]



year_0_ramp = 2025
dir_calibs = "/Users/jsyme/Documents/Projects/FY21/SWCHE131_1000/Data/calibrated_input_files_from_edmundo"
fp_inputs = os.path.join(dir_calibs, "input_all_sectors.csv")
df_input = pd.read_csv(fp_inputs)
field_region = "nation"

regions_run = [
    x for x in sorted(regions_lac) if x in list(df_input[field_region].unique())
]
#regions_run = ["turkey", "india"]

# reduce inputs
df_input = df_input[
    df_input[field_region].isin(regions_run)
].reset_index(drop = True)

warnings.filterwarnings("ignore")

if True:
    # set some parameters (WILL SET TO READ FROM A CONFIG OR STRATEGY DEFINITION FILE)
    dict_config_te = {
        "categories_entc_max_investment_ramp": [
            "pp_hydropower",
            "pp_nuclear"
        ],
        "categories_entc_renewable": [
            "pp_geothermal",
            "pp_hydropower",
            "pp_ocean",
            "pp_solar",
            "pp_wind"
        ],
        "categories_inen_high_heat": [
            "cement", 
            "chemicals", 
            "glass", 
            "lime_and_carbonite", 
            "metals"
        ],
        "dict_entc_renewable_target_msp": {
            "pp_solar": 0.15,
            "pp_geothermal": 0.1,
            "pp_wind": 0.15
        },
        "frac_inen_high_temp_elec_hydg": 0.5*0.45,
        "frac_inen_low_temp_elec": 0.95*0.45,
        "n_tp_ramp": None,
        "vir_renewable_cap_delta_frac": 0.01,
        "vir_renewable_cap_max_frac": 0.05,
        "year_0_ramp": year_0_ramp
    }



    transformations_integrated = dtr.TransformationsIntegrated(
        dict_config_te,
        df_input = df_input,
        field_region = field_region,
        logger = logger,
        regions = regions_run,
    )
# Out:
# 2023-09-28 01:47:44,049 - INFO - Successfully initialized Analysis ID 'sisepuede_run_2023-09-28T01:47:44.049083'
# 2023-09-28 01:47:44,050 - INFO - Verification of SISEPUEDE directory structure completed successfully with 0 errors.
# 2023-09-28 01:47:45,379 - INFO - NemoMod reference file checks completed successfully.
# 2023-09-28 01:47:45,380 - INFO - Successfully initialized SISEPUEDEFileStructure.
# 2023-09-28 01:47:45,383 - INFO - Initializing BaseInputDatabase

# %%
reg = sc.Regions(sa.model_attributes)
",".join([reg.return_region_or_iso(x, return_type = "iso") for x in regions_run])
# Out:
# 'ARG,BOL,BRA,CHL,COL,CRI,DOM,ECU,SLV,GTM,HND,JAM,MEX,NIC,PAN,PRY,PER,URY'

# %%
df_regions_run = pd.DataFrame({regions.key: regions_run})
df_regions_run.to_csv(
    os.path.join(sa.dir_tmp, "regions_run.csv"),
    index = None,
    encoding = "UTF-8"
)

# %%
def get_strategies_from_codes(
    strategy_codes: Union[List[str], str],
) -> Union[List[int], None]:
    """
    Map codes to id as input
    """
    attr_strat = sa.model_attributes.dict_attributes.get("dim_strategy_id")
    dict_map = attr_strat.field_maps.get(f"strategy_code_to_{attr_strat.key}")
    
    # check specification of codes
    strategy_codes = (
        [strategy_codes] 
        if isinstance(strategy_codes, str)
        else (
            strategy_codes
            if sf.islistlike(strategy_codes)
            else None
        )
    )
    
    if strategy_codes is None:
        return None
    
    # get ids to build
    strategies_build = [dict_map.get(x) for x in strategy_codes]
    strategies_build = [x for x in strategies_build if x is not None]
    out = (
        None
        if len(strategies_build) == 0
        else strategies_build
    )
    
    return out



    
strategy_codes_keep = [
    "BASE",
    "LNDU:PLUR",
    "PFLO:BETTER_BASE",
    "PFLO:CHANGE_CONSUMPTION",
    "PFLO:SUPPLY_SIDE_TECH",
    "PFLO:ALL_NO_STOPPING_DEFORESTATION_PLUR",
    "PFLO:ALL_PLUR"
]
strategies_keep = get_strategies_from_codes(strategy_codes_keep)

if True:
    transformations_integrated.build_strategies_to_templates(
        strategies = strategies_keep
    )
# Out:
# 2023-09-28 01:48:56,389 - INFO - Starting build of 6 strategies in 18 regions...
# 2023-09-28 01:48:56,405 - INFO - Starting build for region argentina
# 2023-09-28 01:48:56,420 - INFO - 	Successfully built transformation strategy_id = 1014 ('LNDU: Partial land use reallocation') in 0.01 seconds.
# 2023-09-28 01:48:59,724 - INFO - 	Successfully built transformation strategy_id = 5001 ('PFLO: Better baseline') in 0.22 seconds.
# 2023-09-28 01:49:02,834 - INFO - 	Successfully built transformation strategy_id = 5004 ('PFLO: Change consumer behavior') in 0.14 seconds.
# 2023-09-28 01:49:06,587 - INFO - 	Successfully built transformation strategy_id = 5006 ('PFLO: Supply side technologies and transformations') in 0.76 seconds.
# 2023-09-28 01:49:10,893 - INFO - 	Successfully built transformation strategy_id = 5007 ('PFLO: All transformations without stopping deforestation and partial land use reallocation') in 1.14 seconds.
# 2023-09-28 01:49:14,817 - INFO - 	Successfully built transformation strategy_id = 5009 ('PFLO: All transformations with partial land use reallocation') in 1.02 seconds.
# 2023-09-28 01:49:17,864 - INFO - Exporting 'af' template in region argentina to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/argentina/model_input_variables_argentina_af_calibrated.xlsx
# 2023-09-28 01:49:18,585 - INFO - Exporting 'ce' template in region argentina to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/argentina/model_input_variables_argentina_ce_calibrated.xlsx
# 2023-09-28 01:49:18,797 - INFO - Exporting 'en' template in region argentina to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/argentina/model_input_variables_argentina_en_calibrated.xlsx
# 2023-09-28 01:49:19,855 - INFO - Exporting 'ip' template in region argentina to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/argentina/model_input_variables_argentina_ip_calibrated.xlsx
# 2023-09-28 01:49:20,076 - INFO - Exporting 'se' template in region argentina to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/argentina/model_input_variables_argentina_se_calibrated.xlsx
# 2023-09-28 01:49:20,133 - INFO - Templates build for region argentina complete.
#
#
# 2023-09-28 01:49:20,134 - INFO - Starting build for region bolivia
# 2023-09-28 01:49:20,146 - INFO - 	Successfully built transformation strategy_id = 1014 ('LNDU: Partial land use reallocation') in 0.01 seconds.
# 2023-09-28 01:49:23,514 - INFO - 	Successfully built transformation strategy_id = 5001 ('PFLO: Better baseline') in 0.22 seconds.
# 2023-09-28 01:49:27,201 - INFO - 	Successfully built transformation strategy_id = 5004 ('PFLO: Change consumer behavior') in 0.21 seconds.
# 2023-09-28 01:49:31,303 - INFO - 	Successfully built transformation strategy_id = 5006 ('PFLO: Supply side technologies and transformations') in 0.73 seconds.
# 2023-09-28 01:49:35,883 - INFO - 	Successfully built transformation strategy_id = 5007 ('PFLO: All transformations without stopping deforestation and partial land use reallocation') in 1.25 seconds.
# 2023-09-28 01:49:41,440 - INFO - 	Successfully built transformation strategy_id = 5009 ('PFLO: All transformations with partial land use reallocation') in 1.39 seconds.
# 2023-09-28 01:49:45,009 - INFO - Exporting 'af' template in region bolivia to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/bolivia/model_input_variables_bolivia_af_calibrated.xlsx
# 2023-09-28 01:49:45,785 - INFO - Exporting 'ce' template in region bolivia to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/bolivia/model_input_variables_bolivia_ce_calibrated.xlsx
# 2023-09-28 01:49:46,023 - INFO - Exporting 'en' template in region bolivia to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/bolivia/model_input_variables_bolivia_en_calibrated.xlsx
# 2023-09-28 01:49:47,395 - INFO - Exporting 'ip' template in region bolivia to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/bolivia/model_input_variables_bolivia_ip_calibrated.xlsx
# 2023-09-28 01:49:47,628 - INFO - Exporting 'se' template in region bolivia to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/bolivia/model_input_variables_bolivia_se_calibrated.xlsx
# 2023-09-28 01:49:47,688 - INFO - Templates build for region bolivia complete.
#
#
# 2023-09-28 01:49:47,689 - INFO - Starting build for region brazil
# 2023-09-28 01:49:47,702 - INFO - 	Successfully built transformation strategy_id = 1014 ('LNDU: Partial land use reallocation') in 0.01 seconds.
# 2023-09-28 01:49:51,559 - INFO - 	Successfully built transformation strategy_id = 5001 ('PFLO: Better baseline') in 0.19 seconds.
# 2023-09-28 01:49:55,254 - INFO - 	Successfully built transformation strategy_id = 5004 ('PFLO: Change consumer behavior') in 0.23 seconds.
# 2023-09-28 01:50:00,095 - INFO - 	Successfully built transformation strategy_id = 5006 ('PFLO: Supply side technologies and transformations') in 0.9 seconds.
# 2023-09-28 01:50:05,748 - INFO - 	Successfully built transformation strategy_id = 5007 ('PFLO: All transformations without stopping deforestation and partial land use reallocation') in 1.95 seconds.
# 2023-09-28 01:50:10,485 - INFO - 	Successfully built transformation strategy_id = 5009 ('PFLO: All transformations with partial land use reallocation') in 1.28 seconds.
# 2023-09-28 01:50:14,568 - INFO - Exporting 'af' template in region brazil to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/brazil/model_input_variables_brazil_af_calibrated.xlsx
# 2023-09-28 01:50:15,480 - INFO - Exporting 'ce' template in region brazil to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/brazil/model_input_variables_brazil_ce_calibrated.xlsx
# 2023-09-28 01:50:15,784 - INFO - Exporting 'en' template in region brazil to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/brazil/model_input_variables_brazil_en_calibrated.xlsx
# 2023-09-28 01:50:17,238 - INFO - Exporting 'ip' template in region brazil to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/brazil/model_input_variables_brazil_ip_calibrated.xlsx
# 2023-09-28 01:50:17,495 - INFO - Exporting 'se' template in region brazil to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/brazil/model_input_variables_brazil_se_calibrated.xlsx
# 2023-09-28 01:50:17,557 - INFO - Templates build for region brazil complete.
#
#
# 2023-09-28 01:50:17,558 - INFO - Starting build for region chile
# 2023-09-28 01:50:17,571 - INFO - 	Successfully built transformation strategy_id = 1014 ('LNDU: Partial land use reallocation') in 0.01 seconds.
# 2023-09-28 01:50:21,115 - INFO - 	Successfully built transformation strategy_id = 5001 ('PFLO: Better baseline') in 0.2 seconds.
# 2023-09-28 01:50:24,910 - INFO - 	Successfully built transformation strategy_id = 5004 ('PFLO: Change consumer behavior') in 0.18 seconds.
# 2023-09-28 01:50:29,198 - INFO - 	Successfully built transformation strategy_id = 5006 ('PFLO: Supply side technologies and transformations') in 0.83 seconds.
# 2023-09-28 01:50:33,982 - INFO - 	Successfully built transformation strategy_id = 5007 ('PFLO: All transformations without stopping deforestation and partial land use reallocation') in 1.27 seconds.
# 2023-09-28 01:50:38,947 - INFO - 	Successfully built transformation strategy_id = 5009 ('PFLO: All transformations with partial land use reallocation') in 1.54 seconds.
# 2023-09-28 01:50:42,674 - INFO - Exporting 'af' template in region chile to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/chile/model_input_variables_chile_af_calibrated.xlsx
# 2023-09-28 01:50:43,447 - INFO - Exporting 'ce' template in region chile to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/chile/model_input_variables_chile_ce_calibrated.xlsx
# 2023-09-28 01:50:43,818 - INFO - Exporting 'en' template in region chile to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/chile/model_input_variables_chile_en_calibrated.xlsx
# 2023-09-28 01:50:44,988 - INFO - Exporting 'ip' template in region chile to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/chile/model_input_variables_chile_ip_calibrated.xlsx
# 2023-09-28 01:50:45,221 - INFO - Exporting 'se' template in region chile to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/chile/model_input_variables_chile_se_calibrated.xlsx
# 2023-09-28 01:50:45,275 - INFO - Templates build for region chile complete.
#
#
# 2023-09-28 01:50:45,276 - INFO - Starting build for region colombia
# 2023-09-28 01:50:45,286 - INFO - 	Successfully built transformation strategy_id = 1014 ('LNDU: Partial land use reallocation') in 0.01 seconds.
# 2023-09-28 01:50:48,889 - INFO - 	Successfully built transformation strategy_id = 5001 ('PFLO: Better baseline') in 0.2 seconds.
# 2023-09-28 01:50:52,215 - INFO - 	Successfully built transformation strategy_id = 5004 ('PFLO: Change consumer behavior') in 0.2 seconds.
# 2023-09-28 01:50:56,467 - INFO - 	Successfully built transformation strategy_id = 5006 ('PFLO: Supply side technologies and transformations') in 0.75 seconds.
# 2023-09-28 01:51:00,933 - INFO - 	Successfully built transformation strategy_id = 5007 ('PFLO: All transformations without stopping deforestation and partial land use reallocation') in 1.14 seconds.
# 2023-09-28 01:51:05,227 - INFO - 	Successfully built transformation strategy_id = 5009 ('PFLO: All transformations with partial land use reallocation') in 1.25 seconds.
# 2023-09-28 01:51:08,504 - INFO - Exporting 'af' template in region colombia to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/colombia/model_input_variables_colombia_af_calibrated.xlsx
# 2023-09-28 01:51:09,246 - INFO - Exporting 'ce' template in region colombia to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/colombia/model_input_variables_colombia_ce_calibrated.xlsx
# 2023-09-28 01:51:09,628 - INFO - Exporting 'en' template in region colombia to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/colombia/model_input_variables_colombia_en_calibrated.xlsx
# 2023-09-28 01:51:10,554 - INFO - Exporting 'ip' template in region colombia to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/colombia/model_input_variables_colombia_ip_calibrated.xlsx
# 2023-09-28 01:51:10,751 - INFO - Exporting 'se' template in region colombia to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/colombia/model_input_variables_colombia_se_calibrated.xlsx
# 2023-09-28 01:51:10,797 - INFO - Templates build for region colombia complete.
#
#
# 2023-09-28 01:51:10,798 - INFO - Starting build for region costa_rica
# 2023-09-28 01:51:10,808 - INFO - 	Successfully built transformation strategy_id = 1014 ('LNDU: Partial land use reallocation') in 0.01 seconds.
# 2023-09-28 01:51:14,174 - INFO - 	Successfully built transformation strategy_id = 5001 ('PFLO: Better baseline') in 0.21 seconds.
# 2023-09-28 01:51:17,772 - INFO - 	Successfully built transformation strategy_id = 5004 ('PFLO: Change consumer behavior') in 0.17 seconds.
# 2023-09-28 01:51:22,146 - INFO - 	Successfully built transformation strategy_id = 5006 ('PFLO: Supply side technologies and transformations') in 0.88 seconds.
# 2023-09-28 01:51:26,507 - INFO - 	Successfully built transformation strategy_id = 5007 ('PFLO: All transformations without stopping deforestation and partial land use reallocation') in 0.98 seconds.
# 2023-09-28 01:51:30,782 - INFO - 	Successfully built transformation strategy_id = 5009 ('PFLO: All transformations with partial land use reallocation') in 1.17 seconds.
# 2023-09-28 01:51:34,172 - INFO - Exporting 'af' template in region costa_rica to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/costa_rica/model_input_variables_costa_rica_af_calibrated.xlsx
# 2023-09-28 01:51:34,912 - INFO - Exporting 'ce' template in region costa_rica to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/costa_rica/model_input_variables_costa_rica_ce_calibrated.xlsx
# 2023-09-28 01:51:35,149 - INFO - Exporting 'en' template in region costa_rica to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/costa_rica/model_input_variables_costa_rica_en_calibrated.xlsx
# 2023-09-28 01:51:36,684 - INFO - Exporting 'ip' template in region costa_rica to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/costa_rica/model_input_variables_costa_rica_ip_calibrated.xlsx
# 2023-09-28 01:51:36,898 - INFO - Exporting 'se' template in region costa_rica to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/costa_rica/model_input_variables_costa_rica_se_calibrated.xlsx
# 2023-09-28 01:51:36,950 - INFO - Templates build for region costa_rica complete.
#
#
# 2023-09-28 01:51:36,951 - INFO - Starting build for region dominican_republic
# 2023-09-28 01:51:36,963 - INFO - 	Successfully built transformation strategy_id = 1014 ('LNDU: Partial land use reallocation') in 0.01 seconds.
# 2023-09-28 01:51:40,472 - INFO - 	Successfully built transformation strategy_id = 5001 ('PFLO: Better baseline') in 0.18 seconds.
# 2023-09-28 01:51:43,750 - INFO - 	Successfully built transformation strategy_id = 5004 ('PFLO: Change consumer behavior') in 0.18 seconds.
# 2023-09-28 01:51:47,521 - INFO - 	Successfully built transformation strategy_id = 5006 ('PFLO: Supply side technologies and transformations') in 0.73 seconds.
# 2023-09-28 01:51:52,061 - INFO - 	Successfully built transformation strategy_id = 5007 ('PFLO: All transformations without stopping deforestation and partial land use reallocation') in 1.15 seconds.
# 2023-09-28 01:51:56,551 - INFO - 	Successfully built transformation strategy_id = 5009 ('PFLO: All transformations with partial land use reallocation') in 1.2 seconds.
# 2023-09-28 01:52:00,139 - INFO - Exporting 'af' template in region dominican_republic to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/dominican_republic/model_input_variables_dominican_republic_af_calibrated.xlsx
# 2023-09-28 01:52:00,862 - INFO - Exporting 'ce' template in region dominican_republic to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/dominican_republic/model_input_variables_dominican_republic_ce_calibrated.xlsx
# 2023-09-28 01:52:01,219 - INFO - Exporting 'en' template in region dominican_republic to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/dominican_republic/model_input_variables_dominican_republic_en_calibrated.xlsx
# 2023-09-28 01:52:02,656 - INFO - Exporting 'ip' template in region dominican_republic to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/dominican_republic/model_input_variables_dominican_republic_ip_calibrated.xlsx
# 2023-09-28 01:52:02,874 - INFO - Exporting 'se' template in region dominican_republic to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/dominican_republic/model_input_variables_dominican_republic_se_calibrated.xlsx
# 2023-09-28 01:52:02,925 - INFO - Templates build for region dominican_republic complete.
#
#
# 2023-09-28 01:52:02,926 - INFO - Starting build for region ecuador
# 2023-09-28 01:52:02,937 - INFO - 	Successfully built transformation strategy_id = 1014 ('LNDU: Partial land use reallocation') in 0.01 seconds.
# 2023-09-28 01:52:06,131 - INFO - 	Successfully built transformation strategy_id = 5001 ('PFLO: Better baseline') in 0.16 seconds.
# 2023-09-28 01:52:10,016 - INFO - 	Successfully built transformation strategy_id = 5004 ('PFLO: Change consumer behavior') in 0.17 seconds.
# 2023-09-28 01:52:14,068 - INFO - 	Successfully built transformation strategy_id = 5006 ('PFLO: Supply side technologies and transformations') in 0.95 seconds.
# 2023-09-28 01:52:19,092 - INFO - 	Successfully built transformation strategy_id = 5007 ('PFLO: All transformations without stopping deforestation and partial land use reallocation') in 1.31 seconds.
# 2023-09-28 01:52:23,511 - INFO - 	Successfully built transformation strategy_id = 5009 ('PFLO: All transformations with partial land use reallocation') in 1.1 seconds.
# 2023-09-28 01:52:26,594 - INFO - Exporting 'af' template in region ecuador to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/ecuador/model_input_variables_ecuador_af_calibrated.xlsx
# 2023-09-28 01:52:27,405 - INFO - Exporting 'ce' template in region ecuador to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/ecuador/model_input_variables_ecuador_ce_calibrated.xlsx
# 2023-09-28 01:52:27,727 - INFO - Exporting 'en' template in region ecuador to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/ecuador/model_input_variables_ecuador_en_calibrated.xlsx
# 2023-09-28 01:52:29,000 - INFO - Exporting 'ip' template in region ecuador to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/ecuador/model_input_variables_ecuador_ip_calibrated.xlsx
# 2023-09-28 01:52:29,184 - INFO - Exporting 'se' template in region ecuador to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/ecuador/model_input_variables_ecuador_se_calibrated.xlsx
# 2023-09-28 01:52:29,233 - INFO - Templates build for region ecuador complete.
#
#
# 2023-09-28 01:52:29,234 - INFO - Starting build for region el_salvador
# 2023-09-28 01:52:29,244 - INFO - 	Successfully built transformation strategy_id = 1014 ('LNDU: Partial land use reallocation') in 0.01 seconds.
# 2023-09-28 01:52:32,292 - INFO - 	Successfully built transformation strategy_id = 5001 ('PFLO: Better baseline') in 0.16 seconds.
# 2023-09-28 01:52:35,364 - INFO - 	Successfully built transformation strategy_id = 5004 ('PFLO: Change consumer behavior') in 0.14 seconds.
# 2023-09-28 01:52:39,010 - INFO - 	Successfully built transformation strategy_id = 5006 ('PFLO: Supply side technologies and transformations') in 0.73 seconds.
# 2023-09-28 01:52:42,923 - INFO - 	Successfully built transformation strategy_id = 5007 ('PFLO: All transformations without stopping deforestation and partial land use reallocation') in 0.96 seconds.
# 2023-09-28 01:52:47,032 - INFO - 	Successfully built transformation strategy_id = 5009 ('PFLO: All transformations with partial land use reallocation') in 1.1 seconds.
# 2023-09-28 01:52:50,000 - INFO - Exporting 'af' template in region el_salvador to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/el_salvador/model_input_variables_el_salvador_af_calibrated.xlsx
# 2023-09-28 01:52:50,831 - INFO - Exporting 'ce' template in region el_salvador to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/el_salvador/model_input_variables_el_salvador_ce_calibrated.xlsx
# 2023-09-28 01:52:51,032 - INFO - Exporting 'en' template in region el_salvador to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/el_salvador/model_input_variables_el_salvador_en_calibrated.xlsx
# 2023-09-28 01:52:52,281 - INFO - Exporting 'ip' template in region el_salvador to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/el_salvador/model_input_variables_el_salvador_ip_calibrated.xlsx
# 2023-09-28 01:52:52,468 - INFO - Exporting 'se' template in region el_salvador to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/el_salvador/model_input_variables_el_salvador_se_calibrated.xlsx
# 2023-09-28 01:52:52,521 - INFO - Templates build for region el_salvador complete.
#
#
# 2023-09-28 01:52:52,522 - INFO - Starting build for region guatemala
# 2023-09-28 01:52:52,533 - INFO - 	Successfully built transformation strategy_id = 1014 ('LNDU: Partial land use reallocation') in 0.01 seconds.
# 2023-09-28 01:52:55,571 - INFO - 	Successfully built transformation strategy_id = 5001 ('PFLO: Better baseline') in 0.17 seconds.
# 2023-09-28 01:52:58,658 - INFO - 	Successfully built transformation strategy_id = 5004 ('PFLO: Change consumer behavior') in 0.15 seconds.
# 2023-09-28 01:53:02,618 - INFO - 	Successfully built transformation strategy_id = 5006 ('PFLO: Supply side technologies and transformations') in 0.78 seconds.
# 2023-09-28 01:53:06,526 - INFO - 	Successfully built transformation strategy_id = 5007 ('PFLO: All transformations without stopping deforestation and partial land use reallocation') in 0.97 seconds.
# 2023-09-28 01:53:10,492 - INFO - 	Successfully built transformation strategy_id = 5009 ('PFLO: All transformations with partial land use reallocation') in 1.0 seconds.
# 2023-09-28 01:53:13,397 - INFO - Exporting 'af' template in region guatemala to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/guatemala/model_input_variables_guatemala_af_calibrated.xlsx
# 2023-09-28 01:53:14,103 - INFO - Exporting 'ce' template in region guatemala to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/guatemala/model_input_variables_guatemala_ce_calibrated.xlsx
# 2023-09-28 01:53:14,433 - INFO - Exporting 'en' template in region guatemala to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/guatemala/model_input_variables_guatemala_en_calibrated.xlsx
# 2023-09-28 01:53:15,680 - INFO - Exporting 'ip' template in region guatemala to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/guatemala/model_input_variables_guatemala_ip_calibrated.xlsx
# 2023-09-28 01:53:15,873 - INFO - Exporting 'se' template in region guatemala to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/guatemala/model_input_variables_guatemala_se_calibrated.xlsx
# 2023-09-28 01:53:15,925 - INFO - Templates build for region guatemala complete.
#
#
# 2023-09-28 01:53:15,926 - INFO - Starting build for region honduras
# 2023-09-28 01:53:15,936 - INFO - 	Successfully built transformation strategy_id = 1014 ('LNDU: Partial land use reallocation') in 0.01 seconds.
# 2023-09-28 01:53:19,003 - INFO - 	Successfully built transformation strategy_id = 5001 ('PFLO: Better baseline') in 0.19 seconds.
# 2023-09-28 01:53:22,075 - INFO - 	Successfully built transformation strategy_id = 5004 ('PFLO: Change consumer behavior') in 0.15 seconds.
# 2023-09-28 01:53:25,681 - INFO - 	Successfully built transformation strategy_id = 5006 ('PFLO: Supply side technologies and transformations') in 0.71 seconds.
# 2023-09-28 01:53:29,560 - INFO - 	Successfully built transformation strategy_id = 5007 ('PFLO: All transformations without stopping deforestation and partial land use reallocation') in 0.95 seconds.
# 2023-09-28 01:53:33,499 - INFO - 	Successfully built transformation strategy_id = 5009 ('PFLO: All transformations with partial land use reallocation') in 0.99 seconds.
# 2023-09-28 01:53:36,404 - INFO - Exporting 'af' template in region honduras to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/honduras/model_input_variables_honduras_af_calibrated.xlsx
# 2023-09-28 01:53:37,251 - INFO - Exporting 'ce' template in region honduras to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/honduras/model_input_variables_honduras_ce_calibrated.xlsx
# 2023-09-28 01:53:37,540 - INFO - Exporting 'en' template in region honduras to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/honduras/model_input_variables_honduras_en_calibrated.xlsx
# 2023-09-28 01:53:38,800 - INFO - Exporting 'ip' template in region honduras to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/honduras/model_input_variables_honduras_ip_calibrated.xlsx
# 2023-09-28 01:53:39,035 - INFO - Exporting 'se' template in region honduras to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/honduras/model_input_variables_honduras_se_calibrated.xlsx
# 2023-09-28 01:53:39,087 - INFO - Templates build for region honduras complete.
#
#
# 2023-09-28 01:53:39,088 - INFO - Starting build for region jamaica
# 2023-09-28 01:53:39,102 - INFO - 	Successfully built transformation strategy_id = 1014 ('LNDU: Partial land use reallocation') in 0.01 seconds.
# 2023-09-28 01:53:42,257 - INFO - 	Successfully built transformation strategy_id = 5001 ('PFLO: Better baseline') in 0.19 seconds.
# 2023-09-28 01:53:45,404 - INFO - 	Successfully built transformation strategy_id = 5004 ('PFLO: Change consumer behavior') in 0.14 seconds.
# 2023-09-28 01:53:49,010 - INFO - 	Successfully built transformation strategy_id = 5006 ('PFLO: Supply side technologies and transformations') in 0.72 seconds.
# 2023-09-28 01:53:52,899 - INFO - 	Successfully built transformation strategy_id = 5007 ('PFLO: All transformations without stopping deforestation and partial land use reallocation') in 0.93 seconds.
# 2023-09-28 01:53:56,820 - INFO - 	Successfully built transformation strategy_id = 5009 ('PFLO: All transformations with partial land use reallocation') in 0.99 seconds.
# 2023-09-28 01:53:59,726 - INFO - Exporting 'af' template in region jamaica to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/jamaica/model_input_variables_jamaica_af_calibrated.xlsx
# 2023-09-28 01:54:00,582 - INFO - Exporting 'ce' template in region jamaica to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/jamaica/model_input_variables_jamaica_ce_calibrated.xlsx
# 2023-09-28 01:54:00,781 - INFO - Exporting 'en' template in region jamaica to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/jamaica/model_input_variables_jamaica_en_calibrated.xlsx
# 2023-09-28 01:54:02,054 - INFO - Exporting 'ip' template in region jamaica to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/jamaica/model_input_variables_jamaica_ip_calibrated.xlsx
# 2023-09-28 01:54:02,233 - INFO - Exporting 'se' template in region jamaica to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/jamaica/model_input_variables_jamaica_se_calibrated.xlsx
# 2023-09-28 01:54:02,278 - INFO - Templates build for region jamaica complete.
#
#
# 2023-09-28 01:54:02,279 - INFO - Starting build for region mexico
# 2023-09-28 01:54:02,289 - INFO - 	Successfully built transformation strategy_id = 1014 ('LNDU: Partial land use reallocation') in 0.01 seconds.
# 2023-09-28 01:54:05,277 - INFO - 	Successfully built transformation strategy_id = 5001 ('PFLO: Better baseline') in 0.15 seconds.
# 2023-09-28 01:54:08,342 - INFO - 	Successfully built transformation strategy_id = 5004 ('PFLO: Change consumer behavior') in 0.15 seconds.
# 2023-09-28 01:54:11,904 - INFO - 	Successfully built transformation strategy_id = 5006 ('PFLO: Supply side technologies and transformations') in 0.69 seconds.
# 2023-09-28 01:54:15,914 - INFO - 	Successfully built transformation strategy_id = 5007 ('PFLO: All transformations without stopping deforestation and partial land use reallocation') in 1.08 seconds.
# 2023-09-28 01:54:19,883 - INFO - 	Successfully built transformation strategy_id = 5009 ('PFLO: All transformations with partial land use reallocation') in 0.98 seconds.
# 2023-09-28 01:54:22,906 - INFO - Exporting 'af' template in region mexico to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/mexico/model_input_variables_mexico_af_calibrated.xlsx
# 2023-09-28 01:54:23,556 - INFO - Exporting 'ce' template in region mexico to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/mexico/model_input_variables_mexico_ce_calibrated.xlsx
# 2023-09-28 01:54:23,826 - INFO - Exporting 'en' template in region mexico to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/mexico/model_input_variables_mexico_en_calibrated.xlsx
# 2023-09-28 01:54:24,916 - INFO - Exporting 'ip' template in region mexico to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/mexico/model_input_variables_mexico_ip_calibrated.xlsx
# 2023-09-28 01:54:25,120 - INFO - Exporting 'se' template in region mexico to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/mexico/model_input_variables_mexico_se_calibrated.xlsx
# 2023-09-28 01:54:25,170 - INFO - Templates build for region mexico complete.
#
#
# 2023-09-28 01:54:25,171 - INFO - Starting build for region nicaragua
# 2023-09-28 01:54:25,183 - INFO - 	Successfully built transformation strategy_id = 1014 ('LNDU: Partial land use reallocation') in 0.01 seconds.
# 2023-09-28 01:54:28,144 - INFO - 	Successfully built transformation strategy_id = 5001 ('PFLO: Better baseline') in 0.17 seconds.
# 2023-09-28 01:54:31,138 - INFO - 	Successfully built transformation strategy_id = 5004 ('PFLO: Change consumer behavior') in 0.15 seconds.
# 2023-09-28 01:54:34,805 - INFO - 	Successfully built transformation strategy_id = 5006 ('PFLO: Supply side technologies and transformations') in 0.79 seconds.
# 2023-09-28 01:54:38,862 - INFO - 	Successfully built transformation strategy_id = 5007 ('PFLO: All transformations without stopping deforestation and partial land use reallocation') in 0.96 seconds.
# 2023-09-28 01:54:42,711 - INFO - 	Successfully built transformation strategy_id = 5009 ('PFLO: All transformations with partial land use reallocation') in 0.99 seconds.
# 2023-09-28 01:54:45,775 - INFO - Exporting 'af' template in region nicaragua to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/nicaragua/model_input_variables_nicaragua_af_calibrated.xlsx
# 2023-09-28 01:54:46,521 - INFO - Exporting 'ce' template in region nicaragua to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/nicaragua/model_input_variables_nicaragua_ce_calibrated.xlsx
# 2023-09-28 01:54:46,855 - INFO - Exporting 'en' template in region nicaragua to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/nicaragua/model_input_variables_nicaragua_en_calibrated.xlsx
# 2023-09-28 01:54:48,145 - INFO - Exporting 'ip' template in region nicaragua to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/nicaragua/model_input_variables_nicaragua_ip_calibrated.xlsx
# 2023-09-28 01:54:48,337 - INFO - Exporting 'se' template in region nicaragua to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/nicaragua/model_input_variables_nicaragua_se_calibrated.xlsx
# 2023-09-28 01:54:48,381 - INFO - Templates build for region nicaragua complete.
#
#
# 2023-09-28 01:54:48,382 - INFO - Starting build for region panama
# 2023-09-28 01:54:48,393 - INFO - 	Successfully built transformation strategy_id = 1014 ('LNDU: Partial land use reallocation') in 0.01 seconds.
# 2023-09-28 01:54:51,460 - INFO - 	Successfully built transformation strategy_id = 5001 ('PFLO: Better baseline') in 0.16 seconds.
# 2023-09-28 01:54:54,517 - INFO - 	Successfully built transformation strategy_id = 5004 ('PFLO: Change consumer behavior') in 0.15 seconds.
# 2023-09-28 01:54:58,090 - INFO - 	Successfully built transformation strategy_id = 5006 ('PFLO: Supply side technologies and transformations') in 0.7 seconds.
# 2023-09-28 01:55:02,216 - INFO - 	Successfully built transformation strategy_id = 5007 ('PFLO: All transformations without stopping deforestation and partial land use reallocation') in 1.0 seconds.
# 2023-09-28 01:55:06,078 - INFO - 	Successfully built transformation strategy_id = 5009 ('PFLO: All transformations with partial land use reallocation') in 0.98 seconds.
# 2023-09-28 01:55:09,325 - INFO - Exporting 'af' template in region panama to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/panama/model_input_variables_panama_af_calibrated.xlsx
# 2023-09-28 01:55:10,087 - INFO - Exporting 'ce' template in region panama to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/panama/model_input_variables_panama_ce_calibrated.xlsx
# 2023-09-28 01:55:10,401 - INFO - Exporting 'en' template in region panama to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/panama/model_input_variables_panama_en_calibrated.xlsx
# 2023-09-28 01:55:11,654 - INFO - Exporting 'ip' template in region panama to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/panama/model_input_variables_panama_ip_calibrated.xlsx
# 2023-09-28 01:55:11,831 - INFO - Exporting 'se' template in region panama to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/panama/model_input_variables_panama_se_calibrated.xlsx
# 2023-09-28 01:55:11,876 - INFO - Templates build for region panama complete.
#
#
# 2023-09-28 01:55:11,877 - INFO - Starting build for region paraguay
# 2023-09-28 01:55:11,888 - INFO - 	Successfully built transformation strategy_id = 1014 ('LNDU: Partial land use reallocation') in 0.01 seconds.
# 2023-09-28 01:55:14,899 - INFO - 	Successfully built transformation strategy_id = 5001 ('PFLO: Better baseline') in 0.15 seconds.
# 2023-09-28 01:55:18,092 - INFO - 	Successfully built transformation strategy_id = 5004 ('PFLO: Change consumer behavior') in 0.15 seconds.
# 2023-09-28 01:55:21,707 - INFO - 	Successfully built transformation strategy_id = 5006 ('PFLO: Supply side technologies and transformations') in 0.7 seconds.
# 2023-09-28 01:55:25,499 - INFO - 	Successfully built transformation strategy_id = 5007 ('PFLO: All transformations without stopping deforestation and partial land use reallocation') in 0.92 seconds.
# 2023-09-28 01:55:29,340 - INFO - 	Successfully built transformation strategy_id = 5009 ('PFLO: All transformations with partial land use reallocation') in 0.96 seconds.
# 2023-09-28 01:55:32,214 - INFO - Exporting 'af' template in region paraguay to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/paraguay/model_input_variables_paraguay_af_calibrated.xlsx
# 2023-09-28 01:55:33,076 - INFO - Exporting 'ce' template in region paraguay to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/paraguay/model_input_variables_paraguay_ce_calibrated.xlsx
# 2023-09-28 01:55:33,282 - INFO - Exporting 'en' template in region paraguay to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/paraguay/model_input_variables_paraguay_en_calibrated.xlsx
# 2023-09-28 01:55:34,545 - INFO - Exporting 'ip' template in region paraguay to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/paraguay/model_input_variables_paraguay_ip_calibrated.xlsx
# 2023-09-28 01:55:34,729 - INFO - Exporting 'se' template in region paraguay to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/paraguay/model_input_variables_paraguay_se_calibrated.xlsx
# 2023-09-28 01:55:34,773 - INFO - Templates build for region paraguay complete.
#
#
# 2023-09-28 01:55:34,773 - INFO - Starting build for region peru
# 2023-09-28 01:55:34,783 - INFO - 	Successfully built transformation strategy_id = 1014 ('LNDU: Partial land use reallocation') in 0.01 seconds.
# 2023-09-28 01:55:37,810 - INFO - 	Successfully built transformation strategy_id = 5001 ('PFLO: Better baseline') in 0.19 seconds.
# 2023-09-28 01:55:40,826 - INFO - 	Successfully built transformation strategy_id = 5004 ('PFLO: Change consumer behavior') in 0.14 seconds.
# 2023-09-28 01:55:44,387 - INFO - 	Successfully built transformation strategy_id = 5006 ('PFLO: Supply side technologies and transformations') in 0.69 seconds.
# 2023-09-28 01:55:48,203 - INFO - 	Successfully built transformation strategy_id = 5007 ('PFLO: All transformations without stopping deforestation and partial land use reallocation') in 0.93 seconds.
# 2023-09-28 01:55:52,086 - INFO - 	Successfully built transformation strategy_id = 5009 ('PFLO: All transformations with partial land use reallocation') in 0.97 seconds.
# 2023-09-28 01:55:54,935 - INFO - Exporting 'af' template in region peru to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/peru/model_input_variables_peru_af_calibrated.xlsx
# 2023-09-28 01:55:55,757 - INFO - Exporting 'ce' template in region peru to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/peru/model_input_variables_peru_ce_calibrated.xlsx
# 2023-09-28 01:55:55,952 - INFO - Exporting 'en' template in region peru to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/peru/model_input_variables_peru_en_calibrated.xlsx
# 2023-09-28 01:55:57,230 - INFO - Exporting 'ip' template in region peru to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/peru/model_input_variables_peru_ip_calibrated.xlsx
# 2023-09-28 01:55:57,411 - INFO - Exporting 'se' template in region peru to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/peru/model_input_variables_peru_se_calibrated.xlsx
# 2023-09-28 01:55:57,458 - INFO - Templates build for region peru complete.
#
#
# 2023-09-28 01:55:57,459 - INFO - Starting build for region uruguay
# 2023-09-28 01:55:57,470 - INFO - 	Successfully built transformation strategy_id = 1014 ('LNDU: Partial land use reallocation') in 0.01 seconds.
# 2023-09-28 01:56:00,443 - INFO - 	Successfully built transformation strategy_id = 5001 ('PFLO: Better baseline') in 0.16 seconds.
# 2023-09-28 01:56:03,438 - INFO - 	Successfully built transformation strategy_id = 5004 ('PFLO: Change consumer behavior') in 0.15 seconds.
# 2023-09-28 01:56:07,170 - INFO - 	Successfully built transformation strategy_id = 5006 ('PFLO: Supply side technologies and transformations') in 0.73 seconds.
# 2023-09-28 01:56:10,991 - INFO - 	Successfully built transformation strategy_id = 5007 ('PFLO: All transformations without stopping deforestation and partial land use reallocation') in 0.92 seconds.
# 2023-09-28 01:56:14,832 - INFO - 	Successfully built transformation strategy_id = 5009 ('PFLO: All transformations with partial land use reallocation') in 1.0 seconds.
# 2023-09-28 01:56:17,683 - INFO - Exporting 'af' template in region uruguay to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/uruguay/model_input_variables_uruguay_af_calibrated.xlsx
# 2023-09-28 01:56:18,418 - INFO - Exporting 'ce' template in region uruguay to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/uruguay/model_input_variables_uruguay_ce_calibrated.xlsx
# 2023-09-28 01:56:18,726 - INFO - Exporting 'en' template in region uruguay to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/uruguay/model_input_variables_uruguay_en_calibrated.xlsx
# 2023-09-28 01:56:19,611 - INFO - Exporting 'ip' template in region uruguay to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/uruguay/model_input_variables_uruguay_ip_calibrated.xlsx
# 2023-09-28 01:56:19,896 - INFO - Exporting 'se' template in region uruguay to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/uruguay/model_input_variables_uruguay_se_calibrated.xlsx
# 2023-09-28 01:56:19,941 - INFO - Templates build for region uruguay complete.
#
#
# 2023-09-28 01:56:19,942 - INFO - Integrated transformations build complete in 443.55 seconds.

# %%
# Out:
# ['turkey', 'india']

# %% [markdown]
# # Option to run SISEPUEDE

# %%
import sisepuede as ssp
"""
fn_log = os.path.join(os.getcwd(), "log_sisepuede.log")
os.remove(fn_log) if os.path.exists(fn_log) else None

def _setup_logger(namespace: str, fn_out: Union[str, None] = None) -> None:
    global logger
    
    format_str = "%(asctime)s - %(levelname)s - %(message)s"
    # configure
    if fn_out is not None:
        logging.basicConfig(
            filename = fn_out,
            filemode = "w",
            format = format_str,
            level = logging.DEBUG
        )
    else:
        logging.basicConfig(
            format = format_str,
            level = logging.DEBUG
        )
        
    logger = logging.getLogger(namespace)
    # create console handler and set level to debug
    ch = logging.StreamHandler()
    ch.setLevel(logging.DEBUG)
    # create formatter
    formatter = logging.Formatter(format_str)
    # add formatter to ch
    ch.setFormatter(formatter)
    # add ch to logger
    logger.addHandler(ch)

    return logger

_setup_logger(__name__, fn_log)
""";

sisepuede = ssp.SISEPUEDE(
    "calibrated", 
    logger = logger,
    #n_trials = 1000,
    #id_str = "sisepuede_run_2023-07-11T14:30:38.534039",#id_str = "sisepuede_run_2023-06-13T00:55:37.051768",
    regions = regions_run,#["brazil", "dominican_republic", "chile", "ecuador", "mexico"]
)






# STRATS TO RUN

attr_strat = sisepuede.model_attributes.dict_attributes.get("dim_strategy_id")
dict_code_to_id = attr_strat.field_maps.get(f"strategy_code_to_{attr_strat.key}")
strat_codes_ignore = [
    # AFOLU
    "LNDU:INC_LAND_REHABILITIATION",
    "LSMM:INC_MANAGEMENT_CATTLE_PIGS",
    "LSMM:INC_MANAGEMENT_OTHER",
    "LSMM:INC_MANAGEMENT_POULTRY",
    "LSMM:INC_CAPTURE_BIOGAS",
    "TRWW:INC_COMPLIANCE_SEPTIC",
    "IPPU:DEC_OTHER_FCS",
    "IPPU:DEC_HFCS",
    "IPPU:DEC_PFCS",
    
    # ENERGY
    "TRNS:BUNDLE_DEMAND_MANAGEMENT",
    "TRNS:BUNDLE_DEMAND_MANAGEMENT_REP",
    "TRNS:BUNDLE_EFFICIENCY",
    "TRNS:BUNDLE_EFFICIENCY_REP",
    "TRNS:BUNDLE_FUEL_SWITCH",
    "TRNS:BUNDLE_FUEL_SWITCH_REP",
    "TRNS:BUNDLE_MODE_SHIFT",
    "TRNS:BUNDLE_MODE_SHIFT_REP"
]
strat_ids_drop = [
    dict_code_to_id.get(x) for x in strat_codes_ignore
]
strats_run = [x for x in attr_strat.key_values if x not in strat_ids_drop]
# Out:
# 2023-09-28 02:23:15,563 - INFO - Successfully initialized SISEPUEDEFileStructure.
# 2023-09-28 02:23:15,566 - WARNING - Missing key dict_dimensional_keys: key time_series not found. Tables that rely on the time_series will not have index checking.
# 2023-09-28 02:23:15,567 - INFO - 	Setting export engine to 'sqlite'.
# 2023-09-28 02:23:15,570 - WARNING - No index fields defined. Index field values will not be checked when writing to tables.
# 2023-09-28 02:23:15,571 - INFO - Successfully instantiated table ANALYSIS_METADATA
# 2023-09-28 02:23:15,573 - WARNING - No index fields found in ATTRIBUTE_DESIGN. Initializing index fields.
# 2023-09-28 02:23:15,573 - INFO - Successfully instantiated table ATTRIBUTE_DESIGN
# 2023-09-28 02:23:15,575 - WARNING - No index fields found in ATTRIBUTE_LHC_SAMPLES_EXOGENOUS_UNCERTAINTIES. Initializing index fields.
# 2023-09-28 02:23:15,576 - INFO - Successfully instantiated table ATTRIBUTE_LHC_SAMPLES_EXOGENOUS_UNCERTAINTIES
# 2023-09-28 02:23:15,578 - WARNING - No index fields found in ATTRIBUTE_LHC_SAMPLES_LEVER_EFFECTS. Initializing index fields.
# 2023-09-28 02:23:15,579 - INFO - Successfully instantiated table ATTRIBUTE_LHC_SAMPLES_LEVER_EFFECTS
# 2023-09-28 02:23:15,581 - WARNING - No index fields found in ATTRIBUTE_PRIMARY. Initializing index fields.
# 2023-09-28 02:23:15,582 - INFO - Successfully instantiated table ATTRIBUTE_PRIMARY
# 2023-09-28 02:23:15,583 - WARNING - No index fields found in ATTRIBUTE_STRATEGY. Initializing index fields.
# 2023-09-28 02:23:15,584 - INFO - Successfully instantiated table ATTRIBUTE_STRATEGY
# 2023-09-28 02:23:15,585 - WARNING - No index fields found in MODEL_BASE_INPUT_DATABASE. Initializing index fields.
# 2023-09-28 02:23:15,586 - INFO - Successfully instantiated table MODEL_BASE_INPUT_DATABASE
# 2023-09-28 02:23:15,588 - WARNING - No index fields found in MODEL_INPUT. Initializing index fields.
# 2023-09-28 02:23:15,588 - INFO - Successfully instantiated table MODEL_INPUT
# 2023-09-28 02:23:15,590 - WARNING - No index fields found in MODEL_OUTPUT. Initializing index fields.
# 2023-09-28 02:23:15,591 - INFO - Successfully instantiated table MODEL_OUTPUT
# 2023-09-28 02:23:15,592 - INFO - SISEPUEDEOutputDatabase successfully initialized IterativeDatabase.
# 2023-09-28 02:23:15,593 - INFO - Successfully initialized database with:
# 	type:	sqlite
# 	analysis id:	sisepuede_run_2023-09-28T02:23:14.168676
# 	fp_base_output:	/Users/jsyme/Documents/Projects/git_jbus/sisepuede/out/sisepuede_run_2023-09-28T02;23;14.168676/sisepuede_run_2023-09-28T02;23;14.168676_output_database
# 2023-09-28 02:23:15,594 - INFO - Running SISEPUEDE under template data mode 'calibrated'.
# 2023-09-28 02:23:15,594 - INFO - Initializing BaseInputDatabase
# 2023-09-28 02:23:48,765 - INFO - Initializing FutureTrajectories
# 2023-09-28 02:23:50,181 - INFO - Instantiating 2186 sampling units.
# 2023-09-28 02:23:50,218 - INFO - Iteration 0 complete.
# 2023-09-28 02:23:55,668 - INFO - Iteration 250 complete.
# 2023-09-28 02:24:02,104 - INFO - Iteration 500 complete.
# 2023-09-28 02:24:08,142 - INFO - Iteration 750 complete.
# 2023-09-28 02:24:14,231 - INFO - Iteration 1000 complete.
# 2023-09-28 02:24:20,050 - INFO - Iteration 1250 complete.
# 2023-09-28 02:24:25,684 - INFO - Iteration 1500 complete.
# 2023-09-28 02:24:31,153 - INFO - Iteration 1750 complete.
# 2023-09-28 02:24:37,473 - INFO - Iteration 2000 complete.
# 2023-09-28 02:24:41,421 - INFO - 	2186 sampling units complete in 51.24 seconds.
# 2023-09-28 02:24:41,425 - INFO - 	FutureTrajectories for 'argentina' complete.
# 2023-09-28 02:24:42,934 - INFO - Instantiating 2186 sampling units.
# 2023-09-28 02:24:42,968 - INFO - Iteration 0 complete.
# 2023-09-28 02:24:50,467 - INFO - Iteration 250 complete.
# 2023-09-28 02:24:57,458 - INFO - Iteration 500 complete.
# 2023-09-28 02:25:03,068 - INFO - Iteration 750 complete.
# 2023-09-28 02:25:09,859 - INFO - Iteration 1000 complete.
# 2023-09-28 02:25:15,416 - INFO - Iteration 1250 complete.
# 2023-09-28 02:25:20,940 - INFO - Iteration 1500 complete.
# 2023-09-28 02:25:26,253 - INFO - Iteration 1750 complete.
# 2023-09-28 02:25:31,536 - INFO - Iteration 2000 complete.
# 2023-09-28 02:25:35,908 - INFO - 	2186 sampling units complete in 52.97 seconds.
# 2023-09-28 02:25:35,914 - INFO - 	FutureTrajectories for 'bolivia' complete.
# 2023-09-28 02:25:37,242 - INFO - Instantiating 2186 sampling units.
# 2023-09-28 02:25:37,272 - INFO - Iteration 0 complete.
# 2023-09-28 02:25:42,566 - INFO - Iteration 250 complete.
# 2023-09-28 02:25:47,870 - INFO - Iteration 500 complete.
# 2023-09-28 02:25:53,113 - INFO - Iteration 750 complete.
# 2023-09-28 02:25:58,553 - INFO - Iteration 1000 complete.
# 2023-09-28 02:26:03,968 - INFO - Iteration 1250 complete.
# 2023-09-28 02:26:10,209 - INFO - Iteration 1500 complete.
# 2023-09-28 02:26:15,647 - INFO - Iteration 1750 complete.
# 2023-09-28 02:26:21,075 - INFO - Iteration 2000 complete.
# 2023-09-28 02:26:25,024 - INFO - 	2186 sampling units complete in 47.78 seconds.
# 2023-09-28 02:26:25,029 - INFO - 	FutureTrajectories for 'brazil' complete.
# 2023-09-28 02:26:26,303 - INFO - Instantiating 2186 sampling units.
# 2023-09-28 02:26:26,338 - INFO - Iteration 0 complete.
# 2023-09-28 02:26:31,687 - INFO - Iteration 250 complete.
# 2023-09-28 02:26:36,976 - INFO - Iteration 500 complete.
# 2023-09-28 02:26:42,262 - INFO - Iteration 750 complete.
# 2023-09-28 02:26:48,449 - INFO - Iteration 1000 complete.
# 2023-09-28 02:26:53,801 - INFO - Iteration 1250 complete.
# 2023-09-28 02:26:59,052 - INFO - Iteration 1500 complete.
# 2023-09-28 02:27:04,396 - INFO - Iteration 1750 complete.
# 2023-09-28 02:27:09,853 - INFO - Iteration 2000 complete.
# 2023-09-28 02:27:13,801 - INFO - 	2186 sampling units complete in 47.5 seconds.
# 2023-09-28 02:27:13,805 - INFO - 	FutureTrajectories for 'chile' complete.
# 2023-09-28 02:27:15,071 - INFO - Instantiating 2186 sampling units.
# 2023-09-28 02:27:15,102 - INFO - Iteration 0 complete.
# 2023-09-28 02:27:20,390 - INFO - Iteration 250 complete.
# 2023-09-28 02:27:25,660 - INFO - Iteration 500 complete.
# 2023-09-28 02:27:31,732 - INFO - Iteration 750 complete.
# 2023-09-28 02:27:37,074 - INFO - Iteration 1000 complete.
# 2023-09-28 02:27:42,339 - INFO - Iteration 1250 complete.
# 2023-09-28 02:27:48,239 - INFO - Iteration 1500 complete.
# 2023-09-28 02:27:53,697 - INFO - Iteration 1750 complete.
# 2023-09-28 02:27:59,094 - INFO - Iteration 2000 complete.
# 2023-09-28 02:28:03,055 - INFO - 	2186 sampling units complete in 47.98 seconds.
# 2023-09-28 02:28:03,059 - INFO - 	FutureTrajectories for 'colombia' complete.
# 2023-09-28 02:28:04,346 - INFO - Instantiating 2186 sampling units.
# 2023-09-28 02:28:04,376 - INFO - Iteration 0 complete.
# 2023-09-28 02:28:09,723 - INFO - Iteration 250 complete.
# 2023-09-28 02:28:14,998 - INFO - Iteration 500 complete.
# 2023-09-28 02:28:20,414 - INFO - Iteration 750 complete.
# 2023-09-28 02:28:25,658 - INFO - Iteration 1000 complete.
# 2023-09-28 02:28:32,052 - INFO - Iteration 1250 complete.
# 2023-09-28 02:28:37,719 - INFO - Iteration 1500 complete.
# 2023-09-28 02:28:42,962 - INFO - Iteration 1750 complete.
# 2023-09-28 02:28:48,233 - INFO - Iteration 2000 complete.
# 2023-09-28 02:28:52,159 - INFO - 	2186 sampling units complete in 47.81 seconds.
# 2023-09-28 02:28:52,163 - INFO - 	FutureTrajectories for 'costa_rica' complete.
# 2023-09-28 02:28:53,437 - INFO - Instantiating 2186 sampling units.
# 2023-09-28 02:28:53,466 - INFO - Iteration 0 complete.
# 2023-09-28 02:28:58,690 - INFO - Iteration 250 complete.
# 2023-09-28 02:29:03,950 - INFO - Iteration 500 complete.
# 2023-09-28 02:29:09,289 - INFO - Iteration 750 complete.
# 2023-09-28 02:29:14,585 - INFO - Iteration 1000 complete.
# 2023-09-28 02:29:19,859 - INFO - Iteration 1250 complete.
# 2023-09-28 02:29:25,150 - INFO - Iteration 1500 complete.
# 2023-09-28 02:29:30,423 - INFO - Iteration 1750 complete.
# 2023-09-28 02:29:35,705 - INFO - Iteration 2000 complete.
# 2023-09-28 02:29:40,704 - INFO - 	2186 sampling units complete in 47.27 seconds.
# 2023-09-28 02:29:40,709 - INFO - 	FutureTrajectories for 'dominican_republic' complete.
# 2023-09-28 02:29:41,976 - INFO - Instantiating 2186 sampling units.
# 2023-09-28 02:29:42,005 - INFO - Iteration 0 complete.
# 2023-09-28 02:29:47,518 - INFO - Iteration 250 complete.
# 2023-09-28 02:29:52,760 - INFO - Iteration 500 complete.
# 2023-09-28 02:29:58,331 - INFO - Iteration 750 complete.
# 2023-09-28 02:30:04,230 - INFO - Iteration 1000 complete.
# 2023-09-28 02:30:09,976 - INFO - Iteration 1250 complete.
# 2023-09-28 02:30:15,749 - INFO - Iteration 1500 complete.
# 2023-09-28 02:30:21,848 - INFO - Iteration 1750 complete.
# 2023-09-28 02:30:27,741 - INFO - Iteration 2000 complete.
# 2023-09-28 02:30:32,070 - INFO - 	2186 sampling units complete in 50.09 seconds.
# 2023-09-28 02:30:32,082 - INFO - 	FutureTrajectories for 'ecuador' complete.
# 2023-09-28 02:30:33,427 - INFO - Instantiating 2186 sampling units.
# 2023-09-28 02:30:33,459 - INFO - Iteration 0 complete.
# 2023-09-28 02:30:39,493 - INFO - Iteration 250 complete.
# 2023-09-28 02:30:45,353 - INFO - Iteration 500 complete.
# 2023-09-28 02:30:51,146 - INFO - Iteration 750 complete.
# 2023-09-28 02:30:56,984 - INFO - Iteration 1000 complete.
# 2023-09-28 02:31:02,875 - INFO - Iteration 1250 complete.
# 2023-09-28 02:31:08,758 - INFO - Iteration 1500 complete.
# 2023-09-28 02:31:17,936 - INFO - Iteration 1750 complete.
# 2023-09-28 02:31:24,529 - INFO - Iteration 2000 complete.
# 2023-09-28 02:31:28,815 - INFO - 	2186 sampling units complete in 55.39 seconds.
# 2023-09-28 02:31:28,857 - INFO - 	FutureTrajectories for 'el_salvador' complete.
# 2023-09-28 02:31:30,319 - INFO - Instantiating 2186 sampling units.
# 2023-09-28 02:31:30,353 - INFO - Iteration 0 complete.
# 2023-09-28 02:31:36,138 - INFO - Iteration 250 complete.
# 2023-09-28 02:31:42,218 - INFO - Iteration 500 complete.
# 2023-09-28 02:31:47,699 - INFO - Iteration 750 complete.
# 2023-09-28 02:31:53,148 - INFO - Iteration 1000 complete.
# 2023-09-28 02:31:58,648 - INFO - Iteration 1250 complete.
# 2023-09-28 02:32:04,349 - INFO - Iteration 1500 complete.
# 2023-09-28 02:32:10,021 - INFO - Iteration 1750 complete.
# 2023-09-28 02:32:15,524 - INFO - Iteration 2000 complete.
# 2023-09-28 02:32:19,750 - INFO - 	2186 sampling units complete in 49.43 seconds.
# 2023-09-28 02:32:19,756 - INFO - 	FutureTrajectories for 'guatemala' complete.
# 2023-09-28 02:32:21,099 - INFO - Instantiating 2186 sampling units.
# 2023-09-28 02:32:21,133 - INFO - Iteration 0 complete.
# 2023-09-28 02:32:26,621 - INFO - Iteration 250 complete.
# 2023-09-28 02:32:32,324 - INFO - Iteration 500 complete.
# 2023-09-28 02:32:38,423 - INFO - Iteration 750 complete.
# 2023-09-28 02:32:43,954 - INFO - Iteration 1000 complete.
# 2023-09-28 02:32:49,631 - INFO - Iteration 1250 complete.
# 2023-09-28 02:32:55,168 - INFO - Iteration 1500 complete.
# 2023-09-28 02:33:00,614 - INFO - Iteration 1750 complete.
# 2023-09-28 02:33:10,184 - INFO - Iteration 2000 complete.
# 2023-09-28 02:33:14,311 - INFO - 	2186 sampling units complete in 53.21 seconds.
# 2023-09-28 02:33:14,314 - INFO - 	FutureTrajectories for 'honduras' complete.
# 2023-09-28 02:33:15,739 - INFO - Instantiating 2186 sampling units.
# 2023-09-28 02:33:15,767 - INFO - Iteration 0 complete.
# 2023-09-28 02:33:21,679 - INFO - Iteration 250 complete.
# 2023-09-28 02:33:27,359 - INFO - Iteration 500 complete.
# 2023-09-28 02:33:32,874 - INFO - Iteration 750 complete.
# 2023-09-28 02:33:38,490 - INFO - Iteration 1000 complete.
# 2023-09-28 02:33:44,100 - INFO - Iteration 1250 complete.
# 2023-09-28 02:33:49,684 - INFO - Iteration 1500 complete.
# 2023-09-28 02:33:55,143 - INFO - Iteration 1750 complete.
# 2023-09-28 02:34:00,662 - INFO - Iteration 2000 complete.
# 2023-09-28 02:34:04,809 - INFO - 	2186 sampling units complete in 49.07 seconds.
# 2023-09-28 02:34:04,813 - INFO - 	FutureTrajectories for 'jamaica' complete.
# 2023-09-28 02:34:06,202 - INFO - Instantiating 2186 sampling units.
# 2023-09-28 02:34:06,233 - INFO - Iteration 0 complete.
# 2023-09-28 02:34:11,742 - INFO - Iteration 250 complete.
# 2023-09-28 02:34:17,251 - INFO - Iteration 500 complete.
# 2023-09-28 02:34:22,714 - INFO - Iteration 750 complete.
# 2023-09-28 02:34:28,069 - INFO - Iteration 1000 complete.
# 2023-09-28 02:34:33,444 - INFO - Iteration 1250 complete.
# 2023-09-28 02:34:38,821 - INFO - Iteration 1500 complete.
# 2023-09-28 02:34:44,138 - INFO - Iteration 1750 complete.
# 2023-09-28 02:34:49,623 - INFO - Iteration 2000 complete.
# 2023-09-28 02:34:53,658 - INFO - 	2186 sampling units complete in 47.46 seconds.
# 2023-09-28 02:34:53,662 - INFO - 	FutureTrajectories for 'mexico' complete.
# 2023-09-28 02:34:54,988 - INFO - Instantiating 2186 sampling units.
# 2023-09-28 02:34:55,015 - INFO - Iteration 0 complete.
# 2023-09-28 02:35:00,468 - INFO - Iteration 250 complete.
# 2023-09-28 02:35:05,908 - INFO - Iteration 500 complete.
# 2023-09-28 02:35:11,339 - INFO - Iteration 750 complete.
# 2023-09-28 02:35:16,606 - INFO - Iteration 1000 complete.
# 2023-09-28 02:35:24,062 - INFO - Iteration 1250 complete.
# 2023-09-28 02:35:29,367 - INFO - Iteration 1500 complete.
# 2023-09-28 02:35:34,760 - INFO - Iteration 1750 complete.
# 2023-09-28 02:35:40,133 - INFO - Iteration 2000 complete.
# 2023-09-28 02:35:44,043 - INFO - 	2186 sampling units complete in 49.05 seconds.
# 2023-09-28 02:35:44,048 - INFO - 	FutureTrajectories for 'nicaragua' complete.
# 2023-09-28 02:35:45,353 - INFO - Instantiating 2186 sampling units.
# 2023-09-28 02:35:45,383 - INFO - Iteration 0 complete.
# 2023-09-28 02:35:50,734 - INFO - Iteration 250 complete.
# 2023-09-28 02:35:56,002 - INFO - Iteration 500 complete.
# 2023-09-28 02:36:01,340 - INFO - Iteration 750 complete.
# 2023-09-28 02:36:06,744 - INFO - Iteration 1000 complete.
# 2023-09-28 02:36:12,087 - INFO - Iteration 1250 complete.
# 2023-09-28 02:36:17,667 - INFO - Iteration 1500 complete.
# 2023-09-28 02:36:23,287 - INFO - Iteration 1750 complete.
# 2023-09-28 02:36:29,128 - INFO - Iteration 2000 complete.
# 2023-09-28 02:36:33,223 - INFO - 	2186 sampling units complete in 47.87 seconds.
# 2023-09-28 02:36:33,228 - INFO - 	FutureTrajectories for 'panama' complete.
# 2023-09-28 02:36:34,532 - INFO - Instantiating 2186 sampling units.
# 2023-09-28 02:36:34,565 - INFO - Iteration 0 complete.
# 2023-09-28 02:36:40,040 - INFO - Iteration 250 complete.
# 2023-09-28 02:36:45,610 - INFO - Iteration 500 complete.
# 2023-09-28 02:36:51,206 - INFO - Iteration 750 complete.
# 2023-09-28 02:36:56,960 - INFO - Iteration 1000 complete.
# 2023-09-28 02:37:02,581 - INFO - Iteration 1250 complete.
# 2023-09-28 02:37:08,100 - INFO - Iteration 1500 complete.
# 2023-09-28 02:37:13,594 - INFO - Iteration 1750 complete.
# 2023-09-28 02:37:19,136 - INFO - Iteration 2000 complete.
# 2023-09-28 02:37:23,274 - INFO - 	2186 sampling units complete in 48.74 seconds.
# 2023-09-28 02:37:23,278 - INFO - 	FutureTrajectories for 'paraguay' complete.
# 2023-09-28 02:37:24,588 - INFO - Instantiating 2186 sampling units.
# 2023-09-28 02:37:24,619 - INFO - Iteration 0 complete.
# 2023-09-28 02:37:30,370 - INFO - Iteration 250 complete.
# 2023-09-28 02:37:36,056 - INFO - Iteration 500 complete.
# 2023-09-28 02:37:41,598 - INFO - Iteration 750 complete.
# 2023-09-28 02:37:47,124 - INFO - Iteration 1000 complete.
# 2023-09-28 02:37:52,726 - INFO - Iteration 1250 complete.
# 2023-09-28 02:37:58,308 - INFO - Iteration 1500 complete.
# 2023-09-28 02:38:06,937 - INFO - Iteration 1750 complete.
# 2023-09-28 02:38:12,484 - INFO - Iteration 2000 complete.
# 2023-09-28 02:38:16,763 - INFO - 	2186 sampling units complete in 52.17 seconds.
# 2023-09-28 02:38:16,766 - INFO - 	FutureTrajectories for 'peru' complete.
# 2023-09-28 02:38:18,137 - INFO - Instantiating 2186 sampling units.
# 2023-09-28 02:38:18,171 - INFO - Iteration 0 complete.
# 2023-09-28 02:38:23,855 - INFO - Iteration 250 complete.
# 2023-09-28 02:38:30,145 - INFO - Iteration 500 complete.
# 2023-09-28 02:38:36,607 - INFO - Iteration 750 complete.
# 2023-09-28 02:38:42,164 - INFO - Iteration 1000 complete.
# 2023-09-28 02:38:47,827 - INFO - Iteration 1250 complete.
# 2023-09-28 02:38:53,674 - INFO - Iteration 1500 complete.
# 2023-09-28 02:38:59,365 - INFO - Iteration 1750 complete.
# 2023-09-28 02:39:05,242 - INFO - Iteration 2000 complete.
# 2023-09-28 02:39:09,693 - INFO - 	2186 sampling units complete in 51.55 seconds.
# 2023-09-28 02:39:09,720 - INFO - 	FutureTrajectories for 'uruguay' complete.
# 2023-09-28 02:39:09,770 - INFO - Initializing LHSDesign
# 2023-09-28 02:39:09,772 - INFO - LHSDesign.fields_factors_l reset successful.
# 2023-09-28 02:39:09,772 - INFO - LHSDesign.fields_factors_x reset successful.
# 2023-09-28 02:39:09,891 - INFO - 	LHSDesign for region 'argentina' complete.
# 2023-09-28 02:39:09,892 - INFO - LHSDesign.fields_factors_l reset successful.
# 2023-09-28 02:39:09,892 - INFO - LHSDesign.fields_factors_x reset successful.
# 2023-09-28 02:39:10,064 - INFO - 	LHSDesign for region 'bolivia' complete.
# 2023-09-28 02:39:10,065 - INFO - LHSDesign.fields_factors_l reset successful.
# 2023-09-28 02:39:10,065 - INFO - LHSDesign.fields_factors_x reset successful.
# 2023-09-28 02:39:10,200 - INFO - 	LHSDesign for region 'brazil' complete.
# 2023-09-28 02:39:10,201 - INFO - LHSDesign.fields_factors_l reset successful.
# 2023-09-28 02:39:10,202 - INFO - LHSDesign.fields_factors_x reset successful.
# 2023-09-28 02:39:10,312 - INFO - 	LHSDesign for region 'chile' complete.
# 2023-09-28 02:39:10,312 - INFO - LHSDesign.fields_factors_l reset successful.
# 2023-09-28 02:39:10,313 - INFO - LHSDesign.fields_factors_x reset successful.
# 2023-09-28 02:39:10,409 - INFO - 	LHSDesign for region 'colombia' complete.
# 2023-09-28 02:39:10,409 - INFO - LHSDesign.fields_factors_l reset successful.
# 2023-09-28 02:39:10,410 - INFO - LHSDesign.fields_factors_x reset successful.
# 2023-09-28 02:39:10,545 - INFO - 	LHSDesign for region 'costa_rica' complete.
# 2023-09-28 02:39:10,546 - INFO - LHSDesign.fields_factors_l reset successful.
# 2023-09-28 02:39:10,546 - INFO - LHSDesign.fields_factors_x reset successful.
# 2023-09-28 02:39:10,677 - INFO - 	LHSDesign for region 'dominican_republic' complete.
# 2023-09-28 02:39:10,678 - INFO - LHSDesign.fields_factors_l reset successful.
# 2023-09-28 02:39:10,678 - INFO - LHSDesign.fields_factors_x reset successful.
# 2023-09-28 02:39:10,822 - INFO - 	LHSDesign for region 'ecuador' complete.
# 2023-09-28 02:39:10,822 - INFO - LHSDesign.fields_factors_l reset successful.
# 2023-09-28 02:39:10,823 - INFO - LHSDesign.fields_factors_x reset successful.
# 2023-09-28 02:39:10,959 - INFO - 	LHSDesign for region 'el_salvador' complete.
# 2023-09-28 02:39:10,960 - INFO - LHSDesign.fields_factors_l reset successful.
# 2023-09-28 02:39:10,960 - INFO - LHSDesign.fields_factors_x reset successful.
# 2023-09-28 02:39:11,092 - INFO - 	LHSDesign for region 'guatemala' complete.
# 2023-09-28 02:39:11,093 - INFO - LHSDesign.fields_factors_l reset successful.
# 2023-09-28 02:39:11,093 - INFO - LHSDesign.fields_factors_x reset successful.
# 2023-09-28 02:39:11,226 - INFO - 	LHSDesign for region 'honduras' complete.
# 2023-09-28 02:39:11,226 - INFO - LHSDesign.fields_factors_l reset successful.
# 2023-09-28 02:39:11,227 - INFO - LHSDesign.fields_factors_x reset successful.
# 2023-09-28 02:39:11,353 - INFO - 	LHSDesign for region 'jamaica' complete.
# 2023-09-28 02:39:11,353 - INFO - LHSDesign.fields_factors_l reset successful.
# 2023-09-28 02:39:11,354 - INFO - LHSDesign.fields_factors_x reset successful.
# 2023-09-28 02:39:11,464 - INFO - 	LHSDesign for region 'mexico' complete.
# 2023-09-28 02:39:11,465 - INFO - LHSDesign.fields_factors_l reset successful.
# 2023-09-28 02:39:11,466 - INFO - LHSDesign.fields_factors_x reset successful.
# 2023-09-28 02:39:11,605 - INFO - 	LHSDesign for region 'nicaragua' complete.
# 2023-09-28 02:39:11,606 - INFO - LHSDesign.fields_factors_l reset successful.
# 2023-09-28 02:39:11,606 - INFO - LHSDesign.fields_factors_x reset successful.
# 2023-09-28 02:39:11,781 - INFO - 	LHSDesign for region 'panama' complete.
# 2023-09-28 02:39:11,781 - INFO - LHSDesign.fields_factors_l reset successful.
# 2023-09-28 02:39:11,782 - INFO - LHSDesign.fields_factors_x reset successful.
# 2023-09-28 02:39:11,942 - INFO - 	LHSDesign for region 'paraguay' complete.
# 2023-09-28 02:39:11,943 - INFO - LHSDesign.fields_factors_l reset successful.
# 2023-09-28 02:39:11,943 - INFO - LHSDesign.fields_factors_x reset successful.
# 2023-09-28 02:39:12,080 - INFO - 	LHSDesign for region 'peru' complete.
# 2023-09-28 02:39:12,080 - INFO - LHSDesign.fields_factors_l reset successful.
# 2023-09-28 02:39:12,081 - INFO - LHSDesign.fields_factors_x reset successful.
# 2023-09-28 02:39:12,175 - INFO - 	LHSDesign for region 'uruguay' complete.
# 2023-09-28 02:39:12,176 - INFO - Generating primary keys (values of primary_id)...
# 2023-09-28 02:39:12,178 - INFO - Successfully initialized SISEPUEDEExperimentalManager.
# 2023-09-28 02:39:12,186 - INFO - Successfully initialized NemoMod temporary database path as /Users/jsyme/Documents/Projects/git_jbus/sisepuede/tmp/nemomod_intermediate_database.sqlite.
# 2023-09-28 02:39:12,188 - INFO - Set Julia directory for modules and environment to '/Users/jsyme/Documents/Projects/git_jbus/sisepuede/julia'.
# 2023-09-28 02:39:12,343 - INFO - Successfully read NemoMod input table data from /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/nemo_mod/SpecifiedDemandProfile.csv
# 2023-09-28 02:39:12,355 - INFO - Successfully read NemoMod input table data from /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/nemo_mod/CapacityFactor.csv
# 2023-09-28 02:39:12,487 - INFO - Calling Julia API...
# 2023-09-28 02:39:35,965 - DEBUG - 	Successfully activated Julia with compiled_modules = False
# 2023-09-28 02:39:35,969 - DEBUG - 	Successfully imported julia.Base
# 2023-09-28 02:39:35,970 - DEBUG - 	Successfully imported julia.Main
# 2023-09-28 02:39:36,078 - DEBUG - 	Successfully imported julia.Pkg
# 2023-09-28 02:39:36,721 - DEBUG - 	Available Packages:
# 		'GLPK'
# 		 'HiGHS'
# 		 'Graphs'
# 		 'ExcelReaders'
# 		 'Juniper'
# 		 'DataFrames'
# 		 'PlotlyJS'
# 		 'MLJ'
# 		 'SQLite'
# 		 'Distributions'
# 		 'Clp'
# 		 'LatinHypercubeSampling'
# 		 'ScikitLearn'
# 		 'LazySets'
# 		 'Metal'
# 		 'SCIP'
# 		 'DistributedArrays'
# 		 'Gurobi'
# 		 'AlphaVantage'
# 		 'CSV'
# 		 'Revise'
# 		 'StructArrays'
# 		 'Random'
# 		 'Conda'
# 		 'Shapefile'
# 		 'PyCall'
# 		 'StatsBase'
# 		 'IJulia'
# 		 'Flux'
# 		 'Plots'
# 		 'GeoInterface'
# 		 'NEOSServer'
# 		 'XLSX'
# 		 'Cbc'
# 		 'MathOptInterface'
# 		 'CUDA'
# 		 'Statistics'
# 		 'HypothesisTests'
# 		 'JuMP'
# 		 'Ipopt'
# 		 'LaTeXStrings'
# 		 'SharedArrays'
# 		 'DecisionTree'
# 		 'WebIO'
# 		 'AbstractTrees'
#   Activating2023-09-28 02:39:37,375 - INFO - Successfully activated Julia environment at '/Users/jsyme/Documents/Projects/git_jbus/sisepuede/julia'
#  project at `~/Documents/Projects/git_jbus/sisepuede/julia`
# 2023-09-28 02:40:49,038 - INFO - Successfully initialized JuMP optimizer from solver module Gurobi.
# 2023-09-28 02:40:49,074 - INFO - Successfully initialized SISEPUEDEModels.
# 2023-09-28 02:40:51,235 - INFO - Table ANALYSIS_METADATA successfully written to database.
# 2023-09-28 02:40:51,260 - INFO - Table ATTRIBUTE_DESIGN successfully written to database.
# 2023-09-28 02:40:51,282 - INFO - Table ATTRIBUTE_STRATEGY successfully written to database.
# 2023-09-28 02:41:02,210 - INFO - Table MODEL_BASE_INPUT_DATABASE successfully written to database.

# %%
"""
##  SOME IterativeDatabaseTable THINGS

query = f"select * from {tab_output.table_name} limit 0;"
with tab_output.engine.connect() as con:
    df_columns = pd.read_sql_query(query, con)
    
    
for k in tab_output.columns:
    w = np.where(np.array(tab_output.columns) == k)[0]
    if len(w) > 1:
        print(k)

tab_output = sisepuede.database.db.dict_iterative_database_tables.get("MODEL_OUTPUT")
tab_output._initialize_table() # sispuede randomly started failing at some points
""";

# %%
# drop table
#idt_output = sisepuede.database.db.dict_iterative_database_tables.get("MODEL_OUTPUT")
#idt_output._drop_indices([("turkey", 127127)])

# write to output
#
#
df_in = sisepuede.experimental_manager.dict_future_trajectories.get(region).generate_future_from_lhs_vector(None, None, None, baseline_future_q = False)#True)
df_in.to_csv(
    os.path.join(sisepuede.file_struct.dir_tmp, "temporary_full_inputs.csv"),
    index = None,
    encoding = "UTF-8"
)

# %%
warnings.filterwarnings("ignore")

# %%
dict_filt = {
    "future_id": [0],
    "design_id": [0], 
    "strategy_id": [0, 1014, 5001, 5004, 5006, 5007, 5009]
}


dict_primary_keys_out = sisepuede(
    dict_filt,
    chunk_size = 2,
    reinitialize_output_table_on_verification_failure = True,
    #regions = ["mexico"],
    thresholds = (10**(-5), 10**4.5),
)
# Out:
# 2023-09-28 02:50:03,610 - INFO -
# ***	STARTING REGION argentina	***
#
# 2023-09-28 02:50:05,690 - INFO - Trying run primary_id = 0 in region argentina
# 2023-09-28 02:50:05,693 - INFO - Running AFOLU model
# 2023-09-28 02:50:06,118 - INFO - AFOLU model run successfully completed
# 2023-09-28 02:50:06,119 - INFO - Running CircularEconomy model
# 2023-09-28 02:50:06,221 - INFO - CircularEconomy model run successfully completed
# 2023-09-28 02:50:06,221 - INFO - Running IPPU model
# 2023-09-28 02:50:06,382 - INFO - IPPU model run successfully completed
# 2023-09-28 02:50:06,382 - INFO - Running Energy model (NonElectricEnergy without Fugitive Emissions)
# 2023-09-28 02:50:06,431 - DEBUG - Missing elasticity information found in 'project_energy_consumption_by_fuel_from_effvars': using specified future demands.
# 2023-09-28 02:50:06,482 - ERROR - Error running NonElectricEnergy without Fugitive Emissions: name 'modvar_demscalar' is not defined
# 2023-09-28 02:50:06,482 - INFO - Running Energy model (Electricity and Fuel Production: trying to call Julia)
# 2023-09-28 02:50:06,531 - ERROR - Error running ElectricEnergy model: "Electricity projection cannot proceed: fields 'energy_demand_enfu_subsector_total_pj_trns_fuel_crude', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_furnace_gas', 'energy_demand_enfu_subsector_total_pj_inen_fuel_oil', 'energy_demand_enfu_subsector_total_pj_trns_fuel_waste', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_hydrogen', 'energy_demand_enfu_subsector_total_pj_trns_fuel_geothermal', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_diesel', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_coal', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_waste', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_nuclear', 'energy_demand_enfu_subsector_total_pj_inen_fuel_natural_gas', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_geothermal', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_other', 'energy_demand_enfu_subsector_total_pj_inen_fuel_coal', 'energy_demand_enfu_subsector_total_pj_inen_fuel_kerosene', 'energy_demand_enfu_subsector_total_pj_inen_fuel_hydrocarbon_gas_liquids', 'energy_demand_enfu_subsector_total_pj_trns_fuel_other', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_diesel', 'energy_demand_enfu_subsector_total_pj_inen_fuel_electricity', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_nuclear', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_solar', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_biomass', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_coke', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_oil', 'energy_demand_enfu_subsector_total_pj_trns_fuel_wind', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_electricity', 'energy_demand_enfu_subsector_total_pj_trns_fuel_coal', 'energy_demand_enfu_subsector_total_pj_inen_fuel_wind', 'energy_demand_enfu_subsector_total_pj_trns_fuel_biogas', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_kerosene', 'energy_demand_enfu_subsector_total_pj_trns_fuel_ocean', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_wind', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_ocean', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_hydropower', 'energy_demand_enfu_subsector_total_pj_trns_fuel_hydrogen', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_crude', 'energy_demand_enfu_subsector_total_pj_inen_fuel_solar', 'energy_demand_enfu_subsector_total_pj_inen_fuel_biogas', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_coke', 'energy_demand_enfu_subsector_total_pj_inen_fuel_hydrogen', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_waste', 'energy_demand_enfu_subsector_total_pj_inen_fuel_waste', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_natural_gas', 'energy_demand_enfu_subsector_total_pj_trns_fuel_coke', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_hydrocarbon_gas_liquids', 'energy_demand_enfu_subsector_total_pj_inen_fuel_gasoline', 'energy_demand_enfu_subsector_total_pj_trns_fuel_furnace_gas', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_natural_gas', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_furnace_gas', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_oil', 'energy_demand_enfu_subsector_total_pj_trns_fuel_kerosene', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_electricity', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_biogas', 'energy_demand_enfu_subsector_total_pj_inen_fuel_geothermal', 'energy_demand_enfu_subsector_total_pj_trns_fuel_hydropower', 'energy_demand_enfu_subsector_total_pj_inen_fuel_diesel', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_other', 'energy_demand_enfu_subsector_total_pj_inen_fuel_other', 'energy_demand_enfu_subsector_total_pj_trns_fuel_nuclear', 'energy_demand_enfu_subsector_total_pj_trns_fuel_natural_gas', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_crude', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_biogas', 'energy_demand_enfu_subsector_total_pj_trns_fuel_oil', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_biofuels', 'energy_demand_enfu_subsector_total_pj_inen_fuel_hydropower', 'energy_demand_enfu_subsector_ ...
# 2023-09-28 02:50:06,533 - INFO - Running Energy (Fugitive Emissions)
# 2023-09-28 02:50:06,571 - WARNING - Warning in project_enfu_production_and_demands: Variable 'Energy Demand by Fuel in CCSQ' not found in the data frame. Its fuel demands will not be included.
# 2023-09-28 02:50:06,572 - WARNING - Warning in project_enfu_production_and_demands: Variable 'Energy Demand by Fuel in Energy Technology' not found in the data frame. Its fuel demands will not be included.
# 2023-09-28 02:50:06,573 - WARNING - Warning in project_enfu_production_and_demands: Variable 'Energy Demand by Fuel in Industrial Energy' not found in the data frame. Its fuel demands will not be included.
# 2023-09-28 02:50:06,575 - WARNING - Warning in project_enfu_production_and_demands: Variable 'Energy Demand by Fuel in SCOE' not found in the data frame. Its fuel demands will not be included.
# 2023-09-28 02:50:06,576 - WARNING - Warning in project_enfu_production_and_demands: Variable 'Energy Demand by Fuel in Transportation' not found in the data frame. Its fuel demands will not be included.
# 2023-09-28 02:50:06,587 - ERROR - Error running Fugitive Emissions from Energy model: 'float' object has no attribute 'shape'
# 2023-09-28 02:50:06,588 - INFO - Appending Socioeconomic outputs
# 2023-09-28 02:50:06,609 - INFO - Socioeconomic outputs successfully appended.
# 2023-09-28 02:50:06,620 - INFO - Model run for primary_id = 0 successfully completed in 0.93 seconds (n_tries = 1).
# 2023-09-28 02:50:06,636 - INFO - Trying run primary_id = 14014 in region argentina
# 2023-09-28 02:50:06,637 - INFO - Running AFOLU model
# 2023-09-28 02:50:06,989 - INFO - AFOLU model run successfully completed
# 2023-09-28 02:50:06,990 - INFO - Running CircularEconomy model
# 2023-09-28 02:50:07,092 - INFO - CircularEconomy model run successfully completed
# 2023-09-28 02:50:07,093 - INFO - Running IPPU model
# 2023-09-28 02:50:07,261 - INFO - IPPU model run successfully completed
# 2023-09-28 02:50:07,261 - INFO - Running Energy model (NonElectricEnergy without Fugitive Emissions)
# 2023-09-28 02:50:07,305 - DEBUG - Missing elasticity information found in 'project_energy_consumption_by_fuel_from_effvars': using specified future demands.
# 2023-09-28 02:50:07,352 - ERROR - Error running NonElectricEnergy without Fugitive Emissions: name 'modvar_demscalar' is not defined
# 2023-09-28 02:50:07,353 - INFO - Running Energy model (Electricity and Fuel Production: trying to call Julia)
# 2023-09-28 02:50:07,390 - ERROR - Error running ElectricEnergy model: "Electricity projection cannot proceed: fields 'energy_demand_enfu_subsector_total_pj_trns_fuel_crude', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_furnace_gas', 'energy_demand_enfu_subsector_total_pj_inen_fuel_oil', 'energy_demand_enfu_subsector_total_pj_trns_fuel_waste', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_hydrogen', 'energy_demand_enfu_subsector_total_pj_trns_fuel_geothermal', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_diesel', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_coal', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_waste', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_nuclear', 'energy_demand_enfu_subsector_total_pj_inen_fuel_natural_gas', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_geothermal', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_other', 'energy_demand_enfu_subsector_total_pj_inen_fuel_coal', 'energy_demand_enfu_subsector_total_pj_inen_fuel_kerosene', 'energy_demand_enfu_subsector_total_pj_inen_fuel_hydrocarbon_gas_liquids', 'energy_demand_enfu_subsector_total_pj_trns_fuel_other', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_diesel', 'energy_demand_enfu_subsector_total_pj_inen_fuel_electricity', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_nuclear', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_solar', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_biomass', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_coke', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_oil', 'energy_demand_enfu_subsector_total_pj_trns_fuel_wind', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_electricity', 'energy_demand_enfu_subsector_total_pj_trns_fuel_coal', 'energy_demand_enfu_subsector_total_pj_inen_fuel_wind', 'energy_demand_enfu_subsector_total_pj_trns_fuel_biogas', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_kerosene', 'energy_demand_enfu_subsector_total_pj_trns_fuel_ocean', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_wind', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_ocean', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_hydropower', 'energy_demand_enfu_subsector_total_pj_trns_fuel_hydrogen', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_crude', 'energy_demand_enfu_subsector_total_pj_inen_fuel_solar', 'energy_demand_enfu_subsector_total_pj_inen_fuel_biogas', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_coke', 'energy_demand_enfu_subsector_total_pj_inen_fuel_hydrogen', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_waste', 'energy_demand_enfu_subsector_total_pj_inen_fuel_waste', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_natural_gas', 'energy_demand_enfu_subsector_total_pj_trns_fuel_coke', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_hydrocarbon_gas_liquids', 'energy_demand_enfu_subsector_total_pj_inen_fuel_gasoline', 'energy_demand_enfu_subsector_total_pj_trns_fuel_furnace_gas', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_natural_gas', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_furnace_gas', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_oil', 'energy_demand_enfu_subsector_total_pj_trns_fuel_kerosene', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_electricity', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_biogas', 'energy_demand_enfu_subsector_total_pj_inen_fuel_geothermal', 'energy_demand_enfu_subsector_total_pj_trns_fuel_hydropower', 'energy_demand_enfu_subsector_total_pj_inen_fuel_diesel', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_other', 'energy_demand_enfu_subsector_total_pj_inen_fuel_other', 'energy_demand_enfu_subsector_total_pj_trns_fuel_nuclear', 'energy_demand_enfu_subsector_total_pj_trns_fuel_natural_gas', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_crude', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_biogas', 'energy_demand_enfu_subsector_total_pj_trns_fuel_oil', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_biofuels', 'energy_demand_enfu_subsector_total_pj_inen_fuel_hydropower', 'energy_demand_enfu_subsector_ ...
# 2023-09-28 02:50:07,391 - INFO - Running Energy (Fugitive Emissions)
# 2023-09-28 02:50:07,427 - WARNING - Warning in project_enfu_production_and_demands: Variable 'Energy Demand by Fuel in CCSQ' not found in the data frame. Its fuel demands will not be included.
# 2023-09-28 02:50:07,428 - WARNING - Warning in project_enfu_production_and_demands: Variable 'Energy Demand by Fuel in Energy Technology' not found in the data frame. Its fuel demands will not be included.
# 2023-09-28 02:50:07,429 - WARNING - Warning in project_enfu_production_and_demands: Variable 'Energy Demand by Fuel in Industrial Energy' not found in the data frame. Its fuel demands will not be included.
# 2023-09-28 02:50:07,429 - WARNING - Warning in project_enfu_production_and_demands: Variable 'Energy Demand by Fuel in SCOE' not found in the data frame. Its fuel demands will not be included.
# 2023-09-28 02:50:07,430 - WARNING - Warning in project_enfu_production_and_demands: Variable 'Energy Demand by Fuel in Transportation' not found in the data frame. Its fuel demands will not be included.
# 2023-09-28 02:50:07,438 - ERROR - Error running Fugitive Emissions from Energy model: 'float' object has no attribute 'shape'
# 2023-09-28 02:50:07,439 - INFO - Appending Socioeconomic outputs
# 2023-09-28 02:50:07,458 - INFO - Socioeconomic outputs successfully appended.
# 2023-09-28 02:50:07,464 - INFO - Model run for primary_id = 14014 successfully completed in 0.83 seconds (n_tries = 1).
# 2023-09-28 02:50:07,811 - INFO - Table MODEL_OUTPUT successfully written to database.
# 2023-09-28 02:50:07,880 - INFO - Trying run primary_id = 119119 in region argentina
# 2023-09-28 02:50:07,881 - INFO - Running AFOLU model
# 2023-09-28 02:50:08,327 - INFO - AFOLU model run successfully completed
# 2023-09-28 02:50:08,328 - INFO - Running CircularEconomy model
# 2023-09-28 02:50:08,453 - INFO - CircularEconomy model run successfully completed
# 2023-09-28 02:50:08,454 - INFO - Running IPPU model
# 2023-09-28 02:50:08,668 - INFO - IPPU model run successfully completed
# 2023-09-28 02:50:08,668 - INFO - Running Energy model (NonElectricEnergy without Fugitive Emissions)
# 2023-09-28 02:50:08,714 - DEBUG - Missing elasticity information found in 'project_energy_consumption_by_fuel_from_effvars': using specified future demands.
# 2023-09-28 02:50:08,767 - ERROR - Error running NonElectricEnergy without Fugitive Emissions: name 'modvar_demscalar' is not defined
# 2023-09-28 02:50:08,768 - INFO - Running Energy model (Electricity and Fuel Production: trying to call Julia)
# 2023-09-28 02:50:08,812 - ERROR - Error running ElectricEnergy model: "Electricity projection cannot proceed: fields 'energy_demand_enfu_subsector_total_pj_trns_fuel_crude', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_furnace_gas', 'energy_demand_enfu_subsector_total_pj_inen_fuel_oil', 'energy_demand_enfu_subsector_total_pj_trns_fuel_waste', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_hydrogen', 'energy_demand_enfu_subsector_total_pj_trns_fuel_geothermal', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_diesel', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_coal', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_waste', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_nuclear', 'energy_demand_enfu_subsector_total_pj_inen_fuel_natural_gas', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_geothermal', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_other', 'energy_demand_enfu_subsector_total_pj_inen_fuel_coal', 'energy_demand_enfu_subsector_total_pj_inen_fuel_kerosene', 'energy_demand_enfu_subsector_total_pj_inen_fuel_hydrocarbon_gas_liquids', 'energy_demand_enfu_subsector_total_pj_trns_fuel_other', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_diesel', 'energy_demand_enfu_subsector_total_pj_inen_fuel_electricity', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_nuclear', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_solar', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_biomass', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_coke', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_oil', 'energy_demand_enfu_subsector_total_pj_trns_fuel_wind', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_electricity', 'energy_demand_enfu_subsector_total_pj_trns_fuel_coal', 'energy_demand_enfu_subsector_total_pj_inen_fuel_wind', 'energy_demand_enfu_subsector_total_pj_trns_fuel_biogas', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_kerosene', 'energy_demand_enfu_subsector_total_pj_trns_fuel_ocean', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_wind', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_ocean', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_hydropower', 'energy_demand_enfu_subsector_total_pj_trns_fuel_hydrogen', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_crude', 'energy_demand_enfu_subsector_total_pj_inen_fuel_solar', 'energy_demand_enfu_subsector_total_pj_inen_fuel_biogas', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_coke', 'energy_demand_enfu_subsector_total_pj_inen_fuel_hydrogen', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_waste', 'energy_demand_enfu_subsector_total_pj_inen_fuel_waste', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_natural_gas', 'energy_demand_enfu_subsector_total_pj_trns_fuel_coke', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_hydrocarbon_gas_liquids', 'energy_demand_enfu_subsector_total_pj_inen_fuel_gasoline', 'energy_demand_enfu_subsector_total_pj_trns_fuel_furnace_gas', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_natural_gas', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_furnace_gas', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_oil', 'energy_demand_enfu_subsector_total_pj_trns_fuel_kerosene', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_electricity', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_biogas', 'energy_demand_enfu_subsector_total_pj_inen_fuel_geothermal', 'energy_demand_enfu_subsector_total_pj_trns_fuel_hydropower', 'energy_demand_enfu_subsector_total_pj_inen_fuel_diesel', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_other', 'energy_demand_enfu_subsector_total_pj_inen_fuel_other', 'energy_demand_enfu_subsector_total_pj_trns_fuel_nuclear', 'energy_demand_enfu_subsector_total_pj_trns_fuel_natural_gas', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_crude', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_biogas', 'energy_demand_enfu_subsector_total_pj_trns_fuel_oil', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_biofuels', 'energy_demand_enfu_subsector_total_pj_inen_fuel_hydropower', 'energy_demand_enfu_subsector_ ...
# 2023-09-28 02:50:08,813 - INFO - Running Energy (Fugitive Emissions)
# 2023-09-28 02:50:08,853 - WARNING - Warning in project_enfu_production_and_demands: Variable 'Energy Demand by Fuel in CCSQ' not found in the data frame. Its fuel demands will not be included.
# 2023-09-28 02:50:08,854 - WARNING - Warning in project_enfu_production_and_demands: Variable 'Energy Demand by Fuel in Energy Technology' not found in the data frame. Its fuel demands will not be included.
# 2023-09-28 02:50:08,855 - WARNING - Warning in project_enfu_production_and_demands: Variable 'Energy Demand by Fuel in Industrial Energy' not found in the data frame. Its fuel demands will not be included.
# 2023-09-28 02:50:08,857 - WARNING - Warning in project_enfu_production_and_demands: Variable 'Energy Demand by Fuel in SCOE' not found in the data frame. Its fuel demands will not be included.
# 2023-09-28 02:50:08,859 - WARNING - Warning in project_enfu_production_and_demands: Variable 'Energy Demand by Fuel in Transportation' not found in the data frame. Its fuel demands will not be included.
# 2023-09-28 02:50:08,870 - ERROR - Error running Fugitive Emissions from Energy model: 'float' object has no attribute 'shape'
# 2023-09-28 02:50:08,871 - INFO - Appending Socioeconomic outputs
# 2023-09-28 02:50:08,894 - INFO - Socioeconomic outputs successfully appended.
# 2023-09-28 02:50:08,900 - INFO - Model run for primary_id = 119119 successfully completed in 1.02 seconds (n_tries = 1).
# 2023-09-28 02:50:08,908 - INFO - Trying run primary_id = 122122 in region argentina
# 2023-09-28 02:50:08,908 - INFO - Running AFOLU model
# 2023-09-28 02:50:09,306 - INFO - AFOLU model run successfully completed
# 2023-09-28 02:50:09,307 - INFO - Running CircularEconomy model
# 2023-09-28 02:50:09,413 - INFO - CircularEconomy model run successfully completed
# 2023-09-28 02:50:09,413 - INFO - Running IPPU model
# 2023-09-28 02:50:09,584 - INFO - IPPU model run successfully completed
# 2023-09-28 02:50:09,584 - INFO - Running Energy model (NonElectricEnergy without Fugitive Emissions)
# 2023-09-28 02:50:09,622 - DEBUG - Missing elasticity information found in 'project_energy_consumption_by_fuel_from_effvars': using specified future demands.
# 2023-09-28 02:50:09,668 - ERROR - Error running NonElectricEnergy without Fugitive Emissions: name 'modvar_demscalar' is not defined
# 2023-09-28 02:50:09,669 - INFO - Running Energy model (Electricity and Fuel Production: trying to call Julia)
# 2023-09-28 02:50:09,702 - ERROR - Error running ElectricEnergy model: "Electricity projection cannot proceed: fields 'energy_demand_enfu_subsector_total_pj_trns_fuel_crude', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_furnace_gas', 'energy_demand_enfu_subsector_total_pj_inen_fuel_oil', 'energy_demand_enfu_subsector_total_pj_trns_fuel_waste', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_hydrogen', 'energy_demand_enfu_subsector_total_pj_trns_fuel_geothermal', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_diesel', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_coal', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_waste', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_nuclear', 'energy_demand_enfu_subsector_total_pj_inen_fuel_natural_gas', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_geothermal', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_other', 'energy_demand_enfu_subsector_total_pj_inen_fuel_coal', 'energy_demand_enfu_subsector_total_pj_inen_fuel_kerosene', 'energy_demand_enfu_subsector_total_pj_inen_fuel_hydrocarbon_gas_liquids', 'energy_demand_enfu_subsector_total_pj_trns_fuel_other', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_diesel', 'energy_demand_enfu_subsector_total_pj_inen_fuel_electricity', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_nuclear', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_solar', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_biomass', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_coke', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_oil', 'energy_demand_enfu_subsector_total_pj_trns_fuel_wind', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_electricity', 'energy_demand_enfu_subsector_total_pj_trns_fuel_coal', 'energy_demand_enfu_subsector_total_pj_inen_fuel_wind', 'energy_demand_enfu_subsector_total_pj_trns_fuel_biogas', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_kerosene', 'energy_demand_enfu_subsector_total_pj_trns_fuel_ocean', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_wind', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_ocean', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_hydropower', 'energy_demand_enfu_subsector_total_pj_trns_fuel_hydrogen', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_crude', 'energy_demand_enfu_subsector_total_pj_inen_fuel_solar', 'energy_demand_enfu_subsector_total_pj_inen_fuel_biogas', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_coke', 'energy_demand_enfu_subsector_total_pj_inen_fuel_hydrogen', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_waste', 'energy_demand_enfu_subsector_total_pj_inen_fuel_waste', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_natural_gas', 'energy_demand_enfu_subsector_total_pj_trns_fuel_coke', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_hydrocarbon_gas_liquids', 'energy_demand_enfu_subsector_total_pj_inen_fuel_gasoline', 'energy_demand_enfu_subsector_total_pj_trns_fuel_furnace_gas', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_natural_gas', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_furnace_gas', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_oil', 'energy_demand_enfu_subsector_total_pj_trns_fuel_kerosene', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_electricity', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_biogas', 'energy_demand_enfu_subsector_total_pj_inen_fuel_geothermal', 'energy_demand_enfu_subsector_total_pj_trns_fuel_hydropower', 'energy_demand_enfu_subsector_total_pj_inen_fuel_diesel', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_other', 'energy_demand_enfu_subsector_total_pj_inen_fuel_other', 'energy_demand_enfu_subsector_total_pj_trns_fuel_nuclear', 'energy_demand_enfu_subsector_total_pj_trns_fuel_natural_gas', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_crude', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_biogas', 'energy_demand_enfu_subsector_total_pj_trns_fuel_oil', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_biofuels', 'energy_demand_enfu_subsector_total_pj_inen_fuel_hydropower', 'energy_demand_enfu_subsector_ ...
# 2023-09-28 02:50:09,703 - INFO - Running Energy (Fugitive Emissions)
# 2023-09-28 02:50:09,737 - WARNING - Warning in project_enfu_production_and_demands: Variable 'Energy Demand by Fuel in CCSQ' not found in the data frame. Its fuel demands will not be included.
# 2023-09-28 02:50:09,738 - WARNING - Warning in project_enfu_production_and_demands: Variable 'Energy Demand by Fuel in Energy Technology' not found in the data frame. Its fuel demands will not be included.
# 2023-09-28 02:50:09,740 - WARNING - Warning in project_enfu_production_and_demands: Variable 'Energy Demand by Fuel in Industrial Energy' not found in the data frame. Its fuel demands will not be included.
# 2023-09-28 02:50:09,741 - WARNING - Warning in project_enfu_production_and_demands: Variable 'Energy Demand by Fuel in SCOE' not found in the data frame. Its fuel demands will not be included.
# 2023-09-28 02:50:09,742 - WARNING - Warning in project_enfu_production_and_demands: Variable 'Energy Demand by Fuel in Transportation' not found in the data frame. Its fuel demands will not be included.
# 2023-09-28 02:50:09,751 - ERROR - Error running Fugitive Emissions from Energy model: 'float' object has no attribute 'shape'
# 2023-09-28 02:50:09,752 - INFO - Appending Socioeconomic outputs
# 2023-09-28 02:50:09,771 - INFO - Socioeconomic outputs successfully appended.
# 2023-09-28 02:50:09,776 - INFO - Model run for primary_id = 122122 successfully completed in 0.87 seconds (n_tries = 1).
# 2023-09-28 02:50:10,074 - INFO - Table MODEL_OUTPUT successfully appended to database.
# 2023-09-28 02:50:10,079 - INFO - Trying run primary_id = 124124 in region argentina
# 2023-09-28 02:50:10,080 - INFO - Running AFOLU model
# 2023-09-28 02:50:10,421 - INFO - AFOLU model run successfully completed
# 2023-09-28 02:50:10,422 - INFO - Running CircularEconomy model
# 2023-09-28 02:50:10,523 - INFO - CircularEconomy model run successfully completed
# 2023-09-28 02:50:10,523 - INFO - Running IPPU model
# 2023-09-28 02:50:10,679 - INFO - IPPU model run successfully completed
# 2023-09-28 02:50:10,679 - INFO - Running Energy model (NonElectricEnergy without Fugitive Emissions)
# 2023-09-28 02:50:10,715 - DEBUG - Missing elasticity information found in 'project_energy_consumption_by_fuel_from_effvars': using specified future demands.
# 2023-09-28 02:50:10,762 - ERROR - Error running NonElectricEnergy without Fugitive Emissions: name 'modvar_demscalar' is not defined
# 2023-09-28 02:50:10,763 - INFO - Running Energy model (Electricity and Fuel Production: trying to call Julia)
# 2023-09-28 02:50:10,796 - ERROR - Error running ElectricEnergy model: "Electricity projection cannot proceed: fields 'energy_demand_enfu_subsector_total_pj_trns_fuel_crude', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_furnace_gas', 'energy_demand_enfu_subsector_total_pj_inen_fuel_oil', 'energy_demand_enfu_subsector_total_pj_trns_fuel_waste', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_hydrogen', 'energy_demand_enfu_subsector_total_pj_trns_fuel_geothermal', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_diesel', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_coal', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_waste', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_nuclear', 'energy_demand_enfu_subsector_total_pj_inen_fuel_natural_gas', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_geothermal', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_other', 'energy_demand_enfu_subsector_total_pj_inen_fuel_coal', 'energy_demand_enfu_subsector_total_pj_inen_fuel_kerosene', 'energy_demand_enfu_subsector_total_pj_inen_fuel_hydrocarbon_gas_liquids', 'energy_demand_enfu_subsector_total_pj_trns_fuel_other', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_diesel', 'energy_demand_enfu_subsector_total_pj_inen_fuel_electricity', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_nuclear', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_solar', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_biomass', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_coke', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_oil', 'energy_demand_enfu_subsector_total_pj_trns_fuel_wind', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_electricity', 'energy_demand_enfu_subsector_total_pj_trns_fuel_coal', 'energy_demand_enfu_subsector_total_pj_inen_fuel_wind', 'energy_demand_enfu_subsector_total_pj_trns_fuel_biogas', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_kerosene', 'energy_demand_enfu_subsector_total_pj_trns_fuel_ocean', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_wind', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_ocean', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_hydropower', 'energy_demand_enfu_subsector_total_pj_trns_fuel_hydrogen', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_crude', 'energy_demand_enfu_subsector_total_pj_inen_fuel_solar', 'energy_demand_enfu_subsector_total_pj_inen_fuel_biogas', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_coke', 'energy_demand_enfu_subsector_total_pj_inen_fuel_hydrogen', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_waste', 'energy_demand_enfu_subsector_total_pj_inen_fuel_waste', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_natural_gas', 'energy_demand_enfu_subsector_total_pj_trns_fuel_coke', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_hydrocarbon_gas_liquids', 'energy_demand_enfu_subsector_total_pj_inen_fuel_gasoline', 'energy_demand_enfu_subsector_total_pj_trns_fuel_furnace_gas', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_natural_gas', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_furnace_gas', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_oil', 'energy_demand_enfu_subsector_total_pj_trns_fuel_kerosene', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_electricity', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_biogas', 'energy_demand_enfu_subsector_total_pj_inen_fuel_geothermal', 'energy_demand_enfu_subsector_total_pj_trns_fuel_hydropower', 'energy_demand_enfu_subsector_total_pj_inen_fuel_diesel', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_other', 'energy_demand_enfu_subsector_total_pj_inen_fuel_other', 'energy_demand_enfu_subsector_total_pj_trns_fuel_nuclear', 'energy_demand_enfu_subsector_total_pj_trns_fuel_natural_gas', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_crude', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_biogas', 'energy_demand_enfu_subsector_total_pj_trns_fuel_oil', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_biofuels', 'energy_demand_enfu_subsector_total_pj_inen_fuel_hydropower', 'energy_demand_enfu_subsector_ ...
# 2023-09-28 02:50:10,797 - INFO - Running Energy (Fugitive Emissions)
# 2023-09-28 02:50:10,836 - WARNING - Warning in project_enfu_production_and_demands: Variable 'Energy Demand by Fuel in CCSQ' not found in the data frame. Its fuel demands will not be included.
# 2023-09-28 02:50:10,837 - WARNING - Warning in project_enfu_production_and_demands: Variable 'Energy Demand by Fuel in Energy Technology' not found in the data frame. Its fuel demands will not be included.
# 2023-09-28 02:50:10,838 - WARNING - Warning in project_enfu_production_and_demands: Variable 'Energy Demand by Fuel in Industrial Energy' not found in the data frame. Its fuel demands will not be included.
# 2023-09-28 02:50:10,839 - WARNING - Warning in project_enfu_production_and_demands: Variable 'Energy Demand by Fuel in SCOE' not found in the data frame. Its fuel demands will not be included.
# 2023-09-28 02:50:10,840 - WARNING - Warning in project_enfu_production_and_demands: Variable 'Energy Demand by Fuel in Transportation' not found in the data frame. Its fuel demands will not be included.
# 2023-09-28 02:50:10,850 - ERROR - Error running Fugitive Emissions from Energy model: 'float' object has no attribute 'shape'
# 2023-09-28 02:50:10,851 - INFO - Appending Socioeconomic outputs
# 2023-09-28 02:50:10,871 - INFO - Socioeconomic outputs successfully appended.
# 2023-09-28 02:50:10,877 - INFO - Model run for primary_id = 124124 successfully completed in 0.8 seconds (n_tries = 1).
# 2023-09-28 02:50:10,881 - INFO - Trying run primary_id = 125125 in region argentina
# 2023-09-28 02:50:10,882 - INFO - Running AFOLU model
# 2023-09-28 02:50:11,234 - INFO - AFOLU model run successfully completed
# 2023-09-28 02:50:11,235 - INFO - Running CircularEconomy model
# 2023-09-28 02:50:11,337 - INFO - CircularEconomy model run successfully completed
# 2023-09-28 02:50:11,338 - INFO - Running IPPU model
# 2023-09-28 02:50:11,497 - INFO - IPPU model run successfully completed
# 2023-09-28 02:50:11,498 - INFO - Running Energy model (NonElectricEnergy without Fugitive Emissions)
# 2023-09-28 02:50:11,534 - DEBUG - Missing elasticity information found in 'project_energy_consumption_by_fuel_from_effvars': using specified future demands.
# 2023-09-28 02:50:11,580 - ERROR - Error running NonElectricEnergy without Fugitive Emissions: name 'modvar_demscalar' is not defined
# 2023-09-28 02:50:11,581 - INFO - Running Energy model (Electricity and Fuel Production: trying to call Julia)
# 2023-09-28 02:50:11,612 - ERROR - Error running ElectricEnergy model: "Electricity projection cannot proceed: fields 'energy_demand_enfu_subsector_total_pj_trns_fuel_crude', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_furnace_gas', 'energy_demand_enfu_subsector_total_pj_inen_fuel_oil', 'energy_demand_enfu_subsector_total_pj_trns_fuel_waste', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_hydrogen', 'energy_demand_enfu_subsector_total_pj_trns_fuel_geothermal', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_diesel', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_coal', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_waste', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_nuclear', 'energy_demand_enfu_subsector_total_pj_inen_fuel_natural_gas', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_geothermal', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_other', 'energy_demand_enfu_subsector_total_pj_inen_fuel_coal', 'energy_demand_enfu_subsector_total_pj_inen_fuel_kerosene', 'energy_demand_enfu_subsector_total_pj_inen_fuel_hydrocarbon_gas_liquids', 'energy_demand_enfu_subsector_total_pj_trns_fuel_other', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_diesel', 'energy_demand_enfu_subsector_total_pj_inen_fuel_electricity', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_nuclear', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_solar', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_biomass', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_coke', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_oil', 'energy_demand_enfu_subsector_total_pj_trns_fuel_wind', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_electricity', 'energy_demand_enfu_subsector_total_pj_trns_fuel_coal', 'energy_demand_enfu_subsector_total_pj_inen_fuel_wind', 'energy_demand_enfu_subsector_total_pj_trns_fuel_biogas', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_kerosene', 'energy_demand_enfu_subsector_total_pj_trns_fuel_ocean', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_wind', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_ocean', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_hydropower', 'energy_demand_enfu_subsector_total_pj_trns_fuel_hydrogen', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_crude', 'energy_demand_enfu_subsector_total_pj_inen_fuel_solar', 'energy_demand_enfu_subsector_total_pj_inen_fuel_biogas', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_coke', 'energy_demand_enfu_subsector_total_pj_inen_fuel_hydrogen', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_waste', 'energy_demand_enfu_subsector_total_pj_inen_fuel_waste', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_natural_gas', 'energy_demand_enfu_subsector_total_pj_trns_fuel_coke', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_hydrocarbon_gas_liquids', 'energy_demand_enfu_subsector_total_pj_inen_fuel_gasoline', 'energy_demand_enfu_subsector_total_pj_trns_fuel_furnace_gas', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_natural_gas', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_furnace_gas', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_oil', 'energy_demand_enfu_subsector_total_pj_trns_fuel_kerosene', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_electricity', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_biogas', 'energy_demand_enfu_subsector_total_pj_inen_fuel_geothermal', 'energy_demand_enfu_subsector_total_pj_trns_fuel_hydropower', 'energy_demand_enfu_subsector_total_pj_inen_fuel_diesel', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_other', 'energy_demand_enfu_subsector_total_pj_inen_fuel_other', 'energy_demand_enfu_subsector_total_pj_trns_fuel_nuclear', 'energy_demand_enfu_subsector_total_pj_trns_fuel_natural_gas', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_crude', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_biogas', 'energy_demand_enfu_subsector_total_pj_trns_fuel_oil', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_biofuels', 'energy_demand_enfu_subsector_total_pj_inen_fuel_hydropower', 'energy_demand_enfu_subsector_ ...
# 2023-09-28 02:50:11,613 - INFO - Running Energy (Fugitive Emissions)
# 2023-09-28 02:50:11,647 - WARNING - Warning in project_enfu_production_and_demands: Variable 'Energy Demand by Fuel in CCSQ' not found in the data frame. Its fuel demands will not be included.
# 2023-09-28 02:50:11,648 - WARNING - Warning in project_enfu_production_and_demands: Variable 'Energy Demand by Fuel in Energy Technology' not found in the data frame. Its fuel demands will not be included.
# 2023-09-28 02:50:11,650 - WARNING - Warning in project_enfu_production_and_demands: Variable 'Energy Demand by Fuel in Industrial Energy' not found in the data frame. Its fuel demands will not be included.
# 2023-09-28 02:50:11,651 - WARNING - Warning in project_enfu_production_and_demands: Variable 'Energy Demand by Fuel in SCOE' not found in the data frame. Its fuel demands will not be included.
# 2023-09-28 02:50:11,652 - WARNING - Warning in project_enfu_production_and_demands: Variable 'Energy Demand by Fuel in Transportation' not found in the data frame. Its fuel demands will not be included.
# 2023-09-28 02:50:11,662 - ERROR - Error running Fugitive Emissions from Energy model: 'float' object has no attribute 'shape'
# 2023-09-28 02:50:11,663 - INFO - Appending Socioeconomic outputs
# 2023-09-28 02:50:11,680 - INFO - Socioeconomic outputs successfully appended.
# 2023-09-28 02:50:11,685 - INFO - Model run for primary_id = 125125 successfully completed in 0.8 seconds (n_tries = 1).
# 2023-09-28 02:50:11,941 - INFO - Table MODEL_OUTPUT successfully appended to database.
# 2023-09-28 02:50:11,946 - INFO - Trying run primary_id = 127127 in region argentina
# 2023-09-28 02:50:11,947 - INFO - Running AFOLU model
# 2023-09-28 02:50:12,280 - INFO - AFOLU model run successfully completed
# 2023-09-28 02:50:12,281 - INFO - Running CircularEconomy model
# 2023-09-28 02:50:12,385 - INFO - CircularEconomy model run successfully completed
# 2023-09-28 02:50:12,385 - INFO - Running IPPU model
# 2023-09-28 02:50:12,581 - INFO - IPPU model run successfully completed
# 2023-09-28 02:50:12,582 - INFO - Running Energy model (NonElectricEnergy without Fugitive Emissions)
# 2023-09-28 02:50:12,621 - DEBUG - Missing elasticity information found in 'project_energy_consumption_by_fuel_from_effvars': using specified future demands.
# 2023-09-28 02:50:12,665 - ERROR - Error running NonElectricEnergy without Fugitive Emissions: name 'modvar_demscalar' is not defined
# 2023-09-28 02:50:12,666 - INFO - Running Energy model (Electricity and Fuel Production: trying to call Julia)
# 2023-09-28 02:50:12,699 - ERROR - Error running ElectricEnergy model: "Electricity projection cannot proceed: fields 'energy_demand_enfu_subsector_total_pj_trns_fuel_crude', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_furnace_gas', 'energy_demand_enfu_subsector_total_pj_inen_fuel_oil', 'energy_demand_enfu_subsector_total_pj_trns_fuel_waste', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_hydrogen', 'energy_demand_enfu_subsector_total_pj_trns_fuel_geothermal', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_diesel', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_coal', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_waste', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_nuclear', 'energy_demand_enfu_subsector_total_pj_inen_fuel_natural_gas', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_geothermal', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_other', 'energy_demand_enfu_subsector_total_pj_inen_fuel_coal', 'energy_demand_enfu_subsector_total_pj_inen_fuel_kerosene', 'energy_demand_enfu_subsector_total_pj_inen_fuel_hydrocarbon_gas_liquids', 'energy_demand_enfu_subsector_total_pj_trns_fuel_other', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_diesel', 'energy_demand_enfu_subsector_total_pj_inen_fuel_electricity', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_nuclear', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_solar', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_biomass', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_coke', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_oil', 'energy_demand_enfu_subsector_total_pj_trns_fuel_wind', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_electricity', 'energy_demand_enfu_subsector_total_pj_trns_fuel_coal', 'energy_demand_enfu_subsector_total_pj_inen_fuel_wind', 'energy_demand_enfu_subsector_total_pj_trns_fuel_biogas', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_kerosene', 'energy_demand_enfu_subsector_total_pj_trns_fuel_ocean', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_wind', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_ocean', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_hydropower', 'energy_demand_enfu_subsector_total_pj_trns_fuel_hydrogen', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_crude', 'energy_demand_enfu_subsector_total_pj_inen_fuel_solar', 'energy_demand_enfu_subsector_total_pj_inen_fuel_biogas', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_coke', 'energy_demand_enfu_subsector_total_pj_inen_fuel_hydrogen', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_waste', 'energy_demand_enfu_subsector_total_pj_inen_fuel_waste', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_natural_gas', 'energy_demand_enfu_subsector_total_pj_trns_fuel_coke', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_hydrocarbon_gas_liquids', 'energy_demand_enfu_subsector_total_pj_inen_fuel_gasoline', 'energy_demand_enfu_subsector_total_pj_trns_fuel_furnace_gas', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_natural_gas', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_furnace_gas', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_oil', 'energy_demand_enfu_subsector_total_pj_trns_fuel_kerosene', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_electricity', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_biogas', 'energy_demand_enfu_subsector_total_pj_inen_fuel_geothermal', 'energy_demand_enfu_subsector_total_pj_trns_fuel_hydropower', 'energy_demand_enfu_subsector_total_pj_inen_fuel_diesel', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_other', 'energy_demand_enfu_subsector_total_pj_inen_fuel_other', 'energy_demand_enfu_subsector_total_pj_trns_fuel_nuclear', 'energy_demand_enfu_subsector_total_pj_trns_fuel_natural_gas', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_crude', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_biogas', 'energy_demand_enfu_subsector_total_pj_trns_fuel_oil', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_biofuels', 'energy_demand_enfu_subsector_total_pj_inen_fuel_hydropower', 'energy_demand_enfu_subsector_ ...
# 2023-09-28 02:50:12,700 - INFO - Running Energy (Fugitive Emissions)
# 2023-09-28 02:50:12,741 - WARNING - Warning in project_enfu_production_and_demands: Variable 'Energy Demand by Fuel in CCSQ' not found in the data frame. Its fuel demands will not be included.
# 2023-09-28 02:50:12,742 - WARNING - Warning in project_enfu_production_and_demands: Variable 'Energy Demand by Fuel in Energy Technology' not found in the data frame. Its fuel demands will not be included.
# 2023-09-28 02:50:12,743 - WARNING - Warning in project_enfu_production_and_demands: Variable 'Energy Demand by Fuel in Industrial Energy' not found in the data frame. Its fuel demands will not be included.
# 2023-09-28 02:50:12,744 - WARNING - Warning in project_enfu_production_and_demands: Variable 'Energy Demand by Fuel in SCOE' not found in the data frame. Its fuel demands will not be included.
# 2023-09-28 02:50:12,745 - WARNING - Warning in project_enfu_production_and_demands: Variable 'Energy Demand by Fuel in Transportation' not found in the data frame. Its fuel demands will not be included.
# 2023-09-28 02:50:12,754 - ERROR - Error running Fugitive Emissions from Energy model: 'float' object has no attribute 'shape'
# 2023-09-28 02:50:12,755 - INFO - Appending Socioeconomic outputs
# 2023-09-28 02:50:12,772 - INFO - Socioeconomic outputs successfully appended.
# 2023-09-28 02:50:12,779 - INFO - Model run for primary_id = 127127 successfully completed in 0.83 seconds (n_tries = 1).
# 2023-09-28 02:50:12,780 - INFO -
# ***	 REGION argentina COMPLETE	***
#
# 2023-09-28 02:50:12,780 - INFO -
# ***	STARTING REGION bolivia	***
#
# 2023-09-28 02:50:14,701 - INFO - Trying run primary_id = 0 in region bolivia
# 2023-09-28 02:50:14,702 - INFO - Running AFOLU model
# 2023-09-28 02:50:15,040 - INFO - AFOLU model run successfully completed
# 2023-09-28 02:50:15,040 - INFO - Running CircularEconomy model
# 2023-09-28 02:50:15,217 - INFO - CircularEconomy model run successfully completed
# 2023-09-28 02:50:15,222 - INFO - Running IPPU model
# 2023-09-28 02:50:15,730 - INFO - IPPU model run successfully completed
# 2023-09-28 02:50:15,731 - INFO - Running Energy model (NonElectricEnergy without Fugitive Emissions)
# 2023-09-28 02:50:15,788 - DEBUG - Missing elasticity information found in 'project_energy_consumption_by_fuel_from_effvars': using specified future demands.
# 2023-09-28 02:50:15,844 - ERROR - Error running NonElectricEnergy without Fugitive Emissions: name 'modvar_demscalar' is not defined
# 2023-09-28 02:50:15,845 - INFO - Running Energy model (Electricity and Fuel Production: trying to call Julia)
# ...
# 2023-09-28 02:50:20,837 - INFO - Running Energy (Fugitive Emissions)
# 2023-09-28 02:50:20,875 - WARNING - Warning in project_enfu_production_and_demands: Variable 'Energy Demand by Fuel in CCSQ' not found in the data frame. Its fuel demands will not be included.
# 2023-09-28 02:50:20,877 - WARNING - Warning in project_enfu_production_and_demands: Variable 'Energy Demand by Fuel in Energy Technology' not found in the data frame. Its fuel demands will not be included.
# 2023-09-28 02:50:20,878 - WARNING - Warning in project_enfu_production_and_demands: Variable 'Energy Demand by Fuel in Industrial Energy' not found in the data frame. Its fuel demands will not be included.
# 2023-09-28 02:50:20,880 - WARNING - Warning in project_enfu_production_and_demands: Variable 'Energy Demand by Fuel in SCOE' not found in the data frame. Its fuel demands will not be included.
# 2023-09-28 02:50:20,881 - WARNING - Warning in project_enfu_production_and_demands: Variable 'Energy Demand by Fuel in Transportation' not found in the data frame. Its fuel demands will not be included.
# 2023-09-28 02:50:20,890 - ERROR - Error running Fugitive Emissions from Energy model: 'float' object has no attribute 'shape'
# 2023-09-28 02:50:20,892 - INFO - Appending Socioeconomic outputs
# 2023-09-28 02:50:20,913 - INFO - Socioeconomic outputs successfully appended.
# 2023-09-28 02:50:20,920 - INFO - Model run for primary_id = 124124 successfully completed in 0.97 seconds (n_tries = 1).
# 2023-09-28 02:50:21,224 - INFO - Table MODEL_OUTPUT successfully appended to database.
# 2023-09-28 02:50:21,228 - INFO - Trying run primary_id = 125125 in region bolivia
# 2023-09-28 02:50:21,229 - INFO - Running AFOLU model
# 2023-09-28 02:50:21,599 - INFO - AFOLU model run successfully completed
# 2023-09-28 02:50:21,599 - INFO - Running CircularEconomy model
# 2023-09-28 02:50:21,740 - INFO - CircularEconomy model run successfully completed
# 2023-09-28 02:50:21,741 - INFO - Running IPPU model
# 2023-09-28 02:50:21,950 - INFO - IPPU model run successfully completed
# 2023-09-28 02:50:21,951 - INFO - Running Energy model (NonElectricEnergy without Fugitive Emissions)
# 2023-09-28 02:50:21,997 - DEBUG - Missing elasticity information found in 'project_energy_consumption_by_fuel_from_effvars': using specified future demands.
# 2023-09-28 02:50:22,054 - ERROR - Error running NonElectricEnergy without Fugitive Emissions: name 'modvar_demscalar' is not defined
# 2023-09-28 02:50:22,055 - INFO - Running Energy model (Electricity and Fuel Production: trying to call Julia)
# 2023-09-28 02:50:22,098 - ERROR - Error running ElectricEnergy model: "Electricity projection cannot proceed: fields 'energy_demand_enfu_subsector_total_pj_trns_fuel_crude', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_furnace_gas', 'energy_demand_enfu_subsector_total_pj_inen_fuel_oil', 'energy_demand_enfu_subsector_total_pj_trns_fuel_waste', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_hydrogen', 'energy_demand_enfu_subsector_total_pj_trns_fuel_geothermal', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_diesel', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_coal', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_waste', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_nuclear', 'energy_demand_enfu_subsector_total_pj_inen_fuel_natural_gas', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_geothermal', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_other', 'energy_demand_enfu_subsector_total_pj_inen_fuel_coal', 'energy_demand_enfu_subsector_total_pj_inen_fuel_kerosene', 'energy_demand_enfu_subsector_total_pj_inen_fuel_hydrocarbon_gas_liquids', 'energy_demand_enfu_subsector_total_pj_trns_fuel_other', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_diesel', 'energy_demand_enfu_subsector_total_pj_inen_fuel_electricity', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_nuclear', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_solar', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_biomass', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_coke', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_oil', 'energy_demand_enfu_subsector_total_pj_trns_fuel_wind', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_electricity', 'energy_demand_enfu_subsector_total_pj_trns_fuel_coal', 'energy_demand_enfu_subsector_total_pj_inen_fuel_wind', 'energy_demand_enfu_subsector_total_pj_trns_fuel_biogas', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_kerosene', 'energy_demand_enfu_subsector_total_pj_trns_fuel_ocean', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_wind', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_ocean', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_hydropower', 'energy_demand_enfu_subsector_total_pj_trns_fuel_hydrogen', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_crude', 'energy_demand_enfu_subsector_total_pj_inen_fuel_solar', 'energy_demand_enfu_subsector_total_pj_inen_fuel_biogas', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_coke', 'energy_demand_enfu_subsector_total_pj_inen_fuel_hydrogen', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_waste', 'energy_demand_enfu_subsector_total_pj_inen_fuel_waste', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_natural_gas', 'energy_demand_enfu_subsector_total_pj_trns_fuel_coke', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_hydrocarbon_gas_liquids', 'energy_demand_enfu_subsector_total_pj_inen_fuel_gasoline', 'energy_demand_enfu_subsector_total_pj_trns_fuel_furnace_gas', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_natural_gas', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_furnace_gas', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_oil', 'energy_demand_enfu_subsector_total_pj_trns_fuel_kerosene', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_electricity', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_biogas', 'energy_demand_enfu_subsector_total_pj_inen_fuel_geothermal', 'energy_demand_enfu_subsector_total_pj_trns_fuel_hydropower', 'energy_demand_enfu_subsector_total_pj_inen_fuel_diesel', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_other', 'energy_demand_enfu_subsector_total_pj_inen_fuel_other', 'energy_demand_enfu_subsector_total_pj_trns_fuel_nuclear', 'energy_demand_enfu_subsector_total_pj_trns_fuel_natural_gas', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_crude', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_biogas', 'energy_demand_enfu_subsector_total_pj_trns_fuel_oil', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_biofuels', 'energy_demand_enfu_subsector_total_pj_inen_fuel_hydropower', 'energy_demand_enfu_subsector_ ...
# 2023-09-28 02:50:22,099 - INFO - Running Energy (Fugitive Emissions)
# 2023-09-28 02:50:22,138 - WARNING - Warning in project_enfu_production_and_demands: Variable 'Energy Demand by Fuel in CCSQ' not found in the data frame. Its fuel demands will not be included.
# 2023-09-28 02:50:22,139 - WARNING - Warning in project_enfu_production_and_demands: Variable 'Energy Demand by Fuel in Energy Technology' not found in the data frame. Its fuel demands will not be included.
# 2023-09-28 02:50:22,140 - WARNING - Warning in project_enfu_production_and_demands: Variable 'Energy Demand by Fuel in Industrial Energy' not found in the data frame. Its fuel demands will not be included.
# 2023-09-28 02:50:22,141 - WARNING - Warning in project_enfu_production_and_demands: Variable 'Energy Demand by Fuel in SCOE' not found in the data frame. Its fuel demands will not be included.
# 2023-09-28 02:50:22,142 - WARNING - Warning in project_enfu_production_and_demands: Variable 'Energy Demand by Fuel in Transportation' not found in the data frame. Its fuel demands will not be included.
# 2023-09-28 02:50:22,151 - ERROR - Error running Fugitive Emissions from Energy model: 'float' object has no attribute 'shape'
# 2023-09-28 02:50:22,152 - INFO - Appending Socioeconomic outputs
# 2023-09-28 02:50:22,171 - INFO - Socioeconomic outputs successfully appended.
# 2023-09-28 02:50:22,176 - INFO - Model run for primary_id = 125125 successfully completed in 0.95 seconds (n_tries = 1).
# 2023-09-28 02:50:22,182 - INFO - Trying run primary_id = 127127 in region bolivia
# 2023-09-28 02:50:22,182 - INFO - Running AFOLU model
# 2023-09-28 02:50:22,620 - INFO - AFOLU model run successfully completed
# 2023-09-28 02:50:22,621 - INFO - Running CircularEconomy model
# 2023-09-28 02:50:22,800 - INFO - CircularEconomy model run successfully completed
# 2023-09-28 02:50:22,801 - INFO - Running IPPU model
# 2023-09-28 02:50:23,030 - INFO - IPPU model run successfully completed
# 2023-09-28 02:50:23,031 - INFO - Running Energy model (NonElectricEnergy without Fugitive Emissions)
# 2023-09-28 02:50:23,083 - DEBUG - Missing elasticity information found in 'project_energy_consumption_by_fuel_from_effvars': using specified future demands.
# 2023-09-28 02:50:23,136 - ERROR - Error running NonElectricEnergy without Fugitive Emissions: name 'modvar_demscalar' is not defined
# 2023-09-28 02:50:23,136 - INFO - Running Energy model (Electricity and Fuel Production: trying to call Julia)
# 2023-09-28 02:50:23,176 - ERROR - Error running ElectricEnergy model: "Electricity projection cannot proceed: fields 'energy_demand_enfu_subsector_total_pj_trns_fuel_crude', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_furnace_gas', 'energy_demand_enfu_subsector_total_pj_inen_fuel_oil', 'energy_demand_enfu_subsector_total_pj_trns_fuel_waste', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_hydrogen', 'energy_demand_enfu_subsector_total_pj_trns_fuel_geothermal', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_diesel', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_coal', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_waste', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_nuclear', 'energy_demand_enfu_subsector_total_pj_inen_fuel_natural_gas', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_geothermal', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_other', 'energy_demand_enfu_subsector_total_pj_inen_fuel_coal', 'energy_demand_enfu_subsector_total_pj_inen_fuel_kerosene', 'energy_demand_enfu_subsector_total_pj_inen_fuel_hydrocarbon_gas_liquids', 'energy_demand_enfu_subsector_total_pj_trns_fuel_other', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_diesel', 'energy_demand_enfu_subsector_total_pj_inen_fuel_electricity', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_nuclear', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_solar', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_biomass', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_coke', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_oil', 'energy_demand_enfu_subsector_total_pj_trns_fuel_wind', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_electricity', 'energy_demand_enfu_subsector_total_pj_trns_fuel_coal', 'energy_demand_enfu_subsector_total_pj_inen_fuel_wind', 'energy_demand_enfu_subsector_total_pj_trns_fuel_biogas', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_kerosene', 'energy_demand_enfu_subsector_total_pj_trns_fuel_ocean', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_wind', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_ocean', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_hydropower', 'energy_demand_enfu_subsector_total_pj_trns_fuel_hydrogen', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_crude', 'energy_demand_enfu_subsector_total_pj_inen_fuel_solar', 'energy_demand_enfu_subsector_total_pj_inen_fuel_biogas', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_coke', 'energy_demand_enfu_subsector_total_pj_inen_fuel_hydrogen', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_waste', 'energy_demand_enfu_subsector_total_pj_inen_fuel_waste', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_natural_gas', 'energy_demand_enfu_subsector_total_pj_trns_fuel_coke', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_hydrocarbon_gas_liquids', 'energy_demand_enfu_subsector_total_pj_inen_fuel_gasoline', 'energy_demand_enfu_subsector_total_pj_trns_fuel_furnace_gas', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_natural_gas', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_furnace_gas', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_oil', 'energy_demand_enfu_subsector_total_pj_trns_fuel_kerosene', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_electricity', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_biogas', 'energy_demand_enfu_subsector_total_pj_inen_fuel_geothermal', 'energy_demand_enfu_subsector_total_pj_trns_fuel_hydropower', 'energy_demand_enfu_subsector_total_pj_inen_fuel_diesel', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_other', 'energy_demand_enfu_subsector_total_pj_inen_fuel_other', 'energy_demand_enfu_subsector_total_pj_trns_fuel_nuclear', 'energy_demand_enfu_subsector_total_pj_trns_fuel_natural_gas', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_crude', 'energy_demand_enfu_subsector_total_pj_ccsq_fuel_biogas', 'energy_demand_enfu_subsector_total_pj_trns_fuel_oil', 'energy_demand_enfu_subsector_total_pj_scoe_fuel_biofuels', 'energy_demand_enfu_subsector_total_pj_inen_fuel_hydropower', 'energy_demand_enfu_subsector_ ...
# 2023-09-28 02:50:23,177 - INFO - Running Energy (Fugitive Emissions)
# 2023-09-28 02:50:23,218 - WARNING - Warning in project_enfu_production_and_demands: Variable 'Energy Demand by Fuel in CCSQ' not found in the data frame. Its fuel demands will not be included.
# 2023-09-28 02:50:23,219 - WARNING - Warning in project_enfu_production_and_demands: Variable 'Energy Demand by Fuel in Energy Technology' not found in the data frame. Its fuel demands will not be included.
# 2023-09-28 02:50:23,220 - WARNING - Warning in project_enfu_production_and_demands: Variable 'Energy Demand by Fuel in Industrial Energy' not found in the data frame. Its fuel demands will not be included.
# 2023-09-28 02:50:23,222 - WARNING - Warning in project_enfu_production_and_demands: Variable 'Energy Demand by Fuel in SCOE' not found in the data frame. Its fuel demands will not be included.
# 2023-09-28 02:50:23,223 - WARNING - Warning in project_enfu_production_and_demands: Variable 'Energy Demand by Fuel in Transportation' not found in the data frame. Its fuel demands will not be included.
# 2023-09-28 02:50:23,231 - ERROR - Error running Fugitive Emissions from Energy model: 'float' object has no attribute 'shape'
# 2023-09-28 02:50:23,232 - INFO - Appending Socioeconomic outputs
# 2023-09-28 02:50:23,252 - INFO - Socioeconomic outputs successfully appended.
# 2023-09-28 02:50:23,259 - INFO - Model run for primary_id = 127127 successfully completed in 1.08 seconds (n_tries = 1).
# 2023-09-28 02:50:23,566 - INFO - Table MODEL_OUTPUT successfully appended to database.
# 2023-09-28 02:50:23,568 - INFO -
# ***	 REGION bolivia COMPLETE	***
#
# 2023-09-28 02:50:23,569 - INFO -
# ***	STARTING REGION brazil	***
#
#
# KeyboardInterrupt

# %%
region = "argentina"
df_in = sisepuede.experimental_manager.dict_future_trajectories.get(region).generate_future_from_lhs_vector(None, None, 0, baseline_future_q = True)#True)

# %%
df = df_in[df_in[sisepuede.key_strategy].isin([0])]
ma = sisepuede.model_attributes
me = sisepuede.models.model_energy

l = me.modvar_dict_scoe_fuel_fractions_to_efficiency_factors.values()
l = list(l)

ma.get_standard_variables(
    df,
    me.modvar_scoe_demscalar_heat_energy_demand
)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[63], line 10
#       5 l = me.modvar_dict_scoe_fuel_fractions_to_efficiency_factors.values()
#       6 l = list(l)
#       8 ma.get_standard_variables(
#       9     df,
# ---> 10     l[9]#me.modvar_scoe_demscalar_heat_energy_demand
#      11 )
#
# IndexError: list index out of range

# %%
len(set(sisepuede.database.db.dict_iterative_database_tables.get("MODEL_OUTPUT").columns))
fp = "/Users/jsyme/Documents/Projects/git_jbus/lac_decarbonization/out/sisepuede_run_2023-07-08T01;34;53.827024/sisepuede_run_2023-07-08T01;34;53.827024_output_database.sqlite"

engine = sqlalchemy.create_engine(f"sqlite:///{fp}")

# %%
fp = "/Users/jsyme/Documents/Projects/git_jbus/sisepuede/tmp/nemomod_intermediate_database_ORIG.sqlite"
engine_orig = sqlalchemy.create_engine(f"sqlite:///{fp}")

# %%
df_prod = sqlutil.sql_table_to_df(engine_orig, "vproductionbytechnologyannual")

# %%
df_prod[df_prod["y"].isin(["1001"]) & df_prod["f"].isin(["fuel_coal"])]
# Out:
#             r        t          f     y          val                 solvedtm
# 974  colombia  me_coal  fuel_coal  1001  2534.541279  2023-07-11 22:26:29.493

# %%
ft = sisepuede.experimental_manager.dict_future_trajectories.get(region)
#?ft.generate_future_from_lhs_vector

# %%
region = "brazil"
lhs_design_cur = sisepuede.experimental_manager.dict_lhs_design.get(region)
df_lhs_l, df_lhs_x = lhs_design_cur.retrieve_lhs_tables_by_design(
    0,
    return_type = pd.DataFrame
)
keep_futures = [0, 1]

df_lhs_l = (
    df_lhs_l[
        df_lhs_l[sisepuede.key_future].isin(keep_futures)
    ] 
    if (df_lhs_l is not None) 
    else df_lhs_l
)
# Xs
df_lhs_x = (
    df_lhs_x[
        df_lhs_x[sisepuede.key_future].isin(keep_futures)
    ] 
    if (df_lhs_x is not None) 
    else df_lhs_x
)

# %%
region = "brazil"
df_in = sisepuede.experimental_manager.dict_future_trajectories.get(region).generate_future_from_lhs_vector(None, None, 15, baseline_future_q = False)#True)
df_in = sisepuede.experimental_manager.dict_future_trajectories.get(region).generate_future_from_lhs_vector(
    df_lhs_x, 
    df_row_lhc_sample_l = df_lhs_l, 
    future_id = 1, 
    baseline_future_q = False
)#True)

if False:
    # write to output for testing
    df_in.to_csv(
        os.path.join(sisepuede.file_struct.dir_tmp, "temporary_full_inputs.csv"),
        index = None,
        encoding = "UTF-8"
    )

# %%
model_afolu = sisepuede.models.model_afolu
model_circecon = sisepuede.models.model_circecon
model_energy = sisepuede.models.model_energy
model_ippu = sisepuede.models.model_ippu

import sqlalchemy
# precursor function - can integrate with sisepuede or add in
def format_inputs(
    modvars_extract: Union[List[str], None],
    engine: sqlalchemy.engine.Engine,
    sisepuede_obj: ssp.SISEPUEDE,
    chunk_size: int = 10,
    force_overwrite_existing_primary_keys: bool = False,
    regions: Union[List[str], None] = None,
    table_name_attribute_primary: Union[str, None] = None,
    table_name_output: Union[str, None] = None,
) -> pd.DataFrame:
    """
    Retrieve inputs for merge
    
    Function Arguments
    ------------------
    """
    
    # table names
    table_name_attribute_primary = (
        sisepuede_obj.database.table_name_attribute_primary
        if not isinstance(table_name_attribute_primary, str)
        else table_name_attribute_primary
    )
    table_name_output = (
        sisepuede_obj.database.table_name_output
        if not isinstance(table_name_output, str)
        else table_name_output
    )
    
    # initialize regions
    field_region = sisepuede.key_region
    query = f"SELECT DISTINCT {field_region} FROM {table_name_output};"
    regions_avail = sqlutil.fetch_query_as_df(query, engine)
    
    # set and filter regions
    regions = (
        [x for x in sisepuede_obj.regions if x in regions]
        if sf.islistlike(regions)
        else sisepuede_obj.regions
    )
    regions = (
        [x for x in regions if x in list(regions_avail[field_region])]
        if regions_avail is not None
        else None
    )
    
    # get primary id info
    field_primary = sisepuede.key_primary
    query = f"SELECT DISTINCT {field_primary} FROM {table_name_output};"
    primary_ids_avail = sqlutil.fetch_query_as_df(query, engine)
    primary_ids_avail = (
        primary_ids_avail[field_primary]
        if primary_ids_avail is not None
        else None
    )
    
    
    # return none?
    return_none = regions is None
    return_none |= (len(regions) == 0) if (not return_none) else return_none
    return_none |= not (sf.islistlike(modvars_extract) | (modvars_extract is None))
    return_none |= primary_ids_avail is None
    return_none |= (len(primary_ids_avail) == 0) if (not return_none) else return_none
    
    if return_none:
        return None
    
    
    ##  PRIMARY SELECTION
    
    df_primary_keys = sisepuede_obj.odpt_primary.get_indexing_dataframe(
        key_values = primary_ids_avail
    )
    primary_keys = sisepuede_obj.get_primary_keys(list(df_primary_keys[sisepuede_obj.key_primary]))
    all_designs = list(df_primary_keys[sisepuede_obj.key_design].unique())
    
    # initializations
    df_out = []
    df_out_primary = []
    iterate_outer = 0

    # available indices and resolution
    idt = sisepuede_obj.database.db.dict_iterative_database_tables.get(
        sisepuede_obj.database.table_name_input
    )
    index_conflict_resolution = None
    index_conflict_resolution = "write_replace" if (force_overwrite_existing_primary_keys or (idt.index_conflict_resolution == "write_replace")) else None
    set_available_ids = idt.available_indices


    # 
    fields_ext = None
    if modvars_extract is not None:
        fields_ext = []
        for modvar in modvars_extract:
            fields_ext += sisepuede_obj.model_attributes.build_varlist(
                None,
                modvar
            )
    
    
    for region in regions:

        iterate_inner = 0

        # retrieve region specific future trajectories and lhs design
        future_trajectories_cur = sisepuede_obj.experimental_manager.dict_future_trajectories.get(region)
        lhs_design_cur = sisepuede_obj.experimental_manager.dict_lhs_design.get(region)
        region_out = sisepuede_obj.get_output_region(region)

        sisepuede_obj._log(f"\n***\t BUILDING INPUTS FOR REGION {region}\t***\n", type_log = "info")


        for design in all_designs:

            df_lhs_l, df_lhs_x = lhs_design_cur.retrieve_lhs_tables_by_design(
                design,
                return_type = pd.DataFrame
            )

            # get reduced set of primary keys
            df_primary_keys_cur_design = df_primary_keys[
                df_primary_keys[sisepuede_obj.key_design] == design
            ]
            keep_futures = sorted(list(set(df_primary_keys_cur_design[sisepuede_obj.key_future])))

            # reduce lhs tables - LEs
            df_lhs_l = (
                df_lhs_l[
                    df_lhs_l[sisepuede_obj.key_future].isin(keep_futures)
                ] 
                if (df_lhs_l is not None) 
                else df_lhs_l
            )
            
            # Xs
            df_lhs_x = (
                df_lhs_x[
                    df_lhs_x[sisepuede_obj.key_future].isin(keep_futures)
                ] 
                if (df_lhs_x is not None) 
                else df_lhs_x
            )

            # next, loop over futures
            #  Note that self.generate_future_from_lhs_vector() will return a table for all strategies
            #  associated with the future, so we can prevent redundant calls by running all strategies
            #  that need to be run for a given future

            for future in keep_futures:

                # determine if baseline future and fetch lhs rows
                base_future_q = (future == sisepuede_obj.baseline_future)
                lhs_l = df_lhs_l[df_lhs_l[sisepuede_obj.key_future] == future].iloc[0] if ((df_lhs_l is not None) and not base_future_q) else None
                lhs_x = df_lhs_x[df_lhs_x[sisepuede_obj.key_future] == future].iloc[0] if ((df_lhs_x is not None) and not base_future_q) else None

                # generate the futures and get available strategies
                df_input = future_trajectories_cur.generate_future_from_lhs_vector(
                    lhs_x,
                    df_row_lhc_sample_l = lhs_l,
                    future_id = future,
                    baseline_future_q = base_future_q
                )
                all_strategies = sorted(list(
                    set(df_input[sisepuede_obj.key_strategy])
                ))


                for strategy in all_strategies:

                    # get primary id info
                    df_primary_keys_cur_design_fs = df_primary_keys_cur_design[
                        (df_primary_keys_cur_design[sisepuede_obj.key_future] == future) &
                        (df_primary_keys_cur_design[sisepuede_obj.key_strategy] == strategy)
                    ].reset_index(drop = True)

                    id_primary = df_primary_keys_cur_design_fs[sisepuede_obj.key_primary]
                    id_primary = int(id_primary.iloc[0]) if (len(id_primary) > 0) else None
                    write_q = ((region_out, id_primary) not in set_available_ids) or (index_conflict_resolution == "write_replace")
                    tup = (region_out, id_primary)

                    if (id_primary in primary_keys) and write_q:

                        # filter the data frame down
                        df_input_cur = (
                            df_input[
                                df_input[sisepuede_obj.key_strategy].isin([strategy])
                            ]
                            .copy()
                            .reset_index(drop = True)
                            .sort_values(by = [sisepuede_obj.model_attributes.dim_time_period])
                            .drop([x for x in df_input.columns if x in sisepuede_obj.keys_index], axis = 1)
                        )
                        
                        if fields_ext is not None:
                            df_input_cur.drop(
                                [
                                    x for x in df_input_cur.columns 
                                    if (x not in fields_ext)
                                    & (x != sisepuede_obj.model_attributes.dim_time_period) 
                                ], 
                                axis = 1,
                                inplace = True
                            )

                        df_input_cur = sf.add_data_frame_fields_from_dict(
                            df_input_cur,
                            {
                                sisepuede_obj.key_region: region_out,
                                sisepuede_obj.key_primary: id_primary
                            },
                            prepend_q = True
                        )
                        df_out.append(df_input_cur)
        

    df_out = (
        pd.concat(df_out, axis = 0).reset_index(drop = True)
        if len(df_out) > 0
        else None
    )
    
    return df_out



def get_modvars_to_save(
) -> List[str]:

    # get model variables to keep
    modvars = []
    for subsec in ["Economy", "General"]:
        modvars += sisepuede.model_attributes.get_subsector_variables(subsec, var_type = "input")[1]
    

    ##  AFOLU variables
    
    modvars += [
        model_afolu.modvar_agrc_emissions_ch4_rice,
        model_afolu.modvar_agrc_frac_residues_removed,
        model_afolu.modvar_agrc_frac_no_till, # conservation ag
        model_afolu.modvar_lndu_emissions_conv,
        model_afolu.modvar_lndu_frac_pastures_improved,
        model_afolu.modvar_lsmm_rf_biogas,
        model_afolu.modvar_lvst_ef_ch4_ef,
    ]
    
    modvars += model_afolu.modvar_list_lvst_mm_fractions
    
        
    ##  CircularEconomy variables
    modvars += [
        v.get("treatment_fraction") 
        for v in model_circecon.dict_trww_categories_to_wali_fraction_variables.values()
    ]
    
    modvars += [
        model_circecon.modvar_trww_rf_biogas_recovered,
        model_circecon.modvar_waso_frac_landfill_gas_ch4_to_energy,
        model_circecon.modvar_waso_frac_recovered_for_energy_incineration_isw,
        model_circecon.modvar_waso_frac_recovered_for_energy_incineration_msw,
        model_circecon.modvar_waso_rf_landfill_gas_recovered,
        model_circecon.modvar_waso_waste_per_capita_scalar
    ]
    
    
    ##  Energy variables
    
    modvars += [
        model_energy.modvar_fgtv_frac_non_fugitive_flared,
        model_energy.modvar_fgtv_frac_reduction_fugitive_leaks,
        model_energy.modvar_inen_demscalar,
        model_energy.modvar_enfu_efficiency_factor_industrial_energy,

        # SCOE
        model_energy.modvar_scoe_demscalar_elec_energy_demand,
        model_energy.modvar_scoe_demscalar_heat_energy_demand,
        model_energy.modvar_scoe_efficiency_fact_heat_en_coal,
        model_energy.modvar_scoe_efficiency_fact_heat_en_diesel,
        model_energy.modvar_scoe_efficiency_fact_heat_en_electricity,
        model_energy.modvar_scoe_efficiency_fact_heat_en_gasoline,
        model_energy.modvar_scoe_efficiency_fact_heat_en_hydrogen,
        model_energy.modvar_scoe_efficiency_fact_heat_en_kerosene,
        model_energy.modvar_scoe_efficiency_fact_heat_en_natural_gas,
        model_energy.modvar_scoe_efficiency_fact_heat_en_hgl,
        model_energy.modvar_scoe_efficiency_fact_heat_en_solid_biomass,
        
        # TRNS
        model_energy.modvar_trns_fuel_efficiency_biofuels,
        model_energy.modvar_trns_fuel_efficiency_diesel,
        model_energy.modvar_trns_fuel_efficiency_gasoline,
        model_energy.modvar_trns_fuel_efficiency_hgl,
        model_energy.modvar_trns_fuel_efficiency_hydrogen,
        model_energy.modvar_trns_fuel_efficiency_kerosene,
        model_energy.modvar_trns_fuel_efficiency_natural_gas,
        model_energy.modvar_trns_electrical_efficiency
    ]
    
    ##  IPPU variables
    
    modvars += [
        model_ippu.modvar_ippu_clinker_fraction_cement,
        model_ippu.modvar_ippu_capture_efficacy_co2,
        model_ippu.modvar_ippu_capture_prevalence_co2,
        model_ippu.modvar_ippu_scalar_production
    ]
    
    # add in FC emission factors
    modvars += sum(model_ippu.dict_fc_ef_modvars_by_type.values(), [])
    
    
    
    
    return modvars

# %%
attr_strat = sa.model_attributes.dict_attributes.get("dim_strategy_id")
attr_strat_code = sa.model_attributes.dict_attributes.get("strategy_code")
set(attr_strat.table[attr_strat_code.key]) - set(attr_strat_code.key_values)
# Out:
# {'AGRC:INC_CONSERVATION_AGRICULTURE', 'FRST:DEC_DEFORESTATION'}

# %%
import sql_utilities as sqlutil

vars_extract = sisepuede.model_attributes.build_varlist("Energy Technology", "NemoMod Discounted Capital Investment")
df_out = sisepuede.read_output(None)
engine = sqlalchemy.create_engine(f"sqlite:///{sisepuede.fp_base_output_raw}.sqlite")


# check output directory 
dir_pkg = os.path.join(sisepuede.file_struct.dir_out, f"sisepuede_summary_results_run_{sisepuede.id_fs_safe}")
os.makedirs(dir_pkg) if not os.path.exists(dir_pkg) else None



# add in input variables
modvars_save = get_modvars_to_save()
df_in_merge = format_inputs(modvars_save, engine, sisepuede) # TEMP


subsectors = []
for sector in sorted(list(set(sisepuede.model_attributes.all_sectors))):#["Energy", "IPPU", ]:
    subsectors += sisepuede.model_attributes.get_sector_subsectors(sector)
attr_subsec = sisepuede.model_attributes.dict_attributes.get("abbreviation_subsector")
dict_subsector_name_to_abv = attr_subsec.field_maps.get(f"subsector_to_{attr_subsec.key}")


# index fields
fields_ind = [
    sisepuede.key_primary,
    sisepuede.key_region,
    sisepuede.key_time_period
]


# build variable extract
vars_extract += [f"emission_co2e_subsector_total_{dict_subsector_name_to_abv.get(x)}" for x in subsectors]
for subsector in subsectors:
    modvars_cur = sisepuede.model_attributes.get_subsector_variables(
        subsector,
        var_type = "output"
    )[1]

    vars_cur = sum([sisepuede.model_attributes.dict_model_variables_to_variables.get(x) for x in modvars_cur], [])
    vars_extract += vars_cur
    
vars_extract += [x for x in df_in_merge.columns if x not in fields_ind]



# export outputs only before merge
flds_ind_out = [x for x in fields_ind if x in df_out.columns]
flds_sort_out = sorted([x for x in vars_extract if x in df_out.columns])

df_out[flds_ind_out + flds_sort_out].to_csv(
    os.path.join(dir_pkg, f"sisepuede_results_{sisepuede.id_fs_safe}_WIDE_OUTPUTS_ONLY.csv"),
    index = None,
    encoding = "UTF-8"
)


# export inputs only before merge
flds_ind_in = [x for x in fields_ind if x in df_in_merge.columns]
flds_sort_in = sorted([x for x in vars_extract if x in df_in_merge.columns])

df_in_merge[flds_ind_in + flds_sort_in].to_csv(
    os.path.join(dir_pkg, f"sisepuede_results_{sisepuede.id_fs_safe}_WIDE_INPUTS_ONLY.csv"),
    index = None,
    encoding = "UTF-8"
)


# finally, merge and export
df_melt = pd.merge(
    df_out,
    df_in_merge
)
fields_ext = sorted([x for x in vars_extract if x in df_melt.columns])
df_melt = df_melt[fields_ind + fields_ext];

df_melt.to_csv(
    os.path.join(dir_pkg, f"sisepuede_results_{sisepuede.id_fs_safe}_WIDE_INPUTS_OUTPUTS.csv"),
    index = None,
    encoding = "UTF-8"
)


# melt
"""
df_melt = pd.melt(
    df_melt,
    fields_ind,
    fields_ext
)

    
df_melt.to_csv(
    os.path.join(dir_pkg, f"sisepuede_results_{sisepuede.id_fs_safe}_LONG.csv"),
    index = None,
    encoding = "UTF-8"
)

""";

for tab in ["ATTRIBUTE_PRIMARY", "ATTRIBUTE_STRATEGY"]:
    sisepuede.database.db.read_table(tab).to_csv(
        os.path.join(dir_pkg, f"{tab}.csv"),
        index = None,
        encoding = "UTF-8"
    )


df_primary = sisepuede.odpt_primary.get_indexing_dataframe(sorted(list(df_out[sisepuede.key_primary].unique())))
df_primary.to_csv(
    os.path.join(dir_pkg, f"ATTRIBUTE_PRIMARY.csv"),
    index = None,
    encoding = "UTF-8"
)
# Out:
# 2023-09-11 00:18:26,333 - INFO -
# ***	 BUILDING INPUTS FOR REGION turkey	***

# %%
df_out_all = sisepuede.read_output(None)

# %%
region = "mexico"
future_id = 0
df_out = df_out_all[df_out_all["region"] == region]
df_primary = sisepuede.odpt_primary.get_indexing_dataframe(dict_filt)
#df_in = sisepuede.experimental_manager.dict_future_trajectories.get(region).generate_future_from_lhs_vector(None, None, future_id, True)

if False:
    # write to output for testing
    df_in.to_csv(
        os.path.join(sisepuede.file_struct.dir_tmp, "temporary_full_inputs.csv"),
        index = None,
        encoding = "UTF-8"
    )

# %%
df_in.to_csv(
    os.path.join(sisepuede.file_struct.dir_tmp, "temporary_full_inputs.csv"),
    index = None,
    encoding = "UTF-8"
)

# %%
import sqlalchemy
import sql_utilities as squ
fp = "/Users/jsyme/Documents/Projects/git_jbus/lac_decarbonization/out/sisepuede_run_2023-07-05T02;43;25.818306/sisepuede_run_2023-07-05T02;43;25.818306_output_database.sqlite"
engine = sqlalchemy.create_engine(f"sqlite:///{fp}")
df = squ.sql_table_to_df(engine, "MODEL_OUTPUT")

# %%
regions = sc.Regions(sa.model_attributes)

# %%
def check_model_results2(#self,
    df_results: pd.DataFrame,
    verification_function: Callable,
    epsilon: float = 10**(-6),
    fields_check: Union[List[str], str, None] = None,
    fields_index: Union[List[str], None] = None,
    ignore_nas: bool = False,
    output_only: bool = True,
    thresholds: Tuple[float, float] = (10**(-5), 10**6),
) -> Union[bool, None]:
    """
    Verify numerical integrity of results by looking for fields that include 
        extreme outliers based on the skew function defined. 

    Returns:
        * True: if *no* columnar values of verification_function are outside
            acceptable bounds as defined by thresholds
        * False: if *any* columnar values of verification_function are 
            outside acceptable bounds as defined by thresholds
        * None: if any function input elements are misspecified

    Function Arguments
    ------------------
    - df_results: data frame containing raw output results to verify
    - verification_function: function that is applied along axis to verify 
        values and compare against thresholds

    Keyword Arguments
    ------------------
    - epsilon: numerical value used to determine error in sf.vec_bounds 
        comparison
    - fields_check: optional specification of:
        * subset of fields to check (listlike)
        * "emissions_output" (to only check emissions output fields) 
            * NOT SUPPORTED AT MOMENT
        * "emissions_output_subsector_aggregate" (to only check subsector
            emission aggregate fields) 
        * None (to check all fields not associated with fields_ind)
        * NOTE: If any elements intersect with fields_ind, fields_ind takes 
            priority
    - fields_index: fields to treat as index fields (exempt from checking). 
        If None, check every field in the data frame. If None, uses all 
        indices 
    - ignore_nas: ignore any nas produced by verification function
    - output_only: check only output fields
    - thresholds: Tuple specifying lower and upper limits of 
        verification_function value
    """

    # check fields and threshold specification
    return_none = not (thresholds[0] < thresholds[1])
    return_none |= not isinstance(df_results, pd.DataFrame)
    return_none |= not (
        (sf.islistlike(fields_index) or (fields_index is None))
        if not isinstance(fields_index, str)
        else (fields_index.lower() in ["emissions_output", "emissions_output_subsector_aggregate"])
    )
    return_none |= not isinstance(verification_function, Callable)
    if return_none:
        return None

    # set index and check fields; return True if no valid check fields are found
    fields_index = (
        [
            x for x in sisepuede.model_attributes.sort_ordered_dimensions_of_analysis
            if x in df_results.columns 
        ]
        if fields_index is None
        else fields_index
    )
    fields_index = [x for x in fields_index if (x in df_results.columns)]

    # set fields to check
    fields_check = (
        fields_check
        if not isinstance(fields_check, str)
        else (
            sisepuede.model_attributes.get_all_subsector_emission_total_fields()
            if fields_check == "emissions_output_subsector_aggregate"
            else None
        )
    )
    fields_check = (
        [x for x in df_results.columns if x not in fields_index]
        if not sf.islistlike(fields_check)
        else [x for x in fields_check if (x not in fields_index) and (x in df_results.columns)]
    )
    fields_check = (
        [x for x in fields_check if x in sisepuede.model_attributes.all_variables_output]
        if output_only
        else fields_check
    )
    if len(fields_check) == 0:
        return True


    # apply verification function to columns, then determine if any values fall outside of specified thresholds
    arr_verify = np.array(df_results[fields_check])    
    out = np.abs(np.apply_along_axis(verification_function, 0, arr_verify))
    out = out[out != 0.0]

    # bound values
    out_compare = sf.vec_bounds(out, thresholds)

    vec_thresh_discrepancy = np.abs(out - out_compare)
    vec_thresh_discrepancy = (
        vec_thresh_discrepancy[~np.isnan(vec_thresh_discrepancy)]
        if ignore_nas
        else vec_thresh_discrepancy
    )

    check_val = (vec_thresh_discrepancy.max() <= epsilon)

    return check_val

# %%
check_model_results2(
    df_filt_intervention[
        [x for x in df_filt_intervention.columns if ("emission_co2e_subsector_total" in x)]
    ],
    sf.mean_median_ratio,
    thresholds = (10**(-5), 10**4.5)
)
# Out:
# False

# %%
#idt_output = sisepuede.database.db.dict_iterative_database_tables.get("MODEL_OUTPUT")
#idt_output._drop_indices([("colombia", 125125)])
# get_dims_from_key
# get_indexing_dataframe_from_primary_key
#sisepuede.experimental_manager.primary_key_database.get_indexing_dataframe_from_primary_key([58274])

region = "india"
df_out = df_out_all[
    df_out_all[sisepuede.key_region].isin([region])
    & df_out_all[sisepuede.key_primary].isin([14014])
]
df_out[[x for x in df_out.columns if x.startswith("emission_co2e_") & ("agrc" in x)]]
# Out:
#     emission_co2e_ch4_agrc_anaerobicdom_rice  \
# 36                                 29.159986
# 37                                 29.110760
# 38                                 29.038099
# 39                                 28.994731
# 40                                 28.934985
# 41                                 28.859010
# 42                                 28.766979
# 43                                 28.659091
# 44                                 28.535572
# 45                                 28.396669
# 46                                 28.242655
# 47                                 28.038118
# 48                                 27.789864
# 49                                 27.506859
# 50                                 27.199534
# 51                                 26.878930
# 52                                 26.555886
# 53                                 26.239932
# 54                                 25.938819
# 55                                 25.658119
# 56                                 25.401087
# 57                                 25.168111
# 58                                 24.958205
# 59                                 24.769014
# 60                                 24.597316
# 61                                 24.439504
# 62                                 24.289800
# 63                                 24.145295
# 64                                 24.003590
# 65                                 23.862845
# 66                                 23.721757
# 67                                 23.573367
# 68                                 23.419371
# 69                                 23.261103
# 70                                 23.099587
# 71                                 22.935597
#
#     emission_co2e_ch4_agrc_biomass_burning  \
# 36                                0.819290
# 37                                0.824629
# 38                                0.870561
# 39                                0.930550
# 40                                0.937869
# 41                                1.014162
# 42                                1.027097
# 43                                1.039611
# 44                                1.051686
# 45                                1.063306
# 46                                1.074454
# 47                                1.082907
# 48                                1.088934
# 49                                1.092976
# 50                                1.095607
# 51                                1.097488
# 52                                1.099386
# 53                                1.101967
# 54                                1.105801
# 55                                1.111323
# 56                                1.118810
# 57                                1.128495
# 58                                1.140321
# 59                                1.154102
# 60                                1.169563
# 61                                1.186379
# 62                                1.204281
# 63                                1.222915
# 64                                1.241968
# 65                                1.261182
# 66                                1.280358
# 67                                1.299224
# 68                                1.317704
# 69                                1.335758
# 70                                1.353375
# 71                                1.370557
#
#     emission_co2e_co2_agrc_biomass_bevs_and_spices  \
# 36                                        4.182394
# 37                                        4.175333
# 38                                        4.164912
# 39                                        4.158691
# 40                                        4.150122
# 41                                        4.139225
# 42                                        4.126025
# 43                                        4.110551
# 44                                        4.092835
# 45                                        4.072912
# 46                                        4.050822
# 47                                        4.034010
# 48                                        4.024008
# 49                                        4.021759
# 50                                        4.027556
# 51                                        4.041053
# 52                                        4.061915
# 53                                        4.088821
# 54                                        4.120103
# 55                                        4.153933
# 56                                        4.188501
# 57                                        4.223099
# 58                                        4.256201
# 59                                        4.286603
# 60                                        4.313462
# 61                                        4.336288
# 62                                        4.355700
# 63                                        4.371481
# 64                                        4.383644
# 65                                        4.392359
# 66                                        4.397897
# 67                                        4.400809
# 68                                        4.401248
# 69                                        4.399414
# 70                                        4.395520
# 71                                        4.389778
#
#     emission_co2e_co2_agrc_biomass_fruits  \
# 36                               3.514339
# 37                               3.508406
# 38                               3.499649
# 39                               3.494422
# 40                               3.487222
# 41                               3.478065
# 42                               3.466974
# 43                               3.453971
# 44                               3.439085
# 45                               3.422344
# 46                               3.403783
# 47                               3.402704
# 48                               3.419789
# 49                               3.454422
# 50                               3.504775
# 51                               3.568000
# 52                               3.641071
# 53                               3.720075
# 54                               3.801037
# 55                               3.880258
# 56                               3.954594
# 57                               4.022465
# 58                               4.082109
# 59                               4.132545
# 60                               4.173494
# 61                               4.205251
# 62                               4.229141
# 63                               4.245876
# 64                               4.256319
# 65                               4.261377
# 66                               4.261914
# 67                               4.258611
# 68                               4.252075
# 69                               4.242827
# 70                               4.231292
# 71                               4.217815
#
#     emission_co2e_co2_agrc_biomass_nuts  \
# 36                             2.475018
# 37                             2.470840
# 38                             2.464673
# 39                             2.460992
# 40                             2.455921
# 41                             2.449472
# 42                             2.441661
# 43                             2.432504
# 44                             2.422020
# 45                             2.410230
# 46                             2.397158
# 47                             2.387718
# 48                             2.382729
# 49                             2.382624
# 50                             2.387427
# 51                             2.396776
# 52                             2.410303
# 53                             2.427084
# 54                             2.446020
# 55                             2.465949
# 56                             2.485763
# 57                             2.504989
# 58                             2.522752
# 59                             2.538394
# 60                             2.551487
# 61                             2.561820
# 62                             2.569742
# 63                             2.575219
# 64                             2.578337
# 65                             2.579266
# 66                             2.578219
# 67                             2.575362
# 68                             2.570888
# 69                             2.564983
# 70                             2.557821
# 71                             2.549557
#
#     emission_co2e_co2_agrc_biomass_other_woody_perennial  \
# 36                                           4.349984
# 37                                           4.342640
# 38                                           4.331801
# 39                                           4.325331
# 40                                           4.316419
# 41                                           4.305085
# 42                                           4.291356
# 43                                           4.275262
# 44                                           4.256836
# 45                                           4.236115
# 46                                           4.213139
# 47                                           4.194726
# 48                                           4.181998
# 49                                           4.175569
# 50                                           4.175511
# 51                                           4.181383
# 52                                           4.192669
# 53                                           4.208162
# 54                                           4.226418
# 55                                           4.245912
# 56                                           4.265185
# 57                                           4.283478
# 58                                           4.299650
# 59                                           4.312855
# 60                                           4.322557
# 61                                           4.328506
# 62                                           4.330967
# 63                                           4.329972
# 64                                           4.325709
# 65                                           4.318459
# 66                                           4.308550
# 67                                           4.295839
# 68                                           4.280752
# 69                                           4.263661
# 70                                           4.244878
# 71                                           4.224658
#
#     emission_co2e_co2_agrc_soil_carbon_organic_soils  \
# 36                                        294.430184
# 37                                        293.933149
# 38                                        293.199481
# 39                                        292.761592
# 40                                        292.158336
# 41                                        291.391207
# 42                                        290.461964
# 43                                        289.372619
# 44                                        288.125438
# 45                                        286.722929
# 46                                        285.167838
# 47                                        283.209756
# 48                                        280.953686
# 49                                        278.515750
# 50                                        276.014697
# 51                                        273.562650
# 52                                        271.280067
# 53                                        269.243211
# 54                                        267.499999
# 55                                        266.069429
# 56                                        264.943942
# 57                                        264.128112
# 58                                        263.569415
# 59                                        263.205747
# 60                                        262.972670
# 61                                        262.809370
# 62                                        262.683685
# 63                                        262.543276
# 64                                        262.348743
# 65                                        262.073076
# 66                                        261.700043
# 67                                        261.201073
# 68                                        260.578502
# 69                                        259.838551
# 70                                        258.989597
# 71                                        258.040931
#
#     emission_co2e_n2o_agrc_biomass_burning  \
# 36                                0.207840
# 37                                0.209195
# 38                                0.220847
# 39                                0.236065
# 40                                0.237922
# 41                                0.257276
# 42                                0.260558
# 43                                0.263732
# 44                                0.266796
# 45                                0.269744
# 46                                0.272572
# 47                                0.274716
# 48                                0.276245
# 49                                0.277270
# 50                                0.277938
# 51                                0.278415
# 52                                0.278896
# 53                                0.279551
# 54                                0.280524
# 55                                0.281925
# 56                                0.283824
# 57                                0.286281
# 58                                0.289281
# 59                                0.292777
# 60                                0.296699
# 61                                0.300965
# 62                                0.305507
# 63                                0.310234
# 64                                0.315067
# 65                                0.319941
# 66                                0.324806
# 67                                0.329592
# 68                                0.334280
# 69                                0.338860
# 70                                0.343329
# 71                                0.347688
#
#     emission_co2e_n2o_agrc_crop_residues  emission_co2e_subsector_total_agrc
# 36                              9.965633                          349.104667
# 37                              9.901869                          348.476822
# 38                             10.418495                          348.208518
# 39                             11.360554                          348.722929
# 40                             11.418250                          348.097045
# 41                             12.362632                          348.256134
# 42                             12.520319                          347.362931
# 43                             12.672877                          346.280218
# 44                             12.820090                          345.010357
# 45                             12.961750                          343.555999
# 46                             13.097654                          341.920074
# 47                             13.204042                          339.828697
# 48                             13.284708                          337.401962
# 49                             13.345202                          334.772432
# 50                             13.392377                          332.075422
# 51                             13.433822                          329.438516
# 52                             13.478375                          326.998568
# 53                             13.533255                          324.842058
# 54                             13.604422                          323.023142
# 55                             13.696183                          321.563031
# 56                             13.811003                          320.452708
# 57                             13.951384                          319.696413
# 58                             14.116041                          319.233975
# 59                             14.302343                          318.994380
# 60                             14.506776                          318.904023
# 61                             14.725400                          318.893485
# 62                             14.955540                          318.924363
# 63                             15.193025                          318.937292
# 64                             15.434272                          318.887648
# 65                             15.676403                          318.744910
# 66                             15.917255                          318.490801
# 67                             16.154116                          318.087993
# 68                             16.386135                          317.540955
# 69                             16.612901                          316.858058
# 70                             16.834318                          316.049717
# 71                             17.050500                          315.127081

# %%
region = "turkey"

# 3008, 3009, 303
strat_id, strat_id_intervention = 5009, 5009
future_id = 0
df_in = sisepuede.experimental_manager.dict_future_trajectories.get(region).generate_future_from_lhs_vector(None, None, future_id, True)
df_out = df_out_all[df_out_all[sisepuede.key_region] == region]
# baseline
dict_filt2 = {}
for k in dict_filt.keys():
    val = dict_filt.get(k) if (k != sisepuede.key_strategy) else [strat_id]
    val = [future_id] if (k == sisepuede.key_future) else val
    dict_filt2.update({k: val[0]})

primary_id = sisepuede.odpt_primary.get_key_value(**dict_filt2)
df_filt = df_out[
    df_out[sisepuede.key_primary].isin([primary_id])
]

# intervention
dict_filt_invervention = {}
for k in dict_filt.keys():
    val = dict_filt.get(k) if (k != sisepuede.key_strategy) else [strat_id_intervention]
    val = [future_id] if (k == sisepuede.key_future) else val
    dict_filt_invervention.update({k: val[0]})
primary_id_intervention = sisepuede.odpt_primary.get_key_value(**dict_filt_invervention)
df_filt_intervention = df_out[
    df_out[sisepuede.key_primary].isin([primary_id_intervention])
]


df_in_filt = df_in[
    df_in[sisepuede.key_strategy].isin([strat_id])
]

df_in_filt_intervention = df_in[
    df_in[sisepuede.key_strategy].isin([strat_id_intervention])
]


fig, ax = plt.subplots(2, 1, figsize = (15, 15))
#ax[0].set_ylim(-150, 350)
#ax[0].set_ylim(0, 900)
#ax[1].set_ylim(0, 900)

palette_func = plt.cm.tab20#plt.cm.hsv

flds = [sisepuede.key_time_period]
if False:
    flds += [
        x for x in df_filt.columns 
        if x.startswith("emission_co2e_subsector_total") 
        and (
            False
            or ("ccsq" in x) 
            or ("entc" in x)
            or ("enfu" in x)
            or ("fgtv" in x)
            or ("inen" in x)
            or ("scoe" in x)
            or ("trns" in x)
        )
    ]
    
if False:
    flds += [
        x for x in df_filt.columns 
        if x.startswith("emission_co2e_subsector_total") 
        and (
            #True
            ("agrc" in x)
            or ("frst" in x)
            or ("lndu" in x)
            or ("lsmm" in x)
            or ("lvst" in x)
            or ("soil" in x)
            #("entc" in x) 
            #or ("scoe" in x)
            #or ("lsmm" in x)
            #or ("soil" in x)
            #or ("frst" in x)
            #or ("lndu" in x)
        )
    ]
    
if False:
    flds = [x for x in flds if "trns" in x]
    
if True:
    flds += [
        x for x in df_filt.columns 
        if x.startswith("emission_co2e_") 
        and (
            True
            #and ("lvst" in x)
            #or ("fgtv" in x)
            #and ("subsector_total" not in x)
            and ("subsector_total" in x)
            and 
            (
                True
                #("lvst" in x)
                #or ("lsmm" in x)
                #or ("soil" in x)
            )
        )
    ]

if False:
    flds += [
        x for x in df_filt.columns 
        if x.startswith("energy_demand_enfu_") 
        and (
            True
            #("entc" in x)
            #or ("fgtv" in x)
            #("inen" in x)
            & ("subsector" in x)
            & ("electricity" in x)
        )
    ]

if False:
    #flds = [x for x in df_filt.columns if x.startswith("energy_demand_enfu") and ("total" in x) and ("subsector" not in x)]# and (("natural_gas" in x) or ("crude" in x) or ("electricity" in x) or ("hydrogen" in x))]
    cat = "rail_passenger"
    pre = "energy_consumption_trns"
    fld_ignore = f"{pre}_{cat}"
    flds = [sisepuede.key_time_period] + [x for x in df_filt.columns if x.startswith(pre) and (cat in x) and (x != fld_ignore)]
    #flds = [x for x in df_filt.columns if x.startswith("passenger_distance")]

add_total = True
plot_from_modvar = False

if True:

    # AFOLU
    # modvar_plot = sisepuede.models.model_afolu.modvar_lndu_area_by_cat
    # modvar_plot = sisepuede.models.model_afolu.modvar_lndu_area_converted_from_type
    # modvar_plot = sisepuede.models.model_afolu.modvar_lndu_area_by_cat
    # modvar_plot = sisepuede.models.model_afolu.modvar_soil_emissions_co2_urea
    modvar_plot = sisepuede.models.model_afolu.modvar_lvst_pop
    modvar_plot = sisepuede.models.model_afolu.modvar_lvst_adjusted_equivalent_exports

    # modvar_plot = sisepuede.models.model_afolu.modvar_frst_emissions_co2_sequestration
    # modvar_plot = sisepuede.models.model_afolu.modvar_lndu_emissions_conv
    # modvar_plot = sisepuede.models.model_afolu.modvar_lvst_emissions_ch4_ef
    # modvar_plot = sisepuede.models.model_afolu.modvar_lsmm_emissions_ch4
    
    
    # ENERGY
    #modvar_plot = sisepuede.models.model_electricity.modvar_entc_nemomod_emissions_co2_mne
    modvar_plot = sisepuede.models.model_electricity.modvar_entc_nemomod_production_by_technology
    #modvar_plot = sisepuede.models.model_energy.modvar_trns_energy_consumption_total
    #modvar_plot = sisepuede.models.model_energy.modvar_trns_passenger_distance_traveled
    #modvar_plot = sisepuede.models.model_energy.modvar_trns_passenger_distance_traveled
    #modvar_plot = sisepuede.models.model_energy.modvar_trde_demand_pkm
    #modvar_plot = sisepuede.models.model_energy.modvar_trns_mass_distance_traveled
    #modvar_plot = sisepuede.models.model_energy.modvar_fgtv_emissions_ch4
    #modvar_plot = sisepuede.models.model_energy.modvar_enfu_exports_fuel_adjusted
    #modvar_plot = sisepuede.models.model_energy.modvar_enfu_energy_demand_by_fuel_total
    #modvar_plot = sisepuede.models.model_energy.modvar_enfu_energy_demand_by_fuel_trns
    #modvar_plot = sisepuede.models.model_electricity.modvar_entc_nemomod_production_by_technology
    #modvar_plot = sisepuede.models.model_energy.modvar_fgtv_emissions_ch4
    #modvar_plot = sisepuede.models.model_energy.modvar_trns_vehicle_distance_traveled_electricity
    
    #IPPU
    #modvar_plot = sisepuede.models.model_ippu.modvar_ippu_qty_total_production
    
    
    
    # NO INTERVENTION
    
    df = sisepuede.model_attributes.get_standard_variables(
        df_filt,
        modvar_plot
    )
    df = pd.concat([df_filt[[sisepuede.key_time_period]].reset_index(drop = True), df], axis = 1)
    df = df[[x for x in df.columns if ("nuclear" not in x) and ("crude" not in x)]]
    df = df_filt[flds] if (not plot_from_modvar) else df
    if len(df) > 0:
        for k in df.columns:
            vec = np.array(df[k])
            bnds = (0, np.inf) if (vec[-1] >= 0) else (-np.inf, 0)
            if (max(vec) > 0) and (min(vec) < 0):
                k0 = f"{k}_positive"
                k1 = f"{k}_negative"
                df[k0] = sf.vec_bounds(np.array(df[k]), (0, np.inf))
                df[k1] = sf.vec_bounds(np.array(df[k]), (-np.inf, 0))
                df.drop([k], axis = 1, inplace = True)
            else:
                df[k] = sf.vec_bounds(np.array(df[k]), bnds)
    
    m, n = df.shape
    colors = [palette_func(x/n) for x in range(n)]
    
    alpha = 1 if not add_total else 0.75
    df.plot.area(x = sisepuede.key_time_period, ax = ax[0], color = colors, alpha = alpha)
    if add_total:
        df["total"] = df.drop([sisepuede.key_time_period], axis = 1).sum(axis = 1)
        df[[sisepuede.key_time_period, "total"]].plot(x = sisepuede.key_time_period, ax = ax[0], color = "black", linewidth = 5)
    df_plot_noint = df.copy()
        
        
    # INTERVENTION
    
    df = sisepuede.model_attributes.get_standard_variables(
        df_filt_intervention,
        modvar_plot
    )
    df = pd.concat([df_filt_intervention[[sisepuede.key_time_period]].reset_index(drop = True), df], axis = 1)
    df = df[[x for x in df.columns if ("nuclear" not in x) and ("crude" not in x)]]
    df = df_filt_intervention[flds] if (not plot_from_modvar) else df
    
    if False:
        # UNCOMMENT TO USE DIFF
        vec = np.array(df[sisepuede.key_time_period])
        flds = [x for x in df.columns if (x != sisepuede.key_time_period)]
        df = pd.DataFrame(np.array(df_filt_intervention[flds]) - np.array(df_filt[flds]), columns = flds)
        df[sisepuede.key_time_period] = vec

    
    
    for k in df.columns:
        vec = np.array(df[k])
        bnds = (0, np.inf) if (vec[-1] >= 0) else (-np.inf, 0)
        if (max(vec) > 0) and (min(vec) < 0):
            k0 = f"{k}_positive"
            k1 = f"{k}_negative"
            df[k0] = sf.vec_bounds(np.array(df[k]), (0, np.inf))
            df[k1] = sf.vec_bounds(np.array(df[k]), (-np.inf, 0))
            df.drop([k], axis = 1, inplace = True)
        else:
            df[k] = sf.vec_bounds(np.array(df[k]), bnds)
    
    m, n = df.shape
    colors = [palette_func(x/n) for x in range(n)]
    
    alpha = 1 if not add_total else 0.75
    df.plot.area(x = sisepuede.key_time_period, ax = ax[1], color = colors, alpha = alpha)
    if add_total:
        df["total"] = df.drop([sisepuede.key_time_period], axis = 1).sum(axis = 1)
        df[[sisepuede.key_time_period, "total"]].plot(x = sisepuede.key_time_period, ax = ax[1], color = "black", linewidth = 5)
    df_plot_int = df.copy()
    #df.plot(ax = ax[1], color = colors)

# %%
df_filt[["emission_co2e_subsector_total_entc"]]
# Out:
#     emission_co2e_subsector_total_entc
# 0                            18.704226
# 1                            18.221058
# 2                             5.984976
# 3                            19.540498
# 4                            19.723638
# 5                            20.056282
# 6                            20.823536
# 7                            22.130868
# 8                            23.753421
# 9                            24.486811
# 10                           25.090514
# 11                           24.683980
# 12                           24.249945
# 13                           23.788843
# 14                           23.302042
# 15                           22.791850
# 16                           22.274525
# 17                           21.795534
# 18                           21.237571
# 19                           20.667660
# 20                           20.084231
# 21                           19.508963
# 22                           18.920897
# 23                           18.322485
# 24                           17.715738
# 25                           17.102385
# 26                           16.497633
# 27                           15.887458
# 28                           16.203710
# 29                           16.387146
# 30                           16.663291
# 31                           15.242630
# 32                           13.346303
# 33                           11.766999
# 34                           10.546373
# 35                            9.447572

# %%
(
    df_in_filt[
        [
            x for x in df_in_filt.columns
            if True
            & ("scoe" in x)
            & ("consumpinit_scoe_" in x)
        ]
    ]
    .head()
)
# Out:
#      consumpinit_scoe_gj_per_hh_residential_elec_appliances  \
# 504                                          42.790168
# 505                                          43.342112
# 506                                          45.417386
# 507                                          41.509825
# 508                                          43.376854
#
#      consumpinit_scoe_gj_per_hh_residential_heat_energy  \
# 504                                           2.252114
# 505                                           2.281164
# 506                                           2.390389
# 507                                           2.184728
# 508                                           2.282992
#
#      consumpinit_scoe_tj_per_mmmgdp_commercial_municipal_elec_appliances  \
# 504                                         791.052446
# 505                                         790.454777
# 506                                         817.533887
# 507                                         737.320994
# 508                                         759.503863
#
#      consumpinit_scoe_tj_per_mmmgdp_commercial_municipal_heat_energy  \
# 504                                          41.634339
# 505                                          41.602883
# 506                                          43.028099
# 507                                          38.806368
# 508                                          39.973888
#
#      consumpinit_scoe_tj_per_mmmgdp_other_se_elec_appliances  \
# 504                                                0.0
# 505                                                0.0
# 506                                                0.0
# 507                                                0.0
# 508                                                0.0
#
#      consumpinit_scoe_tj_per_mmmgdp_other_se_heat_energy
# 504                                                0.0
# 505                                                0.0
# 506                                                0.0
# 507                                                0.0
# 508                                                0.0

# %%
(
    df_filt[
        [
            x for x in df_filt.columns
            if True
            & ("household" in x)
        ]
    ]
    .head()
)
# Out:
#    qty_gnrl_households
# 0             18781464
# 1             19118133
# 2             19452362
# 3             19772281
# 4             20062912

# %%
# residential fuel consumption
x = 18781464*2.252114/1000
x_res_inv = 587205
x_res_inv/x
# Out:
# 13.882571931494374

# %%
x_res_inv
# Out:
# 587205

# %%
df_tmp = pd.read_csv("/Users/jsyme/Documents/Projects/git_jbus/sisepuede_launcher/colombia_example.csv")

# %%
df_tmp[df_tmp["primary_id"].isin([125857])][
    [x for x in df_tmp.columns if x.startswith("emission_co2e_subsector_total")]
].sum(axis = 1).plot()
# Out:
# <AxesSubplot: >

# %%
#df_in_filt[[x for x in df_in_filt.columns if x.startswith("exports_lvst")]]
df_filt[[x for x in df_filt.columns if x.startswith("emission_co2e_subsector")]].tail().sum(axis = 1)
# Out:
# 31    3292.424960
# 32    3349.195064
# 33    3405.958095
# 34    3462.737743
# 35    3497.690592
# dtype: float64

# %%
#df_filt[[x for x in df_filt.columns if ("emission_co2e" in x) & ("frst" in x)]]

# %%
area = 196437500
0.0006*0.38*area
# Out:
# 44787.75

# %%
df_filt[
    [x for x in df_filt.columns if ("emission_co2e_co2" in x) and ("metal" in x)]
].tail().sum(axis = 1)
# Out:
# 2551    174.267899
# 2552    178.834690
# 2553    183.280485
# 2554    187.601053
# 2555    191.792604
# dtype: float64

# %%
sa.model_attributes.get_standard_variables(
    df_filt,
    model_afolu.modvar_lndu_area_converted_from_type
).head()
# Out:
#    area_lndu_conversion_from_croplands  \
# 0                         34259.528106
# 1                         34737.660993
# 2                         35215.960720
# 3                         35690.757330
# 4                         36158.226832
#
#    area_lndu_conversion_from_forests_mangroves  \
# 0                                  1290.749926
# 1                                  1387.556829
# 2                                  1488.422663
# 3                                  1593.393318
# 4                                  1702.510773
#
#    area_lndu_conversion_from_forests_primary  \
# 0                               1.046884e+06
# 1                               1.053775e+06
# 2                               1.059969e+06
# 3                               1.065468e+06
# 4                               1.070278e+06
#
#    area_lndu_conversion_from_forests_secondary  \
# 0                                   143.758774
# 1                                   226.819061
# 2                                   312.865803
# 3                                   401.646669
# 4                                   492.909864
#
#    area_lndu_conversion_from_grasslands  area_lndu_conversion_from_other  \
# 0                         139029.789638                     10351.816780
# 1                         140721.691235                     11502.495387
# 2                         142419.581860                     12694.055942
# 3                         144123.231522                     13924.976806
# 4                         145832.664332                     15193.738765
#
#    area_lndu_conversion_from_settlements  area_lndu_conversion_from_wetlands
# 0                            1665.974155                         5988.452273
# 1                            1813.990762                         6188.327866
# 2                            1964.014433                         6386.192557
# 3                            2115.686503                         6581.985642
# 4                            2268.660211                         6775.649455

# %%
sa.model_attributes.get_standard_variables(
    df_filt_intervention,
    model_afolu.modvar_lndu_area_converted_to_type
).tail()
# Out:
#     area_lndu_conversion_to_croplands  \
# 31                      157357.062645
# 32                      153095.345389
# 33                      148612.159926
# 34                      143942.036712
# 35                      142520.597925
#
#     area_lndu_conversion_to_forests_mangroves  \
# 31                               37970.044233
# 32                               37938.279233
# 33                               37884.350339
# 34                               37805.697454
# 35                               37955.452220
#
#     area_lndu_conversion_to_forests_primary  \
# 31                                      0.0
# 32                                      0.0
# 33                                      0.0
# 34                                      0.0
# 35                                      0.0
#
#     area_lndu_conversion_to_forests_secondary  \
# 31                               1.097878e+06
# 32                               1.040758e+06
# 33                               9.809019e+05
# 34                               9.197510e+05
# 35                               9.058818e+05
#
#     area_lndu_conversion_to_grasslands  area_lndu_conversion_to_other  \
# 31                         2541.747847                   63277.246174
# 32                         2624.657364                   47784.764492
# 33                         2711.027314                   32351.521687
# 34                         2796.984229                   16964.996037
# 35                         2808.063557                   16960.071252
#
#     area_lndu_conversion_to_settlements  area_lndu_conversion_to_wetlands
# 31                           838.109221                               0.0
# 32                           474.779753                               0.0
# 33                           214.253740                               0.0
# 34                            56.339077                               0.0
# 35                            56.322722                               0.0

# %%
df_filt_intervention[
    [x for x in df_filt_intervention.columns if ("emission_co2e_co2" in x) and ("metal" in x)]
].tail().sum(axis = 1)
# Out:
# 2731    58.191944
# 2732    56.074297
# 2733    53.874267
# 2734    51.603679
# 2735    49.274082
# dtype: float64

# %%
df_filt[
    [x for x in df_filt.columns if ("emission_co2e" in x) and ("metal" in x)]
].sum(axis = 1)
# Out:
# 2520     66.733555
# 2521     62.952373
# 2522     64.726351
# 2523     68.608067
# 2524     70.595169
# 2525     72.326768
# 2526     74.194818
# 2527     76.067225
# 2528     77.930395
# 2529     79.782779
# 2530     81.622862
# 2531     85.791599
# 2532     89.976830
# 2533     94.171132
# 2534     98.367276
# 2535    102.558248
# 2536    107.067163
# 2537    111.561497
# 2538    116.033872
# 2539    120.477204
# 2540    124.884707
# 2541    129.532077
# 2542    134.131095
# 2543    138.675092
# 2544    143.157754
# 2545    147.573127
# 2546    152.303259
# 2547    156.951171
# 2548    161.511015
# 2549    165.977362
# 2550    170.345187
# 2551    175.049285
# 2552    179.636553
# 2553    184.102282
# 2554    188.442222
# 2555    192.652568
# dtype: float64
