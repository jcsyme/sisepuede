# %%
import warnings
warnings.filterwarnings("ignore")

import os, os.path
import numpy as np
import pandas as pd
import model_attributes as ma
from attribute_table import AttributeTable
import model_afolu as mafl
import model_ippu as mi
import model_circular_economy as mc
import model_energy as me
import model_electricity as ml
import model_socioeconomic as se
from model_socioeconomic import Socioeconomic
import pathlib
import setup_analysis as sa
import sisepuede as ssp
import support_classes as sc
import support_functions as sf
import importlib
import time
import matplotlib.pyplot as plt
import sql_utilities as sq
from typing import *
import sqlalchemy
import sql_utilities as sqlutil
import time
importlib.reload(ma)
importlib.reload(sa)
importlib.reload(sf)
importlib.reload(mafl)
importlib.reload(mc)
importlib.reload(mi)
importlib.reload(me)
importlib.reload(se)
importlib.reload(ml)
# Out:
# MISSIONSEARCHNOTE: As of 2023-10-06, there is a temporary solution implemeted in ModelAttributes.get_variable_to_simplex_group_dictionary() to ensure that transition probability rows are enforced on a simplex.
#
# FIX THIS ASAP TO DERIVE PROPERLY.
# MISSIONSEARCHNOTE: As of 2023-10-06, there is a temporary solution implemeted in ModelAttributes.get_variable_to_simplex_group_dictionary() to ensure that transition probability rows are enforced on a simplex.
#
# FIX THIS ASAP TO DERIVE PROPERLY.
# <module 'model_electricity' from '/Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_electricity.py'>

# %%
import model_attributes_new as man
import model_variable as mv
import units_manager as um

# %%
fp = "/Users/jsyme/Documents/Projects/git_jbus/sisepuede/out/sisepuede_summary_results_run_sisepuede_run_2024-02-10T17;45;35.578004/sisepuede_results_sisepuede_run_2024-02-10T17;45;35.578004_WIDE_INPUTS_OUTPUTS.csv"
df_test = pd.read_csv(fp)
df_base = (
    df_test[
        df_test["primary_id"].isin([14014])
    ]
    .reset_index(drop = True)
)

# %%
importlib.reload(sf)
importlib.reload(mv)
importlib.reload(um)
importlib.reload(man)

fp = "/Users/jsyme/Documents/Projects/git_jbus/sisepuede/docs_new/source/csvs"
path = pathlib.Path(fp)
matt_new = man.ModelAttributesNew(
    path, 
    fp_config = path.parents[2].joinpath("sisepuede.config")
)


# modvar = matt_new.dict_variables.get("Volumetric Energy Density")
# modvar.get_property("subsector")
unit_energy = matt_new.get_unit("energy")
unit_power = matt_new.get_unit("power")
unit_power.get_unit_key("none")

# %%
matt_new.get_variable_characteristic(
    ":math:\\text{CH}_4 Crop Anaerobic Decomposition Emission Factor",#mov,
    "unit_area",
)
# Out:
# 'ha'

# %%
matt_new.extract_model_variable(
    df_base,
    mov,#get_variable_from_category
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 matt_new.extract_model_variable(
#       2     df_base,
# ----> 3     mov,#get_variable_from_category
#       4 )
#
# NameError: name 'mov' is not defined

# %%
matt_new.get_variable_from_category(
    sa.model_attributes.subsec_name_trde,
    "private_and_public",
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 matt_new.get_variable_from_category(
#       2     sa.model_attributes.subsec_name_trde,
#       3     "private_and_public",
#       4 )
#
# File ~/Documents/Projects/git_jbus/sisepuede/python/model_attributes_new.py:5664, in ModelAttributesNew.get_variable_from_category(self, subsector, category)
#    5661 self.check_subsector(subsector)
#    5663 # get the value from the dictionary
# -> 5664 attr_subsec = self.get_attribute_table(subec)
#    5665 subsec_abv = self.get_subsector_attribute(subsector, "abv_subsector")
#    5666 attr_retrieve = f"{subsec_abv}_variable"
#
# NameError: name 'subec' is not defined

# %%
matt_new.get_subsector_attribute("Transportation Demand", "abv_subsector")
# Out:
# 'trde'

# %%
a = matt_new.get_attribute_table("Transportation Demand").get_attribute(
    "regional",
    "partial_category_ern_trde",
)

print(f"a:\t{a}")
# Out:
# a:	None

# %%
# Out:
#                        category_name cat_transportation_demand  \
# 0     Regional Transportation Demand                  regional
# 1      Freight Transportation Demand                   freight
# 2  Private and Public Transportation        private_and_public
#
#                                          description  data_source  hyperlink  \
# 0  International and domestic civil (passenger an...          NaN        NaN
# 1  Demand for freight transportation. Driven prim...          NaN        NaN
# 2  Transportation for private and public transpor...          NaN        NaN
#
#    notes    partial_category_en_trde  freight_category
# 0    NaN  Passenger-Kilometer Demand                 0
# 1    NaN  Megatonne-Kilometer Demand                 1
# 2    NaN  Passenger-Kilometer Demand                 0

# %%
matt_new.get_variable_characteristic(mov, "unit_area")
# Out:
# 'ha'

# %%
modvar = ":math:\\text{CH}_4 Crop Anaerobic Decomposition Emission Factor"
#modvar = "Unadjusted Land Use Transition Probability"
#modvar = "GDP"
#modvar = "Population"

matt_new.get_variable_characteristic(modvar, "emission_gas")
mov = matt_new.dict_variables.get(modvar)
mov.dict_category_keys
matt_new.get_variable_characteristic(
    mov.name,
    matt_new.varchar_str_unit_length
)

# %%
sa.model_attributes.get_variable_categories("GDP")
mov.name
# Out:
# ':math:\\text{CH}_4 Crop Anaerobic Decomposition Emission Factor'

# %%
#matt_new.get_other_attribute("emission_gas").attribute_table.table

# %%
matt_new.get_gwp("Sulfur Hexflouride", gwp = 20)
# Out:
# 18300.0

# %%
matt_new.get_subsector_attribute(matt_new.subsec_name_enfu, "pycategory_primary")
units_gas = um.Units(
    matt_new.get_other_attribute("emission_gas")
)

units_gas.get_attribute("Methane", "global_warming_potential_20")
# Out:
# 81.2

# %%
cat = matt_new.get_subsector_attribute(matt_new.subsec_name_enfu, "pycategory_primary")
cat = f"cat_{cat}"
matt_new.get_var_dicts_by_shared_category(
    matt_new.subsec_name_scoe,
    cat,
    ["energy_efficiency_variable_by_fuel", "fuel_fraction_variable_by_fuel", "energy_demand_variable_by_fuel"]
)
# Out:
# {'fuel_fraction_variable_by_fuel_to_energy_efficiency_variable_by_fuel': {'SCOE Fraction Heat Energy Demand Hydrogen': 'SCOE Efficiency Factor for Heat Energy from Hydrogen',
#   'SCOE Fraction Heat Energy Demand Diesel': 'SCOE Efficiency Factor for Heat Energy from Diesel',
#   'SCOE Fraction Heat Energy Demand Coal': 'SCOE Efficiency Factor for Heat Energy from Coal',
#   'SCOE Fraction Heat Energy Demand Gasoline': 'SCOE Efficiency Factor for Heat Energy from Gasoline',
#   'SCOE Fraction Heat Energy Demand Kerosene': 'SCOE Efficiency Factor for Heat Energy from Kerosene',
#   'SCOE Fraction Heat Energy Demand Natural Gas': 'SCOE Efficiency Factor for Heat Energy from Natural Gas',
#   'SCOE Fraction Heat Energy Demand Electricity': 'SCOE Efficiency Factor for Heat Energy from Electricity',
#   'SCOE Fraction Heat Energy Demand Solid Biomass': 'SCOE Efficiency Factor for Heat Energy from Solid Biomass',
#   'SCOE Fraction Heat Energy Demand Hydrocarbon Gas Liquids': 'SCOE Efficiency Factor for Heat Energy from Hydrocarbon Gas Liquids'},
#  'energy_efficiency_variable_by_fuel_to_fuel_fraction_variable_by_fuel': {'SCOE Efficiency Factor for Heat Energy from Hydrogen': 'SCOE Fraction Heat Energy Demand Hydrogen',
#   'SCOE Efficiency Factor for Heat Energy from Diesel': 'SCOE Fraction Heat Energy Demand Diesel',
#   'SCOE Efficiency Factor for Heat Energy from Coal': 'SCOE Fraction Heat Energy Demand Coal',
#   'SCOE Efficiency Factor for Heat Energy from Gasoline': 'SCOE Fraction Heat Energy Demand Gasoline',
#   'SCOE Efficiency Factor for Heat Energy from Kerosene': 'SCOE Fraction Heat Energy Demand Kerosene',
#   'SCOE Efficiency Factor for Heat Energy from Natural Gas': 'SCOE Fraction Heat Energy Demand Natural Gas',
#   'SCOE Efficiency Factor for Heat Energy from Electricity': 'SCOE Fraction Heat Energy Demand Electricity',
#   'SCOE Efficiency Factor for Heat Energy from Solid Biomass': 'SCOE Fraction Heat Energy Demand Solid Biomass',
#   'SCOE Efficiency Factor for Heat Energy from Hydrocarbon Gas Liquids': 'SCOE Fraction Heat Energy Demand Hydrocarbon Gas Liquids'}}

# %%
matt_new.get_attribute_table(
    "Energy Technology", 
    table_type = "key_variable_definitions"
).table
# Out:
#    variable_type                                           variable  \
# 0          Input  :math:\text{CH}_4 Fuel Production NemoMod Emis...
# 1          Input  :math:\text{CH}_4 NemoMod EmissionsActivityRat...
# 2          Input  :math:\text{CO}_2 Fuel Production NemoMod Emis...
# 3          Input  :math:\text{CO}_2 NemoMod EmissionsActivityRat...
# 4          Input  :math:\text{N}_2\text{O} Fuel Production NemoM...
# ..           ...                                                ...
# 66        Output  NemoMod :math:\text{N}_2\text{O} Emissions fro...
# 67        Output              NemoMod Discounted Capital Investment
# 68        Output                 NemoMod Discounted Operating Costs
# 69        Output                        NemoMod Generation Capacity
# 70        Output                   NemoMod Production by Technology
#
#                                           information  \
# 0   | Ratio of emissions of :math:`\text{CH}_4` to...
# 1   Scalar applied to the stationary combustion em...
# 2   | Ratio of emissions of :math:`\text{CO}_2` to...
# 3   Scalar applied to the stationary combustion em...
# 4   | Ratio of emissions of :math:`\text{N}_2\text...
# ..                                                ...
# 66  Taken from NemoMod variable **vannualemissions...
# 67   | Discounted capital investment in new genera...
# 68   | Discounted operating (fixed and variable) c...
# 69   | Total annual generation capacity (in config...
# 70   | Production of electricity by generation tec...
#
#                                       variable_schema  \
# 0   ``nemomod_entc_emissions_activity_ratio_fuel_p...
# 1   ``nemomod_entc_emissions_activity_ratio_scalar...
# 2   ``nemomod_entc_emissions_activity_ratio_fuel_p...
# 3   ``nemomod_entc_emissions_activity_ratio_scalar...
# 4   ``nemomod_entc_emissions_activity_ratio_fuel_p...
# ..                                                ...
# 66  ``emission_co2e_$EMISSION-GAS$_entc_processing...
# 67  ``nemomod_entc_discounted_capital_investment_$...
# 68  ``nemomod_entc_discounted_operating_costs_$CAT...
# 69  ``nemomod_entc_total_annual_generation_capacit...
# 70  ``nemomod_entc_annual_production_by_technology...
#
#                                            categories  reference  \
# 0      ``fp_natural_gas``|``fp_petroleum_refinement``        NaN
# 1   ``pp_biogas``|``pp_biomass``|``pp_coal``|``pp_...        NaN
# 2   ``fp_hydrogen_gasification``|``fp_hydrogen_ref...        NaN
# 3   ``pp_biogas``|``pp_biomass``|``pp_coal``|``pp_...        NaN
# 4      ``fp_natural_gas``|``fp_petroleum_refinement``        NaN
# ..                                                ...        ...
# 66  ``fp_hydrogen_electrolysis``|``fp_hydrogen_gas...        NaN
# 67  ``fp_hydrogen_electrolysis``|``fp_hydrogen_gas...        NaN
# 68  ``fp_hydrogen_electrolysis``|``fp_hydrogen_gas...        NaN
# 69  ``pp_biogas``|``pp_biomass``|``pp_coal``|``pp_...        NaN
# 70  ``pp_biogas``|``pp_biomass``|``pp_coal``|``pp_...        NaN
#
#     default_value  default_lhs_scalar_minimum_at_final_time_period  \
# 0               0                                                1
# 1               0                                                1
# 2               0                                                1
# 3               0                                                1
# 4               0                                                1
# ..            ...                                              ...
# 66              0                                                1
# 67              0                                                1
# 68              0                                                1
# 69              0                                                1
# 70              0                                                1
#
#     default_lhs_scalar_maximum_at_final_time_period  simplex_group  \
# 0                                                 1            NaN
# 1                                                 1            NaN
# 2                                                 1            NaN
# 3                                                 1            NaN
# 4                                                 1            NaN
# ..                                              ...            ...
# 66                                                1            NaN
# 67                                                1            NaN
# 68                                                1            NaN
# 69                                                1            NaN
# 70                                                1            NaN
#
#    abbreviation_subsector  emissions_total_by_gas_component cat_fuel notes
# 0                    none                                 0     none   NaN
# 1                    none                                 0     none   NaN
# 2                    none                                 0     none   NaN
# 3                    none                                 0     none   NaN
# 4                    none                                 0     none   NaN
# ..                    ...                               ...      ...   ...
# 66                   none                                 1     none   NaN
# 67                   none                                 0     none   NaN
# 68                   none                                 0     none   NaN
# 69                   none                                 0     none   NaN
# 70                   none                                 0     none   NaN
#
# [71 rows x 14 columns]

# %%
s = set({1, 4, 8, 8})

s &= set({1, 4})
s
# Out:
# {1, 4}

# %%
#def get_subsector_variables
#matt_new.all_subsectors_with_primary_category
sa.model_attributes.dict_model_variable_to_category_restriction
# Out:
# {'Agriculture Equivalent Exports': 'all',
#  'Agriculture Fraction Dry': 'all',
#  'Agriculture Fraction Temperate': 'all',
#  'Agriculture Fraction Tropical': 'all',
#  'Agriculture Fraction Wet': 'all',
#  'Crop Demand Income Elasticity': 'all',
#  'Crop Fraction Animal Feed': 'all',
#  'Crop Yield Factor': 'all',
#  'Fraction of Agriculture Demand Imported': 'all',
#  'Initial Cropland Area Proportion': 'all',
#  'Adjusted Agriculture Equivalent Exports': 'all',
#  'Adjusted Agriculture Equivalent Imports': 'all',
#  'Changes to Agriculture Net Imports Lost': 'all',
#  'Crop Area': 'all',
#  'Crop Demand': 'all',
#  'Crop Yield': 'all',
#  'Cropland Area Proportion': 'all',
#  ':math:\\text{CH}_4 Crop Anaerobic Decomposition Emission Factor': 'partial',
#  ':math:\\text{CH}_4 Crop Biomass Burning Emission Factor': 'partial',
#  ':math:\\text{CO}_2 Crop Biomass Emission Factor': 'partial',
#  ':math:\\text{N}_2\\text{O} Crop Biomass Burning Emission Factor': 'partial',
#  'Above Ground Residue Dry Matter Intercept': 'partial',
#  'Above Ground Residue Dry Matter Slope': 'partial',
#  'AGRC Combustion Factor': 'partial',
#  'Dry Matter Fraction of Harvested Crop': 'partial',
#  'Fraction of Food Loss Sent to Municipal Solid Waste': 'partial',
#  'Fraction of Food Produced Lost Before Consumption': 'partial',
#  'Fraction of Residues Burned': 'partial',
#  'Fraction of Residues Removed': 'partial',
#  'N Content of Above Ground Residues': 'partial',
#  'N Content of Below Ground Residues': 'partial',
#  'No Till Crop Fraction': 'partial',
#  'Ratio of Above Ground Residue to Harvested Yield': 'partial',
#  'Ratio of Below Ground Biomass to Above Ground Biomass': 'partial',
#  ':math:\\text{CH}_4 Emissions from Biomass Burning': 'partial',
#  ':math:\\text{CH}_4 Emissions from Rice': 'partial',
#  ':math:\\text{CO}_2 Emissions from Biomass Carbon Stock Changes': 'partial',
#  ':math:\\text{CO}_2 Emissions from Soil Carbon in Organic Soils': 'partial',
#  ':math:\\text{N}_2\\text{O} Emissions from Biomass Burning': 'partial',
#  ':math:\\text{N}_2\\text{O} Emissions from Crop Residues': 'partial',
#  'Total Food Loss Sent to Municipal Solid Waste': 'partial',
#  'Total Food Produced Lost Before Consumption': 'partial',
#  'Annual Capture and Sequestration by Type': 'all',
#  'CCSQ Efficiency Factor for Heat Energy from Geothermal': 'all',
#  'CCSQ Efficiency Factor for Heat Energy from Hydrogen': 'all',
#  'CCSQ Efficiency Factor for Heat Energy from Natural Gas': 'all',
#  'CCSQ Energy Demand Per Mass of :math:\\text{CO}_2 Captured': 'all',
#  'CCSQ Fraction Energy Electricity': 'all',
#  'CCSQ Fraction Energy Heat': 'all',
#  'CCSQ Fraction Heat Energy Demand Geothermal': 'all',
#  'CCSQ Fraction Heat Energy Demand Hydrogen': 'all',
#  'CCSQ Fraction Heat Energy Demand Natural Gas': 'all',
#  ':math:\\text{CH}_4 Emissions from CCSQ': 'all',
#  ':math:\\text{CO}_2 Emissions from CCSQ': 'all',
#  ':math:\\text{N}_2\\text{O} Emissions from CCSQ': 'all',
#  'Electrical Energy Consumption from CCSQ': 'all',
#  'Energy Consumption from CCSQ': 'all',
#  'Total Electrical Energy Consumption from CCSQ': 'partial',
#  'Total Energy Consumption from CCSQ': 'partial',
#  'GDP': 'partial',
#  'GDP per Capita': 'partial',
#  ':math:\\text{CH}_4 Stationary Combustion Emission Factor': 'all',
#  ':math:\\text{CO}_2 Combustion Emission Factor': 'all',
#  ':math:\\text{N}_2\\text{O} Stationary Combustion Emission Factor': 'all',
#  'Average Industrial Energy Fuel Efficiency Factor': 'partial',
#  'Electrical Transmission Loss Fraction': 'partial',
#  'Fraction of Fuel Demand Imported': 'partial',
#  'Fuel Exports': 'partial',
#  'Gravimetric Energy Density': 'partial',
#  'Gravimetric Fuel Price': 'partial',
#  'Minimum Fraction of Fuel Used for Electricity Generation': 'partial',
#  'NemoMod REMinProductionTarget': 'partial',
#  'Thermal Fuel Price': 'partial',
#  'Volumetric Energy Density': 'partial',
#  'Volumetric Fuel Price': 'partial',
#  'Adjusted Fuel Exports': 'partial',
#  'Electrical Transmission Loss': 'partial',
#  'Energy Demand by Fuel in CCSQ': 'partial',
#  'Energy Demand by Fuel in Energy Technology': 'partial',
#  'Energy Demand by Fuel in Industrial Energy': 'partial',
#  'Energy Demand by Fuel in SCOE': 'partial',
#  'Energy Demand by Fuel in Transportation': 'partial',
#  'Fuel Imports': 'partial',
#  'Fuel Production': 'partial',
#  'Total Energy Demand by Fuel': 'partial',
#  'Unused Fuel Exported': 'partial',
#  'Value of Fuel Consumed in CCSQ': 'partial',
#  'Value of Fuel Consumed in Energy Technology': 'partial',
#  'Value of Fuel Consumed in Industrial Energy': 'partial',
#  'Value of Fuel Consumed in SCOE': 'partial',
#  'Value of Fuel Consumed in Transportation': 'partial',
#  'NemoMod CapitalCostStorage': 'all',
#  'NemoMod ResidualStorageCapacity': 'all',
#  'NemoMod StorageStartLevel': 'all',
#  'NemoMod TotalAnnualMaxCapacityInvestmentStorage': 'all',
#  'NemoMod TotalAnnualMaxCapacityStorage': 'all',
#  'NemoMod TotalAnnualMinCapacityInvestmentStorage': 'all',
#  'NemoMod TotalAnnualMinCapacityStorage': 'all',
#  'NemoMod Discounted Capital Investment Storage': 'all',
#  'NemoMod Discounted Operating Costs Storage': 'all',
#  ':math:\\text{CH}_4 Fuel Production NemoMod EmissionsActivityRatio': 'partial',
#  ':math:\\text{CH}_4 NemoMod EmissionsActivityRatio Scalar': 'partial',
#  ':math:\\text{CO}_2 Fuel Production NemoMod EmissionsActivityRatio': 'partial',
#  ':math:\\text{CO}_2 NemoMod EmissionsActivityRatio Scalar': 'partial',
#  ':math:\\text{N}_2\\text{O} Fuel Production NemoMod EmissionsActivityRatio': 'partial',
#  ':math:\\text{N}_2\\text{O} NemoMod EmissionsActivityRatio Scalar': 'partial',
#  'Fuel Production NemoMod InputActivityRatio Biomass': 'partial',
#  'Fuel Production NemoMod InputActivityRatio Coal': 'partial',
#  'Fuel Production NemoMod InputActivityRatio Coal Deposits': 'partial',
#  'Fuel Production NemoMod InputActivityRatio Crude': 'partial',
#  'Fuel Production NemoMod InputActivityRatio Diesel': 'partial',
#  'Fuel Production NemoMod InputActivityRatio Electricity': 'partial',
#  'Fuel Production NemoMod InputActivityRatio Gasoline': 'partial',
#  'Fuel Production NemoMod InputActivityRatio Natural Gas': 'partial',
#  'Fuel Production NemoMod InputActivityRatio Natural Gas Unprocessed': 'partial',
#  'Fuel Production NemoMod InputActivityRatio Oil': 'partial',
#  'Fuel Production NemoMod OutputActivityRatio Coal': 'partial',
#  'Fuel Production NemoMod OutputActivityRatio Crude': 'partial',
#  'Fuel Production NemoMod OutputActivityRatio Diesel': 'partial',
#  'Fuel Production NemoMod OutputActivityRatio Gasoline': 'partial',
#  'Fuel Production NemoMod OutputActivityRatio Hydrocarbon Gas Liquids': 'partial',
#  'Fuel Production NemoMod OutputActivityRatio Hydrogen': 'partial',
#  'Fuel Production NemoMod OutputActivityRatio Kerosene': 'partial',
#  'Fuel Production NemoMod OutputActivityRatio Natural Gas': 'partial',
#  'Fuel Production NemoMod OutputActivityRatio Natural Gas Unprocessed': 'partial',
#  'Fuel Production NemoMod OutputActivityRatio Oil': 'partial',
#  'Maximum Production Increase Fraction to Satisfy MinShareProduction Electricity': 'partial',
#  'NemoMod CapitalCost': 'partial',
#  'NemoMod FixedCost': 'partial',
#  'NemoMod MinShareProduction': 'partial',
#  'NemoMod ReserveMargin': 'partial',
#  'NemoMod ReserveMarginTagTechnology': 'partial',
#  'NemoMod ResidualCapacity': 'partial',
#  'NemoMod RETagTechnology': 'partial',
#  'NemoMod TotalAnnualMaxCapacity': 'partial',
#  'NemoMod TotalAnnualMaxCapacityInvestment': 'partial',
#  'NemoMod TotalAnnualMinCapacity': 'partial',
#  'NemoMod TotalAnnualMinCapacityInvestment': 'partial',
#  'NemoMod VariableCost': 'partial',
#  'Technology Efficiency of Fuel Use': 'partial',
#  'NemoMod Discounted Capital Investment': 'partial',
#  'NemoMod :math:\\text{CH}_4 Emissions from Electricity Generation': 'partial',
#  'NemoMod :math:\\text{CH}_4 Emissions from Electricity Generation for CCSQ': 'partial',
#  'NemoMod :math:\\text{CH}_4 Emissions from Electricity Generation for Energy Technology': 'partial',
#  'NemoMod :math:\\text{CH}_4 Emissions from Electricity Generation for Export': 'partial',
#  'NemoMod :math:\\text{CH}_4 Emissions from Electricity Generation for Industrial Energy': 'partial',
#  'NemoMod :math:\\text{CH}_4 Emissions from Electricity Generation for SCOE': 'partial',
#  'NemoMod :math:\\text{CH}_4 Emissions from Electricity Generation for Transportation': 'partial',
#  'NemoMod :math:\\text{CH}_4 Emissions from Fuel Mining and Extraction': 'partial',
#  'NemoMod :math:\\text{CH}_4 Emissions from Fuel Processing and Refinement': 'partial',
#  'NemoMod :math:\\text{CO}_2 Emissions from Electricity Generation': 'partial',
#  'NemoMod :math:\\text{CO}_2 Emissions from Electricity Generation for CCSQ': 'partial',
#  'NemoMod :math:\\text{CO}_2 Emissions from Electricity Generation for Energy Technology': 'partial',
#  'NemoMod :math:\\text{CO}_2 Emissions from Electricity Generation for Export': 'partial',
#  'NemoMod :math:\\text{CO}_2 Emissions from Electricity Generation for Industrial Energy': 'partial',
#  'NemoMod :math:\\text{CO}_2 Emissions from Electricity Generation for SCOE': 'partial',
#  'NemoMod :math:\\text{CO}_2 Emissions from Electricity Generation for Transportation': 'partial',
#  'NemoMod :math:\\text{CO}_2 Emissions from Fuel Mining and Extraction': 'partial',
#  'NemoMod :math:\\text{CO}_2 Emissions from Fuel Processing and Refinement': 'partial',
#  'NemoMod :math:\\text{N}_2\\text{O} Emissions from Electricity Generation': 'partial',
#  'NemoMod :math:\\text{N}_2\\text{O} Emissions from Electricity Generation for CCSQ': 'partial',
#  'NemoMod :math:\\text{N}_2\\text{O} Emissions from Electricity Generation for Energy Technology': 'partial',
#  'NemoMod :math:\\text{N}_2\\text{O} Emissions from Electricity Generation for Export': 'partial',
#  'NemoMod :math:\\text{N}_2\\text{O} Emissions from Electricity Generation for Industrial Energy': 'partial',
#  'NemoMod :math:\\text{N}_2\\text{O} Emissions from Electricity Generation for SCOE': 'partial',
#  'NemoMod :math:\\text{N}_2\\text{O} Emissions from Electricity Generation for Transportation': 'partial',
#  'NemoMod :math:\\text{N}_2\\text{O} Emissions from Fuel Mining and Extraction': 'partial',
#  'NemoMod :math:\\text{N}_2\\text{O} Emissions from Fuel Processing and Refinement': 'partial',
#  'NemoMod Discounted Operating Costs': 'partial',
#  'NemoMod Generation Capacity': 'partial',
#  'NemoMod Production by Technology': 'partial',
#  ':math:\\text{CH}_4 Forest Methane Emissions': 'all',
#  ':math:\\text{CO}_2 Forest Fire Emission Factor': 'all',
#  'Average Fraction of Forest Burned Annually': 'all',
#  'Fire Biomass Consumption for Temperate Forests': 'all',
#  'Fire Biomass Consumption for Tropical Forests': 'all',
#  'Forest Fraction Temperate Nutrient Poor': 'all',
#  'Forest Fraction Temperate Nutrient Rich': 'all',
#  'Forest Fraction Tropical': 'all',
#  'Forest Sequestration Emission Factor': 'all',
#  ':math:\\text{CH}_4 Emissions from Forests': 'all',
#  ':math:\\text{CO}_2 Emissions from Forest Sequestration': 'all',
#  'C Carbon Harvested Wood Products Emission Factor': 'partial',
#  'HWP Half Life Paper': 'partial',
#  'HWP Half Life Wood': 'partial',
#  'Initial Per Household Wood Demand': 'partial',
#  ':math:\\text{CO}_2 Emissions from Forest Fires': 'partial',
#  ':math:\\text{CO}_2 Emissions from Harvested Wood Products': 'partial',
#  ':math:\\text{CH}_4 FGTV Production Flaring Emission Factor': 'partial',
#  ':math:\\text{CH}_4 FGTV Production Fugitive Emission Factor': 'partial',
#  ':math:\\text{CH}_4 FGTV Production Venting Emission Factor': 'partial',
#  ':math:\\text{CH}_4 FGTV Transmission Emission Factor': 'partial',
#  ':math:\\text{CH}_4 FGTV Distribution Emission Factor': 'partial',
#  ':math:\\text{CO}_2 FGTV Production Flaring Emission Factor': 'partial',
#  ':math:\\text{CO}_2 FGTV Production Fugitive Emission Factor': 'partial',
#  ':math:\\text{CO}_2 FGTV Production Venting Emission Factor': 'partial',
#  ':math:\\text{CO}_2 FGTV Transmission Emission Factor': 'partial',
#  ':math:\\text{CO}_2 FGTV Distribution Emission Factor': 'partial',
#  ':math:\\text{N}_2\\text{O} FGTV Production Flaring Emission Factor': 'partial',
#  ':math:\\text{N}_2\\text{O} FGTV Production Fugitive Emission Factor': 'partial',
#  ':math:\\text{N}_2\\text{O} FGTV Production Venting Emission Factor': 'partial',
#  ':math:\\text{N}_2\\text{O} FGTV Transmission Emission Factor': 'partial',
#  'NMVOC FGTV Production Flaring Emission Factor': 'partial',
#  'NMVOC FGTV Production Fugitive Emission Factor': 'partial',
#  'NMVOC FGTV Production Venting Emission Factor': 'partial',
#  'NMVOC FGTV Transmission Emission Factor': 'partial',
#  'NMVOC FGTV Distribution Emission Factor': 'partial',
#  'Fraction Non-Fugitive :math:\\text{CH}_4 Flared': 'partial',
#  'Reduction in Fugitive Leaks': 'partial',
#  ':math:\\text{CH}_4 Fugitive Emissions': 'partial',
#  ':math:\\text{CO}_2 Fugitive Emissions': 'partial',
#  ':math:\\text{N}_2\\text{O} Fugitive Emissions': 'partial',
#  'NMVOC Fugitive Emissions': 'partial',
#  'Population': 'all',
#  ':math:\\text{CH}_4 Annual Emission Limit': 'partial',
#  ':math:\\text{CO}_2 Annual Emission Limit': 'partial',
#  ':math:\\text{N}_2\\text{O} Annual Emission Limit': 'partial',
#  'Area of Country': 'partial',
#  'Climate Change Factor for Average Hydropower Availability': 'partial',
#  'Elasticity National Occupation Rate to GDP Per Capita': 'partial',
#  'Fraction Eating Red Meat': 'partial',
#  'Initial National Occupancy Rate': 'partial',
#  'National Occupancy Rate': 'partial',
#  'Number of Households': 'partial',
#  'Total Population': 'partial',
#  ':math:\\text{CH}_4 Production Process Emission Factor': 'partial',
#  ':math:\\text{CO}_2 Clinker Production Process Emission Factor': 'partial',
#  ':math:\\text{CO}_2 Product Use Emission Factor': 'partial',
#  ':math:\\text{CO}_2 Production Process Emission Factor': 'partial',
#  ':math:\\text{N}_2\\text{O} GDP Production Process Emission Factor': 'partial',
#  ':math:\\text{N}_2\\text{O} Production Process Emission Factor': 'partial',
#  ':math:\\text{NF}_3 Production Process Emission Factor': 'partial',
#  ':math:\\text{SF}_6 GDP Production Process Emission Factor': 'partial',
#  ':math:\\text{SF}_6 Production Process Emission Factor': 'partial',
#  'Average Lifespan of Housing Construction': 'partial',
#  'Average per Household Demand for Construction Materials': 'partial',
#  'Clinker Fraction of Cement': 'partial',
#  'COD Wastewater Factor': 'partial',
#  'Dodecafluoropentane Production Process Emission Factor': 'partial',
#  'Elasticity of Industrial Production to GDP': 'partial',
#  'Elasticity of Product Use Rate to GDP per Capita': 'partial',
#  'HCFC-141b GDP Product Use Emission Factor': 'partial',
#  'HCFC-142b GDP Product Use Emission Factor': 'partial',
#  'HFC-125 GDP Product Use Emission Factor': 'partial',
#  'HFC-125 Production Process Emission Factor': 'partial',
#  'HFC-134 GDP Product Use Emission Factor': 'partial',
#  'HFC-134a GDP Product Use Emission Factor': 'partial',
#  'HFC-134a Production Process Emission Factor': 'partial',
#  'HFC-143 GDP Product Use Emission Factor': 'partial',
#  'HFC-143a GDP Product Use Emission Factor': 'partial',
#  'HFC-143a Production Process Emission Factor': 'partial',
#  'HFC-152a GDP Product Use Emission Factor': 'partial',
#  'HFC-152a Production Process Emission Factor': 'partial',
#  'HFC-227ea GDP Product Use Emission Factor': 'partial',
#  'HFC-227ea Production Process Emission Factor': 'partial',
#  'HFC-23 GDP Product Use Emission Factor': 'partial',
#  'HFC-23 Production Process Emission Factor': 'partial',
#  'HFC-236fa GDP Product Use Emission Factor': 'partial',
#  'HFC-245fa GDP Product Use Emission Factor': 'partial',
#  'HFC-32 GDP Product Use Emission Factor': 'partial',
#  'HFC-32 Production Process Emission Factor': 'partial',
#  'HFC-365mfc GDP Product Use Emission Factor': 'partial',
#  'HFC-365mfc Production Process Emission Factor': 'partial',
#  'HFC-41 Production Process Emission Factor': 'partial',
#  'HFC-43-10mee GDP Product Use Emission Factor': 'partial',
#  'Industrial :math:\\text{CO}_2 Capture Efficacy': 'partial',
#  'Industrial :math:\\text{CO}_2 Capture Prevalence': 'partial',
#  'Industrial Production Scalar': 'partial',
#  'Initial Industrial Production': 'partial',
#  'Initial Non-Energy Fuel Use': 'partial',
#  'Initial Other Non-Energy :math:\\text{CO}_2 Emissions': 'partial',
#  'Maximum Recycled Material Ratio in Virgin Process': 'partial',
#  'Net Imports of Cement Clinker': 'partial',
#  'Octafluorooxolane Production Process Emission Factor': 'partial',
#  'PFC-1114 Production Process Emission Factor': 'partial',
#  'PFC-116 GDP Product Use Emission Factor': 'partial',
#  'PFC-116 Production Process Emission Factor': 'partial',
#  'PFC-14 GDP Product Use Emission Factor': 'partial',
#  'PFC-14 Production Process Emission Factor': 'partial',
#  'PFC-218 Production Process Emission Factor': 'partial',
#  'PFC-31-10 GDP Product Use Emission Factor': 'partial',
#  'PFC-31-10 Production Process Emission Factor': 'partial',
#  'PFC-51-14 GDP Product Use Emission Factor': 'partial',
#  'PFC-51-14 Production Process Emission Factor': 'partial',
#  'PFC-C-1418 Production Process Emission Factor': 'partial',
#  'PFC-C-318 Production Process Emission Factor': 'partial',
#  'Ratio of Production to Harvested Wood Demand': 'partial',
#  'Wastewater Production Factor': 'partial',
#  ':math:\\text{CH}_4 Emissions from Industrial Production Processes': 'partial',
#  ':math:\\text{CO}_2 Captured in Industrial Processes and Product Use': 'partial',
#  ':math:\\text{CO}_2 Emissions from Industrial Product Use': 'partial',
#  ':math:\\text{CO}_2 Emissions from Industrial Production Processes': 'partial',
#  ':math:\\text{N}_2\\text{O} Emissions from Industrial Production Processes': 'partial',
#  ':math:\\text{NF}_3 Emissions from Industrial Production Processes': 'partial',
#  ':math:\\text{SF}_6 Emissions from Industrial Production Processes': 'partial',
#  'Change to Net Imports of Products': 'partial',
#  'Demand for Harvested Wood': 'partial',
#  'Dodecafluoropentane Emissions from Industrial Production Processes': 'partial',
#  'HCFC-141b Emissions from Industrial Product Use': 'partial',
#  'HCFC-142b Emissions from Industrial Product Use': 'partial',
#  'HFC Emissions from Industrial Product Use': 'partial',
#  'HFC Emissions from Industrial Production Processes': 'partial',
#  'HFC-125 Emissions from Industrial Product Use': 'partial',
#  'HFC-125 Emissions from Industrial Production Processes': 'partial',
#  'HFC-134 Emissions from Industrial Product Use': 'partial',
#  'HFC-134a Emissions from Industrial Product Use': 'partial',
#  'HFC-134a Emissions from Industrial Production Processes': 'partial',
#  'HFC-143 Emissions from Industrial Product Use': 'partial',
#  'HFC-143a Emissions from Industrial Product Use': 'partial',
#  'HFC-143a Emissions from Industrial Production Processes': 'partial',
#  'HFC-152a Emissions from Industrial Product Use': 'partial',
#  'HFC-152a Emissions from Industrial Production Processes': 'partial',
#  'HFC-227ea Emissions from Industrial Product Use': 'partial',
#  'HFC-227ea Emissions from Industrial Production Processes': 'partial',
#  'HFC-23 Emissions from Industrial Product Use': 'partial',
#  'HFC-23 Emissions from Industrial Production Processes': 'partial',
#  'HFC-236fa Emissions from Industrial Product Use': 'partial',
#  'HFC-245fa Emissions from Industrial Product Use': 'partial',
#  'HFC-32 Emissions from Industrial Product Use': 'partial',
#  'HFC-32 Emissions from Industrial Production Processes': 'partial',
#  'HFC-365mfc Emissions from Industrial Product Use': 'partial',
#  'HFC-365mfc Emissions from Industrial Production Processes': 'partial',
#  'HFC-41 Emissions from Industrial Production Processes': 'partial',
#  'HFC-43-10mee Emissions from Industrial Product Use': 'partial',
#  'Industrial Production': 'partial',
#  'Other Fluorinated Compound Emissions from Industrial Product Use': 'partial',
#  'Other Fluorinated Compound Emissions from Industrial Production Processes': 'partial',
#  'PFC Emissions from Industrial Product Use': 'partial',
#  'PFC Emissions from Industrial Production Processes': 'partial',
#  'PFC-1114 Emissions from Industrial Production Processes': 'partial',
#  'PFC-116 Emissions from Industrial Product Use': 'partial',
#  'PFC-116 Emissions from Industrial Production Processes': 'partial',
#  'PFC-14 Emissions from Industrial Product Use': 'partial',
#  'PFC-14 Emissions from Industrial Production Processes': 'partial',
#  'PFC-1418 Emissions from Industrial Production Processes': 'partial',
#  'PFC-218 Emissions from Industrial Production Processes': 'partial',
#  'PFC-31-10 Emissions from Industrial Product Use': 'partial',
#  'PFC-31-10 Emissions from Industrial Production Processes': 'partial',
#  'PFC-318 Emissions from Industrial Production Processes': 'partial',
#  'PFC-51-14 Emissions from Industrial Product Use': 'partial',
#  'PFC-51-14 Emissions from Industrial Production Processes': 'partial',
#  'Recycled Material Used in Industrial Production': 'partial',
#  'Industrial Energy Demand Scalar': 'partial',
#  'Industrial Energy Fuel Fraction Coal': 'partial',
#  'Industrial Energy Fuel Fraction Coke': 'partial',
#  'Industrial Energy Fuel Fraction Diesel': 'partial',
#  'Industrial Energy Fuel Fraction Electricity': 'partial',
#  'Industrial Energy Fuel Fraction Furnace Gas': 'partial',
#  'Industrial Energy Fuel Fraction Gasoline': 'partial',
#  'Industrial Energy Fuel Fraction Geothermal': 'partial',
#  'Industrial Energy Fuel Fraction Hydrocarbon Gas Liquids': 'partial',
#  'Industrial Energy Fuel Fraction Hydrogen': 'partial',
#  'Industrial Energy Fuel Fraction Kerosene': 'partial',
#  'Industrial Energy Fuel Fraction Natural Gas': 'partial',
#  'Industrial Energy Fuel Fraction Oil': 'partial',
#  'Industrial Energy Fuel Fraction Solar': 'partial',
#  'Industrial Energy Fuel Fraction Solid Biomass': 'partial',
#  'Initial Energy Consumption in Agriculture and Livestock': 'partial',
#  'Initial Energy Consumption Intensity of GDP': 'partial',
#  'Initial Energy Consumption Intensity of Production': 'partial',
#  ':math:\\text{CH}_4 Emissions from Industrial Energy': 'partial',
#  ':math:\\text{CO}_2 Captured in Industrial Energy': 'partial',
#  ':math:\\text{CO}_2 Emissions from Industrial Energy': 'partial',
#  ':math:\\text{N}_2\\text{O} Emissions from Industrial Energy': 'partial',
#  'Electrical Energy Consumption from Industrial Energy': 'partial',
#  'Energy Consumption from Industrial Energy': 'partial',
#  'Energy Demand in Industrial Energy': 'partial',
#  'Total Electrical Energy Consumption from Industrial Energy': 'partial',
#  'Total Energy Consumption from Industrial Energy': 'partial',
#  'Initial Land Use Area Proportion': 'all',
#  'Soil Carbon Land Use Factor': 'all',
#  ':math:\\text{CO}_2 Emissions from Conversion Away from Land Use Type': 'all',
#  'Area of Land Use Converted Away from Type': 'all',
#  'Area of Land Use Converted to Type': 'all',
#  'Land Use Area': 'all',
#  ':math:\\text{CO}_2 Land Use Conversion Emission Factor': 'all',
#  'Unadjusted Land Use Transition Probability': 'all',
#  ':math:\\text{CO}_2 Emissions from Land Use Conversion': 'all',
#  'Area of Land Use Converted': 'all',
#  'Fraction of Increasing Net Exports Met': 'partial',
#  'Fraction of Increasing Net Imports Met': 'partial',
#  'Fraction of Pastures Improved': 'partial',
#  'Fraction of Soils Mineral': 'partial',
#  'Land Use BOC :math:\\text{CH}_4 Emission Factor': 'partial',
#  'Land Use Fraction Dry': 'partial',
#  'Land Use Fraction Fertilized': 'partial',
#  'Land Use Fraction Temperate': 'partial',
#  'Land Use Fraction Tropical': 'partial',
#  'Land Use Fraction Wet': 'partial',
#  'Land Use Yield Reallocation Factor': 'partial',
#  'Maximum Soil Carbon Land Input Factor Without Manure': 'partial',
#  'Maximum Soil Carbon Land Management Factor': 'partial',
#  'Pasture Fraction of Grassland': 'partial',
#  'Unimproved Soil Carbon Land Management Factor': 'partial',
#  'Vegetarian Diet Exchange Scalar': 'partial',
#  ':math:\\text{CH}_4 Emissions from Wetlands': 'partial',
#  'Area of Improved Land': 'partial',
#  'Treatment Fraction Advanced Aerobic': 'all',
#  'Treatment Fraction Advanced Anaerobic': 'all',
#  'Treatment Fraction Improved Latrine': 'all',
#  'Treatment Fraction Primary': 'all',
#  'Treatment Fraction Secondary Aerobic': 'all',
#  'Treatment Fraction Secondary Anaerobic': 'all',
#  'Treatment Fraction Septic': 'all',
#  'Treatment Fraction Unimproved Latrine': 'all',
#  'Treatment Fraction Untreated No Sewerage': 'all',
#  'Treatment Fraction Untreated With Sewerage': 'all',
#  '(Optional) Elasticity of Protein in Diet to GDP per Capita': 'partial',
#  'Average Protein Consumption Per Capita': 'partial',
#  'BOD Correction Factor for TOW': 'partial',
#  'BOD per Capita': 'partial',
#  'COD per GDP': 'partial',
#  'Factor for Nitrogen in Non-Consumed Protein Disposed in Sewer System': 'partial',
#  'Fraction of Protein in Diet with Red Meat': 'partial',
#  'Fraction of Protein in Diet without Red Meat': 'partial',
#  'Initial Per Capita Annual Domestic Wastewater Generated': 'partial',
#  'Initial Per GDP Annual Industrial Wastewater Generated': 'partial',
#  'Log Elasticity DWW Production to GDP Per Capita': 'partial',
#  'Maximum BOD :math:\\text{CH}_4 Producing Capacity': 'partial',
#  'Maximum COD :math:\\text{CH}_4 Producing Capacity': 'partial',
#  'Nitrogen Density of Industrial Wastewater': 'partial',
#  'Phosphorous Per BOD Factor': 'partial',
#  'Phosphorous Per COD Factor': 'partial',
#  'Scalar to Account for Nitrogen in Household Products': 'partial',
#  ':math:\\text{CH}_4 Enteric Fermentation Emission Factor': 'all',
#  'Animal Weight': 'all',
#  'Daily Dry Matter Consumption': 'all',
#  'Daily Nitrogen Generation Factor': 'all',
#  'Daily Volatile Solid Generation Factor': 'all',
#  'Fraction of Livestock Demand Imported': 'all',
#  'Initial Livestock Head Count': 'all',
#  'Livestock Equivalent Exports': 'all',
#  'Livestock Manure Management Fraction Anaerobic Digester': 'all',
#  'Livestock Manure Management Fraction Anaerobic Lagoon': 'all',
#  'Livestock Manure Management Fraction Composting': 'all',
#  'Livestock Manure Management Fraction Daily Spread': 'all',
#  'Livestock Manure Management Fraction Deep Bedding': 'all',
#  'Livestock Manure Management Fraction Dry Lot': 'all',
#  'Livestock Manure Management Fraction Incineration': 'all',
#  'Livestock Manure Management Fraction Liquid Slurry': 'all',
#  'Livestock Manure Management Fraction Paddock Pasture Range': 'all',
#  'Livestock Manure Management Fraction Poultry Manure': 'all',
#  'Livestock Manure Management Fraction Solid Storage': 'all',
#  'Maximum Manure :math:\\text{CH}_4 Generation Capacity': 'all',
#  ':math:\\text{CH}_4 Emissions from Livestock Enteric Fermentation': 'all',
#  'Adjusted Livestock Equivalent Exports': 'all',
#  'Adjusted Livestock Equivalent Imports': 'all',
#  'Changes to Livestock Net Imports Lost': 'all',
#  'Livestock Demand': 'all',
#  'Livestock Head Count': 'all',
#  'Carrying Capacity Scalar': 'partial',
#  'Elasticity of Livestock Demand to GDP per Capita': 'partial',
#  'Fraction Nitrogen Excretion in Dung': 'partial',
#  'Total Domestic Animal Mass': 'partial',
#  ':math:\\text{N}_2\\text{O} Manure Management Emission Factor': 'all',
#  'Fraction of Nitrogen Lost to Leaching': 'all',
#  'Fraction of Nitrogen Lost to Volatilisation': 'all',
#  'Manure Management Methane Correction Factor': 'all',
#  ':math:\\text{CH}_4 Emissions from Manure Management': 'all',
#  ':math:\\text{N}_2\\text{O} Emissions from Manure Management': 'all',
#  'Nitrogen Available for Fertilizer': 'all',
#  'Biogas Recovery Factor at LSMM Anaerobic Digesters': 'partial',
#  'Fraction of Nitrogen Used in Fertilizer': 'partial',
#  'Nitrogen from Bedding per Animal': 'partial',
#  'Nitrogen from Co-Digestates Factor': 'partial',
#  'Ratio of :math:\\text{N}_2 to :math:\\text{N}_2\\text{O}': 'partial',
#  'Dung Incinerated': 'partial',
#  'LSMM Biogas Recovered from Anaerobic Digesters': 'partial',
#  'Total Nitrogen Available for Construction/Feed/Other': 'partial',
#  'Total Nitrogen Available for Fertilizer from Dung': 'partial',
#  'Total Nitrogen Available for Fertilizer from Urine': 'partial',
#  'Total Nitrogen to Pastures': 'partial',
#  'Soil Organic C Stocks': 'all',
#  ':math:\\text{EF}_{1FR} - \\text{N}_2\\text{O} Rice Fields': 'partial',
#  ':math:\\text{EF}_1 - \\text{N}_2\\text{O} Organic Amendments and Fertilizer': 'partial',
#  ':math:\\text{EF}_1 - \\text{N}_2\\text{O} Synthetic Fertilizer': 'partial',
#  ':math:\\text{EF}_2 - \\text{N}_2\\text{O} Emissions from Drained and Managed Organic Soils': 'partial',
#  'C Annual Cultivated Organic Soils Emission Factor': 'partial',
#  'C Liming Emission Factor Dolomite': 'partial',
#  'C Liming Emission Factor Limestone': 'partial',
#  'C to N Ratio of Soil Organic Matter': 'partial',
#  'C Urea Emission Factor': 'partial',
#  'EF3 N Pasture Range and Paddock': 'partial',
#  'EF4 N Volatilisation and Re-Deposition Emission Factor': 'partial',
#  'EF5 N Leaching and Runoff Emission Factor': 'partial',
#  'Fertilizer N Demand Scalar': 'partial',
#  'Fraction Synthetic Fertilizer Use Urea': 'partial',
#  'Initial Liming Dolomite Applied to Soils': 'partial',
#  'Initial Liming Limestone Applied to Soils': 'partial',
#  'Initial Synthetic Fertilizer Use': 'partial',
#  'Leaching Fraction of N Lost': 'partial',
#  'Liming Demand Scalar': 'partial',
#  'Volatilisation Fraction from Non-Urea Synthetic Fertilizers': 'partial',
#  'Volatilisation Fraction from Organic Amendments and Fertilizers': 'partial',
#  'Volatilisation Fraction from Urea Synthetic Fertilizers': 'partial',
#  ':math:\\text{CO}_2 Emissions from Lime': 'partial',
#  ':math:\\text{CO}_2 Emissions from Soil Carbon in Mineral Soils': 'partial',
#  ':math:\\text{CO}_2 Emissions from Urea': 'partial',
#  ':math:\\text{N}_2\\text{O} Emissions from Fertilizer Use': 'partial',
#  ':math:\\text{N}_2\\text{O} Emissions from Mineral Soils': 'partial',
#  ':math:\\text{N}_2\\text{O} Emissions from Organic Soils': 'partial',
#  ':math:\\text{N}_2\\text{O} Emissions from Paddock Pasture and Range': 'partial',
#  'Organic Fertilizer N Use': 'partial',
#  'Synthetic Fertilizer N Use': 'partial',
#  'Total Fertilizer N Use': 'partial',
#  'Total Lime Use': 'partial',
#  'Total Urea Use': 'partial',
#  ':math:\\text{N}_2\\text{O} Incineration Emission Factor': 'all',
#  'Elasticity of Municipal Solid Waste Produced to GDP per Capita': 'all',
#  'Initial Composition Fraction Industrial Solid Waste': 'all',
#  'Initial Composition Fraction Municipal Solid Waste': 'all',
#  'K': 'all',
#  'Waste Per Capita Scale Factor': 'all',
#  ':math:\\text{CH}_4 Emissions from Landfills': 'all',
#  ':math:\\text{CH}_4 Emissions from Open Dumping': 'all',
#  'Total Solid Waste Produced': 'all',
#  'Total Waste Incinerated': 'all',
#  'Total Waste Landfilled': 'all',
#  'Total Waste Open Dumped': 'all',
#  ':math:\\text{CH}_4 Anaerobic Biogas Emission Factor': 'partial',
#  ':math:\\text{CH}_4 Composting Emission Factor': 'partial',
#  ':math:\\text{CH}_4 ISW Incineration Emission Factor': 'partial',
#  ':math:\\text{CH}_4 MSW Incineration Emission Factor': 'partial',
#  ':math:\\text{CH}_4 Recovery Factor Landfill Gas': 'partial',
#  ':math:\\text{N}_2\\text{O} Composting Emission Factor': 'partial',
#  'Average Annual Waste Transported Per Waste Collection Vehicle': 'partial',
#  'Average Methane Correction Factor at Landfills': 'partial',
#  'Average Methane Correction Factor for Open Dumping': 'partial',
#  'Average Oxidization Factor at Landfills': 'partial',
#  'Average VKMT Per Waste Collection Vehicle': 'partial',
#  'Biogas Recovery Factor': 'partial',
#  'Fraction of ISW Incineration Recovered for Energy': 'partial',
#  'Fraction of Landfill Gas Recovered at Landfills': 'partial',
#  'Fraction of Landfill Gas Recovered for Energy': 'partial',
#  'Fraction of Methane Flared at Composting Facilities': 'partial',
#  'Fraction of MSW Incineration Recovered for Energy': 'partial',
#  'Fraction of Non-Recycled Solid Waste Incinerated': 'partial',
#  'Fraction of Non-Recycled Solid Waste Landfilled': 'partial',
#  'Fraction of Non-Recycled Solid Waste Open Dumps': 'partial',
#  'Fraction of Waste Composted': 'partial',
#  'Fraction of Waste Recycled': 'partial',
#  'Fraction of Waste Treated Anaerobically': 'partial',
#  'Historical Back Projection Growth Rate in Solid Waste Generation': 'partial',
#  'Initial Per Capita Municipal Solid Waste Generated': 'partial',
#  'Per GDP Industrial Solid Waste Generated': 'partial',
#  ':math:\\text{CH}_4 Emissions from Anaerobic Biogas': 'partial',
#  ':math:\\text{CH}_4 Emissions from Composting': 'partial',
#  ':math:\\text{CH}_4 Emissions from Incineration': 'partial',
#  ':math:\\text{CO}_2 Emissions from Incineration': 'partial',
#  ':math:\\text{N}_2\\text{O} Emissions from Composting': 'partial',
#  ':math:\\text{N}_2\\text{O} Emissions from Incineration': 'partial',
#  'Biogas Recovered from Anaerobic Facilities': 'partial',
#  'Biogas Recovered from Landfills': 'partial',
#  'Total ISW Recovered for Energy': 'partial',
#  'Total MSW Recovered for Energy': 'partial',
#  'Total Waste Anaerobic Biogas': 'partial',
#  'Total Waste Composted': 'partial',
#  'Total Waste Recycled': 'partial',
#  'SCOE Appliance Energy Demand Scalar': 'all',
#  'SCOE Efficiency Factor for Heat Energy from Coal': 'all',
#  'SCOE Efficiency Factor for Heat Energy from Diesel': 'all',
#  'SCOE Efficiency Factor for Heat Energy from Electricity': 'all',
#  'SCOE Efficiency Factor for Heat Energy from Gasoline': 'all',
#  'SCOE Efficiency Factor for Heat Energy from Hydrocarbon Gas Liquids': 'all',
#  'SCOE Efficiency Factor for Heat Energy from Hydrogen': 'all',
#  'SCOE Efficiency Factor for Heat Energy from Kerosene': 'all',
#  'SCOE Efficiency Factor for Heat Energy from Natural Gas': 'all',
#  'SCOE Efficiency Factor for Heat Energy from Solid Biomass': 'all',
#  'SCOE Fraction Heat Energy Demand Coal': 'all',
#  'SCOE Fraction Heat Energy Demand Diesel': 'all',
#  'SCOE Fraction Heat Energy Demand Electricity': 'all',
#  'SCOE Fraction Heat Energy Demand Gasoline': 'all',
#  'SCOE Fraction Heat Energy Demand Hydrocarbon Gas Liquids': 'all',
#  'SCOE Fraction Heat Energy Demand Hydrogen': 'all',
#  'SCOE Fraction Heat Energy Demand Kerosene': 'all',
#  'SCOE Fraction Heat Energy Demand Natural Gas': 'all',
#  'SCOE Fraction Heat Energy Demand Solid Biomass': 'all',
#  'SCOE Heat Energy Demand Scalar': 'all',
#  ':math:\\text{CH}_4 Emissions from SCOE': 'all',
#  ':math:\\text{CO}_2 Emissions from SCOE': 'all',
#  ':math:\\text{N}_2\\text{O} Emissions from SCOE': 'all',
#  'Electrical Energy Consumption from SCOE': 'all',
#  'Energy Consumption from SCOE': 'all',
#  'Heat Energy Demand in SCOE': 'all',
#  'SCOE Elasticity of Per GDP Electrical Applicance Demand to GDP Per Capita': 'partial',
#  'SCOE Elasticity of Per GDP Heat Energy Demand to GDP Per Capita': 'partial',
#  'SCOE Elasticity of Per Household Electrical Applicance Demand to GDP Per Capita': 'partial',
#  'SCOE Elasticity of Per Household Heat Energy Demand to GDP Per Capita': 'partial',
#  'SCOE Initial Per GDP Electric Appliances Energy Consumption': 'partial',
#  'SCOE Initial Per GDP Heat Energy Consumption': 'partial',
#  'SCOE Initial Per Household Electric Appliances Energy Consumption': 'partial',
#  'SCOE Initial Per Household Heat Energy Consumption': 'partial',
#  'Total Electrical Energy Consumption from SCOE': 'partial',
#  'Total Energy Consumption from SCOE': 'partial',
#  ':math:\\text{CH}_4 Emissions from Transportation': 'all',
#  ':math:\\text{CO}_2 Emissions from Transportation': 'all',
#  ':math:\\text{N}_2\\text{O} Emissions from Transportation': 'all',
#  'Energy Consumption from Transportation': 'all',
#  'Total Vehicle Distance Traveled': 'all',
#  ':math:\\text{CH}_4 Biofuels Mobile Combustion Emission Factor': 'partial',
#  ':math:\\text{CH}_4 Diesel Mobile Combustion Emission Factor': 'partial',
#  ':math:\\text{CH}_4 Gasoline Mobile Combustion Emission Factor': 'partial',
#  ':math:\\text{CH}_4 Hydrocarbon Gas Liquids Mobile Combustion Emission Factor': 'partial',
#  ':math:\\text{CH}_4 Kerosene Mobile Combustion Emission Factor': 'partial',
#  ':math:\\text{CH}_4 Natural Gas Mobile Combustion Emission Factor': 'partial',
#  ':math:\\text{N}_2\\text{O} Biofuels Mobile Combustion Emission Factor': 'partial',
#  ':math:\\text{N}_2\\text{O} Diesel Mobile Combustion Emission Factor': 'partial',
#  ':math:\\text{N}_2\\text{O} Gasoline Mobile Combustion Emission Factor': 'partial',
#  ':math:\\text{N}_2\\text{O} Hydrocarbon Gas Liquids Mobile Combustion Emission Factor': 'partial',
#  ':math:\\text{N}_2\\text{O} Kerosene Mobile Combustion Emission Factor': 'partial',
#  ':math:\\text{N}_2\\text{O} Natural Gas Mobile Combustion Emission Factor': 'partial',
#  'Average Freight Vehicle Load': 'partial',
#  'Average Passenger Vehicle Occupancy Rate': 'partial',
#  'Electrical Vehicle Efficiency': 'partial',
#  'Freight Transportation Mode Share': 'partial',
#  'Fuel Efficiency Biofuels': 'partial',
#  'Fuel Efficiency Diesel': 'partial',
#  'Fuel Efficiency Gasoline': 'partial',
#  'Fuel Efficiency Hydrocarbon Gas Liquids': 'partial',
#  'Fuel Efficiency Hydrogen': 'partial',
#  'Fuel Efficiency Kerosene': 'partial',
#  'Fuel Efficiency Natural Gas': 'partial',
#  'Private and Public Transportation Mode Share': 'partial',
#  'Regional Transportation Mode Share': 'partial',
#  'Transportation Mode Fuel Fraction Biofuels': 'partial',
#  'Transportation Mode Fuel Fraction Diesel': 'partial',
#  'Transportation Mode Fuel Fraction Electricity': 'partial',
#  'Transportation Mode Fuel Fraction Gasoline': 'partial',
#  'Transportation Mode Fuel Fraction Hydrocarbon Gas Liquids': 'partial',
#  'Transportation Mode Fuel Fraction Hydrogen': 'partial',
#  'Transportation Mode Fuel Fraction Kerosene': 'partial',
#  'Transportation Mode Fuel Fraction Natural Gas': 'partial',
#  'Electrical Energy Consumption from Transportation': 'partial',
#  'Total Electrical Energy Consumption from Transportation': 'partial',
#  'Total Energy Consumption from Transportation': 'partial',
#  'Total Megatonne-Kilometer Demand by Vehicle': 'partial',
#  'Total Passenger Distance by Vehicle': 'partial',
#  'Transportation Modal Energy Consumption from Biofuels': 'partial',
#  'Transportation Modal Energy Consumption from Diesel': 'partial',
#  'Transportation Modal Energy Consumption from Electricity': 'partial',
#  'Transportation Modal Energy Consumption from Gasoline': 'partial',
#  'Transportation Modal Energy Consumption from Hydrocarbon Gas Liquids': 'partial',
#  'Transportation Modal Energy Consumption from Hydrogen': 'partial',
#  'Transportation Modal Energy Consumption from Kerosene': 'partial',
#  'Transportation Modal Energy Consumption from Natural Gas': 'partial',
#  'Vehicle Distance Traveled from Biofuels': 'partial',
#  'Vehicle Distance Traveled from Diesel': 'partial',
#  'Vehicle Distance Traveled from Electricity': 'partial',
#  'Vehicle Distance Traveled from Gasoline': 'partial',
#  'Vehicle Distance Traveled from Hydrocarbon Gas Liquids': 'partial',
#  'Vehicle Distance Traveled from Hydrogen': 'partial',
#  'Vehicle Distance Traveled from Kerosene': 'partial',
#  'Vehicle Distance Traveled from Natural Gas': 'partial',
#  'Transportation Demand Scalar': 'all',
#  'Elasticity of Megatonne-Kilometer Demand to GDP': 'partial',
#  'Elasticity of Passenger-Kilometer Demand per Capita to GDP per Capita': 'partial',
#  'Initial Megatonne-Kilometer Demand': 'partial',
#  'Initial per Capita Passenger-Kilometer Demand': 'partial',
#  'Megatonne-Kilometer Demand': 'partial',
#  'Passenger-Kilometer Demand': 'partial',
#  ':math:\\text{N}_2\\text{O} Wastewater Treatment Emission Factor': 'all',
#  'Fraction of Nitrogen Removed in Treatment': 'all',
#  'Fraction of Phosphorous Removed in Treatment': 'all',
#  'Fraction of Total Organic Waste Removed in Treatment': 'all',
#  'Wastewater Treatment Methane Correction Factor': 'all',
#  ':math:\\text{CH}_4 Emissions from Wastewater Treatment': 'all',
#  ':math:\\text{N}_2\\text{O} Emissions from Wastewater Effluent': 'all',
#  ':math:\\text{N}_2\\text{O} Emissions from Wastewater Treatment': 'all',
#  'Total BOD Organic Waste in Effluent': 'all',
#  'Total BOD Removed in Treatment': 'all',
#  'Total COD Organic Waste in Effluent': 'all',
#  'Total COD Removed in Treatment': 'all',
#  'Volume of Wastewater Treated': 'all',
#  ':math:\\text{K}_{REM} Sludge Factor': 'partial',
#  'Biogas Recovery Factor at Wastewater Treatment Plants': 'partial',
#  'Septic Sludge Compliance Fraction': 'partial',
#  'Biogas Recovered from Wastewater Treatment Plants': 'partial',
#  'Mass of Sludge Produced': 'partial',
#  'Total Nitrogen Removed in Treatment': 'partial',
#  'Total Nitrogen in Effluent': 'partial',
#  'Total Phosphorous Removed in Treatment': 'partial',
#  'Total Phosphorous in Effluent': 'partial'}

# %%
"this" == None
# Out:
# False

# %%
# this is a thing
for k, v in matt_new.dict_variables.items():
    if v.get_property("subsector") == "Agriculture":
        print(k)
# Out:
# :math:\text{CH}_4 Crop Anaerobic Decomposition Emission Factor
# :math:\text{CH}_4 Crop Biomass Burning Emission Factor
# :math:\text{CO}_2 Crop Biomass Emission Factor
# :math:\text{N}_2\text{O} Crop Biomass Burning Emission Factor
# AGRC Combustion Factor
# Above Ground Residue Dry Matter Intercept
# Above Ground Residue Dry Matter Slope
# Agriculture Equivalent Exports
# Agriculture Fraction Dry
# Agriculture Fraction Temperate
# Agriculture Fraction Tropical
# Agriculture Fraction Wet
# Crop Demand Income Elasticity
# Crop Fraction Animal Feed
# Crop Yield Factor
# Dry Matter Fraction of Harvested Crop
# Fraction of Agriculture Demand Imported
# Fraction of Food Loss Sent to Municipal Solid Waste
# Fraction of Food Produced Lost Before Consumption
# Fraction of Residues Burned
# Fraction of Residues Removed
# Initial Cropland Area Proportion
# N Content of Above Ground Residues
# N Content of Below Ground Residues
# No Till Crop Fraction
# Ratio of Above Ground Residue to Harvested Yield
# Ratio of Below Ground Biomass to Above Ground Biomass
# :math:\text{CH}_4 Emissions from Biomass Burning
# :math:\text{CH}_4 Emissions from Rice
# :math:\text{CO}_2 Emissions from Biomass Carbon Stock Changes
# :math:\text{CO}_2 Emissions from Soil Carbon in Organic Soils
# :math:\text{N}_2\text{O} Emissions from Biomass Burning
# :math:\text{N}_2\text{O} Emissions from Crop Residues
# Adjusted Agriculture Equivalent Exports
# Adjusted Agriculture Equivalent Imports
# Changes to Agriculture Net Imports Lost
# Crop Area
# Crop Demand
# Crop Yield
# Cropland Area Proportion
# Total Food Loss Sent to Municipal Solid Waste
# Total Food Produced Lost Before Consumption

# %%
matt_new.configuration.get("area_units") 
matt_new.get_volume_equivalent("m3")
# Out:
# 1.0

# %%
#matt_new.get_unit("monetary").convert("mm_usd", "mmm_usd")
unit_energy.attribute_table.table
# ?sf.format_print_list
# Out:
# Signature: sf.format_print_list(list_in: list, delim=',') -> str
# Docstring: Print (as string) values of list_in to string separated by `delim`
# File:      ~/Documents/Projects/git_jbus/sisepuede/python/support_functions.py
# Type:      function

# %%
#matt_new.get_other_attribute("region").table
matt_new.get_other_attribute("emission_gas").table.head()
# Out:
#                           gas emission_gas                  name  \
# 0         :math:`\text{CH}_4`          ch4               Methane
# 1         :math:`\text{CO}_2`          co2        Carbon Dioxide
# 2  :math:`\text{N}_2\text{O}`          n2o          Nitrus Oxide
# 3         :math:`\text{NF}_3`          nf3  Nitrogen Trifluoride
# 4         :math:`\text{SF}_6`          sf6    Sulfur Hexflouride
#
#    global_warming_potential_20  global_warming_potential_100  \
# 0                         81.2                          27.9
# 1                          1.0                           1.0
# 2                        273.0                         273.0
# 3                      13400.0                       17400.0
# 4                      18300.0                       25200.0
#
#    global_warming_potential_500    source flourinated_compound_designation
# 0                          7.95  IPCC AR6                             none
# 1                          1.00  IPCC AR6                             none
# 2                        130.00  IPCC AR6                             none
# 3                      18200.00  IPCC AR6                         Other FC
# 4                      34100.00  IPCC AR6                         Other FC

# %%
#matt_new.get_unit("energy").convert("kWh", "GJ")
unit_energy = matt_new.get_unit("energy")
unit_power = matt_new.get_unit("power")

input_unit = "mw"
units = unit_energy.get_unit_key(input_unit)
units = unit_power.get_unit_key(input_unit)
units
# Out:
# 'mw'

# %%
unit_energy.get_attribute("kWh", "hourly_unit_power_equivalent")
# Out:
# '``kw``'

# %%
mv.clean_element(
    unit_power.get_attribute("MW", "annualized_unit_energy_equivalent")
)
# Out:
# 'mwy'

# %%
#matt_new.get_unit("energy").attribute_table.table
matt_new.get_unit("energy").get_unit_key(modvar)

# %%
#sa.model_attributes.get_energy_power_swap("MW")
unit_energy.attribute_table.table
# Out:
#    energy unit_energy hourly_unit_power_equivalent  \
# 0      kJ          kj                         none
# 1     BTU         btu                         none
# 2      MJ          mj                         none
# 3    MBTU        mbtu                         none
# 4     kWh         kwh                       ``kw``
# 5      GJ          gj                         none
# 6   MMBTU       mmbtu                         none
# 7     MWh         mwh                       ``mw``
# 8      TJ          tj                         none
# 9     MWy         mwy                         none
# 10     PJ          pj                         none
# 11    GWy         gwy                         none
#
#    annualized_unit_power_equivalent                           name  \
# 0                              none                      Kilojoule
# 1                              none           British Thermal Unit
# 2                              none                      Megajoule
# 3                              none  Thousand British Thermal Unit
# 4                              none                  Kilowatt-hour
# 5                              none                      Gigajoule
# 6                              none   Million British Thermal Unit
# 7                              none                  Megawatt-hour
# 8                              none                      Terajoule
# 9                            ``mw``                  Megawatt-year
# 10                             none                      Petajoule
# 11                           ``gw``                  Gigawatt-year
#
#     energy_equivalent_kj  energy_equivalent_btu  energy_equivalent_mj  \
# 0           1.000000e+00           9.478134e-01          1.000000e-03
# 1           1.055060e+00           1.000000e+00          1.055060e-03
# 2           1.000000e+03           9.478134e+02          1.000000e+00
# 3           1.055060e+03           1.000000e+03          1.055060e+00
# 4           3.600000e+03           3.412128e+03          3.600000e+00
# 5           1.000000e+06           9.478134e+05          1.000000e+03
# 6           1.055060e+06           1.000000e+06          1.055060e+03
# 7           3.600000e+06           3.412128e+06          3.600000e+03
# 8           1.000000e+09           9.478134e+08          1.000000e+06
# 9           3.155760e+10           2.991072e+10          3.160000e+07
# 10          1.000000e+12           9.480000e+11          1.000000e+09
# 11          3.160000e+13           2.990000e+13          3.155760e+10
#
#     energy_equivalent_mbtu  energy_equivalent_kwh  energy_equivalent_gj  \
# 0             9.500000e-04           2.777780e-04          1.000000e-06
# 1             1.000000e-03           2.930710e-04          1.060000e-06
# 2             9.500000e-01           2.777778e-01          1.000000e-03
# 3             1.000000e+00           2.930722e-01          1.055060e-03
# 4             3.410000e+00           1.000000e+00          3.600000e-03
# 5             9.478100e+02           2.777778e+02          1.000000e+00
# 6             1.000000e+03           2.930722e+02          1.055060e+00
# 7             3.412130e+03           1.000000e+03          3.600000e+00
# 8             9.478134e+05           2.777778e+05          1.000000e+03
# 9             2.991072e+07           8.766000e+06          3.155760e+04
# 10            9.480000e+08           2.777778e+08          1.000000e+06
# 11            2.990000e+10           8.766000e+09          3.155760e+07
#
#     energy_equivalent_mmbtu  energy_equivalent_mwh  energy_equivalent_tj  \
# 0              9.480000e-07           2.780000e-07          1.000000e-09
# 1              1.000000e-06           2.930710e-07          1.060000e-09
# 2              9.478130e-04           2.780000e-04          1.000000e-06
# 3              1.000000e-03           2.930000e-04          1.060000e-06
# 4              3.412128e-03           1.000000e-03          3.600000e-06
# 5              9.478134e-01           2.780000e-01          1.000000e-03
# 6              1.000000e+00           2.930000e-01          1.055060e-03
# 7              3.412128e+00           1.000000e+00          3.600000e-03
# 8              9.478134e+02           2.780000e+02          1.000000e+00
# 9              2.991072e+04           8.770000e+03          3.155760e+01
# 10             9.480000e+05           2.780000e+05          1.000000e+03
# 11             2.990000e+07           8.770000e+06          3.155760e+04
#
#     energy_equivalent_mwy  energy_equivalent_pj  energy_equivalent_gwy
# 0            3.170000e-11          1.000000e-12           3.170000e-14
# 1            3.340000e-11          1.060000e-12           3.340000e-14
# 2            3.170000e-08          1.000000e-09           3.170000e-11
# 3            3.340000e-08          1.060000e-09           3.340000e-11
# 4            1.140000e-07          3.600000e-09           1.140000e-10
# 5            3.170000e-05          1.000000e-06           3.170000e-08
# 6            3.340000e-05          1.060000e-06           3.340000e-08
# 7            1.140770e-04          3.600000e-06           1.140000e-07
# 8            3.168809e-02          1.000000e-03           3.170000e-05
# 9            1.000000e+00          3.155760e-02           1.000000e-03
# 10           3.168809e+01          1.000000e+00           3.168809e-02
# 11           1.000000e+03          3.155760e+01           1.000000e+00

# %%
modvar = matt_new.dict_variables.get("Unadjusted Land Use Transition Probability")
modvar = matt_new.dict_variables.get(":math:\\text{CH}_4 Stationary Combustion Emission Factor")

#modvar.attribute("unit_mass")
modvar.attribute("unit_area")
modvar.name_fs_safe.upper()
# Out:
# 'CH4_STATIONARY_COMBUSTION_EMISSION_FACTOR'

# %%
for k, v in matt_new.dict_attributes.get("unit").items():
    print(v.key)
    print(v.table.dtypes)
    print("\n")

# %%
#import units_manager as um
attr = matt_new.dict_attributes.get("unit").get("area")

fields_avail = [
    x for x in attr.table.columns
    if attr.table[x].dtype not in ["float64", "int64"]
]
fields_avail
# Out:
# ['area', 'unit_area', 'name']

# %%
importlib.reload(um)
attr = matt_new.dict_attributes.get("unit").get("energy")
unit = um.Units(
    attr,
    key_prependage = "unit_",
)
unit.key

#attr.table
unit.get_unit_key("GJ")
# Out:
# 'gj'

# %%
importlib.reload(sf)
importlib.reload(mv)
import time


t0 = time.time()
#modvar = mv.ModelVariable(
#    attr_vars.table.iloc[2],
#    sa.model_attributes.dict_attributes,
#)
t1 = time.time()

"""
vs = mv.VariableSchema(
    modvar.dict_varinfo.get("variable_schema")
)
vs.mutable_elements_clean_ordered
vs.replace({"cat_industry": "cement"}, keys_are_clean = True,)
""";

#modvar.dict_varinfo
#modvar.dict_varinfo





series = attr_vars.table.iloc[2].copy()
series["variable_schema"] = "``ef_ippu_$UNIT-MASS$_$EMISSION-GAS$_per_$UNIT-MASS$_product_use_$CAT-INDUSTRY-DIM1$_$CAT-INDUSTRY-DIM2$_$CAT-TRANSPORTATION$`` (``$UNIT-MASS$ = tonne``, ``$EMISSION-GAS$ = co2``"
series["categories"] = "(``$CAT-INDUSTRY_DIM2$ = paper|cement|plastic``, ``$CAT-INDUSTRY-DIM1$ = product_use_lubricants|product_use_paraffin_wax|cement|plastic``, ``$CAT-TRANSPORTATION$ = aviation|rail_freight|dymm``)"
series["default_value"] = 0.0
#series["categories"] = "(``$CAT-INDUSTRY$ = all``, ``$CAT-TRANSPORTATION$ = aviation|rail_freight|dymm``)"

#series["variable_schema"] = "pij_$CAT-LANDUSE-DIM1$_to_$CAT-LANDUSE-DIM2$"
#series["categories"] = "all"

modvar = mv.ModelVariable(
    series,
    sa.model_attributes.dict_attributes,
)





# get_root_element("CAT-INDUSTRY-DIM4")
#modvar.schema.get_root_element("cat_industry_dim3")
# modvar.schema.mutable_elements_clean_ordered
modvar.dict_category_keys
modvar.schema.mutable_elements_clean_ordered
# Out:
# ['cat_industry_dim1', 'cat_industry_dim2', 'cat_transportation']

# %%
regex_at = re.compile("attribute_unit_(.*).csv")
regex_at.match("attribute_unit_temp_gr.csv").groups()
# Out:
# ('temp_gr',)

# %%
#sa.model_attributes.all_model_variables
fp = "/Users/jsyme/Documents/Projects/git_jbus/sisepuede/docs/source/csvs/attribute_length.csv"
at = AttributeTable(fp, "length", clean_table_fields = True,)
at.table()
# Out:
#   length unit_length        name  length_equivalent_m  length_equivalent_km  \
# 0      m       ``m``      Meters         1.000000e+00               0.00100
# 1     km      ``km``  Kilometers         1.000000e+03               1.00000
# 2   Mile    ``mile``       Miles         1.609340e+03               1.60934
# 3     Mm     ``mgm``  Megameters         1.000000e+06            1000.00000
# 4     Gm      ``gm``  Gigameters         1.000000e+09         1000000.00000
#
#    length_equivalent_mile  length_equivalent_mgm  length_equivalent_gm
# 0            6.213730e-04               0.000001          1.000000e-09
# 1            6.213700e-01               0.001000          1.000000e-06
# 2            1.000000e+00               0.001609          1.609340e-06
# 3            6.213700e-04               1.000000          1.000000e-03
# 4            6.213700e-07            1000.000000          1.000000e+00

# %%
modvar(
    df, 
    expand_to_all_categories = False,
    return_type = "array",
)
# Out:
# array([[0.92536768, 0.24845778, 0.37953433, 0.14847882, 0.25139435,
#         0.71123234, 0.15856626, 0.48581205, 0.68147416, 0.54829414,
#         0.08388734, 0.42894816, 0.66173826, 0.07984463, 0.47521661,
#         0.38798217, 0.5266003 , 0.4420342 , 0.88720961, 0.88586851,
#         0.70495647, 0.64484206, 0.15106266, 0.60722337],
#        [0.92536768, 0.24845778, 0.37953433, 0.14847882, 0.25139435,
#         0.71123234, 0.15856626, 0.48581205, 0.68147416, 0.54829414,
#         0.08388734, 0.42894816, 0.66173826, 0.07984463, 0.47521661,
#         0.38798217, 0.5266003 , 0.4420342 , 0.88720961, 0.88586851,
#         0.70495647, 0.64484206, 0.15106266, 0.60722337],
#        [0.92536768, 0.24845778, 0.37953433, 0.14847882, 0.25139435,
#         0.71123234, 0.15856626, 0.48581205, 0.68147416, 0.54829414,
#         0.08388734, 0.42894816, 0.66173826, 0.07984463, 0.47521661,
#         0.38798217, 0.5266003 , 0.4420342 , 0.88720961, 0.88586851,
#         0.70495647, 0.64484206, 0.15106266, 0.60722337],
#        [0.92536768, 0.24845778, 0.37953433, 0.14847882, 0.25139435,
#         0.71123234, 0.15856626, 0.48581205, 0.68147416, 0.54829414,
#         0.08388734, 0.42894816, 0.66173826, 0.07984463, 0.47521661,
#         0.38798217, 0.5266003 , 0.4420342 , 0.88720961, 0.88586851,
#         0.70495647, 0.64484206, 0.15106266, 0.60722337],
#        [0.92536768, 0.24845778, 0.37953433, 0.14847882, 0.25139435,
#         0.71123234, 0.15856626, 0.48581205, 0.68147416, 0.54829414,
#         0.08388734, 0.42894816, 0.66173826, 0.07984463, 0.47521661,
#         0.38798217, 0.5266003 , 0.4420342 , 0.88720961, 0.88586851,
#         0.70495647, 0.64484206, 0.15106266, 0.60722337],
#        [0.92536768, 0.24845778, 0.37953433, 0.14847882, 0.25139435,
#         0.71123234, 0.15856626, 0.48581205, 0.68147416, 0.54829414,
#         0.08388734, 0.42894816, 0.66173826, 0.07984463, 0.47521661,
#         0.38798217, 0.5266003 , 0.4420342 , 0.88720961, 0.88586851,
#         0.70495647, 0.64484206, 0.15106266, 0.60722337],
#        [0.92536768, 0.24845778, 0.37953433, 0.14847882, 0.25139435,
#         0.71123234, 0.15856626, 0.48581205, 0.68147416, 0.54829414,
#         0.08388734, 0.42894816, 0.66173826, 0.07984463, 0.47521661,
#         0.38798217, 0.5266003 , 0.4420342 , 0.88720961, 0.88586851,
#         0.70495647, 0.64484206, 0.15106266, 0.60722337],
#        [0.92536768, 0.24845778, 0.37953433, 0.14847882, 0.25139435,
#         0.71123234, 0.15856626, 0.48581205, 0.68147416, 0.54829414,
#         0.08388734, 0.42894816, 0.66173826, 0.07984463, 0.47521661,
#         0.38798217, 0.5266003 , 0.4420342 , 0.88720961, 0.88586851,
#         0.70495647, 0.64484206, 0.15106266, 0.60722337],
#        [0.92536768, 0.24845778, 0.37953433, 0.14847882, 0.25139435,
#         0.71123234, 0.15856626, 0.48581205, 0.68147416, 0.54829414,
#         0.08388734, 0.42894816, 0.66173826, 0.07984463, 0.47521661,
#         0.38798217, 0.5266003 , 0.4420342 , 0.88720961, 0.88586851,
#         0.70495647, 0.64484206, 0.15106266, 0.60722337],
#        [0.92536768, 0.24845778, 0.37953433, 0.14847882, 0.25139435,
#         0.71123234, 0.15856626, 0.48581205, 0.68147416, 0.54829414,
#         0.08388734, 0.42894816, 0.66173826, 0.07984463, 0.47521661,
#         0.38798217, 0.5266003 , 0.4420342 , 0.88720961, 0.88586851,
#         0.70495647, 0.64484206, 0.15106266, 0.60722337],
#        [0.92536768, 0.24845778, 0.37953433, 0.14847882, 0.25139435,
#         0.71123234, 0.15856626, 0.48581205, 0.68147416, 0.54829414,
#         0.08388734, 0.42894816, 0.66173826, 0.07984463, 0.47521661,
#         0.38798217, 0.5266003 , 0.4420342 , 0.88720961, 0.88586851,
#         0.70495647, 0.64484206, 0.15106266, 0.60722337],
#        [0.92536768, 0.24845778, 0.37953433, 0.14847882, 0.25139435,
#         0.71123234, 0.15856626, 0.48581205, 0.68147416, 0.54829414,
#         0.08388734, 0.42894816, 0.66173826, 0.07984463, 0.47521661,
#         0.38798217, 0.5266003 , 0.4420342 , 0.88720961, 0.88586851,
#         0.70495647, 0.64484206, 0.15106266, 0.60722337],
#        [0.92536768, 0.24845778, 0.37953433, 0.14847882, 0.25139435,
#         0.71123234, 0.15856626, 0.48581205, 0.68147416, 0.54829414,
#         0.08388734, 0.42894816, 0.66173826, 0.07984463, 0.47521661,
#         0.38798217, 0.5266003 , 0.4420342 , 0.88720961, 0.88586851,
#         0.70495647, 0.64484206, 0.15106266, 0.60722337],
#        [0.92536768, 0.24845778, 0.37953433, 0.14847882, 0.25139435,
#         0.71123234, 0.15856626, 0.48581205, 0.68147416, 0.54829414,
#         0.08388734, 0.42894816, 0.66173826, 0.07984463, 0.47521661,
#         0.38798217, 0.5266003 , 0.4420342 , 0.88720961, 0.88586851,
#         0.70495647, 0.64484206, 0.15106266, 0.60722337],
#        [0.92536768, 0.24845778, 0.37953433, 0.14847882, 0.25139435,
#         0.71123234, 0.15856626, 0.48581205, 0.68147416, 0.54829414,
#         0.08388734, 0.42894816, 0.66173826, 0.07984463, 0.47521661,
#         0.38798217, 0.5266003 , 0.4420342 , 0.88720961, 0.88586851,
#         0.70495647, 0.64484206, 0.15106266, 0.60722337],
#        [0.92536768, 0.24845778, 0.37953433, 0.14847882, 0.25139435,
#         0.71123234, 0.15856626, 0.48581205, 0.68147416, 0.54829414,
#         0.08388734, 0.42894816, 0.66173826, 0.07984463, 0.47521661,
#         0.38798217, 0.5266003 , 0.4420342 , 0.88720961, 0.88586851,
#         0.70495647, 0.64484206, 0.15106266, 0.60722337],
#        [0.92536768, 0.24845778, 0.37953433, 0.14847882, 0.25139435,
#         0.71123234, 0.15856626, 0.48581205, 0.68147416, 0.54829414,
#         0.08388734, 0.42894816, 0.66173826, 0.07984463, 0.47521661,
#         0.38798217, 0.5266003 , 0.4420342 , 0.88720961, 0.88586851,
#         0.70495647, 0.64484206, 0.15106266, 0.60722337],
#        [0.92536768, 0.24845778, 0.37953433, 0.14847882, 0.25139435,
#         0.71123234, 0.15856626, 0.48581205, 0.68147416, 0.54829414,
#         0.08388734, 0.42894816, 0.66173826, 0.07984463, 0.47521661,
#         0.38798217, 0.5266003 , 0.4420342 , 0.88720961, 0.88586851,
#         0.70495647, 0.64484206, 0.15106266, 0.60722337],
#        [0.92536768, 0.24845778, 0.37953433, 0.14847882, 0.25139435,
#         0.71123234, 0.15856626, 0.48581205, 0.68147416, 0.54829414,
#         0.08388734, 0.42894816, 0.66173826, 0.07984463, 0.47521661,
#         0.38798217, 0.5266003 , 0.4420342 , 0.88720961, 0.88586851,
#         0.70495647, 0.64484206, 0.15106266, 0.60722337],
#        [0.92536768, 0.24845778, 0.37953433, 0.14847882, 0.25139435,
#         0.71123234, 0.15856626, 0.48581205, 0.68147416, 0.54829414,
#         0.08388734, 0.42894816, 0.66173826, 0.07984463, 0.47521661,
#         0.38798217, 0.5266003 , 0.4420342 , 0.88720961, 0.88586851,
#         0.70495647, 0.64484206, 0.15106266, 0.60722337]])

# %%
#modvar.name.replace(":math:", "").replace("{", "").replace("\\text", "").replace("}")
df = np.full((20, len(modvar.fields_space)), -1)
df = pd.DataFrame(df, columns = modvar.fields_space)
for fld in modvar.fields:
    df[fld] = np.random.rand()

# %%
importlib.reload(mv)

series = attr_vars.table.iloc[2].copy()
series["variable_schema"] = "``ef_ippu_$UNIT-MASS$_$EMISSION-GAS$_per_$UNIT-MASS$_product_use_$CAT-INDUSTRY-DIM1$_$CAT-INDUSTRY-DIM2$_$CAT-TRANSPORTATION$`` (``$UNIT-MASS$ = tonne``, ``$EMISSION-GAS$ = co2``"
series["categories"] = "(``$CAT-INDUSTRY_DIM2$ = paper|cement|plastic``, ``$CAT-INDUSTRY-DIM1$ = product_use_lubricants|product_use_paraffin_wax|cement|plastic``, ``$CAT-TRANSPORTATION$ = aviation|rail_freight|dymm``)"

modvar = mv.ModelVariable(
    series,
    sa.model_attributes.dict_attributes,
)




modvar.get_categories_by_element(
    #{
    #    "cat_industry_dim1": ["metals", "plastic", "chemicals"],#"``metals|plastic|chemicals``"
    #},
    dict_category_space = modvar.dict_category_key_space,
)

# %%
modvar.schema.get_root_element("cat_indusdtry_dim2")
20000/122.2
# Out:
# 163.66612111292963

# %%
regex.match("CAT-INDUSTRY-DIM3")
mv.clean_element("-")
# Out:
# '_'

# %%
modvar.schema.mutable_elements_ordered
modvar.schema.space_char
re.compile(f".*{modvar.schema.space_char}{modvar.schema.flag_dim}(\d*)$").match("ahitheX-DIM34")
# Out:
# <re.Match object; span=(0, 13), match='ahitheX-DIM34'>

# %%
#modvar.schema.get_attribute("emission_gas")
hasattr(attr_cat, "key_values")
#modvar.get_categories_from_string(modvar.dict_varinfo.get(modvar.key_categories), "|", "`")

modvar.get_categories_by_element(
    category_subspace = {
        "cat_industry": "``product_use_lubricants|product_use_paraffin_wax``",
        "cat_transportation": "``product_use_lubricants``|``product_use_paraffin_wax``",
        "cat_transportation": "``product_use_lubricants``|``product_use_paraffin_wax``",
    },
    dict_category_space = modvar.dict_category_keys,
    
)
# Out:
# {'cat_industry': ['product_use_lubricants', 'product_use_paraffin_wax']}

# %%
modvar.schema.get_mutable_element(
    "ef_ippu_tonne_co2_per_tonne_production_thisun_jfijdf_clinker",
    "cat_industry"
)
# Out:
# 'thisun_jfijdf'

# %%
modvar.build_field_from_elements(
    {"cat_industry": "cement"}, 
    keys_are_clean = True
)
# Out:
# 'ef_ippu_tonne_co2_per_tonne_production_cement_clinker'

# %%
class Field:
    
    def __init__(self,
        field: str,
        cat: Union[Dict, str, None],
    ):
        
        self.field = field
        self.cat = cat
        
        
    
    def __call__(self,
    ):
        
        return self.field
    

field = Field("ef_ippu_tonne_co2_per_tonne_production_cement_clinker", {"cat_industry": "cement"})

field(), field.cat
# Out:
# ('ef_ippu_tonne_co2_per_tonne_production_cement_clinker',
#  {'cat_industry': 'cement'})

# %%
sr = "``ef_ippu_$UNIT-MASS$_$EMISSION-GAS$_per_$UNIT-MASS$_production_$CAT-INDUSTRY-I$_$CAT-TRANSPORTATION-J$`` (``$UNIT-MASS$ = tonne``, ``$EMISSION-GAS$ = ch4``)"
vs2 = mv.VariableSchema(sr)
vs2.mutable_elements_ordered


vs2.replace({"cat_industry_i": "cementitude", "cat_transportation_j": "airplanification"}, keys_are_clean = True,)
# Out:
# 'ef_ippu_tonne_ch4_per_tonne_production_cementitude_airplanification'

# %%
vs.mutable_elements_clean_ordered

# %%
sa.model_attributes.dict_attributes.get("abbreviation_subsector").table;

# %%
dict1 = {}

dict1[None] = 2
dict1
# Out:
# {None: 2}

# %%
def get_variable_schema_base(#self,
    var_schema_raw: str,
) -> str:
    """
    Using a raw variable schema, replace any unit and emission specifications
    """
    
    dict_replacements, schema  = mv.clean_schema(
        var_schema_raw, 
        return_type = "all"
    )
    
    return dict_replacements, schema

dict_replacements, schema = get_variable_schema_base(
    modvar.dict_varinfo.get("variable_schema")
)

# %%
isinstance(pd.DataFrame, type)
# Out:
# True

# %%
#regex = re.compile("(.*)\$(.*)\$(.*$)")
regex = re.compile("(?<=\$)(.*?)(?=\$)")
regex.findall("this $THIS$ $THIS2$")
#regex = re.search("(?<=\$)(.*?)(?=\$)", "this $HERE$ $NOPE$")
# Out:
# ['THIS', ' ', 'THIS2']

# %%
string = "this $THIS$ $THIS2$"
string.count("$")
# Out:
# 0

# %%
modvar.dict_varinfo.get("variable_schema")
# Out:
# '``ef_ippu_$UNIT-MASS$_$EMISSION-GAS$_per_$UNIT-MASS$_production_$CAT-INDUSTRY$`` (``$UNIT-MASS$ = tonne``, ``$EMISSION-GAS$ = ch4``)'

# %%
arr_1 = np.array([7, 11, 13, 17, 19, 23, 29])

prs = [2, 3, 5, 7, 11, 13, 17, 19]
arr_2 = []
gaps = []
for i in range(np.prod(prs)):
    check = [i%x for x in prs]
    binary = int(0 in check)
    
    arr_2.append(binary)
    if not binary:
        gaps.append(i)


P = np.prod(prs)
gaps_g1 = [x for x in gaps if x > 1]

classes = []
if False:
    l = []
    for i in range(1, 2):#len(arr_1) + 1):
        subs = list(itertools.combinations(gaps_g1, i))

        l.extend(subs)


    classes = []
    for i, sub in enumerate(l):
        val = np.prod(sub)
        mod = val%P

        classes.append(mod)

    classes = set(classes)
diffs = np.array(gaps[1:]) - np.array(gaps[0:-1])
len([x for x in diffs if x == 4])
w = np.abs(np.array(diffs[1:]) - np.array(diffs[0:-1]))
w = np.where(w == 0)
w;




pi1 = prs[-1]
counts_2 = []

P_prev = np.prod(prs[0:-1])
# check counts of 2 among each subdivision--should be relatively smooth
for i in range(pi1):
    gps = [x for x in gaps if (x >= i*P_prev) & (x < (i + 1)*P_prev)]
    
    ds = np.array(gps[1:]) - np.array(gps[0:-1])
    n = len([x for x in ds if x == 2])
    
    print(n)
    counts_2.append(n)
    #len([x for x in diffs[0:n] if x == 2])
    
    
import sympy
# non-prime nums
gaps_nopr = [x for x in gaps if (not sympy.isprime(x)) and (x > 1)]


l = []
for i in range(1, len(gaps_nopr) + 1):
    subs = list(itertools.combinations(gaps_nopr, i))
    
    l.extend(subs)

classes = []
for i, sub in enumerate(l):
    val = np.prod(sub)
    mod = val%P
    
    classes.append(mod)
    
    
gaps_nopr = [x for x in gaps if (not sympy.isprime(x)) and (x > 1)]
classes = []
for i in range(1, 3):#len(gaps_nopr) + 1):
    combs = itertools.combinations(gaps_nopr, i)
    
    for comb in combs:
        class_check = np.prod(comb)%P
        classes.append(class_check) if (class_check not in classes) else None
    
classes2 = classes.copy()
