# %%
import os, os.path
import numpy as np
import pandas as pd
import model_attributes as ma
from attribute_table import AttributeTable
import model_afolu as mafl
import model_ippu as mi
import model_circular_economy as mc
import model_energy as me
import model_electricity as ml
import model_socioeconomic as se
from model_socioeconomic import Socioeconomic
import pathlib
import setup_analysis as sa
import sisepuede as ssp
import support_classes as sc
import support_functions as sf
import importlib
import time
import warnings
import matplotlib.pyplot as plt
import sql_utilities as sq
from typing import *
import sqlalchemy
import sql_utilities as sqlutil
import time
importlib.reload(ma)
importlib.reload(sa)
importlib.reload(sf)
importlib.reload(mafl)
importlib.reload(mc)
importlib.reload(mi)
importlib.reload(me)
importlib.reload(se)
importlib.reload(ml)

warnings.filterwarnings("ignore")
# Out:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:2710: UserWarning: Invalid subsector attribute 'key_varreqs_partial'. Valid return type values are:'pycategory_primary', 'abv_subsector', 'sector', 'abv_sector', 'key_varreqs_all'
#   warnings.warn(f"Invalid subsector attribute '{return_type}'. Valid return type values are:{valid_rts}")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:2446: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for desig, df in df_by_designation:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:5405: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:5405: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:5405: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:5405: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:5405: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:5405: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:5405: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:5405: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:5405: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:5405: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:5405: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:5405: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'public', 'road_light', 'road_heavy_freight', 'road_heavy_regional' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'public', 'rail_freight', 'rail_passenger', 'road_light', 'road_heavy_freight', 'road_heavy_regional', 'water_borne' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'powered_bikes', 'public', 'rail_freight', 'rail_passenger', 'road_heavy_freight', 'road_heavy_regional', 'road_light', 'water_borne' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'powered_bikes', 'public', 'road_light', 'road_heavy_freight', 'road_heavy_regional' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'public', 'road_heavy_freight', 'road_heavy_regional', 'road_light' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'public', 'rail_freight', 'rail_passenger', 'road_heavy_freight', 'road_heavy_regional', 'road_light', 'water_borne' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'public', 'rail_freight', 'rail_passenger', 'road_heavy_freight', 'road_heavy_regional', 'water_borne' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'aviation', 'public', 'rail_freight', 'rail_passenger', 'road_heavy_freight', 'road_heavy_regional', 'road_light', 'water_borne' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'aviation' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'road_light', 'road_heavy_freight', 'road_heavy_regional' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'rail_freight', 'rail_passenger', 'road_light', 'road_heavy_freight', 'road_heavy_regional', 'water_borne' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'aviation', 'powered_bikes', 'rail_freight', 'rail_passenger', 'road_heavy_freight', 'road_heavy_regional', 'road_light', 'water_borne' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'powered_bikes', 'road_light', 'road_heavy_freight', 'road_heavy_regional' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'road_heavy_freight', 'road_heavy_regional', 'road_light' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'aviation', 'rail_freight', 'rail_passenger', 'road_heavy_freight', 'road_heavy_regional', 'road_light', 'water_borne' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'rail_freight', 'rail_passenger', 'road_heavy_freight', 'road_heavy_regional', 'water_borne' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'public', 'rail_passenger', 'road_light', 'road_heavy_freight', 'road_heavy_regional', 'water_borne' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'aviation', 'powered_bikes', 'public', 'rail_passenger', 'road_heavy_freight', 'road_heavy_regional', 'road_light', 'water_borne' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'aviation', 'public', 'rail_passenger', 'road_heavy_freight', 'road_heavy_regional', 'road_light', 'water_borne' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'public', 'rail_passenger', 'road_heavy_freight', 'road_heavy_regional', 'water_borne' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'public', 'rail_freight', 'road_light', 'road_heavy_freight', 'road_heavy_regional', 'water_borne' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'aviation', 'powered_bikes', 'public', 'rail_freight', 'road_heavy_freight', 'road_heavy_regional', 'road_light', 'water_borne' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'aviation', 'public', 'rail_freight', 'road_heavy_freight', 'road_heavy_regional', 'road_light', 'water_borne' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'public', 'rail_freight', 'road_heavy_freight', 'road_heavy_regional', 'water_borne' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'public', 'road_light', 'road_heavy_regional' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'public', 'rail_freight', 'rail_passenger', 'road_light', 'road_heavy_regional', 'water_borne' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'aviation', 'powered_bikes', 'public', 'rail_freight', 'rail_passenger', 'road_heavy_regional', 'road_light', 'water_borne' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'powered_bikes', 'public', 'road_light', 'road_heavy_regional' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'public', 'road_heavy_regional', 'road_light' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'aviation', 'public', 'rail_freight', 'rail_passenger', 'road_heavy_regional', 'road_light', 'water_borne' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'public', 'rail_freight', 'rail_passenger', 'road_heavy_regional', 'water_borne' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'public', 'road_light', 'road_heavy_freight' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'public', 'rail_freight', 'rail_passenger', 'road_light', 'road_heavy_freight', 'water_borne' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'aviation', 'powered_bikes', 'public', 'rail_freight', 'rail_passenger', 'road_heavy_freight', 'road_light', 'water_borne' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'powered_bikes', 'public', 'road_light', 'road_heavy_freight' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'public', 'road_heavy_freight', 'road_light' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'aviation', 'public', 'rail_freight', 'rail_passenger', 'road_heavy_freight', 'road_light', 'water_borne' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'public', 'rail_freight', 'rail_passenger', 'road_heavy_freight', 'water_borne' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'public', 'road_heavy_freight', 'road_heavy_regional' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'aviation', 'powered_bikes', 'public', 'rail_freight', 'rail_passenger', 'road_heavy_freight', 'road_heavy_regional', 'water_borne' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'powered_bikes', 'public', 'road_heavy_freight', 'road_heavy_regional' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'aviation', 'public', 'rail_freight', 'rail_passenger', 'road_heavy_freight', 'road_heavy_regional', 'water_borne' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'public', 'rail_freight', 'rail_passenger', 'road_light', 'road_heavy_freight', 'road_heavy_regional' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'aviation', 'powered_bikes', 'public', 'rail_freight', 'rail_passenger', 'road_heavy_freight', 'road_heavy_regional', 'road_light' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'aviation', 'public', 'rail_freight', 'rail_passenger', 'road_heavy_freight', 'road_heavy_regional', 'road_light' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'public', 'rail_freight', 'rail_passenger', 'road_heavy_freight', 'road_heavy_regional' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:5405: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:5405: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:5405: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:5405: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'other', 'settlements' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'grasslands', 'settlements' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'grasslands', 'other' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:5405: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:5405: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:5405: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:5405: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:5405: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'cement', 'chemicals', 'electronics', 'glass', 'lime_and_carbonite', 'metals', 'mining', 'other_product_manufacturing', 'paper', 'plastic', 'recycled_glass', 'recycled_metals', 'recycled_paper', 'recycled_plastic', 'recycled_rubber_and_leather', 'recycled_textiles', 'recycled_wood', 'rubber_and_leather', 'textiles', 'wood' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'mining' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'agriculture_and_livestock', 'chemicals', 'electronics', 'glass', 'lime_and_carbonite', 'metals', 'mining', 'other_product_manufacturing', 'paper', 'plastic', 'recycled_glass', 'recycled_metals', 'recycled_paper', 'recycled_plastic', 'recycled_rubber_and_leather', 'recycled_textiles', 'recycled_wood', 'rubber_and_leather', 'textiles', 'wood' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'agriculture_and_livestock', 'cement', 'electronics', 'glass', 'lime_and_carbonite', 'metals', 'mining', 'other_product_manufacturing', 'paper', 'plastic', 'recycled_glass', 'recycled_metals', 'recycled_paper', 'recycled_plastic', 'recycled_rubber_and_leather', 'recycled_textiles', 'recycled_wood', 'rubber_and_leather', 'textiles', 'wood' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'agriculture_and_livestock', 'cement', 'chemicals', 'glass', 'lime_and_carbonite', 'metals', 'mining', 'other_product_manufacturing', 'paper', 'plastic', 'recycled_glass', 'recycled_metals', 'recycled_paper', 'recycled_plastic', 'recycled_rubber_and_leather', 'recycled_textiles', 'recycled_wood', 'rubber_and_leather', 'textiles', 'wood' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'agriculture_and_livestock', 'cement', 'chemicals', 'electronics', 'lime_and_carbonite', 'metals', 'mining', 'other_product_manufacturing', 'paper', 'plastic', 'recycled_glass', 'recycled_metals', 'recycled_paper', 'recycled_plastic', 'recycled_rubber_and_leather', 'recycled_textiles', 'recycled_wood', 'rubber_and_leather', 'textiles', 'wood' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'agriculture_and_livestock', 'cement', 'chemicals', 'electronics', 'glass', 'metals', 'mining', 'other_product_manufacturing', 'paper', 'plastic', 'recycled_glass', 'recycled_metals', 'recycled_paper', 'recycled_plastic', 'recycled_rubber_and_leather', 'recycled_textiles', 'recycled_wood', 'rubber_and_leather', 'textiles', 'wood' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'agriculture_and_livestock', 'cement', 'chemicals', 'electronics', 'glass', 'lime_and_carbonite', 'mining', 'other_product_manufacturing', 'paper', 'plastic', 'recycled_glass', 'recycled_metals', 'recycled_paper', 'recycled_plastic', 'recycled_rubber_and_leather', 'recycled_textiles', 'recycled_wood', 'rubber_and_leather', 'textiles', 'wood' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'agriculture_and_livestock', 'cement', 'chemicals', 'electronics', 'glass', 'lime_and_carbonite', 'metals', 'other_product_manufacturing', 'paper', 'plastic', 'recycled_glass', 'recycled_metals', 'recycled_paper', 'recycled_plastic', 'recycled_rubber_and_leather', 'recycled_textiles', 'recycled_wood', 'rubber_and_leather', 'textiles', 'wood' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'agriculture_and_livestock', 'cement', 'chemicals', 'electronics', 'glass', 'lime_and_carbonite', 'metals', 'mining', 'paper', 'plastic', 'recycled_glass', 'recycled_metals', 'recycled_paper', 'recycled_plastic', 'recycled_rubber_and_leather', 'recycled_textiles', 'recycled_wood', 'rubber_and_leather', 'textiles', 'wood' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'agriculture_and_livestock', 'cement', 'chemicals', 'electronics', 'glass', 'lime_and_carbonite', 'metals', 'mining', 'other_product_manufacturing', 'plastic', 'recycled_glass', 'recycled_metals', 'recycled_paper', 'recycled_plastic', 'recycled_rubber_and_leather', 'recycled_textiles', 'recycled_wood', 'rubber_and_leather', 'textiles', 'wood' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'agriculture_and_livestock', 'cement', 'chemicals', 'electronics', 'glass', 'lime_and_carbonite', 'metals', 'mining', 'other_product_manufacturing', 'paper', 'recycled_glass', 'recycled_metals', 'recycled_paper', 'recycled_plastic', 'recycled_rubber_and_leather', 'recycled_textiles', 'recycled_wood', 'rubber_and_leather', 'textiles', 'wood' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'agriculture_and_livestock', 'cement', 'chemicals', 'electronics', 'glass', 'lime_and_carbonite', 'metals', 'mining', 'other_product_manufacturing', 'paper', 'plastic', 'recycled_metals', 'recycled_paper', 'recycled_plastic', 'recycled_rubber_and_leather', 'recycled_textiles', 'recycled_wood', 'rubber_and_leather', 'textiles', 'wood' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'agriculture_and_livestock', 'cement', 'chemicals', 'electronics', 'glass', 'lime_and_carbonite', 'metals', 'mining', 'other_product_manufacturing', 'paper', 'plastic', 'recycled_glass', 'recycled_paper', 'recycled_plastic', 'recycled_rubber_and_leather', 'recycled_textiles', 'recycled_wood', 'rubber_and_leather', 'textiles', 'wood' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'agriculture_and_livestock', 'cement', 'chemicals', 'electronics', 'glass', 'lime_and_carbonite', 'metals', 'mining', 'other_product_manufacturing', 'paper', 'plastic', 'recycled_glass', 'recycled_metals', 'recycled_plastic', 'recycled_rubber_and_leather', 'recycled_textiles', 'recycled_wood', 'rubber_and_leather', 'textiles', 'wood' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'agriculture_and_livestock', 'cement', 'chemicals', 'electronics', 'glass', 'lime_and_carbonite', 'metals', 'mining', 'other_product_manufacturing', 'paper', 'plastic', 'recycled_glass', 'recycled_metals', 'recycled_paper', 'recycled_rubber_and_leather', 'recycled_textiles', 'recycled_wood', 'rubber_and_leather', 'textiles', 'wood' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'agriculture_and_livestock', 'cement', 'chemicals', 'electronics', 'glass', 'lime_and_carbonite', 'metals', 'mining', 'other_product_manufacturing', 'paper', 'plastic', 'recycled_glass', 'recycled_metals', 'recycled_paper', 'recycled_plastic', 'recycled_textiles', 'recycled_wood', 'rubber_and_leather', 'textiles', 'wood' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'agriculture_and_livestock', 'cement', 'chemicals', 'electronics', 'glass', 'lime_and_carbonite', 'metals', 'mining', 'other_product_manufacturing', 'paper', 'plastic', 'recycled_glass', 'recycled_metals', 'recycled_paper', 'recycled_plastic', 'recycled_rubber_and_leather', 'recycled_wood', 'rubber_and_leather', 'textiles', 'wood' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'agriculture_and_livestock', 'cement', 'chemicals', 'electronics', 'glass', 'lime_and_carbonite', 'metals', 'mining', 'other_product_manufacturing', 'paper', 'plastic', 'recycled_glass', 'recycled_metals', 'recycled_paper', 'recycled_plastic', 'recycled_rubber_and_leather', 'recycled_textiles', 'rubber_and_leather', 'textiles', 'wood' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'agriculture_and_livestock', 'cement', 'chemicals', 'electronics', 'glass', 'lime_and_carbonite', 'metals', 'mining', 'other_product_manufacturing', 'paper', 'plastic', 'recycled_glass', 'recycled_metals', 'recycled_paper', 'recycled_plastic', 'recycled_rubber_and_leather', 'recycled_textiles', 'recycled_wood', 'textiles', 'wood' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'agriculture_and_livestock', 'cement', 'chemicals', 'electronics', 'glass', 'lime_and_carbonite', 'metals', 'mining', 'other_product_manufacturing', 'paper', 'plastic', 'recycled_glass', 'recycled_metals', 'recycled_paper', 'recycled_plastic', 'recycled_rubber_and_leather', 'recycled_textiles', 'recycled_wood', 'rubber_and_leather', 'wood' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'agriculture_and_livestock', 'cement', 'chemicals', 'electronics', 'glass', 'lime_and_carbonite', 'metals', 'mining', 'other_product_manufacturing', 'paper', 'plastic', 'recycled_glass', 'recycled_metals', 'recycled_paper', 'recycled_plastic', 'recycled_rubber_and_leather', 'recycled_textiles', 'recycled_wood', 'rubber_and_leather', 'textiles' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:5405: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:5405: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:5405: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:5405: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:5405: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# ...
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'agriculture_and_livestock', 'cement', 'chemicals', 'electronics', 'glass', 'lime_and_carbonite', 'metals', 'mining', 'paper', 'plastic', 'recycled_glass', 'recycled_metals', 'recycled_paper', 'recycled_plastic', 'recycled_rubber_and_leather', 'recycled_textiles', 'recycled_wood', 'rubber_and_leather', 'textiles', 'wood' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'agriculture_and_livestock', 'cement', 'chemicals', 'electronics', 'glass', 'lime_and_carbonite', 'metals', 'mining', 'other_product_manufacturing', 'plastic', 'recycled_glass', 'recycled_metals', 'recycled_paper', 'recycled_plastic', 'recycled_rubber_and_leather', 'recycled_textiles', 'recycled_wood', 'rubber_and_leather', 'textiles', 'wood' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'agriculture_and_livestock', 'cement', 'chemicals', 'electronics', 'glass', 'lime_and_carbonite', 'metals', 'mining', 'other_product_manufacturing', 'paper', 'recycled_glass', 'recycled_metals', 'recycled_paper', 'recycled_plastic', 'recycled_rubber_and_leather', 'recycled_textiles', 'recycled_wood', 'rubber_and_leather', 'textiles', 'wood' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'agriculture_and_livestock', 'cement', 'chemicals', 'electronics', 'glass', 'lime_and_carbonite', 'metals', 'mining', 'other_product_manufacturing', 'paper', 'plastic', 'recycled_metals', 'recycled_paper', 'recycled_plastic', 'recycled_rubber_and_leather', 'recycled_textiles', 'recycled_wood', 'rubber_and_leather', 'textiles', 'wood' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'agriculture_and_livestock', 'cement', 'chemicals', 'electronics', 'glass', 'lime_and_carbonite', 'metals', 'mining', 'other_product_manufacturing', 'paper', 'plastic', 'recycled_glass', 'recycled_paper', 'recycled_plastic', 'recycled_rubber_and_leather', 'recycled_textiles', 'recycled_wood', 'rubber_and_leather', 'textiles', 'wood' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'agriculture_and_livestock', 'cement', 'chemicals', 'electronics', 'glass', 'lime_and_carbonite', 'metals', 'mining', 'other_product_manufacturing', 'paper', 'plastic', 'recycled_glass', 'recycled_metals', 'recycled_plastic', 'recycled_rubber_and_leather', 'recycled_textiles', 'recycled_wood', 'rubber_and_leather', 'textiles', 'wood' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'agriculture_and_livestock', 'cement', 'chemicals', 'electronics', 'glass', 'lime_and_carbonite', 'metals', 'mining', 'other_product_manufacturing', 'paper', 'plastic', 'recycled_glass', 'recycled_metals', 'recycled_paper', 'recycled_rubber_and_leather', 'recycled_textiles', 'recycled_wood', 'rubber_and_leather', 'textiles', 'wood' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'agriculture_and_livestock', 'cement', 'chemicals', 'electronics', 'glass', 'lime_and_carbonite', 'metals', 'mining', 'other_product_manufacturing', 'paper', 'plastic', 'recycled_glass', 'recycled_metals', 'recycled_paper', 'recycled_plastic', 'recycled_textiles', 'recycled_wood', 'rubber_and_leather', 'textiles', 'wood' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'agriculture_and_livestock', 'cement', 'chemicals', 'electronics', 'glass', 'lime_and_carbonite', 'metals', 'mining', 'other_product_manufacturing', 'paper', 'plastic', 'recycled_glass', 'recycled_metals', 'recycled_paper', 'recycled_plastic', 'recycled_rubber_and_leather', 'recycled_wood', 'rubber_and_leather', 'textiles', 'wood' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'agriculture_and_livestock', 'cement', 'chemicals', 'electronics', 'glass', 'lime_and_carbonite', 'metals', 'mining', 'other_product_manufacturing', 'paper', 'plastic', 'recycled_glass', 'recycled_metals', 'recycled_paper', 'recycled_plastic', 'recycled_rubber_and_leather', 'recycled_textiles', 'rubber_and_leather', 'textiles', 'wood' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'agriculture_and_livestock', 'cement', 'chemicals', 'electronics', 'glass', 'lime_and_carbonite', 'metals', 'mining', 'other_product_manufacturing', 'paper', 'plastic', 'recycled_glass', 'recycled_metals', 'recycled_paper', 'recycled_plastic', 'recycled_rubber_and_leather', 'recycled_textiles', 'recycled_wood', 'textiles', 'wood' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'agriculture_and_livestock', 'cement', 'chemicals', 'electronics', 'glass', 'lime_and_carbonite', 'metals', 'mining', 'other_product_manufacturing', 'paper', 'plastic', 'recycled_glass', 'recycled_metals', 'recycled_paper', 'recycled_plastic', 'recycled_rubber_and_leather', 'recycled_textiles', 'recycled_wood', 'rubber_and_leather', 'wood' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:4461: UserWarning: clean_partial_category_dictionary: Invalid categories values 'agriculture_and_livestock', 'cement', 'chemicals', 'electronics', 'glass', 'lime_and_carbonite', 'metals', 'mining', 'other_product_manufacturing', 'paper', 'plastic', 'recycled_glass', 'recycled_metals', 'recycled_paper', 'recycled_plastic', 'recycled_rubber_and_leather', 'recycled_textiles', 'recycled_wood', 'rubber_and_leather', 'textiles' dropped when cleaning the dictionary. Category values not found.
#   warnings.warn(f"clean_partial_category_dictionary: Invalid categories values {missing_vals} dropped when cleaning the dictionary. Category values not found.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:5405: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:5405: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:5405: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:5405: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:5405: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:5405: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:5405: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:5405: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:5405: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:5405: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:5405: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:5405: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:5405: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:5405: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:5405: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:5405: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:5405: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:5405: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:5405: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:5405: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:

# %%
import model_attributes_new as man

# %%
importlib.reload(sf)
importlib.reload(mv)
importlib.reload(um)
importlib.reload(man)

fp = "/Users/jsyme/Documents/Projects/git_jbus/sisepuede/docs_new/source/csvs"
path = pathlib.Path(fp)
#path.exists()

matt_new = man.ModelAttributesNew(path, fp_config = path.parents[2].joinpath("sisepuede.config"))


#modvar = matt_new.dict_variables.get("Volumetric Energy Density")
#modvar.get_property("subsector")
unit_energy = matt_new.get_unit("energy")
unit_power = matt_new.get_unit("power")
unit_power.get_unit_key("none")

# %%
def get_fields_from_variables(#self,
    modvars: Union[str, List[str]],
    sort: bool = False,
) -> Union[List[str], None]:
    """
    Using a list of model variables (or individual), return list of fields.
        Option to sort using sort = True
    """
    
    modvars = [modvars] if isinstance(modvars, str) else list(modvars)
    out = []
    
    for modvar_name in modvars:
        modvar = matt_new.dict_variables.get(modvar_name)
        if modvar is None:
            continue
        
        out += modvar.fields
    
    out.sort() if sort else None
    
    return out
        
get_fields_from_variables(
    ["AGRC Combustion Factor", "Agriculture Fraction Dry"]
)
# Out:
# ['frac_agrc_combustion_factor_cereals',
#  'frac_agrc_combustion_factor_other_annual',
#  'frac_agrc_combustion_factor_pulses',
#  'frac_agrc_combustion_factor_rice',
#  'frac_agrc_combustion_factor_tubers',
#  'frac_agrc_bevs_and_spices_cl2_dry',
#  'frac_agrc_cereals_cl2_dry',
#  'frac_agrc_fibers_cl2_dry',
#  'frac_agrc_fruits_cl2_dry',
#  'frac_agrc_herbs_and_other_perennial_crops_cl2_dry',
#  'frac_agrc_nuts_cl2_dry',
#  'frac_agrc_other_annual_cl2_dry',
#  'frac_agrc_other_woody_perennial_cl2_dry',
#  'frac_agrc_pulses_cl2_dry',
#  'frac_agrc_rice_cl2_dry',
#  'frac_agrc_sugar_cane_cl2_dry',
#  'frac_agrc_tubers_cl2_dry',
#  'frac_agrc_vegetables_and_vines_cl2_dry']

# %%
dict(
    (x, matt_new.get_subsector_variables(x))
    for x in matt_new.all_subsectors
)
# Out:
# {'Agriculture': [':math:\\text{CH}_4 Crop Anaerobic Decomposition Emission Factor',
#   ':math:\\text{CH}_4 Crop Biomass Burning Emission Factor',
#   ':math:\\text{CO}_2 Crop Biomass Emission Factor',
#   ':math:\\text{N}_2\\text{O} Crop Biomass Burning Emission Factor',
#   'AGRC Combustion Factor',
#   'Above Ground Residue Dry Matter Intercept',
#   'Above Ground Residue Dry Matter Slope',
#   'Agriculture Equivalent Exports',
#   'Agriculture Fraction Dry',
#   'Agriculture Fraction Temperate',
#   'Agriculture Fraction Tropical',
#   'Agriculture Fraction Wet',
#   'Crop Demand Income Elasticity',
#   'Crop Fraction Animal Feed',
#   'Crop Yield Factor',
#   'Dry Matter Fraction of Harvested Crop',
#   'Fraction of Agriculture Demand Imported',
#   'Fraction of Food Loss Sent to Municipal Solid Waste',
#   'Fraction of Food Produced Lost Before Consumption',
#   'Fraction of Residues Burned',
#   'Fraction of Residues Removed',
#   'Initial Cropland Area Proportion',
#   'N Content of Above Ground Residues',
#   'N Content of Below Ground Residues',
#   'No Till Crop Fraction',
#   'Ratio of Above Ground Residue to Harvested Yield',
#   'Ratio of Below Ground Biomass to Above Ground Biomass',
#   ':math:\\text{CH}_4 Emissions from Biomass Burning',
#   ':math:\\text{CH}_4 Emissions from Rice',
#   ':math:\\text{CO}_2 Emissions from Biomass Carbon Stock Changes',
#   ':math:\\text{CO}_2 Emissions from Soil Carbon in Organic Soils',
#   ':math:\\text{N}_2\\text{O} Emissions from Biomass Burning',
#   ':math:\\text{N}_2\\text{O} Emissions from Crop Residues',
#   'Adjusted Agriculture Equivalent Exports',
#   'Adjusted Agriculture Equivalent Imports',
#   'Changes to Agriculture Net Imports Lost',
#   'Crop Area',
#   'Crop Demand',
#   'Crop Yield',
#   'Cropland Area Proportion',
#   'Total Food Loss Sent to Municipal Solid Waste',
#   'Total Food Produced Lost Before Consumption'],
#  'Carbon Capture and Sequestration': ['Annual Capture and Sequestration by Type',
#   'CCSQ Efficiency Factor for Heat Energy from Geothermal',
#   'CCSQ Efficiency Factor for Heat Energy from Hydrogen',
#   'CCSQ Efficiency Factor for Heat Energy from Natural Gas',
#   'CCSQ Energy Demand Per Mass of :math:\\text{CO}_2 Captured',
#   'CCSQ Fraction Energy Electricity',
#   'CCSQ Fraction Energy Heat',
#   'CCSQ Fraction Heat Energy Demand Geothermal',
#   'CCSQ Fraction Heat Energy Demand Hydrogen',
#   'CCSQ Fraction Heat Energy Demand Natural Gas',
#   ':math:\\text{CH}_4 Emissions from CCSQ',
#   ':math:\\text{CO}_2 Emissions from CCSQ',
#   ':math:\\text{N}_2\\text{O} Emissions from CCSQ',
#   'Electrical Energy Consumption from CCSQ',
#   'Energy Consumption from CCSQ',
#   'Total Electrical Energy Consumption from CCSQ',
#   'Total Energy Consumption from CCSQ'],
#  'Economy': ['GDP', 'GDP per Capita'],
#  'Energy Fuels': [':math:\\text{CH}_4 Stationary Combustion Emission Factor',
#   ':math:\\text{CO}_2 Combustion Emission Factor',
#   ':math:\\text{N}_2\\text{O} Stationary Combustion Emission Factor',
#   'Average Industrial Energy Fuel Efficiency Factor',
#   'Electrical Transmission Loss Fraction',
#   'Fraction of Fuel Demand Imported',
#   'Fuel Exports',
#   'Gravimetric Energy Density',
#   'Gravimetric Fuel Price',
#   'Minimum Fraction of Fuel Used for Electricity Generation',
#   'NemoMod REMinProductionTarget',
#   'Thermal Fuel Price',
#   'Volumetric Energy Density',
#   'Volumetric Fuel Price',
#   'Adjusted Fuel Exports',
#   'Electrical Transmission Loss',
#   'Energy Demand by Fuel in CCSQ',
#   'Energy Demand by Fuel in Energy Technology',
#   'Energy Demand by Fuel in Industrial Energy',
#   'Energy Demand by Fuel in SCOE',
#   'Energy Demand by Fuel in Transportation',
#   'Fuel Imports',
#   'Fuel Production',
#   'Total Energy Demand by Fuel',
#   'Unused Fuel Exported',
#   'Value of Fuel Consumed in CCSQ',
#   'Value of Fuel Consumed in Energy Technology',
#   'Value of Fuel Consumed in Industrial Energy',
#   'Value of Fuel Consumed in SCOE',
#   'Value of Fuel Consumed in Transportation'],
#  'Energy Storage': ['NemoMod CapitalCostStorage',
#   'NemoMod ResidualStorageCapacity',
#   'NemoMod StorageStartLevel',
#   'NemoMod TotalAnnualMaxCapacityInvestmentStorage',
#   'NemoMod TotalAnnualMaxCapacityStorage',
#   'NemoMod TotalAnnualMinCapacityInvestmentStorage',
#   'NemoMod TotalAnnualMinCapacityStorage',
#   'NemoMod Discounted Capital Investment Storage',
#   'NemoMod Discounted Operating Costs Storage'],
#  'Energy Technology': [':math:\\text{CH}_4 Fuel Production NemoMod EmissionsActivityRatio',
#   ':math:\\text{CH}_4 NemoMod EmissionsActivityRatio Scalar',
#   ':math:\\text{CO}_2 Fuel Production NemoMod EmissionsActivityRatio',
#   ':math:\\text{CO}_2 NemoMod EmissionsActivityRatio Scalar',
#   ':math:\\text{N}_2\\text{O} Fuel Production NemoMod EmissionsActivityRatio',
#   ':math:\\text{N}_2\\text{O} NemoMod EmissionsActivityRatio Scalar',
#   'Fuel Production NemoMod InputActivityRatio Biomass',
#   'Fuel Production NemoMod InputActivityRatio Coal',
#   'Fuel Production NemoMod InputActivityRatio Coal Deposits',
#   'Fuel Production NemoMod InputActivityRatio Crude',
#   'Fuel Production NemoMod InputActivityRatio Diesel',
#   'Fuel Production NemoMod InputActivityRatio Electricity',
#   'Fuel Production NemoMod InputActivityRatio Gasoline',
#   'Fuel Production NemoMod InputActivityRatio Natural Gas',
#   'Fuel Production NemoMod InputActivityRatio Natural Gas Unprocessed',
#   'Fuel Production NemoMod InputActivityRatio Oil',
#   'Fuel Production NemoMod OutputActivityRatio Coal',
#   'Fuel Production NemoMod OutputActivityRatio Crude',
#   'Fuel Production NemoMod OutputActivityRatio Diesel',
#   'Fuel Production NemoMod OutputActivityRatio Gasoline',
#   'Fuel Production NemoMod OutputActivityRatio Hydrocarbon Gas Liquids',
#   'Fuel Production NemoMod OutputActivityRatio Hydrogen',
#   'Fuel Production NemoMod OutputActivityRatio Kerosene',
#   'Fuel Production NemoMod OutputActivityRatio Natural Gas',
#   'Fuel Production NemoMod OutputActivityRatio Natural Gas Unprocessed',
#   'Fuel Production NemoMod OutputActivityRatio Oil',
#   'Maximum Production Increase Fraction to Satisfy MinShareProduction Electricity',
#   'NemoMod CapitalCost',
#   'NemoMod FixedCost',
#   'NemoMod MinShareProduction',
#   'NemoMod RETagTechnology',
#   'NemoMod ReserveMargin',
#   'NemoMod ReserveMarginTagTechnology',
#   'NemoMod ResidualCapacity',
#   'NemoMod TotalAnnualMaxCapacity',
#   'NemoMod TotalAnnualMaxCapacityInvestment',
#   'NemoMod TotalAnnualMinCapacity',
#   'NemoMod TotalAnnualMinCapacityInvestment',
#   'NemoMod VariableCost',
#   'Technology Efficiency of Fuel Use',
#   'NemoMod :math:\\text{CH}_4 Emissions from Electricity Generation',
#   'NemoMod :math:\\text{CH}_4 Emissions from Electricity Generation for CCSQ',
#   'NemoMod :math:\\text{CH}_4 Emissions from Electricity Generation for Energy Technology',
#   'NemoMod :math:\\text{CH}_4 Emissions from Electricity Generation for Export',
#   'NemoMod :math:\\text{CH}_4 Emissions from Electricity Generation for Industrial Energy',
#   'NemoMod :math:\\text{CH}_4 Emissions from Electricity Generation for SCOE',
#   'NemoMod :math:\\text{CH}_4 Emissions from Electricity Generation for Transportation',
#   'NemoMod :math:\\text{CH}_4 Emissions from Fuel Mining and Extraction',
#   'NemoMod :math:\\text{CH}_4 Emissions from Fuel Processing and Refinement',
#   'NemoMod :math:\\text{CO}_2 Emissions from Electricity Generation',
#   'NemoMod :math:\\text{CO}_2 Emissions from Electricity Generation for CCSQ',
#   'NemoMod :math:\\text{CO}_2 Emissions from Electricity Generation for Energy Technology',
#   'NemoMod :math:\\text{CO}_2 Emissions from Electricity Generation for Export',
#   'NemoMod :math:\\text{CO}_2 Emissions from Electricity Generation for Industrial Energy',
#   'NemoMod :math:\\text{CO}_2 Emissions from Electricity Generation for SCOE',
#   'NemoMod :math:\\text{CO}_2 Emissions from Electricity Generation for Transportation',
#   'NemoMod :math:\\text{CO}_2 Emissions from Fuel Mining and Extraction',
#   'NemoMod :math:\\text{CO}_2 Emissions from Fuel Processing and Refinement',
#   'NemoMod :math:\\text{N}_2\\text{O} Emissions from Electricity Generation',
#   'NemoMod :math:\\text{N}_2\\text{O} Emissions from Electricity Generation for CCSQ',
#   'NemoMod :math:\\text{N}_2\\text{O} Emissions from Electricity Generation for Energy Technology',
#   'NemoMod :math:\\text{N}_2\\text{O} Emissions from Electricity Generation for Export',
#   'NemoMod :math:\\text{N}_2\\text{O} Emissions from Electricity Generation for Industrial Energy',
#   'NemoMod :math:\\text{N}_2\\text{O} Emissions from Electricity Generation for SCOE',
#   'NemoMod :math:\\text{N}_2\\text{O} Emissions from Electricity Generation for Transportation',
#   'NemoMod :math:\\text{N}_2\\text{O} Emissions from Fuel Mining and Extraction',
#   'NemoMod :math:\\text{N}_2\\text{O} Emissions from Fuel Processing and Refinement',
#   'NemoMod Discounted Capital Investment',
#   'NemoMod Discounted Operating Costs',
#   'NemoMod Generation Capacity',
#   'NemoMod Production by Technology'],
#  'Forest': [':math:\\text{CH}_4 Forest Methane Emissions',
#   ':math:\\text{CO}_2 Forest Fire Emission Factor',
#   'Average Fraction of Forest Burned Annually',
#   'C Carbon Harvested Wood Products Emission Factor',
#   'Fire Biomass Consumption for Temperate Forests',
#   'Fire Biomass Consumption for Tropical Forests',
#   'Forest Fraction Temperate Nutrient Poor',
#   'Forest Fraction Temperate Nutrient Rich',
#   'Forest Fraction Tropical',
#   'Forest Sequestration Emission Factor',
#   'HWP Half Life Paper',
#   'HWP Half Life Wood',
#   'Initial Per Household Wood Demand',
#   ':math:\\text{CH}_4 Emissions from Forests',
#   ':math:\\text{CO}_2 Emissions from Forest Fires',
#   ':math:\\text{CO}_2 Emissions from Forest Sequestration',
#   ':math:\\text{CO}_2 Emissions from Harvested Wood Products'],
#  'Fugitive Emissions': [':math:\\text{CH}_4 FGTV Distribution Emission Factor',
#   ':math:\\text{CH}_4 FGTV Production Flaring Emission Factor',
#   ':math:\\text{CH}_4 FGTV Production Fugitive Emission Factor',
#   ':math:\\text{CH}_4 FGTV Production Venting Emission Factor',
#   ':math:\\text{CH}_4 FGTV Transmission Emission Factor',
#   ':math:\\text{CO}_2 FGTV Distribution Emission Factor',
#   ':math:\\text{CO}_2 FGTV Production Flaring Emission Factor',
#   ':math:\\text{CO}_2 FGTV Production Fugitive Emission Factor',
#   ':math:\\text{CO}_2 FGTV Production Venting Emission Factor',
#   ':math:\\text{CO}_2 FGTV Transmission Emission Factor',
#   ':math:\\text{N}_2\\text{O} FGTV Production Flaring Emission Factor',
#   ':math:\\text{N}_2\\text{O} FGTV Production Fugitive Emission Factor',
#   ':math:\\text{N}_2\\text{O} FGTV Production Venting Emission Factor',
#   ':math:\\text{N}_2\\text{O} FGTV Transmission Emission Factor',
#   'Fraction Non-Fugitive :math:\\text{CH}_4 Flared',
#   'NMVOC FGTV Distribution Emission Factor',
#   'NMVOC FGTV Production Flaring Emission Factor',
#   'NMVOC FGTV Production Fugitive Emission Factor',
#   'NMVOC FGTV Production Venting Emission Factor',
#   'NMVOC FGTV Transmission Emission Factor',
#   'Reduction in Fugitive Leaks',
#   ':math:\\text{CH}_4 Fugitive Emissions',
#   ':math:\\text{CO}_2 Fugitive Emissions',
#   ':math:\\text{N}_2\\text{O} Fugitive Emissions',
#   'NMVOC Fugitive Emissions'],
#  'General': [':math:\\text{CH}_4 Annual Emission Limit',
#   ':math:\\text{CO}_2 Annual Emission Limit',
#   ':math:\\text{N}_2\\text{O} Annual Emission Limit',
#   'Area of Country',
#   'Climate Change Factor for Average Hydropower Availability',
#   'Elasticity National Occupation Rate to GDP Per Capita',
#   'Fraction Eating Red Meat',
#   'Initial National Occupancy Rate',
#   'Population',
#   'National Occupancy Rate',
#   'Number of Households',
#   'Total Population'],
#  'IPPU': [':math:\\text{CH}_4 Production Process Emission Factor',
#   ':math:\\text{CO}_2 Clinker Production Process Emission Factor',
#   ':math:\\text{CO}_2 Product Use Emission Factor',
#   ':math:\\text{CO}_2 Production Process Emission Factor',
#   ':math:\\text{NF}_3 Production Process Emission Factor',
#   ':math:\\text{N}_2\\text{O} GDP Production Process Emission Factor',
#   ':math:\\text{N}_2\\text{O} Production Process Emission Factor',
#   ':math:\\text{SF}_6 GDP Production Process Emission Factor',
#   ':math:\\text{SF}_6 Production Process Emission Factor',
#   'Average Lifespan of Housing Construction',
#   'Average per Household Demand for Construction Materials',
#   'COD Wastewater Factor',
#   'Clinker Fraction of Cement',
#   'Dodecafluoropentane Production Process Emission Factor',
#   'Elasticity of Industrial Production to GDP',
#   'Elasticity of Product Use Rate to GDP per Capita',
#   'HCFC-141b GDP Product Use Emission Factor',
#   'HCFC-142b GDP Product Use Emission Factor',
#   'HFC-125 GDP Product Use Emission Factor',
#   'HFC-125 Production Process Emission Factor',
#   'HFC-134 GDP Product Use Emission Factor',
#   'HFC-134a GDP Product Use Emission Factor',
#   'HFC-134a Production Process Emission Factor',
#   'HFC-143 GDP Product Use Emission Factor',
#   'HFC-143a GDP Product Use Emission Factor',
#   'HFC-143a Production Process Emission Factor',
#   'HFC-152a GDP Product Use Emission Factor',
#   'HFC-152a Production Process Emission Factor',
#   'HFC-227ea GDP Product Use Emission Factor',
#   'HFC-227ea Production Process Emission Factor',
#   'HFC-23 GDP Product Use Emission Factor',
#   'HFC-23 Production Process Emission Factor',
#   'HFC-236fa GDP Product Use Emission Factor',
#   'HFC-245fa GDP Product Use Emission Factor',
#   'HFC-32 GDP Product Use Emission Factor',
#   'HFC-32 Production Process Emission Factor',
#   'HFC-365mfc GDP Product Use Emission Factor',
#   'HFC-365mfc Production Process Emission Factor',
#   'HFC-41 Production Process Emission Factor',
#   'HFC-43-10mee GDP Product Use Emission Factor',
#   'Industrial :math:\\text{CO}_2 Capture Efficacy',
#   'Industrial :math:\\text{CO}_2 Capture Prevalence',
#   'Industrial Production Scalar',
#   'Initial Industrial Production',
#   'Initial Non-Energy Fuel Use',
#   'Initial Other Non-Energy :math:\\text{CO}_2 Emissions',
#   'Maximum Recycled Material Ratio in Virgin Process',
#   'Net Imports of Cement Clinker',
#   'Octafluorooxolane Production Process Emission Factor',
#   'PFC-1114 Production Process Emission Factor',
#   'PFC-116 GDP Product Use Emission Factor',
#   'PFC-116 Production Process Emission Factor',
#   'PFC-14 GDP Product Use Emission Factor',
#   'PFC-14 Production Process Emission Factor',
#   'PFC-218 Production Process Emission Factor',
#   'PFC-31-10 GDP Product Use Emission Factor',
#   'PFC-31-10 Production Process Emission Factor',
#   'PFC-51-14 GDP Product Use Emission Factor',
#   'PFC-51-14 Production Process Emission Factor',
#   'PFC-C-1418 Production Process Emission Factor',
#   'PFC-C-318 Production Process Emission Factor',
#   'Ratio of Production to Harvested Wood Demand',
#   'Wastewater Production Factor',
#   ':math:\\text{CH}_4 Emissions from Industrial Production Processes',
#   ':math:\\text{CO}_2 Captured in Industrial Processes and Product Use',
#   ':math:\\text{CO}_2 Emissions from Industrial Product Use',
#   ':math:\\text{CO}_2 Emissions from Industrial Production Processes',
#   ':math:\\text{NF}_3 Emissions from Industrial Production Processes',
#   ':math:\\text{N}_2\\text{O} Emissions from Industrial Production Processes',
#   ':math:\\text{SF}_6 Emissions from Industrial Production Processes',
#   'Change to Net Imports of Products',
#   'Demand for Harvested Wood',
#   'Dodecafluoropentane Emissions from Industrial Production Processes',
#   'HCFC-141b Emissions from Industrial Product Use',
#   'HCFC-142b Emissions from Industrial Product Use',
#   'HFC Emissions from Industrial Product Use',
#   'HFC Emissions from Industrial Production Processes',
#   'HFC-125 Emissions from Industrial Product Use',
#   'HFC-125 Emissions from Industrial Production Processes',
#   'HFC-134 Emissions from Industrial Product Use',
#   'HFC-134a Emissions from Industrial Product Use',
#   'HFC-134a Emissions from Industrial Production Processes',
#   'HFC-143 Emissions from Industrial Product Use',
#   'HFC-143a Emissions from Industrial Product Use',
#   'HFC-143a Emissions from Industrial Production Processes',
#   'HFC-152a Emissions from Industrial Product Use',
#   'HFC-152a Emissions from Industrial Production Processes',
#   'HFC-227ea Emissions from Industrial Product Use',
#   'HFC-227ea Emissions from Industrial Production Processes',
#   'HFC-23 Emissions from Industrial Product Use',
#   'HFC-23 Emissions from Industrial Production Processes',
#   'HFC-236fa Emissions from Industrial Product Use',
#   'HFC-245fa Emissions from Industrial Product Use',
#   'HFC-32 Emissions from Industrial Product Use',
#   'HFC-32 Emissions from Industrial Production Processes',
#   'HFC-365mfc Emissions from Industrial Product Use',
#   'HFC-365mfc Emissions from Industrial Production Processes',
#   'HFC-41 Emissions from Industrial Production Processes',
#   'HFC-43-10mee Emissions from Industrial Product Use',
#   'Industrial Production',
#   'Other Fluorinated Compound Emissions from Industrial Product Use',
#   'Other Fluorinated Compound Emissions from Industrial Production Processes',
#   'PFC Emissions from Industrial Product Use',
#   'PFC Emissions from Industrial Production Processes',
#   'PFC-1114 Emissions from Industrial Production Processes',
#   'PFC-116 Emissions from Industrial Product Use',
#   'PFC-116 Emissions from Industrial Production Processes',
#   'PFC-14 Emissions from Industrial Product Use',
#   'PFC-14 Emissions from Industrial Production Processes',
#   'PFC-1418 Emissions from Industrial Production Processes',
#   'PFC-218 Emissions from Industrial Production Processes',
#   'PFC-31-10 Emissions from Industrial Product Use',
#   'PFC-31-10 Emissions from Industrial Production Processes',
#   'PFC-318 Emissions from Industrial Production Processes',
#   'PFC-51-14 Emissions from Industrial Product Use',
#   'PFC-51-14 Emissions from Industrial Production Processes',
#   'Recycled Material Used in Industrial Production'],
#  'Industrial Energy': ['Industrial Energy Demand Scalar',
#   'Industrial Energy Fuel Fraction Coal',
#   'Industrial Energy Fuel Fraction Coke',
#   'Industrial Energy Fuel Fraction Diesel',
#   'Industrial Energy Fuel Fraction Electricity',
#   'Industrial Energy Fuel Fraction Furnace Gas',
#   'Industrial Energy Fuel Fraction Gasoline',
#   'Industrial Energy Fuel Fraction Geothermal',
#   'Industrial Energy Fuel Fraction Hydrocarbon Gas Liquids',
#   'Industrial Energy Fuel Fraction Hydrogen',
#   'Industrial Energy Fuel Fraction Kerosene',
#   'Industrial Energy Fuel Fraction Natural Gas',
#   'Industrial Energy Fuel Fraction Oil',
#   'Industrial Energy Fuel Fraction Solar',
#   'Industrial Energy Fuel Fraction Solid Biomass',
#   'Initial Energy Consumption Intensity of GDP',
#   'Initial Energy Consumption Intensity of Production',
#   'Initial Energy Consumption in Agriculture and Livestock',
#   ':math:\\text{CH}_4 Emissions from Industrial Energy',
#   ':math:\\text{CO}_2 Captured in Industrial Energy',
#   ':math:\\text{CO}_2 Emissions from Industrial Energy',
#   ':math:\\text{N}_2\\text{O} Emissions from Industrial Energy',
#   'Electrical Energy Consumption from Industrial Energy',
#   'Energy Consumption from Industrial Energy',
#   'Energy Demand in Industrial Energy',
#   'Total Electrical Energy Consumption from Industrial Energy',
#   'Total Energy Consumption from Industrial Energy'],
#  'Land Use': [':math:\\text{CO}_2 Land Use Conversion Emission Factor',
#   'Fraction of Increasing Net Exports Met',
#   'Fraction of Increasing Net Imports Met',
#   'Fraction of Pastures Improved',
#   'Fraction of Soils Mineral',
#   'Initial Land Use Area Proportion',
#   'Land Use BOC :math:\\text{CH}_4 Emission Factor',
#   'Land Use Fraction Dry',
#   'Land Use Fraction Fertilized',
#   'Land Use Fraction Temperate',
#   'Land Use Fraction Tropical',
#   'Land Use Fraction Wet',
#   'Land Use Yield Reallocation Factor',
#   'Maximum Soil Carbon Land Input Factor Without Manure',
#   'Maximum Soil Carbon Land Management Factor',
#   'Pasture Fraction of Grassland',
#   'Soil Carbon Land Use Factor',
#   'Unadjusted Land Use Transition Probability',
#   'Unimproved Soil Carbon Land Management Factor',
#   'Vegetarian Diet Exchange Scalar',
#   ':math:\\text{CH}_4 Emissions from Wetlands',
#   ':math:\\text{CO}_2 Emissions from Conversion Away from Land Use Type',
#   ':math:\\text{CO}_2 Emissions from Land Use Conversion',
#   'Area of Improved Land',
#   'Area of Land Use Converted',
#   'Area of Land Use Converted Away from Type',
#   'Area of Land Use Converted to Type',
#   'Land Use Area'],
#  'Liquid Waste': ['(Optional) Elasticity of Protein in Diet to GDP per Capita',
#   'Average Protein Consumption Per Capita',
#   'BOD Correction Factor for TOW',
#   'BOD per Capita',
#   'COD per GDP',
#   'Factor for Nitrogen in Non-Consumed Protein Disposed in Sewer System',
#   'Fraction of Protein in Diet with Red Meat',
#   'Fraction of Protein in Diet without Red Meat',
#   'Initial Per Capita Annual Domestic Wastewater Generated',
#   'Initial Per GDP Annual Industrial Wastewater Generated',
#   'Log Elasticity DWW Production to GDP Per Capita',
#   'Maximum BOD :math:\\text{CH}_4 Producing Capacity',
#   'Maximum COD :math:\\text{CH}_4 Producing Capacity',
#   'Nitrogen Density of Industrial Wastewater',
#   'Phosphorous Per BOD Factor',
#   'Phosphorous Per COD Factor',
#   'Scalar to Account for Nitrogen in Household Products',
#   'Treatment Fraction Advanced Aerobic',
#   'Treatment Fraction Advanced Anaerobic',
#   'Treatment Fraction Improved Latrine',
#   'Treatment Fraction Primary',
#   'Treatment Fraction Secondary Aerobic',
#   'Treatment Fraction Secondary Anaerobic',
#   'Treatment Fraction Septic',
#   'Treatment Fraction Unimproved Latrine',
#   'Treatment Fraction Untreated No Sewerage',
#   'Treatment Fraction Untreated With Sewerage'],
#  'Livestock': [':math:\\text{CH}_4 Enteric Fermentation Emission Factor',
#   'Animal Weight',
#   'Carrying Capacity Scalar',
#   'Daily Dry Matter Consumption',
#   'Daily Nitrogen Generation Factor',
#   'Daily Volatile Solid Generation Factor',
#   'Elasticity of Livestock Demand to GDP per Capita',
#   'Fraction Nitrogen Excretion in Dung',
#   'Fraction of Livestock Demand Imported',
#   'Initial Livestock Head Count',
#   'Livestock Equivalent Exports',
#   'Livestock Manure Management Fraction Anaerobic Digester',
#   'Livestock Manure Management Fraction Anaerobic Lagoon',
#   'Livestock Manure Management Fraction Composting',
#   'Livestock Manure Management Fraction Daily Spread',
#   'Livestock Manure Management Fraction Deep Bedding',
#   'Livestock Manure Management Fraction Dry Lot',
#   'Livestock Manure Management Fraction Incineration',
#   'Livestock Manure Management Fraction Liquid Slurry',
#   'Livestock Manure Management Fraction Paddock Pasture Range',
#   'Livestock Manure Management Fraction Poultry Manure',
#   'Livestock Manure Management Fraction Solid Storage',
#   'Maximum Manure :math:\\text{CH}_4 Generation Capacity',
#   ':math:\\text{CH}_4 Emissions from Livestock Enteric Fermentation',
#   'Adjusted Livestock Equivalent Exports',
#   'Adjusted Livestock Equivalent Imports',
#   'Changes to Livestock Net Imports Lost',
#   'Livestock Demand',
#   'Livestock Head Count',
#   'Total Domestic Animal Mass'],
#  'Livestock Manure Management': [':math:\\text{N}_2\\text{O} Manure Management Emission Factor',
#   'Biogas Recovery Factor at LSMM Anaerobic Digesters',
#   'Fraction of Nitrogen Lost to Leaching',
#   'Fraction of Nitrogen Lost to Volatilisation',
#   'Fraction of Nitrogen Used in Fertilizer',
#   'Manure Management Methane Correction Factor',
#   'Nitrogen from Bedding per Animal',
#   'Nitrogen from Co-Digestates Factor',
#   'Ratio of :math:\\text{N}_2 to :math:\\text{N}_2\\text{O}',
#   ':math:\\text{CH}_4 Emissions from Manure Management',
#   ':math:\\text{N}_2\\text{O} Emissions from Manure Management',
#   'Dung Incinerated',
#   'LSMM Biogas Recovered from Anaerobic Digesters',
#   'Nitrogen Available for Fertilizer',
#   'Total Nitrogen Available for Construction/Feed/Other',
#   'Total Nitrogen Available for Fertilizer from Dung',
#   'Total Nitrogen Available for Fertilizer from Urine',
#   'Total Nitrogen to Pastures'],
#  'Soil Management': [':math:\\text{EF}_1 - \\text{N}_2\\text{O} Organic Amendments and Fertilizer',
#   ':math:\\text{EF}_1 - \\text{N}_2\\text{O} Synthetic Fertilizer',
#   ':math:\\text{EF}_2 - \\text{N}_2\\text{O} Emissions from Drained and Managed Organic Soils',
#   ':math:\\text{EF}_{1FR} - \\text{N}_2\\text{O} Rice Fields',
#   'C Annual Cultivated Organic Soils Emission Factor',
#   'C Liming Emission Factor Dolomite',
#   'C Liming Emission Factor Limestone',
#   'C Urea Emission Factor',
#   'C to N Ratio of Soil Organic Matter',
#   'EF3 N Pasture Range and Paddock',
#   'EF4 N Volatilisation and Re-Deposition Emission Factor',
#   'EF5 N Leaching and Runoff Emission Factor',
#   'Fertilizer N Demand Scalar',
#   'Fraction Synthetic Fertilizer Use Urea',
#   'Initial Liming Dolomite Applied to Soils',
#   'Initial Liming Limestone Applied to Soils',
#   'Initial Synthetic Fertilizer Use',
#   'Leaching Fraction of N Lost',
#   'Liming Demand Scalar',
#   'Soil Organic C Stocks',
#   'Volatilisation Fraction from Non-Urea Synthetic Fertilizers',
#   'Volatilisation Fraction from Organic Amendments and Fertilizers',
#   'Volatilisation Fraction from Urea Synthetic Fertilizers',
#   ':math:\\text{CO}_2 Emissions from Lime',
#   ':math:\\text{CO}_2 Emissions from Soil Carbon in Mineral Soils',
#   ':math:\\text{CO}_2 Emissions from Urea',
#   ':math:\\text{N}_2\\text{O} Emissions from Fertilizer Use',
#   ':math:\\text{N}_2\\text{O} Emissions from Mineral Soils',
#   ':math:\\text{N}_2\\text{O} Emissions from Organic Soils',
#   ':math:\\text{N}_2\\text{O} Emissions from Paddock Pasture and Range',
#   'Organic Fertilizer N Use',
#   'Synthetic Fertilizer N Use',
#   'Total Fertilizer N Use',
#   'Total Lime Use',
#   'Total Urea Use'],
#  'Solid Waste': [':math:\\text{CH}_4 Anaerobic Biogas Emission Factor',
#   ':math:\\text{CH}_4 Composting Emission Factor',
#   ':math:\\text{CH}_4 ISW Incineration Emission Factor',
#   ':math:\\text{CH}_4 MSW Incineration Emission Factor',
#   ':math:\\text{CH}_4 Recovery Factor Landfill Gas',
#   ':math:\\text{N}_2\\text{O} Composting Emission Factor',
#   ':math:\\text{N}_2\\text{O} Incineration Emission Factor',
#   'Average Annual Waste Transported Per Waste Collection Vehicle',
#   'Average Methane Correction Factor at Landfills',
#   'Average Methane Correction Factor for Open Dumping',
#   'Average Oxidization Factor at Landfills',
#   'Average VKMT Per Waste Collection Vehicle',
#   'Biogas Recovery Factor',
#   'Elasticity of Municipal Solid Waste Produced to GDP per Capita',
#   'Fraction of ISW Incineration Recovered for Energy',
#   'Fraction of Landfill Gas Recovered at Landfills',
#   'Fraction of Landfill Gas Recovered for Energy',
#   'Fraction of MSW Incineration Recovered for Energy',
#   'Fraction of Methane Flared at Composting Facilities',
#   'Fraction of Non-Recycled Solid Waste Incinerated',
#   'Fraction of Non-Recycled Solid Waste Landfilled',
#   'Fraction of Non-Recycled Solid Waste Open Dumps',
#   'Fraction of Waste Composted',
#   'Fraction of Waste Recycled',
#   'Fraction of Waste Treated Anaerobically',
#   'Historical Back Projection Growth Rate in Solid Waste Generation',
#   'Initial Composition Fraction Industrial Solid Waste',
#   'Initial Composition Fraction Municipal Solid Waste',
#   'Initial Per Capita Municipal Solid Waste Generated',
#   'K',
#   'Per GDP Industrial Solid Waste Generated',
#   'Waste Per Capita Scale Factor',
#   ':math:\\text{CH}_4 Emissions from Anaerobic Biogas',
#   ':math:\\text{CH}_4 Emissions from Composting',
#   ':math:\\text{CH}_4 Emissions from Incineration',
#   ':math:\\text{CH}_4 Emissions from Landfills',
#   ':math:\\text{CH}_4 Emissions from Open Dumping',
#   ':math:\\text{CO}_2 Emissions from Incineration',
#   ':math:\\text{N}_2\\text{O} Emissions from Composting',
#   ':math:\\text{N}_2\\text{O} Emissions from Incineration',
#   'Biogas Recovered from Anaerobic Facilities',
#   'Biogas Recovered from Landfills',
#   'Total ISW Recovered for Energy',
#   'Total MSW Recovered for Energy',
#   'Total Solid Waste Produced',
#   'Total Waste Anaerobic Biogas',
#   'Total Waste Composted',
#   'Total Waste Incinerated',
#   'Total Waste Landfilled',
#   'Total Waste Open Dumped',
#   'Total Waste Recycled'],
#  'Stationary Combustion and Other Energy': ['SCOE Appliance Energy Demand Scalar',
#   'SCOE Efficiency Factor for Heat Energy from Coal',
#   'SCOE Efficiency Factor for Heat Energy from Diesel',
#   'SCOE Efficiency Factor for Heat Energy from Electricity',
#   'SCOE Efficiency Factor for Heat Energy from Gasoline',
#   'SCOE Efficiency Factor for Heat Energy from Hydrocarbon Gas Liquids',
#   'SCOE Efficiency Factor for Heat Energy from Hydrogen',
#   'SCOE Efficiency Factor for Heat Energy from Kerosene',
#   'SCOE Efficiency Factor for Heat Energy from Natural Gas',
#   'SCOE Efficiency Factor for Heat Energy from Solid Biomass',
#   'SCOE Elasticity of Per GDP Electrical Applicance Demand to GDP Per Capita',
#   'SCOE Elasticity of Per GDP Heat Energy Demand to GDP Per Capita',
#   'SCOE Elasticity of Per Household Electrical Applicance Demand to GDP Per Capita',
#   'SCOE Elasticity of Per Household Heat Energy Demand to GDP Per Capita',
#   'SCOE Fraction Heat Energy Demand Coal',
#   'SCOE Fraction Heat Energy Demand Diesel',
#   'SCOE Fraction Heat Energy Demand Electricity',
#   'SCOE Fraction Heat Energy Demand Gasoline',
#   'SCOE Fraction Heat Energy Demand Hydrocarbon Gas Liquids',
#   'SCOE Fraction Heat Energy Demand Hydrogen',
#   'SCOE Fraction Heat Energy Demand Kerosene',
#   'SCOE Fraction Heat Energy Demand Natural Gas',
#   'SCOE Fraction Heat Energy Demand Solid Biomass',
#   'SCOE Heat Energy Demand Scalar',
#   'SCOE Initial Per GDP Electric Appliances Energy Consumption',
#   'SCOE Initial Per GDP Heat Energy Consumption',
#   'SCOE Initial Per Household Electric Appliances Energy Consumption',
#   'SCOE Initial Per Household Heat Energy Consumption',
#   ':math:\\text{CH}_4 Emissions from SCOE',
#   ':math:\\text{CO}_2 Emissions from SCOE',
#   ':math:\\text{N}_2\\text{O} Emissions from SCOE',
#   'Electrical Energy Consumption from SCOE',
#   'Energy Consumption from SCOE',
#   'Heat Energy Demand in SCOE',
#   'Total Electrical Energy Consumption from SCOE',
#   'Total Energy Consumption from SCOE'],
#  'Transportation': [':math:\\text{CH}_4 Biofuels Mobile Combustion Emission Factor',
#   ':math:\\text{CH}_4 Diesel Mobile Combustion Emission Factor',
#   ':math:\\text{CH}_4 Gasoline Mobile Combustion Emission Factor',
#   ':math:\\text{CH}_4 Hydrocarbon Gas Liquids Mobile Combustion Emission Factor',
#   ':math:\\text{CH}_4 Kerosene Mobile Combustion Emission Factor',
#   ':math:\\text{CH}_4 Natural Gas Mobile Combustion Emission Factor',
#   ':math:\\text{N}_2\\text{O} Biofuels Mobile Combustion Emission Factor',
#   ':math:\\text{N}_2\\text{O} Diesel Mobile Combustion Emission Factor',
#   ':math:\\text{N}_2\\text{O} Gasoline Mobile Combustion Emission Factor',
#   ':math:\\text{N}_2\\text{O} Hydrocarbon Gas Liquids Mobile Combustion Emission Factor',
#   ':math:\\text{N}_2\\text{O} Kerosene Mobile Combustion Emission Factor',
#   ':math:\\text{N}_2\\text{O} Natural Gas Mobile Combustion Emission Factor',
#   'Average Freight Vehicle Load',
#   'Average Passenger Vehicle Occupancy Rate',
#   'Electrical Vehicle Efficiency',
#   'Freight Transportation Mode Share',
#   'Fuel Efficiency Biofuels',
#   'Fuel Efficiency Diesel',
#   'Fuel Efficiency Gasoline',
#   'Fuel Efficiency Hydrocarbon Gas Liquids',
#   'Fuel Efficiency Hydrogen',
#   'Fuel Efficiency Kerosene',
#   'Fuel Efficiency Natural Gas',
#   'Private and Public Transportation Mode Share',
#   'Regional Transportation Mode Share',
#   'Transportation Mode Fuel Fraction Biofuels',
#   'Transportation Mode Fuel Fraction Diesel',
#   'Transportation Mode Fuel Fraction Electricity',
#   'Transportation Mode Fuel Fraction Gasoline',
#   'Transportation Mode Fuel Fraction Hydrocarbon Gas Liquids',
#   'Transportation Mode Fuel Fraction Hydrogen',
#   'Transportation Mode Fuel Fraction Kerosene',
#   'Transportation Mode Fuel Fraction Natural Gas',
#   ':math:\\text{CH}_4 Emissions from Transportation',
#   ':math:\\text{CO}_2 Emissions from Transportation',
#   ':math:\\text{N}_2\\text{O} Emissions from Transportation',
#   'Electrical Energy Consumption from Transportation',
#   'Energy Consumption from Transportation',
#   'Total Electrical Energy Consumption from Transportation',
#   'Total Energy Consumption from Transportation',
#   'Total Megatonne-Kilometer Demand by Vehicle',
#   'Total Passenger Distance by Vehicle',
#   'Total Vehicle Distance Traveled',
#   'Transportation Modal Energy Consumption from Biofuels',
#   'Transportation Modal Energy Consumption from Diesel',
#   'Transportation Modal Energy Consumption from Electricity',
#   'Transportation Modal Energy Consumption from Gasoline',
#   'Transportation Modal Energy Consumption from Hydrocarbon Gas Liquids',
#   'Transportation Modal Energy Consumption from Hydrogen',
#   'Transportation Modal Energy Consumption from Kerosene',
#   'Transportation Modal Energy Consumption from Natural Gas',
#   'Vehicle Distance Traveled from Biofuels',
#   'Vehicle Distance Traveled from Diesel',
#   'Vehicle Distance Traveled from Electricity',
#   'Vehicle Distance Traveled from Gasoline',
#   'Vehicle Distance Traveled from Hydrocarbon Gas Liquids',
#   'Vehicle Distance Traveled from Hydrogen',
#   'Vehicle Distance Traveled from Kerosene',
#   'Vehicle Distance Traveled from Natural Gas'],
#  'Transportation Demand': ['Elasticity of Megatonne-Kilometer Demand to GDP',
#   'Elasticity of Passenger-Kilometer Demand per Capita to GDP per Capita',
#   'Initial Megatonne-Kilometer Demand',
#   'Initial per Capita Passenger-Kilometer Demand',
#   'Transportation Demand Scalar',
#   'Megatonne-Kilometer Demand',
#   'Passenger-Kilometer Demand'],
#  'Wastewater Treatment': [':math:\\text{K}_{REM} Sludge Factor',
#   ':math:\\text{N}_2\\text{O} Wastewater Treatment Emission Factor',
#   'Biogas Recovery Factor at Wastewater Treatment Plants',
#   'Fraction of Nitrogen Removed in Treatment',
#   'Fraction of Phosphorous Removed in Treatment',
#   'Fraction of Total Organic Waste Removed in Treatment',
#   'Septic Sludge Compliance Fraction',
#   'Wastewater Treatment Methane Correction Factor',
#   ':math:\\text{CH}_4 Emissions from Wastewater Treatment',
#   ':math:\\text{N}_2\\text{O} Emissions from Wastewater Effluent',
#   ':math:\\text{N}_2\\text{O} Emissions from Wastewater Treatment',
#   'Biogas Recovered from Wastewater Treatment Plants',
#   'Mass of Sludge Produced',
#   'Total BOD Organic Waste in Effluent',
#   'Total BOD Removed in Treatment',
#   'Total COD Organic Waste in Effluent',
#   'Total COD Removed in Treatment',
#   'Total Nitrogen Removed in Treatment',
#   'Total Nitrogen in Effluent',
#   'Total Phosphorous Removed in Treatment',
#   'Total Phosphorous in Effluent',
#   'Volume of Wastewater Treated']}

# %%
#def get_subsector_variables
#matt_new.all_subsectors_with_primary_category
matt_new.subsector_field_category_py
# Out:
# 'primary_category_py'

# %%
len(sa.model_attributes.all_variables)
# Out:
# 3604

# %%
# this is a thing
for k, v in matt_new.dict_variables.items():
    if v.get_property("subsector") == "Agriculture":
        print(k)
# Out:
# :math:\text{CH}_4 Crop Anaerobic Decomposition Emission Factor
# :math:\text{CH}_4 Crop Biomass Burning Emission Factor
# :math:\text{CO}_2 Crop Biomass Emission Factor
# :math:\text{N}_2\text{O} Crop Biomass Burning Emission Factor
# AGRC Combustion Factor
# Above Ground Residue Dry Matter Intercept
# Above Ground Residue Dry Matter Slope
# Agriculture Equivalent Exports
# Agriculture Fraction Dry
# Agriculture Fraction Temperate
# Agriculture Fraction Tropical
# Agriculture Fraction Wet
# Crop Demand Income Elasticity
# Crop Fraction Animal Feed
# Crop Yield Factor
# Dry Matter Fraction of Harvested Crop
# Fraction of Agriculture Demand Imported
# Fraction of Food Loss Sent to Municipal Solid Waste
# Fraction of Food Produced Lost Before Consumption
# Fraction of Residues Burned
# Fraction of Residues Removed
# Initial Cropland Area Proportion
# N Content of Above Ground Residues
# N Content of Below Ground Residues
# No Till Crop Fraction
# Ratio of Above Ground Residue to Harvested Yield
# Ratio of Below Ground Biomass to Above Ground Biomass
# :math:\text{CH}_4 Emissions from Biomass Burning
# :math:\text{CH}_4 Emissions from Rice
# :math:\text{CO}_2 Emissions from Biomass Carbon Stock Changes
# :math:\text{CO}_2 Emissions from Soil Carbon in Organic Soils
# :math:\text{N}_2\text{O} Emissions from Biomass Burning
# :math:\text{N}_2\text{O} Emissions from Crop Residues
# Adjusted Agriculture Equivalent Exports
# Adjusted Agriculture Equivalent Imports
# Changes to Agriculture Net Imports Lost
# Crop Area
# Crop Demand
# Crop Yield
# Cropland Area Proportion
# Total Food Loss Sent to Municipal Solid Waste
# Total Food Produced Lost Before Consumption

# %%
matt_new.configuration.get("area_units") 
matt_new.get_volume_equivalent("m3")
# Out:
# 1.0

# %%
#matt_new.get_unit("monetary").convert("mm_usd", "mmm_usd")
unit_energy.attribute_table.table
# ?sf.format_print_list
# Out:
# Signature: sf.format_print_list(list_in: list, delim=',') -> str
# Docstring: Print (as string) values of list_in to string separated by `delim`
# File:      ~/Documents/Projects/git_jbus/sisepuede/python/support_functions.py
# Type:      function

# %%
#matt_new.get_other_attribute("region").table
matt_new.get_other_attribute("emission_gas").table.head()
# Out:
#                           gas emission_gas                  name  \
# 0         :math:`\text{CH}_4`          ch4               Methane
# 1         :math:`\text{CO}_2`          co2        Carbon Dioxide
# 2  :math:`\text{N}_2\text{O}`          n2o          Nitrus Oxide
# 3         :math:`\text{NF}_3`          nf3  Nitrogen Trifluoride
# 4         :math:`\text{SF}_6`          sf6    Sulfur Hexflouride
#
#    global_warming_potential_20  global_warming_potential_100  \
# 0                         81.2                          27.9
# 1                          1.0                           1.0
# 2                        273.0                         273.0
# 3                      13400.0                       17400.0
# 4                      18300.0                       25200.0
#
#    global_warming_potential_500    source flourinated_compound_designation
# 0                          7.95  IPCC AR6                             none
# 1                          1.00  IPCC AR6                             none
# 2                        130.00  IPCC AR6                             none
# 3                      18200.00  IPCC AR6                         Other FC
# 4                      34100.00  IPCC AR6                         Other FC

# %%
#matt_new.get_unit("energy").convert("kWh", "GJ")
unit_energy = matt_new.get_unit("energy")
unit_power = matt_new.get_unit("power")

input_unit = "mw"
units = unit_energy.get_unit_key(input_unit)
units = unit_power.get_unit_key(input_unit)
units
# Out:
# 'mw'

# %%
unit_energy.get_attribute("kWh", "hourly_unit_power_equivalent")
# Out:
# '``kw``'

# %%
mv.clean_element(
    unit_power.get_attribute("MW", "annualized_unit_energy_equivalent")
)
# Out:
# 'mwy'

# %%
#matt_new.get_unit("energy").attribute_table.table
matt_new.get_unit("energy").get_unit_key(modvar)

# %%
#sa.model_attributes.get_energy_power_swap("MW")
unit_energy.attribute_table.table
# Out:
#    energy unit_energy hourly_unit_power_equivalent  \
# 0      kJ          kj                         none
# 1     BTU         btu                         none
# 2      MJ          mj                         none
# 3    MBTU        mbtu                         none
# 4     kWh         kwh                       ``kw``
# 5      GJ          gj                         none
# 6   MMBTU       mmbtu                         none
# 7     MWh         mwh                       ``mw``
# 8      TJ          tj                         none
# 9     MWy         mwy                         none
# 10     PJ          pj                         none
# 11    GWy         gwy                         none
#
#    annualized_unit_power_equivalent                           name  \
# 0                              none                      Kilojoule
# 1                              none           British Thermal Unit
# 2                              none                      Megajoule
# 3                              none  Thousand British Thermal Unit
# 4                              none                  Kilowatt-hour
# 5                              none                      Gigajoule
# 6                              none   Million British Thermal Unit
# 7                              none                  Megawatt-hour
# 8                              none                      Terajoule
# 9                            ``mw``                  Megawatt-year
# 10                             none                      Petajoule
# 11                           ``gw``                  Gigawatt-year
#
#     energy_equivalent_kj  energy_equivalent_btu  energy_equivalent_mj  \
# 0           1.000000e+00           9.478134e-01          1.000000e-03
# 1           1.055060e+00           1.000000e+00          1.055060e-03
# 2           1.000000e+03           9.478134e+02          1.000000e+00
# 3           1.055060e+03           1.000000e+03          1.055060e+00
# 4           3.600000e+03           3.412128e+03          3.600000e+00
# 5           1.000000e+06           9.478134e+05          1.000000e+03
# 6           1.055060e+06           1.000000e+06          1.055060e+03
# 7           3.600000e+06           3.412128e+06          3.600000e+03
# 8           1.000000e+09           9.478134e+08          1.000000e+06
# 9           3.155760e+10           2.991072e+10          3.160000e+07
# 10          1.000000e+12           9.480000e+11          1.000000e+09
# 11          3.160000e+13           2.990000e+13          3.155760e+10
#
#     energy_equivalent_mbtu  energy_equivalent_kwh  energy_equivalent_gj  \
# 0             9.500000e-04           2.777780e-04          1.000000e-06
# 1             1.000000e-03           2.930710e-04          1.060000e-06
# 2             9.500000e-01           2.777778e-01          1.000000e-03
# 3             1.000000e+00           2.930722e-01          1.055060e-03
# 4             3.410000e+00           1.000000e+00          3.600000e-03
# 5             9.478100e+02           2.777778e+02          1.000000e+00
# 6             1.000000e+03           2.930722e+02          1.055060e+00
# 7             3.412130e+03           1.000000e+03          3.600000e+00
# 8             9.478134e+05           2.777778e+05          1.000000e+03
# 9             2.991072e+07           8.766000e+06          3.155760e+04
# 10            9.480000e+08           2.777778e+08          1.000000e+06
# 11            2.990000e+10           8.766000e+09          3.155760e+07
#
#     energy_equivalent_mmbtu  energy_equivalent_mwh  energy_equivalent_tj  \
# 0              9.480000e-07           2.780000e-07          1.000000e-09
# 1              1.000000e-06           2.930710e-07          1.060000e-09
# 2              9.478130e-04           2.780000e-04          1.000000e-06
# 3              1.000000e-03           2.930000e-04          1.060000e-06
# 4              3.412128e-03           1.000000e-03          3.600000e-06
# 5              9.478134e-01           2.780000e-01          1.000000e-03
# 6              1.000000e+00           2.930000e-01          1.055060e-03
# 7              3.412128e+00           1.000000e+00          3.600000e-03
# 8              9.478134e+02           2.780000e+02          1.000000e+00
# 9              2.991072e+04           8.770000e+03          3.155760e+01
# 10             9.480000e+05           2.780000e+05          1.000000e+03
# 11             2.990000e+07           8.770000e+06          3.155760e+04
#
#     energy_equivalent_mwy  energy_equivalent_pj  energy_equivalent_gwy
# 0            3.170000e-11          1.000000e-12           3.170000e-14
# 1            3.340000e-11          1.060000e-12           3.340000e-14
# 2            3.170000e-08          1.000000e-09           3.170000e-11
# 3            3.340000e-08          1.060000e-09           3.340000e-11
# 4            1.140000e-07          3.600000e-09           1.140000e-10
# 5            3.170000e-05          1.000000e-06           3.170000e-08
# 6            3.340000e-05          1.060000e-06           3.340000e-08
# 7            1.140770e-04          3.600000e-06           1.140000e-07
# 8            3.168809e-02          1.000000e-03           3.170000e-05
# 9            1.000000e+00          3.155760e-02           1.000000e-03
# 10           3.168809e+01          1.000000e+00           3.168809e-02
# 11           1.000000e+03          3.155760e+01           1.000000e+00

# %%
modvar = matt_new.dict_variables.get("Unadjusted Land Use Transition Probability")
modvar = matt_new.dict_variables.get(":math:\\text{CH}_4 Stationary Combustion Emission Factor")

#modvar.attribute("unit_mass")
modvar.attribute("unit_area")
modvar.name_fs_safe.upper()
# Out:
# 'CH4_STATIONARY_COMBUSTION_EMISSION_FACTOR'

# %%
for k, v in matt_new.dict_attributes.get("unit").items():
    print(v.key)
    print(v.table.dtypes)
    print("\n")

# %%
#import units_manager as um
attr = matt_new.dict_attributes.get("unit").get("area")

fields_avail = [
    x for x in attr.table.columns
    if attr.table[x].dtype not in ["float64", "int64"]
]
fields_avail
# Out:
# ['area', 'unit_area', 'name']

# %%
importlib.reload(um)
attr = matt_new.dict_attributes.get("unit").get("energy")
unit = um.Units(
    attr,
    key_prependage = "unit_",
)
unit.key

#attr.table
unit.get_unit_key("GJ")
# Out:
# 'gj'

# %%
importlib.reload(sf)
importlib.reload(mv)
import time


t0 = time.time()
#modvar = mv.ModelVariable(
#    attr_vars.table.iloc[2],
#    sa.model_attributes.dict_attributes,
#)
t1 = time.time()

"""
vs = mv.VariableSchema(
    modvar.dict_varinfo.get("variable_schema")
)
vs.mutable_elements_clean_ordered
vs.replace({"cat_industry": "cement"}, keys_are_clean = True,)
""";

#modvar.dict_varinfo
#modvar.dict_varinfo





series = attr_vars.table.iloc[2].copy()
series["variable_schema"] = "``ef_ippu_$UNIT-MASS$_$EMISSION-GAS$_per_$UNIT-MASS$_product_use_$CAT-INDUSTRY-DIM1$_$CAT-INDUSTRY-DIM2$_$CAT-TRANSPORTATION$`` (``$UNIT-MASS$ = tonne``, ``$EMISSION-GAS$ = co2``"
series["categories"] = "(``$CAT-INDUSTRY_DIM2$ = paper|cement|plastic``, ``$CAT-INDUSTRY-DIM1$ = product_use_lubricants|product_use_paraffin_wax|cement|plastic``, ``$CAT-TRANSPORTATION$ = aviation|rail_freight|dymm``)"
series["default_value"] = 0.0
#series["categories"] = "(``$CAT-INDUSTRY$ = all``, ``$CAT-TRANSPORTATION$ = aviation|rail_freight|dymm``)"

#series["variable_schema"] = "pij_$CAT-LANDUSE-DIM1$_to_$CAT-LANDUSE-DIM2$"
#series["categories"] = "all"

modvar = mv.ModelVariable(
    series,
    sa.model_attributes.dict_attributes,
)





# get_root_element("CAT-INDUSTRY-DIM4")
#modvar.schema.get_root_element("cat_industry_dim3")
# modvar.schema.mutable_elements_clean_ordered
modvar.dict_category_keys
modvar.schema.mutable_elements_clean_ordered
# Out:
# ['cat_industry_dim1', 'cat_industry_dim2', 'cat_transportation']

# %%
regex_at = re.compile("attribute_unit_(.*).csv")
regex_at.match("attribute_unit_temp_gr.csv").groups()
# Out:
# ('temp_gr',)

# %%
#sa.model_attributes.all_model_variables
fp = "/Users/jsyme/Documents/Projects/git_jbus/sisepuede/docs/source/csvs/attribute_length.csv"
at = AttributeTable(fp, "length", clean_table_fields = True,)
at.table()
# Out:
#   length unit_length        name  length_equivalent_m  length_equivalent_km  \
# 0      m       ``m``      Meters         1.000000e+00               0.00100
# 1     km      ``km``  Kilometers         1.000000e+03               1.00000
# 2   Mile    ``mile``       Miles         1.609340e+03               1.60934
# 3     Mm     ``mgm``  Megameters         1.000000e+06            1000.00000
# 4     Gm      ``gm``  Gigameters         1.000000e+09         1000000.00000
#
#    length_equivalent_mile  length_equivalent_mgm  length_equivalent_gm
# 0            6.213730e-04               0.000001          1.000000e-09
# 1            6.213700e-01               0.001000          1.000000e-06
# 2            1.000000e+00               0.001609          1.609340e-06
# 3            6.213700e-04               1.000000          1.000000e-03
# 4            6.213700e-07            1000.000000          1.000000e+00

# %%
modvar(
    df, 
    expand_to_all_categories = False,
    return_type = "array",
)
# Out:
# array([[0.92536768, 0.24845778, 0.37953433, 0.14847882, 0.25139435,
#         0.71123234, 0.15856626, 0.48581205, 0.68147416, 0.54829414,
#         0.08388734, 0.42894816, 0.66173826, 0.07984463, 0.47521661,
#         0.38798217, 0.5266003 , 0.4420342 , 0.88720961, 0.88586851,
#         0.70495647, 0.64484206, 0.15106266, 0.60722337],
#        [0.92536768, 0.24845778, 0.37953433, 0.14847882, 0.25139435,
#         0.71123234, 0.15856626, 0.48581205, 0.68147416, 0.54829414,
#         0.08388734, 0.42894816, 0.66173826, 0.07984463, 0.47521661,
#         0.38798217, 0.5266003 , 0.4420342 , 0.88720961, 0.88586851,
#         0.70495647, 0.64484206, 0.15106266, 0.60722337],
#        [0.92536768, 0.24845778, 0.37953433, 0.14847882, 0.25139435,
#         0.71123234, 0.15856626, 0.48581205, 0.68147416, 0.54829414,
#         0.08388734, 0.42894816, 0.66173826, 0.07984463, 0.47521661,
#         0.38798217, 0.5266003 , 0.4420342 , 0.88720961, 0.88586851,
#         0.70495647, 0.64484206, 0.15106266, 0.60722337],
#        [0.92536768, 0.24845778, 0.37953433, 0.14847882, 0.25139435,
#         0.71123234, 0.15856626, 0.48581205, 0.68147416, 0.54829414,
#         0.08388734, 0.42894816, 0.66173826, 0.07984463, 0.47521661,
#         0.38798217, 0.5266003 , 0.4420342 , 0.88720961, 0.88586851,
#         0.70495647, 0.64484206, 0.15106266, 0.60722337],
#        [0.92536768, 0.24845778, 0.37953433, 0.14847882, 0.25139435,
#         0.71123234, 0.15856626, 0.48581205, 0.68147416, 0.54829414,
#         0.08388734, 0.42894816, 0.66173826, 0.07984463, 0.47521661,
#         0.38798217, 0.5266003 , 0.4420342 , 0.88720961, 0.88586851,
#         0.70495647, 0.64484206, 0.15106266, 0.60722337],
#        [0.92536768, 0.24845778, 0.37953433, 0.14847882, 0.25139435,
#         0.71123234, 0.15856626, 0.48581205, 0.68147416, 0.54829414,
#         0.08388734, 0.42894816, 0.66173826, 0.07984463, 0.47521661,
#         0.38798217, 0.5266003 , 0.4420342 , 0.88720961, 0.88586851,
#         0.70495647, 0.64484206, 0.15106266, 0.60722337],
#        [0.92536768, 0.24845778, 0.37953433, 0.14847882, 0.25139435,
#         0.71123234, 0.15856626, 0.48581205, 0.68147416, 0.54829414,
#         0.08388734, 0.42894816, 0.66173826, 0.07984463, 0.47521661,
#         0.38798217, 0.5266003 , 0.4420342 , 0.88720961, 0.88586851,
#         0.70495647, 0.64484206, 0.15106266, 0.60722337],
#        [0.92536768, 0.24845778, 0.37953433, 0.14847882, 0.25139435,
#         0.71123234, 0.15856626, 0.48581205, 0.68147416, 0.54829414,
#         0.08388734, 0.42894816, 0.66173826, 0.07984463, 0.47521661,
#         0.38798217, 0.5266003 , 0.4420342 , 0.88720961, 0.88586851,
#         0.70495647, 0.64484206, 0.15106266, 0.60722337],
#        [0.92536768, 0.24845778, 0.37953433, 0.14847882, 0.25139435,
#         0.71123234, 0.15856626, 0.48581205, 0.68147416, 0.54829414,
#         0.08388734, 0.42894816, 0.66173826, 0.07984463, 0.47521661,
#         0.38798217, 0.5266003 , 0.4420342 , 0.88720961, 0.88586851,
#         0.70495647, 0.64484206, 0.15106266, 0.60722337],
#        [0.92536768, 0.24845778, 0.37953433, 0.14847882, 0.25139435,
#         0.71123234, 0.15856626, 0.48581205, 0.68147416, 0.54829414,
#         0.08388734, 0.42894816, 0.66173826, 0.07984463, 0.47521661,
#         0.38798217, 0.5266003 , 0.4420342 , 0.88720961, 0.88586851,
#         0.70495647, 0.64484206, 0.15106266, 0.60722337],
#        [0.92536768, 0.24845778, 0.37953433, 0.14847882, 0.25139435,
#         0.71123234, 0.15856626, 0.48581205, 0.68147416, 0.54829414,
#         0.08388734, 0.42894816, 0.66173826, 0.07984463, 0.47521661,
#         0.38798217, 0.5266003 , 0.4420342 , 0.88720961, 0.88586851,
#         0.70495647, 0.64484206, 0.15106266, 0.60722337],
#        [0.92536768, 0.24845778, 0.37953433, 0.14847882, 0.25139435,
#         0.71123234, 0.15856626, 0.48581205, 0.68147416, 0.54829414,
#         0.08388734, 0.42894816, 0.66173826, 0.07984463, 0.47521661,
#         0.38798217, 0.5266003 , 0.4420342 , 0.88720961, 0.88586851,
#         0.70495647, 0.64484206, 0.15106266, 0.60722337],
#        [0.92536768, 0.24845778, 0.37953433, 0.14847882, 0.25139435,
#         0.71123234, 0.15856626, 0.48581205, 0.68147416, 0.54829414,
#         0.08388734, 0.42894816, 0.66173826, 0.07984463, 0.47521661,
#         0.38798217, 0.5266003 , 0.4420342 , 0.88720961, 0.88586851,
#         0.70495647, 0.64484206, 0.15106266, 0.60722337],
#        [0.92536768, 0.24845778, 0.37953433, 0.14847882, 0.25139435,
#         0.71123234, 0.15856626, 0.48581205, 0.68147416, 0.54829414,
#         0.08388734, 0.42894816, 0.66173826, 0.07984463, 0.47521661,
#         0.38798217, 0.5266003 , 0.4420342 , 0.88720961, 0.88586851,
#         0.70495647, 0.64484206, 0.15106266, 0.60722337],
#        [0.92536768, 0.24845778, 0.37953433, 0.14847882, 0.25139435,
#         0.71123234, 0.15856626, 0.48581205, 0.68147416, 0.54829414,
#         0.08388734, 0.42894816, 0.66173826, 0.07984463, 0.47521661,
#         0.38798217, 0.5266003 , 0.4420342 , 0.88720961, 0.88586851,
#         0.70495647, 0.64484206, 0.15106266, 0.60722337],
#        [0.92536768, 0.24845778, 0.37953433, 0.14847882, 0.25139435,
#         0.71123234, 0.15856626, 0.48581205, 0.68147416, 0.54829414,
#         0.08388734, 0.42894816, 0.66173826, 0.07984463, 0.47521661,
#         0.38798217, 0.5266003 , 0.4420342 , 0.88720961, 0.88586851,
#         0.70495647, 0.64484206, 0.15106266, 0.60722337],
#        [0.92536768, 0.24845778, 0.37953433, 0.14847882, 0.25139435,
#         0.71123234, 0.15856626, 0.48581205, 0.68147416, 0.54829414,
#         0.08388734, 0.42894816, 0.66173826, 0.07984463, 0.47521661,
#         0.38798217, 0.5266003 , 0.4420342 , 0.88720961, 0.88586851,
#         0.70495647, 0.64484206, 0.15106266, 0.60722337],
#        [0.92536768, 0.24845778, 0.37953433, 0.14847882, 0.25139435,
#         0.71123234, 0.15856626, 0.48581205, 0.68147416, 0.54829414,
#         0.08388734, 0.42894816, 0.66173826, 0.07984463, 0.47521661,
#         0.38798217, 0.5266003 , 0.4420342 , 0.88720961, 0.88586851,
#         0.70495647, 0.64484206, 0.15106266, 0.60722337],
#        [0.92536768, 0.24845778, 0.37953433, 0.14847882, 0.25139435,
#         0.71123234, 0.15856626, 0.48581205, 0.68147416, 0.54829414,
#         0.08388734, 0.42894816, 0.66173826, 0.07984463, 0.47521661,
#         0.38798217, 0.5266003 , 0.4420342 , 0.88720961, 0.88586851,
#         0.70495647, 0.64484206, 0.15106266, 0.60722337],
#        [0.92536768, 0.24845778, 0.37953433, 0.14847882, 0.25139435,
#         0.71123234, 0.15856626, 0.48581205, 0.68147416, 0.54829414,
#         0.08388734, 0.42894816, 0.66173826, 0.07984463, 0.47521661,
#         0.38798217, 0.5266003 , 0.4420342 , 0.88720961, 0.88586851,
#         0.70495647, 0.64484206, 0.15106266, 0.60722337]])

# %%
#modvar.name.replace(":math:", "").replace("{", "").replace("\\text", "").replace("}")
df = np.full((20, len(modvar.fields_space)), -1)
df = pd.DataFrame(df, columns = modvar.fields_space)
for fld in modvar.fields:
    df[fld] = np.random.rand()

# %%
importlib.reload(mv)

series = attr_vars.table.iloc[2].copy()
series["variable_schema"] = "``ef_ippu_$UNIT-MASS$_$EMISSION-GAS$_per_$UNIT-MASS$_product_use_$CAT-INDUSTRY-DIM1$_$CAT-INDUSTRY-DIM2$_$CAT-TRANSPORTATION$`` (``$UNIT-MASS$ = tonne``, ``$EMISSION-GAS$ = co2``"
series["categories"] = "(``$CAT-INDUSTRY_DIM2$ = paper|cement|plastic``, ``$CAT-INDUSTRY-DIM1$ = product_use_lubricants|product_use_paraffin_wax|cement|plastic``, ``$CAT-TRANSPORTATION$ = aviation|rail_freight|dymm``)"

modvar = mv.ModelVariable(
    series,
    sa.model_attributes.dict_attributes,
)




modvar.get_categories_by_element(
    #{
    #    "cat_industry_dim1": ["metals", "plastic", "chemicals"],#"``metals|plastic|chemicals``"
    #},
    dict_category_space = modvar.dict_category_key_space,
)

# %%
modvar.schema.get_root_element("cat_indusdtry_dim2")
20000/122.2
# Out:
# 163.66612111292963

# %%
regex.match("CAT-INDUSTRY-DIM3")
mv.clean_element("-")
# Out:
# '_'

# %%
modvar.schema.mutable_elements_ordered
modvar.schema.space_char
re.compile(f".*{modvar.schema.space_char}{modvar.schema.flag_dim}(\d*)$").match("ahitheX-DIM34")
# Out:
# <re.Match object; span=(0, 13), match='ahitheX-DIM34'>

# %%
#modvar.schema.get_attribute("emission_gas")
hasattr(attr_cat, "key_values")
#modvar.get_categories_from_string(modvar.dict_varinfo.get(modvar.key_categories), "|", "`")

modvar.get_categories_by_element(
    category_subspace = {
        "cat_industry": "``product_use_lubricants|product_use_paraffin_wax``",
        "cat_transportation": "``product_use_lubricants``|``product_use_paraffin_wax``",
        "cat_transportation": "``product_use_lubricants``|``product_use_paraffin_wax``",
    },
    dict_category_space = modvar.dict_category_keys,
    
)
# Out:
# {'cat_industry': ['product_use_lubricants', 'product_use_paraffin_wax']}

# %%
modvar.schema.get_mutable_element(
    "ef_ippu_tonne_co2_per_tonne_production_thisun_jfijdf_clinker",
    "cat_industry"
)
# Out:
# 'thisun_jfijdf'

# %%
modvar.build_field_from_elements(
    {"cat_industry": "cement"}, 
    keys_are_clean = True
)
# Out:
# 'ef_ippu_tonne_co2_per_tonne_production_cement_clinker'

# %%
class Field:
    
    def __init__(self,
        field: str,
        cat: Union[Dict, str, None],
    ):
        
        self.field = field
        self.cat = cat
        
        
    
    def __call__(self,
    ):
        
        return self.field
    

field = Field("ef_ippu_tonne_co2_per_tonne_production_cement_clinker", {"cat_industry": "cement"})

field(), field.cat
# Out:
# ('ef_ippu_tonne_co2_per_tonne_production_cement_clinker',
#  {'cat_industry': 'cement'})

# %%
sr = "``ef_ippu_$UNIT-MASS$_$EMISSION-GAS$_per_$UNIT-MASS$_production_$CAT-INDUSTRY-I$_$CAT-TRANSPORTATION-J$`` (``$UNIT-MASS$ = tonne``, ``$EMISSION-GAS$ = ch4``)"
vs2 = mv.VariableSchema(sr)
vs2.mutable_elements_ordered


vs2.replace({"cat_industry_i": "cementitude", "cat_transportation_j": "airplanification"}, keys_are_clean = True,)
# Out:
# 'ef_ippu_tonne_ch4_per_tonne_production_cementitude_airplanification'

# %%
vs.mutable_elements_clean_ordered

# %%
sa.model_attributes.dict_attributes.get("abbreviation_subsector").table;

# %%
dict1 = {}

dict1[None] = 2
dict1
# Out:
# {None: 2}

# %%
def get_variable_schema_base(#self,
    var_schema_raw: str,
) -> str:
    """
    Using a raw variable schema, replace any unit and emission specifications
    """
    
    dict_replacements, schema  = mv.clean_schema(
        var_schema_raw, 
        return_type = "all"
    )
    
    return dict_replacements, schema

dict_replacements, schema = get_variable_schema_base(
    modvar.dict_varinfo.get("variable_schema")
)

# %%
isinstance(pd.DataFrame, type)
# Out:
# True

# %%
#regex = re.compile("(.*)\$(.*)\$(.*$)")
regex = re.compile("(?<=\$)(.*?)(?=\$)")
regex.findall("this $THIS$ $THIS2$")
#regex = re.search("(?<=\$)(.*?)(?=\$)", "this $HERE$ $NOPE$")
# Out:
# ['THIS', ' ', 'THIS2']

# %%
string = "this $THIS$ $THIS2$"
string.count("$")
# Out:
# 0

# %%
modvar.dict_varinfo.get("variable_schema")
# Out:
# '``ef_ippu_$UNIT-MASS$_$EMISSION-GAS$_per_$UNIT-MASS$_production_$CAT-INDUSTRY$`` (``$UNIT-MASS$ = tonne``, ``$EMISSION-GAS$ = ch4``)'

# %%
arr_1 = np.array([7, 11, 13, 17, 19, 23, 29])

prs = [2, 3, 5, 7, 11, 13, 17, 19]
arr_2 = []
gaps = []
for i in range(np.prod(prs)):
    check = [i%x for x in prs]
    binary = int(0 in check)
    
    arr_2.append(binary)
    if not binary:
        gaps.append(i)


P = np.prod(prs)
gaps_g1 = [x for x in gaps if x > 1]

classes = []
if False:
    l = []
    for i in range(1, 2):#len(arr_1) + 1):
        subs = list(itertools.combinations(gaps_g1, i))

        l.extend(subs)


    classes = []
    for i, sub in enumerate(l):
        val = np.prod(sub)
        mod = val%P

        classes.append(mod)

    classes = set(classes)
diffs = np.array(gaps[1:]) - np.array(gaps[0:-1])
len([x for x in diffs if x == 4])
w = np.abs(np.array(diffs[1:]) - np.array(diffs[0:-1]))
w = np.where(w == 0)
w;




pi1 = prs[-1]
counts_2 = []

P_prev = np.prod(prs[0:-1])
# check counts of 2 among each subdivision--should be relatively smooth
for i in range(pi1):
    gps = [x for x in gaps if (x >= i*P_prev) & (x < (i + 1)*P_prev)]
    
    ds = np.array(gps[1:]) - np.array(gps[0:-1])
    n = len([x for x in ds if x == 2])
    
    print(n)
    counts_2.append(n)
    #len([x for x in diffs[0:n] if x == 2])
    
    
import sympy
# non-prime nums
gaps_nopr = [x for x in gaps if (not sympy.isprime(x)) and (x > 1)]


l = []
for i in range(1, len(gaps_nopr) + 1):
    subs = list(itertools.combinations(gaps_nopr, i))
    
    l.extend(subs)

classes = []
for i, sub in enumerate(l):
    val = np.prod(sub)
    mod = val%P
    
    classes.append(mod)
    
    
gaps_nopr = [x for x in gaps if (not sympy.isprime(x)) and (x > 1)]
classes = []
for i in range(1, 3):#len(gaps_nopr) + 1):
    combs = itertools.combinations(gaps_nopr, i)
    
    for comb in combs:
        class_check = np.prod(comb)%P
        classes.append(class_check) if (class_check not in classes) else None
    
classes2 = classes.copy()
