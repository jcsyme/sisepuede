# %%
import define_transformations_afolu as dta
import define_transformations_circular_economy as dtc
import define_transformations_energy as dte
import define_transformations_ippu as dti
import define_transformations_integrated as dtr

import os, os.path
import numpy as np
import pandas as pd
#from model_attributes import *
import model_attributes as ma
import model_afolu as mafl
import model_ippu as mi
import model_circular_economy as mc
import model_electricity as ml
import model_energy as me
import model_socioeconomic as se
import setup_analysis as sa
import sisepuede_data_api as api
import sisepuede_models as sm
import support_classes as sc
import support_functions as sf
import importlib
import time
import warnings
import matplotlib.pyplot as plt
from typing import Union
import inspect
import ingestion as ing
import logging
from sisepuede_file_structure import *
import transformations_base_afolu as tba
import transformations_base_circular_economy as tbc
import transformations_base_energy as tbe
import transformations_base_general as tbg
import transformations_base_ippu as tbi


importlib.reload(ma)
importlib.reload(sa)
importlib.reload(sf)
importlib.reload(mafl)
importlib.reload(mc)
importlib.reload(mi)
importlib.reload(me)
importlib.reload(se)
importlib.reload(tbc)
importlib.reload(tbe)


import sisepuede as ssp


def _setup_logger(namespace: str, fn_out: Union[str, None] = None) -> None:
    global logger
    
    format_str = "%(asctime)s - %(levelname)s - %(message)s"
    # configure
    if fn_out is not None:
        logging.basicConfig(
            filename = fn_out,
            filemode = "w",
            format = format_str,
            level = logging.DEBUG
        )
    else:
        logging.basicConfig(
            format = format_str,
            level = logging.DEBUG
        )
        
    logger = logging.getLogger(namespace)
    # create console handler and set level to debug
    ch = logging.StreamHandler()
    ch.setLevel(logging.DEBUG)
    # create formatter
    formatter = logging.Formatter(format_str)
    # add formatter to ch
    ch.setFormatter(formatter)
    # add ch to logger
    logger.addHandler(ch)

    return logger

_setup_logger(__name__, os.path.join(os.getcwd(), "log_build_sisepuede_transformations.log"))
# Out:
# /Users/jsyme/anaconda3/envs/amber_is_your_energy/lib/python3.11/site-packages/scipy/__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.26.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{CH}_4 Stationary Combustion Emission Factor successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{CO}_2 Combustion Emission Factor successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{N}_2\text{O} Stationary Combustion Emission Factor successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Average Industrial Energy Fuel Efficiency Factor successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Electrical Transmission Loss Fraction successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Fraction of Fuel Demand Imported successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Fuel Exports successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Gravimetric Energy Density successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Gravimetric Fuel Price successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Minimum Fraction of Fuel Used for Electricity Generation successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable NemoMod REMinProductionTarget successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Thermal Fuel Price successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Volumetric Energy Density successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Volumetric Fuel Price successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Adjusted Fuel Exports successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Electrical Transmission Loss successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Energy Demand by Fuel in CCSQ successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Energy Demand by Fuel in Energy Technology successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Energy Demand by Fuel in Industrial Energy successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Energy Demand by Fuel in SCOE successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Energy Demand by Fuel in Transportation successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Fuel Imports successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Fuel Production successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Total Energy Demand by Fuel successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Unused Fuel Exported successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Value of Fuel Consumed in CCSQ successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Value of Fuel Consumed in Energy Technology successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Value of Fuel Consumed in Industrial Energy successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Value of Fuel Consumed in SCOE successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Value of Fuel Consumed in Transportation successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable NemoMod CapitalCostStorage successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable NemoMod ResidualStorageCapacity successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable NemoMod StorageStartLevel successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable NemoMod TotalAnnualMaxCapacityInvestmentStorage successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable NemoMod TotalAnnualMaxCapacityStorage successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable NemoMod TotalAnnualMinCapacityInvestmentStorage successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable NemoMod TotalAnnualMinCapacityStorage successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable NemoMod Discounted Capital Investment Storage successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable NemoMod Discounted Operating Costs Storage successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Industrial Energy Demand Scalar successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Industrial Energy Fuel Fraction Coal successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Industrial Energy Fuel Fraction Coke successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Industrial Energy Fuel Fraction Diesel successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Industrial Energy Fuel Fraction Electricity successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Industrial Energy Fuel Fraction Furnace Gas successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Industrial Energy Fuel Fraction Gasoline successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Industrial Energy Fuel Fraction Geothermal successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Industrial Energy Fuel Fraction Hydrocarbon Gas Liquids successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Industrial Energy Fuel Fraction Hydrogen successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Industrial Energy Fuel Fraction Kerosene successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Industrial Energy Fuel Fraction Natural Gas successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Industrial Energy Fuel Fraction Oil successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Industrial Energy Fuel Fraction Solar successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Industrial Energy Fuel Fraction Solid Biomass successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Initial Energy Consumption Intensity of GDP successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Initial Energy Consumption Intensity of Production successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Initial Energy Consumption in Agriculture and Livestock successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{CH}_4 Emissions from Industrial Energy successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{CO}_2 Captured in Industrial Energy successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{CO}_2 Emissions from Industrial Energy successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{N}_2\text{O} Emissions from Industrial Energy successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Electrical Energy Consumption from Industrial Energy successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Energy Consumption from Industrial Energy successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Energy Demand in Industrial Energy successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Total Electrical Energy Consumption from Industrial Energy successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Total Energy Consumption from Industrial Energy successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable SCOE Appliance Energy Demand Scalar successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable SCOE Efficiency Factor for Heat Energy from Coal successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable SCOE Efficiency Factor for Heat Energy from Diesel successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable SCOE Efficiency Factor for Heat Energy from Electricity successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable SCOE Efficiency Factor for Heat Energy from Gasoline successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable SCOE Efficiency Factor for Heat Energy from Hydrocarbon Gas Liquids successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable SCOE Efficiency Factor for Heat Energy from Hydrogen successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable SCOE Efficiency Factor for Heat Energy from Kerosene successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable SCOE Efficiency Factor for Heat Energy from Natural Gas successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable SCOE Efficiency Factor for Heat Energy from Solid Biomass successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable SCOE Elasticity of Per GDP Electrical Applicance Demand to GDP Per Capita successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable SCOE Elasticity of Per GDP Heat Energy Demand to GDP Per Capita successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable SCOE Elasticity of Per Household Electrical Applicance Demand to GDP Per Capita successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable SCOE Elasticity of Per Household Heat Energy Demand to GDP Per Capita successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable SCOE Fraction Heat Energy Demand Coal successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable SCOE Fraction Heat Energy Demand Diesel successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable SCOE Fraction Heat Energy Demand Electricity successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable SCOE Fraction Heat Energy Demand Gasoline successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable SCOE Fraction Heat Energy Demand Hydrocarbon Gas Liquids successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable SCOE Fraction Heat Energy Demand Hydrogen successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable SCOE Fraction Heat Energy Demand Kerosene successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable SCOE Fraction Heat Energy Demand Natural Gas successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable SCOE Fraction Heat Energy Demand Solid Biomass successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable SCOE Heat Energy Demand Scalar successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable SCOE Initial Per GDP Electric Appliances Energy Consumption successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable SCOE Initial Per GDP Heat Energy Consumption successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable SCOE Initial Per Household Electric Appliances Energy Consumption successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable SCOE Initial Per Household Heat Energy Consumption successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{CH}_4 Emissions from SCOE successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{CO}_2 Emissions from SCOE successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{N}_2\text{O} Emissions from SCOE successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Electrical Energy Consumption from SCOE successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Energy Consumption from SCOE successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Heat Energy Demand in SCOE successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Total Electrical Energy Consumption from SCOE successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Total Energy Consumption from SCOE successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{CH}_4 Biofuels Mobile Combustion Emission Factor successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{CH}_4 Diesel Mobile Combustion Emission Factor successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{CH}_4 Gasoline Mobile Combustion Emission Factor successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{CH}_4 Hydrocarbon Gas Liquids Mobile Combustion Emission Factor successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{CH}_4 Kerosene Mobile Combustion Emission Factor successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{CH}_4 Natural Gas Mobile Combustion Emission Factor successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{N}_2\text{O} Biofuels Mobile Combustion Emission Factor successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{N}_2\text{O} Diesel Mobile Combustion Emission Factor successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{N}_2\text{O} Gasoline Mobile Combustion Emission Factor successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{N}_2\text{O} Hydrocarbon Gas Liquids Mobile Combustion Emission Factor successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{N}_2\text{O} Kerosene Mobile Combustion Emission Factor successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{N}_2\text{O} Natural Gas Mobile Combustion Emission Factor successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Average Freight Vehicle Load successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Average Passenger Vehicle Occupancy Rate successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Electrical Vehicle Efficiency successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Freight Transportation Mode Share successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Fuel Efficiency Biofuels successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Fuel Efficiency Diesel successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Fuel Efficiency Gasoline successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Fuel Efficiency Hydrocarbon Gas Liquids successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Fuel Efficiency Hydrogen successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Fuel Efficiency Kerosene successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Fuel Efficiency Natural Gas successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Private and Public Transportation Mode Share successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Regional Transportation Mode Share successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Transportation Mode Fuel Fraction Biofuels successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Transportation Mode Fuel Fraction Diesel successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Transportation Mode Fuel Fraction Electricity successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Transportation Mode Fuel Fraction Gasoline successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Transportation Mode Fuel Fraction Hydrocarbon Gas Liquids successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Transportation Mode Fuel Fraction Hydrogen successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Transportation Mode Fuel Fraction Kerosene successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Transportation Mode Fuel Fraction Natural Gas successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{CH}_4 Emissions from Transportation successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{CO}_2 Emissions from Transportation successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{N}_2\text{O} Emissions from Transportation successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Electrical Energy Consumption from Transportation successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Energy Consumption from Transportation successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Total Electrical Energy Consumption from Transportation successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Total Energy Consumption from Transportation successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Total Megatonne-Kilometer Demand by Vehicle successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Total Passenger Distance by Vehicle successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Total Vehicle Distance Traveled successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Transportation Modal Energy Consumption from Biofuels successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Transportation Modal Energy Consumption from Diesel successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Transportation Modal Energy Consumption from Electricity successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Transportation Modal Energy Consumption from Gasoline successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Transportation Modal Energy Consumption from Hydrocarbon Gas Liquids successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Transportation Modal Energy Consumption from Hydrogen successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Transportation Modal Energy Consumption from Kerosene successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Transportation Modal Energy Consumption from Natural Gas successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Vehicle Distance Traveled from Biofuels successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Vehicle Distance Traveled from Diesel successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Vehicle Distance Traveled from Electricity successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Vehicle Distance Traveled from Gasoline successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Vehicle Distance Traveled from Hydrocarbon Gas Liquids successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Vehicle Distance Traveled from Hydrogen successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Vehicle Distance Traveled from Kerosene successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Vehicle Distance Traveled from Natural Gas successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# ...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{CO}_2 Emissions from Industrial Product Use successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{CO}_2 Emissions from Industrial Production Processes successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{NF}_3 Emissions from Industrial Production Processes successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{N}_2\text{O} Emissions from Industrial Production Processes successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{SF}_6 Emissions from Industrial Production Processes successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Change to Net Imports of Products successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Demand for Harvested Wood successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Dodecafluoropentane Emissions from Industrial Production Processes successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable HCFC-141b Emissions from Industrial Product Use successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable HCFC-142b Emissions from Industrial Product Use successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable HFC Emissions from Industrial Product Use successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable HFC Emissions from Industrial Production Processes successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable HFC-125 Emissions from Industrial Product Use successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable HFC-125 Emissions from Industrial Production Processes successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable HFC-134 Emissions from Industrial Product Use successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable HFC-134a Emissions from Industrial Product Use successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable HFC-134a Emissions from Industrial Production Processes successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable HFC-143 Emissions from Industrial Product Use successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable HFC-143a Emissions from Industrial Product Use successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable HFC-143a Emissions from Industrial Production Processes successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable HFC-152a Emissions from Industrial Product Use successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable HFC-152a Emissions from Industrial Production Processes successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable HFC-227ea Emissions from Industrial Product Use successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable HFC-227ea Emissions from Industrial Production Processes successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable HFC-23 Emissions from Industrial Product Use successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable HFC-23 Emissions from Industrial Production Processes successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable HFC-236fa Emissions from Industrial Product Use successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable HFC-245fa Emissions from Industrial Product Use successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable HFC-32 Emissions from Industrial Product Use successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable HFC-32 Emissions from Industrial Production Processes successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable HFC-365mfc Emissions from Industrial Product Use successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable HFC-365mfc Emissions from Industrial Production Processes successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable HFC-41 Emissions from Industrial Production Processes successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable HFC-43-10mee Emissions from Industrial Product Use successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Industrial Production successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Other Fluorinated Compound Emissions from Industrial Product Use successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Other Fluorinated Compound Emissions from Industrial Production Processes successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable PFC Emissions from Industrial Product Use successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable PFC Emissions from Industrial Production Processes successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable PFC-1114 Emissions from Industrial Production Processes successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable PFC-116 Emissions from Industrial Product Use successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable PFC-116 Emissions from Industrial Production Processes successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable PFC-14 Emissions from Industrial Product Use successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable PFC-14 Emissions from Industrial Production Processes successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable PFC-1418 Emissions from Industrial Production Processes successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable PFC-218 Emissions from Industrial Production Processes successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable PFC-31-10 Emissions from Industrial Product Use successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable PFC-31-10 Emissions from Industrial Production Processes successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable PFC-318 Emissions from Industrial Production Processes successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable PFC-51-14 Emissions from Industrial Product Use successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable PFC-51-14 Emissions from Industrial Production Processes successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Recycled Material Used in Industrial Production successfully set with 0 errors...
#   warnings.warn(f"Warning passed from optional_log: {msg}.")
# <Logger __main__ (DEBUG)>

# %%
"""dir_repo_data = "/Users/jsyme/Documents/Projects/git_jbus/sisepuede_data"

# supporting classes
regions = sc.Regions(sa.model_attributes)
time_periods = sc.TimePeriods(sa.model_attributes)

repo = api.SISEPUEDEBatchDataRepository(
    dir_repo_data,
    sa.model_attributes
)

modvars = [
    "Socioeconomic",
    model_afolu.modvar_agrc_area_prop_init,
    model_afolu.modvar_agrc_yf,
    model_afolu.modvar_lndu_initial_frac,
    
]

df_sectored_repo_0 = repo.read(
    modvars, 
    add_time_periods = True
)

df_sectored_repo = (
    df_sectored_repo_0
    .dropna()
    .reset_index(drop = True)
)
""";

# %%
import sisepuede_file_structure as sfs
file_struct = sfs.SISEPUEDEFileStructure()
matt = file_struct.model_attributes
# Out:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Successfully initialized Analysis ID 'sisepuede_run_2024-03-26T22:25:50.503376'.
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Verification of SISEPUEDE directory structure completed successfully with 0 errors..
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{CH}_4 Stationary Combustion Emission Factor successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{CO}_2 Combustion Emission Factor successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{N}_2\text{O} Stationary Combustion Emission Factor successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Average Industrial Energy Fuel Efficiency Factor successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Electrical Transmission Loss Fraction successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Fraction of Fuel Demand Imported successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Fuel Exports successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Gravimetric Energy Density successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Gravimetric Fuel Price successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Minimum Fraction of Fuel Used for Electricity Generation successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable NemoMod REMinProductionTarget successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Thermal Fuel Price successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Volumetric Energy Density successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Volumetric Fuel Price successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Adjusted Fuel Exports successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Electrical Transmission Loss successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Energy Demand by Fuel in CCSQ successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Energy Demand by Fuel in Energy Technology successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Energy Demand by Fuel in Industrial Energy successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Energy Demand by Fuel in SCOE successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Energy Demand by Fuel in Transportation successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Fuel Imports successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Fuel Production successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Total Energy Demand by Fuel successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Unused Fuel Exported successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Value of Fuel Consumed in CCSQ successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Value of Fuel Consumed in Energy Technology successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Value of Fuel Consumed in Industrial Energy successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Value of Fuel Consumed in SCOE successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Value of Fuel Consumed in Transportation successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable NemoMod CapitalCostStorage successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable NemoMod ResidualStorageCapacity successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable NemoMod StorageStartLevel successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable NemoMod TotalAnnualMaxCapacityInvestmentStorage successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable NemoMod TotalAnnualMaxCapacityStorage successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable NemoMod TotalAnnualMinCapacityInvestmentStorage successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable NemoMod TotalAnnualMinCapacityStorage successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable NemoMod Discounted Capital Investment Storage successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable NemoMod Discounted Operating Costs Storage successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Industrial Energy Demand Scalar successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Industrial Energy Fuel Fraction Coal successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Industrial Energy Fuel Fraction Coke successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Industrial Energy Fuel Fraction Diesel successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Industrial Energy Fuel Fraction Electricity successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Industrial Energy Fuel Fraction Furnace Gas successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Industrial Energy Fuel Fraction Gasoline successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Industrial Energy Fuel Fraction Geothermal successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Industrial Energy Fuel Fraction Hydrocarbon Gas Liquids successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Industrial Energy Fuel Fraction Hydrogen successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Industrial Energy Fuel Fraction Kerosene successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Industrial Energy Fuel Fraction Natural Gas successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Industrial Energy Fuel Fraction Oil successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Industrial Energy Fuel Fraction Solar successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Industrial Energy Fuel Fraction Solid Biomass successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Initial Energy Consumption Intensity of GDP successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Initial Energy Consumption Intensity of Production successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Initial Energy Consumption in Agriculture and Livestock successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{CH}_4 Emissions from Industrial Energy successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{CO}_2 Captured in Industrial Energy successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{CO}_2 Emissions from Industrial Energy successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{N}_2\text{O} Emissions from Industrial Energy successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Electrical Energy Consumption from Industrial Energy successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Energy Consumption from Industrial Energy successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Energy Demand in Industrial Energy successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Total Electrical Energy Consumption from Industrial Energy successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Total Energy Consumption from Industrial Energy successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable SCOE Appliance Energy Demand Scalar successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable SCOE Efficiency Factor for Heat Energy from Coal successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable SCOE Efficiency Factor for Heat Energy from Diesel successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable SCOE Efficiency Factor for Heat Energy from Electricity successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable SCOE Efficiency Factor for Heat Energy from Gasoline successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable SCOE Efficiency Factor for Heat Energy from Hydrocarbon Gas Liquids successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable SCOE Efficiency Factor for Heat Energy from Hydrogen successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable SCOE Efficiency Factor for Heat Energy from Kerosene successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable SCOE Efficiency Factor for Heat Energy from Natural Gas successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable SCOE Efficiency Factor for Heat Energy from Solid Biomass successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable SCOE Elasticity of Per GDP Electrical Applicance Demand to GDP Per Capita successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable SCOE Elasticity of Per GDP Heat Energy Demand to GDP Per Capita successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable SCOE Elasticity of Per Household Electrical Applicance Demand to GDP Per Capita successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable SCOE Elasticity of Per Household Heat Energy Demand to GDP Per Capita successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable SCOE Fraction Heat Energy Demand Coal successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable SCOE Fraction Heat Energy Demand Diesel successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable SCOE Fraction Heat Energy Demand Electricity successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable SCOE Fraction Heat Energy Demand Gasoline successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable SCOE Fraction Heat Energy Demand Hydrocarbon Gas Liquids successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable SCOE Fraction Heat Energy Demand Hydrogen successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable SCOE Fraction Heat Energy Demand Kerosene successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable SCOE Fraction Heat Energy Demand Natural Gas successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable SCOE Fraction Heat Energy Demand Solid Biomass successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable SCOE Heat Energy Demand Scalar successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable SCOE Initial Per GDP Electric Appliances Energy Consumption successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable SCOE Initial Per GDP Heat Energy Consumption successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable SCOE Initial Per Household Electric Appliances Energy Consumption successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable SCOE Initial Per Household Heat Energy Consumption successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{CH}_4 Emissions from SCOE successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{CO}_2 Emissions from SCOE successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{N}_2\text{O} Emissions from SCOE successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Electrical Energy Consumption from SCOE successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Energy Consumption from SCOE successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Heat Energy Demand in SCOE successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Total Electrical Energy Consumption from SCOE successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Total Energy Consumption from SCOE successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{CH}_4 Biofuels Mobile Combustion Emission Factor successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{CH}_4 Diesel Mobile Combustion Emission Factor successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{CH}_4 Gasoline Mobile Combustion Emission Factor successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{CH}_4 Hydrocarbon Gas Liquids Mobile Combustion Emission Factor successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{CH}_4 Kerosene Mobile Combustion Emission Factor successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{CH}_4 Natural Gas Mobile Combustion Emission Factor successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{N}_2\text{O} Biofuels Mobile Combustion Emission Factor successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{N}_2\text{O} Diesel Mobile Combustion Emission Factor successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{N}_2\text{O} Gasoline Mobile Combustion Emission Factor successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{N}_2\text{O} Hydrocarbon Gas Liquids Mobile Combustion Emission Factor successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{N}_2\text{O} Kerosene Mobile Combustion Emission Factor successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{N}_2\text{O} Natural Gas Mobile Combustion Emission Factor successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Average Freight Vehicle Load successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Average Passenger Vehicle Occupancy Rate successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Electrical Vehicle Efficiency successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Freight Transportation Mode Share successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Fuel Efficiency Biofuels successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Fuel Efficiency Diesel successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Fuel Efficiency Gasoline successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Fuel Efficiency Hydrocarbon Gas Liquids successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Fuel Efficiency Hydrogen successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Fuel Efficiency Kerosene successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Fuel Efficiency Natural Gas successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Private and Public Transportation Mode Share successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Regional Transportation Mode Share successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Transportation Mode Fuel Fraction Biofuels successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Transportation Mode Fuel Fraction Diesel successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Transportation Mode Fuel Fraction Electricity successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Transportation Mode Fuel Fraction Gasoline successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Transportation Mode Fuel Fraction Hydrocarbon Gas Liquids successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Transportation Mode Fuel Fraction Hydrogen successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Transportation Mode Fuel Fraction Kerosene successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Transportation Mode Fuel Fraction Natural Gas successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{CH}_4 Emissions from Transportation successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{CO}_2 Emissions from Transportation successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{N}_2\text{O} Emissions from Transportation successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Electrical Energy Consumption from Transportation successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Energy Consumption from Transportation successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Total Electrical Energy Consumption from Transportation successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Total Energy Consumption from Transportation successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Total Megatonne-Kilometer Demand by Vehicle successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Total Passenger Distance by Vehicle successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Total Vehicle Distance Traveled successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Transportation Modal Energy Consumption from Biofuels successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Transportation Modal Energy Consumption from Diesel successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Transportation Modal Energy Consumption from Electricity successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Transportation Modal Energy Consumption from Gasoline successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Transportation Modal Energy Consumption from Hydrocarbon Gas Liquids successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Transportation Modal Energy Consumption from Hydrogen successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Transportation Modal Energy Consumption from Kerosene successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Transportation Modal Energy Consumption from Natural Gas successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Vehicle Distance Traveled from Biofuels successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Vehicle Distance Traveled from Diesel successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Vehicle Distance Traveled from Electricity successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Vehicle Distance Traveled from Gasoline successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Vehicle Distance Traveled from Hydrocarbon Gas Liquids successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Vehicle Distance Traveled from Hydrogen successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Vehicle Distance Traveled from Kerosene successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Vehicle Distance Traveled from Natural Gas successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{CH}_4 Anaerobic Biogas Emission Factor successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{CH}_4 Composting Emission Factor successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{CH}_4 ISW Incineration Emission Factor successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{CH}_4 MSW Incineration Emission Factor successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{CH}_4 Recovery Factor Landfill Gas successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{N}_2\text{O} Composting Emission Factor successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable :math:\text{N}_2\text{O} Incineration Emission Factor successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Average Annual Waste Transported Per Waste Collection Vehicle successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# ...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable HFC-245fa Emissions from Industrial Product Use successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable HFC-32 Emissions from Industrial Product Use successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable HFC-32 Emissions from Industrial Production Processes successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable HFC-365mfc Emissions from Industrial Product Use successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable HFC-365mfc Emissions from Industrial Production Processes successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable HFC-41 Emissions from Industrial Production Processes successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable HFC-43-10mee Emissions from Industrial Product Use successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Industrial Production successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Other Fluorinated Compound Emissions from Industrial Product Use successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Other Fluorinated Compound Emissions from Industrial Production Processes successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable PFC Emissions from Industrial Product Use successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable PFC Emissions from Industrial Production Processes successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable PFC-1114 Emissions from Industrial Production Processes successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable PFC-116 Emissions from Industrial Product Use successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable PFC-116 Emissions from Industrial Production Processes successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable PFC-14 Emissions from Industrial Product Use successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable PFC-14 Emissions from Industrial Production Processes successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable PFC-1418 Emissions from Industrial Production Processes successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable PFC-218 Emissions from Industrial Production Processes successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable PFC-31-10 Emissions from Industrial Product Use successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable PFC-31-10 Emissions from Industrial Production Processes successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable PFC-318 Emissions from Industrial Production Processes successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable PFC-51-14 Emissions from Industrial Product Use successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable PFC-51-14 Emissions from Industrial Production Processes successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Properties for variable Recycled Material Used in Industrial Production successfully set with 0 errors...
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:2972: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for desig, df in df_by_designation:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:6100: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:6100: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:6100: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:6100: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:6100: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:6100: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:6100: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:6100: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:6100: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:6100: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:6100: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:6100: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:6100: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:6100: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:6100: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:6100: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:6100: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:6100: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:6100: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:6100: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/model_attributes.py:6100: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in dfg:
# MISSIONSEARCHNOTE: As of 2023-10-06, there is a temporary solution implemeted in ModelAttributes.get_variable_to_simplex_group_dictionary() to ensure that transition probability rows are enforced on a simplex.
#
# FIX THIS ASAP TO DERIVE PROPERLY.
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Error trying to write self.model_attributes to pickle at '/Users/jsyme/Documents/Projects/git_jbus/sisepuede/out/sisepuede_run_2024-03-26T22;25;50.503376/sisepuede_run_2024-03-26T22;25;50.503376_model_attributes.pkl': Can't pickle <class 'model_attributes.ModelAttributes'>: it's not the same object as model_attributes.ModelAttributes.
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Successfully read NemoMod input table data from /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/nemo_mod/SpecifiedDemandProfile.csv.
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: Successfully read NemoMod input table data from /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/nemo_mod/CapacityFactor.csv.
#   vector_reference: Union[list, np.ndarray],
# /Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/support_functions.py:2135: UserWarning: Warning passed from optional_log: NemoMod reference file checks completed successfully..
#   vector_reference: Union[list, np.ndarray],

# %%
warnings.filterwarnings("ignore")

# %%
sisepuede = ssp.SISEPUEDE(
    "calibrated",
    initialize_as_dummy = True,
    regions = ["india"],
    try_exogenous_xl_types_in_variable_specification = True,
)
# Out:
# 2024-03-26 22:27:46,267 - INFO - Successfully initialized SISEPUEDEFileStructure.
# 2024-03-26 22:27:46,267 - INFO - Successfully initialized SISEPUEDEFileStructure.
# 2024-03-26 22:27:46,267 - INFO - Successfully initialized SISEPUEDEFileStructure.
# 2024-03-26 22:27:46,272 - WARNING - Missing key dict_dimensional_keys: key time_series not found. Tables that rely on the time_series will not have index checking.
# 2024-03-26 22:27:46,272 - WARNING - Missing key dict_dimensional_keys: key time_series not found. Tables that rely on the time_series will not have index checking.
# 2024-03-26 22:27:46,272 - WARNING - Missing key dict_dimensional_keys: key time_series not found. Tables that rely on the time_series will not have index checking.
# 2024-03-26 22:27:46,274 - INFO - 	Setting export engine to 'sqlite'.
# 2024-03-26 22:27:46,274 - INFO - 	Setting export engine to 'sqlite'.
# 2024-03-26 22:27:46,274 - INFO - 	Setting export engine to 'sqlite'.
# 2024-03-26 22:27:46,279 - WARNING - No index fields defined. Index field values will not be checked when writing to tables.
# 2024-03-26 22:27:46,279 - WARNING - No index fields defined. Index field values will not be checked when writing to tables.
# 2024-03-26 22:27:46,279 - WARNING - No index fields defined. Index field values will not be checked when writing to tables.
# 2024-03-26 22:27:46,281 - INFO - Successfully instantiated table ANALYSIS_METADATA
# 2024-03-26 22:27:46,281 - INFO - Successfully instantiated table ANALYSIS_METADATA
# 2024-03-26 22:27:46,281 - INFO - Successfully instantiated table ANALYSIS_METADATA
# 2024-03-26 22:27:46,284 - WARNING - No index fields found in ATTRIBUTE_DESIGN. Initializing index fields.
# 2024-03-26 22:27:46,284 - WARNING - No index fields found in ATTRIBUTE_DESIGN. Initializing index fields.
# 2024-03-26 22:27:46,284 - WARNING - No index fields found in ATTRIBUTE_DESIGN. Initializing index fields.
# 2024-03-26 22:27:46,286 - INFO - Successfully instantiated table ATTRIBUTE_DESIGN
# 2024-03-26 22:27:46,286 - INFO - Successfully instantiated table ATTRIBUTE_DESIGN
# 2024-03-26 22:27:46,286 - INFO - Successfully instantiated table ATTRIBUTE_DESIGN
# 2024-03-26 22:27:46,290 - WARNING - No index fields found in ATTRIBUTE_LHC_SAMPLES_EXOGENOUS_UNCERTAINTIES. Initializing index fields.
# 2024-03-26 22:27:46,290 - WARNING - No index fields found in ATTRIBUTE_LHC_SAMPLES_EXOGENOUS_UNCERTAINTIES. Initializing index fields.
# 2024-03-26 22:27:46,290 - WARNING - No index fields found in ATTRIBUTE_LHC_SAMPLES_EXOGENOUS_UNCERTAINTIES. Initializing index fields.
# MISSIONSEARCHNOTE: As of 2023-10-06, there is a temporary solution implemeted in ModelAttributes.get_variable_to_simplex_group_dictionary() to ensure that transition probability rows are enforced on a simplex.
#
# FIX THIS ASAP TO DERIVE PROPERLY.
# 2024-03-26 22:27:46,293 - INFO - Successfully instantiated table ATTRIBUTE_LHC_SAMPLES_EXOGENOUS_UNCERTAINTIES
# 2024-03-26 22:27:46,293 - INFO - Successfully instantiated table ATTRIBUTE_LHC_SAMPLES_EXOGENOUS_UNCERTAINTIES
# 2024-03-26 22:27:46,293 - INFO - Successfully instantiated table ATTRIBUTE_LHC_SAMPLES_EXOGENOUS_UNCERTAINTIES
# 2024-03-26 22:27:46,300 - WARNING - No index fields found in ATTRIBUTE_LHC_SAMPLES_LEVER_EFFECTS. Initializing index fields.
# 2024-03-26 22:27:46,300 - WARNING - No index fields found in ATTRIBUTE_LHC_SAMPLES_LEVER_EFFECTS. Initializing index fields.
# 2024-03-26 22:27:46,300 - WARNING - No index fields found in ATTRIBUTE_LHC_SAMPLES_LEVER_EFFECTS. Initializing index fields.
# 2024-03-26 22:27:46,303 - INFO - Successfully instantiated table ATTRIBUTE_LHC_SAMPLES_LEVER_EFFECTS
# 2024-03-26 22:27:46,303 - INFO - Successfully instantiated table ATTRIBUTE_LHC_SAMPLES_LEVER_EFFECTS
# 2024-03-26 22:27:46,303 - INFO - Successfully instantiated table ATTRIBUTE_LHC_SAMPLES_LEVER_EFFECTS
# 2024-03-26 22:27:46,308 - WARNING - No index fields found in ATTRIBUTE_PRIMARY. Initializing index fields.
# 2024-03-26 22:27:46,308 - WARNING - No index fields found in ATTRIBUTE_PRIMARY. Initializing index fields.
# 2024-03-26 22:27:46,308 - WARNING - No index fields found in ATTRIBUTE_PRIMARY. Initializing index fields.
# 2024-03-26 22:27:46,310 - INFO - Successfully instantiated table ATTRIBUTE_PRIMARY
# 2024-03-26 22:27:46,310 - INFO - Successfully instantiated table ATTRIBUTE_PRIMARY
# 2024-03-26 22:27:46,310 - INFO - Successfully instantiated table ATTRIBUTE_PRIMARY
# 2024-03-26 22:27:46,316 - WARNING - No index fields found in ATTRIBUTE_STRATEGY. Initializing index fields.
# 2024-03-26 22:27:46,316 - WARNING - No index fields found in ATTRIBUTE_STRATEGY. Initializing index fields.
# 2024-03-26 22:27:46,316 - WARNING - No index fields found in ATTRIBUTE_STRATEGY. Initializing index fields.
# 2024-03-26 22:27:46,319 - INFO - Successfully instantiated table ATTRIBUTE_STRATEGY
# 2024-03-26 22:27:46,319 - INFO - Successfully instantiated table ATTRIBUTE_STRATEGY
# 2024-03-26 22:27:46,319 - INFO - Successfully instantiated table ATTRIBUTE_STRATEGY
# 2024-03-26 22:27:46,323 - WARNING - No index fields found in MODEL_BASE_INPUT_DATABASE. Initializing index fields.
# 2024-03-26 22:27:46,323 - WARNING - No index fields found in MODEL_BASE_INPUT_DATABASE. Initializing index fields.
# 2024-03-26 22:27:46,323 - WARNING - No index fields found in MODEL_BASE_INPUT_DATABASE. Initializing index fields.
# 2024-03-26 22:27:46,326 - INFO - Successfully instantiated table MODEL_BASE_INPUT_DATABASE
# 2024-03-26 22:27:46,326 - INFO - Successfully instantiated table MODEL_BASE_INPUT_DATABASE
# 2024-03-26 22:27:46,326 - INFO - Successfully instantiated table MODEL_BASE_INPUT_DATABASE
# 2024-03-26 22:27:46,330 - WARNING - No index fields found in MODEL_INPUT. Initializing index fields.
# 2024-03-26 22:27:46,330 - WARNING - No index fields found in MODEL_INPUT. Initializing index fields.
# 2024-03-26 22:27:46,330 - WARNING - No index fields found in MODEL_INPUT. Initializing index fields.
# 2024-03-26 22:27:46,332 - INFO - Successfully instantiated table MODEL_INPUT
# 2024-03-26 22:27:46,332 - INFO - Successfully instantiated table MODEL_INPUT
# 2024-03-26 22:27:46,332 - INFO - Successfully instantiated table MODEL_INPUT
# 2024-03-26 22:27:46,338 - WARNING - No index fields found in MODEL_OUTPUT. Initializing index fields.
# 2024-03-26 22:27:46,338 - WARNING - No index fields found in MODEL_OUTPUT. Initializing index fields.
# 2024-03-26 22:27:46,338 - WARNING - No index fields found in MODEL_OUTPUT. Initializing index fields.
# 2024-03-26 22:27:46,340 - INFO - Successfully instantiated table MODEL_OUTPUT
# 2024-03-26 22:27:46,340 - INFO - Successfully instantiated table MODEL_OUTPUT
# 2024-03-26 22:27:46,340 - INFO - Successfully instantiated table MODEL_OUTPUT
# 2024-03-26 22:27:46,342 - INFO - SISEPUEDEOutputDatabase successfully initialized IterativeDatabase.
# 2024-03-26 22:27:46,342 - INFO - SISEPUEDEOutputDatabase successfully initialized IterativeDatabase.
# 2024-03-26 22:27:46,342 - INFO - SISEPUEDEOutputDatabase successfully initialized IterativeDatabase.
# 2024-03-26 22:27:46,345 - INFO - Successfully initialized database with:
# 	type:	sqlite
# 	analysis id:	sisepuede_run_2024-03-26T22:27:45.000288
# 	fp_base_output:	/Users/jsyme/Documents/Projects/git_jbus/sisepuede/out/sisepuede_run_2024-03-26T22;27;45.000288/sisepuede_run_2024-03-26T22;27;45.000288_output_database
# 2024-03-26 22:27:46,345 - INFO - Successfully initialized database with:
# 	type:	sqlite
# 	analysis id:	sisepuede_run_2024-03-26T22:27:45.000288
# 	fp_base_output:	/Users/jsyme/Documents/Projects/git_jbus/sisepuede/out/sisepuede_run_2024-03-26T22;27;45.000288/sisepuede_run_2024-03-26T22;27;45.000288_output_database
# 2024-03-26 22:27:46,345 - INFO - Successfully initialized database with:
# 	type:	sqlite
# 	analysis id:	sisepuede_run_2024-03-26T22:27:45.000288
# 	fp_base_output:	/Users/jsyme/Documents/Projects/git_jbus/sisepuede/out/sisepuede_run_2024-03-26T22;27;45.000288/sisepuede_run_2024-03-26T22;27;45.000288_output_database
# 2024-03-26 22:27:46,347 - INFO - Running SISEPUEDE under template data mode 'calibrated'.
# 2024-03-26 22:27:46,347 - INFO - Running SISEPUEDE under template data mode 'calibrated'.
# 2024-03-26 22:27:46,347 - INFO - Running SISEPUEDE under template data mode 'calibrated'.
# 2024-03-26 22:27:46,349 - INFO - Initializing BaseInputDatabase
# 2024-03-26 22:27:46,349 - INFO - Initializing BaseInputDatabase
# 2024-03-26 22:27:46,349 - INFO - Initializing BaseInputDatabase
# 2024-03-26 22:27:50,191 - INFO - Initializing FutureTrajectories
# 2024-03-26 22:27:50,191 - INFO - Initializing FutureTrajectories
# 2024-03-26 22:27:50,191 - INFO - Initializing FutureTrajectories
# 2024-03-26 22:28:00,099 - INFO - Instantiating 1476 sampling units.
# 2024-03-26 22:28:00,099 - INFO - Instantiating 1476 sampling units.
# 2024-03-26 22:28:00,099 - INFO - Instantiating 1476 sampling units.
# 2024-03-26 22:28:00,196 - INFO - Iteration 0 complete.
# 2024-03-26 22:28:00,196 - INFO - Iteration 0 complete.
# 2024-03-26 22:28:00,196 - INFO - Iteration 0 complete.
# 2024-03-26 22:28:14,931 - INFO - Iteration 250 complete.
# 2024-03-26 22:28:14,931 - INFO - Iteration 250 complete.
# 2024-03-26 22:28:14,931 - INFO - Iteration 250 complete.
# 2024-03-26 22:28:21,900 - INFO - Iteration 500 complete.
# 2024-03-26 22:28:21,900 - INFO - Iteration 500 complete.
# 2024-03-26 22:28:21,900 - INFO - Iteration 500 complete.
# 2024-03-26 22:28:28,980 - INFO - Iteration 750 complete.
# 2024-03-26 22:28:28,980 - INFO - Iteration 750 complete.
# 2024-03-26 22:28:28,980 - INFO - Iteration 750 complete.
# 2024-03-26 22:28:35,804 - INFO - Iteration 1000 complete.
# 2024-03-26 22:28:35,804 - INFO - Iteration 1000 complete.
# 2024-03-26 22:28:35,804 - INFO - Iteration 1000 complete.
# 2024-03-26 22:28:42,620 - INFO - Iteration 1250 complete.
# 2024-03-26 22:28:42,620 - INFO - Iteration 1250 complete.
# 2024-03-26 22:28:42,620 - INFO - Iteration 1250 complete.
# 2024-03-26 22:28:48,888 - INFO - 	1476 sampling units complete in 48.79 seconds.
# 2024-03-26 22:28:48,888 - INFO - 	1476 sampling units complete in 48.79 seconds.
# 2024-03-26 22:28:48,888 - INFO - 	1476 sampling units complete in 48.79 seconds.
# 2024-03-26 22:28:48,897 - INFO - 	FutureTrajectories for 'india' complete.
# 2024-03-26 22:28:48,897 - INFO - 	FutureTrajectories for 'india' complete.
# 2024-03-26 22:28:48,897 - INFO - 	FutureTrajectories for 'india' complete.
# 2024-03-26 22:28:48,900 - INFO - Initializing LHSDesign
# 2024-03-26 22:28:48,900 - INFO - Initializing LHSDesign
# 2024-03-26 22:28:48,900 - INFO - Initializing LHSDesign
# 2024-03-26 22:28:48,901 - INFO - LHSDesign.fields_factors_l reset successful.
# 2024-03-26 22:28:48,901 - INFO - LHSDesign.fields_factors_l reset successful.
# 2024-03-26 22:28:48,901 - INFO - LHSDesign.fields_factors_l reset successful.
# 2024-03-26 22:28:48,902 - INFO - LHSDesign.fields_factors_x reset successful.
# 2024-03-26 22:28:48,902 - INFO - LHSDesign.fields_factors_x reset successful.
# 2024-03-26 22:28:48,902 - INFO - LHSDesign.fields_factors_x reset successful.
# 2024-03-26 22:28:48,934 - INFO - 	LHSDesign for region 'india' complete.
# 2024-03-26 22:28:48,934 - INFO - 	LHSDesign for region 'india' complete.
# 2024-03-26 22:28:48,934 - INFO - 	LHSDesign for region 'india' complete.
# 2024-03-26 22:28:48,936 - INFO - Generating primary keys (values of primary_id)...
# 2024-03-26 22:28:48,936 - INFO - Generating primary keys (values of primary_id)...
# 2024-03-26 22:28:48,936 - INFO - Generating primary keys (values of primary_id)...
# 2024-03-26 22:28:48,939 - INFO - Successfully initialized SISEPUEDEExperimentalManager.
# 2024-03-26 22:28:48,939 - INFO - Successfully initialized SISEPUEDEExperimentalManager.
# 2024-03-26 22:28:48,939 - INFO - Successfully initialized SISEPUEDEExperimentalManager.
# 2024-03-26 22:28:48,952 - INFO - Successfully initialized NemoMod temporary database path as /Users/jsyme/Documents/Projects/git_jbus/sisepuede/tmp/nemomod_intermediate_database.sqlite.
# 2024-03-26 22:28:48,952 - INFO - Successfully initialized NemoMod temporary database path as /Users/jsyme/Documents/Projects/git_jbus/sisepuede/tmp/nemomod_intermediate_database.sqlite.
# 2024-03-26 22:28:48,952 - INFO - Successfully initialized NemoMod temporary database path as /Users/jsyme/Documents/Projects/git_jbus/sisepuede/tmp/nemomod_intermediate_database.sqlite.
# 2024-03-26 22:28:48,965 - INFO - Set Julia directory for modules and environment to '/Users/jsyme/Documents/Projects/git_jbus/sisepuede/julia'.
# 2024-03-26 22:28:48,965 - INFO - Set Julia directory for modules and environment to '/Users/jsyme/Documents/Projects/git_jbus/sisepuede/julia'.
# 2024-03-26 22:28:48,965 - INFO - Set Julia directory for modules and environment to '/Users/jsyme/Documents/Projects/git_jbus/sisepuede/julia'.
# 2024-03-26 22:28:49,105 - INFO - Successfully initialized SISEPUEDEModels.
# 2024-03-26 22:28:49,105 - INFO - Successfully initialized SISEPUEDEModels.
# 2024-03-26 22:28:49,105 - INFO - Successfully initialized SISEPUEDEModels.
# 2024-03-26 22:28:49,145 - INFO - Table ANALYSIS_METADATA successfully written to database.
# 2024-03-26 22:28:49,145 - INFO - Table ANALYSIS_METADATA successfully written to database.
# 2024-03-26 22:28:49,145 - INFO - Table ANALYSIS_METADATA successfully written to database.
# 2024-03-26 22:28:49,157 - INFO - Table ATTRIBUTE_DESIGN successfully written to database.
# 2024-03-26 22:28:49,157 - INFO - Table ATTRIBUTE_DESIGN successfully written to database.
# 2024-03-26 22:28:49,157 - INFO - Table ATTRIBUTE_DESIGN successfully written to database.
# 2024-03-26 22:28:49,171 - INFO - Table ATTRIBUTE_STRATEGY successfully written to database.
# 2024-03-26 22:28:49,171 - INFO - Table ATTRIBUTE_STRATEGY successfully written to database.
# 2024-03-26 22:28:49,171 - INFO - Table ATTRIBUTE_STRATEGY successfully written to database.
# 2024-03-26 22:28:50,596 - INFO - Table MODEL_BASE_INPUT_DATABASE successfully written to database.
# 2024-03-26 22:28:50,596 - INFO - Table MODEL_BASE_INPUT_DATABASE successfully written to database.
# 2024-03-26 22:28:50,596 - INFO - Table MODEL_BASE_INPUT_DATABASE successfully written to database.

# %%
def build_inputs(
    strats_run: int = 0,
) -> pd.DataFrame:
    """
    Get India's inputs (tmp)
    """
    region = "india"
    # strats to run
    # 0, 1014, 5009
    strats_run = [strats_run]
    attr_primary = sisepuede.odpt_primary.get_indexing_dataframe(
        {
            sisepuede.key_design: [0],
            sisepuede.key_future: [0],
            sisepuede.key_strategy: strats_run,
        }
    )

    
    df_input = []
    for i, row in attr_primary.iterrows():

        primary = row[sisepuede.key_primary]
        dict_out = sisepuede.generate_scenario_database_from_primary_key(
            primary
        )

        df_input.append(dict_out.get(region))

    df_input = pd.concat(df_input, axis = 0).reset_index(drop = True)
    
    return df_input



def build_input_df(
    strats_run: int = 0,
) -> pd.DataFrame:
    """
    Put everything together to build a coherent dataframe
    """


    df_input = build_inputs(strats_run = strats_run,)
    df_probs_new = get_probs_copernicus()
    df_input = overwrite_inputs(df_input, df_probs_new)
    df_input = merge_into_all_tp_and_fill(df_input)
    
    df_input.drop(
        [sisepuede.key_primary],
        axis = 1,
        inplace = True,
    )#= np.array(df_input[sisepuede.key_primary]).astype(int)
    
    return df_input



def get_probs_copernicus(
) -> pd.DataFrame:
    """
    Retrieve Copernicus transition probabilities
    """
    # import transition probabilities
    df_probs = pd.read_csv(
        sa.fp_csv_transition_probability_estimation_annual_copernicus,
    )

    # clean to sisepuede readable
    isos_keep = sisepuede.region_definitions.return_region_or_iso(
        sisepuede.regions, 
        return_type = "iso",
    )
    
    df_probs = (
        sisepuede.region_definitions.add_region_or_iso_field(
            df_probs[
                df_probs[sisepuede.region_definitions.field_iso].isin(isos_keep)
            ]
            .reset_index(drop = True)
        )
        .drop([sisepuede.region_definitions.field_iso], axis = 1)
    )

    df_probs = (
        sisepuede.time_period_definitions.years_to_tps(
            df_probs
        )
        .drop([sisepuede.time_period_definitions.field_year], axis = 1)
    )
    
    return df_probs



def get_strategies_from_codes(
    strategy_codes: Union[List[str], str],
) -> Union[List[int], None]:
    """
    Map codes to id as input
    """
    attr_strat = sa.model_attributes.get_dimensional_attribute_table(sa.model_attributes.dim_strategy_id)
    dict_map = attr_strat.field_maps.get(f"strategy_code_to_{attr_strat.key}")
    
    # check specification of codes
    strategy_codes = (
        [strategy_codes] 
        if isinstance(strategy_codes, str)
        else (
            strategy_codes
            if sf.islistlike(strategy_codes)
            else None
        )
    )
    
    if strategy_codes is None:
        return None
    
    # get ids to build
    strategies_build = [dict_map.get(x) for x in strategy_codes]
    strategies_build = [x for x in strategies_build if x is not None]
    out = (
        None
        if len(strategies_build) == 0
        else strategies_build
    )
    
    return out



def merge_into_all_tp_and_fill(
    df_input: pd.DataFrame,
) -> pd.DataFrame:
    """
    merge into all time periods, then fill down
    """
    
    
    df_out = sisepuede.time_period_definitions.get_time_period_df()
    df_out = (
        pd.merge(
            df_out,
            df_input,
            how = "left",
        )
        .interpolate(method = "ffill")
        .interpolate(method = "bfill")
    )
    
    return df_out



def overwrite_df_values(
    df: pd.DataFrame,
    dict_vals: Dict,
) -> pd.DataFrame:
    """
    Overwrite some field values
    """
    
    for k, v in dict_vals.items():
        
        if k not in df.columns:
            continue
            
        df[k] = v
        
    return df



def overwrite_inputs(
    df_input: pd.DataFrame,
    df_probs: pd.DataFrame,
) -> pd.DataFrame:
    """
    Overwrite existing India inputs with those from transition probabilties
    """
    
    
    df_out = sf.match_df_to_target_df(
        df_input,
        df_probs,
        [
            sisepuede.region_definitions.key,
            sisepuede.time_period_definitions.field_time_period
        ],
        try_interpolate = True,
    )
    
    return df_out

# %%
#df_input_base = build_input_df(strats_run = 1014)
#df_input_all = build_input_df(strats_run = 5009)


df_input_base = build_input_df(strats_run = 0)

# %%
df_input_all = build_input_df(strats_run = 5009)

# %%
 sa.model_attributes.build_variable_fields("Fraction of Residues Burned")[0]
# Out:
# 'frac_agrc_crop_residues_burned'

# %%
# SOME DATA NOTES (TO GET A PRELIMINARY ADJUSTMENT)
#
# grassland total area = 0.153861209*328726000 = 50578179.789734
# 12 millino ha are pasture (https://uknowledge.uky.edu/cgi/viewcontent.cgi?article=1998&context=igc)
var_lndu_pasture_frac = sa.model_attributes.build_variable_fields("Pasture Fraction of Grassland")[0]
est_pasture_frac = 12000000/50578179.789734

# red meat fraction: https://www.pewresearch.org/short-reads/2021/07/08/eight-in-ten-indians-limit-meat-in-their-diets-and-four-in-ten-consider-themselves-vegetarian/
# assume that 69% do not eat red meat--this should hopefully help tame some of the influence 
var_gnrl_frac_eating_red_meat = sa.model_attributes.build_variable_fields("Fraction Eating Red Meat")[0]
frac_gnrl_eating_red_meat = 0.31

# India burns about 20% of residues: https://www.nature.com/articles/s41467-022-34093-z
var_agrc_frac_res_burned = sa.model_attributes.build_variable_fields("Fraction of Residues Burned")[0]
est_frac_res_burned = 0.2

# try to cut air elasticities; most show demand as ranging from 1-2; will drop to 1 https://www.vtpi.org/elasticities.pdf
elast_trde_regional = 1.0
var_trde_elast_regional = sa.model_attributes.build_variable_fields(
    "Elasticity of Passenger-Kilometer Demand per Capita to GDP per Capita",
    restrict_to_category_values = ["regional"],
)[0]

"""
# get yield factors as stable
dict_yf_update = sa.model_attributes.extract_model_variable(
    df_input,
    "Crop Yield Factor",
    return_type = "data_frame",
)
dict_yf_update = dict_yf_update.iloc[0].to_dict()
""";

# turn off crop elasticities to income for this run
dict_elast_agrc = sa.model_attributes.build_variable_fields(
    "Crop Demand Income Elasticity",
)
dict_elast_agrc = dict((x, 0.0) for x in dict_elast_agrc)

# turn off lvst elasticities
dict_elast_lvst = sa.model_attributes.build_variable_fields(
    "Elasticity of Livestock Demand to GDP per Capita",
)
dict_elast_lvst = dict((x, 0.0) for x in dict_elast_lvst)





# define a function to mix yields
def mix_yields_with_base(
    df: pd.DataFrame,
    mix_base_frac: float, 
) -> pd.DataFrame:
    """
    Yields look wonky, so mix the inital value (frac `mix_base_frac`) with 
        value specified in data frame; mix_base_frac = 0 will return the
        original data frame, while mix_base_frac = 1 will populate each
        field factor with the initial value.
    """
    
    vars_yf = sa.model_attributes.build_variable_fields(
        "Crop Yield Factor",
    )
    
    for field in vars_yf:
        if (field not in df.columns):
            continue
        
        vec = df[field].to_numpy()
        vec_new = vec[0]*mix_base_frac + (1 - mix_base_frac)*vec
        
        df[field] = vec_new
        
    return df
        


    
def reallocate_scoe(
    df: pd.DataFrame,
) -> pd.DataFrame:
    """
    Reallocate some energy in SCOE since current estimates are wild
    """
    
    # india: https://www.iea.org/countries/india
    
    ##  COMMERCIAL get field names to use to assign fractions
    
    dict_flds_com = {
        "consumpinit_scoe_tj_per_mmmgdp_commercial_municipal_elec_appliances": 0,
        "consumpinit_scoe_tj_per_mmmgdp_commercial_municipal_heat_energy": 0,
    }

    for field in dict_flds_com.keys():
        dict_flds_com.update({field: df[field].iloc[0]})

    denom = sum(dict_flds_com.values())
    dict_flds_com = dict((k, v/denom) for k, v in dict_flds_com.items())
    
    # get new total factors
    gdp = float(
        sa.model_attributes.extract_model_variable(
            df,
            "GDP"
        )
        .iloc[0]
    )
    
    total_energy_com = 729148 # from IEA
    dict_flds_com = dict((k, (total_energy_com/gdp)*v) for k, v in dict_flds_com.items())
    
    

    ##  RESIDENTAIL
    
    dict_flds_res = {
        "consumpinit_scoe_gj_per_hh_residential_elec_appliances": 0,
        "consumpinit_scoe_gj_per_hh_residential_heat_energy": 0,
    }

    for field in dict_flds_res.keys():
        dict_flds_res.update({field: df[field].iloc[0]})

    denom = sum(dict_flds_res.values())
    dict_flds_res = dict((k, v/denom) for k, v in dict_flds_res.items())
    
    pop = float(
        sa.model_attributes.extract_model_variable(
            df,
            "Population"
        )
        .iloc[0]
        .sum()
    )
    occ = float(
        sa.model_attributes.extract_model_variable(
            df,
            "Initial National Occupancy Rate"
        )
        .iloc[0]
    )
    hh = pop/occ

    
    total_energy_res = 6341932
    dict_flds_res = dict((k, (1000*total_energy_res/hh)*v) for k, v in dict_flds_res.items())
    
    # update output values
    
    dict_flds_res.update(dict_flds_com)
    
    return dict_flds_res

    

dict_value_overwrites = {
    var_agrc_frac_res_burned: est_frac_res_burned,
    var_gnrl_frac_eating_red_meat: frac_gnrl_eating_red_meat,
    var_lndu_pasture_frac: est_pasture_frac,
    var_trde_elast_regional: elast_trde_regional,
}
#dict_value_overwrites.update(dict_yf_update)
dict_value_overwrites.update(dict_elast_agrc)
dict_value_overwrites.update(dict_elast_lvst)
dict_value_overwrites.update(reallocate_scoe(df_input_base))

# %%
#### df_input = df_input_base.copy()
df_input = overwrite_df_values(
    df_input_base,
    dict_value_overwrites,
)


if False:
    # already did this once, don't want to keep doing it again
    df_input = mix_yields_with_base(
        df_input,
        0.45
    )
"""
#?model_afolu.get_markov_matrices
model_afolu = mafl.AFOLU(sa.model_attributes)
sa.model_attributes.extract_model_variable(
    df_input,
    model_afolu.modvar_lndu_prob_transition
).sum(axis = 1)
""";

# %%
df_out2[
    ["time_period"] + 
    [x for x in df_out.columns if ("area" in x) and ("lndu" in x) and ("conversion" not in x)]
].plot.area(x = "time_period")
# Out:
# <AxesSubplot: xlabel='time_period'>

# %%
warnings.filterwarnings("ignore")
# 
# TEMPORARY!
#df_input_new["lndu_reallocation_factor"] = 0.5

df_out = sisepuede.models.project(
    df_input,
    include_electricity_in_energy = False
);
# Out:
# 2024-03-26 23:50:46,709 - INFO - Running AFOLU model
# 2024-03-26 23:50:46,709 - INFO - Running AFOLU model
# 2024-03-26 23:50:46,709 - INFO - Running AFOLU model
# 2024-03-26 23:50:47,134 - INFO - AFOLU model run successfully completed
# 2024-03-26 23:50:47,134 - INFO - AFOLU model run successfully completed
# 2024-03-26 23:50:47,134 - INFO - AFOLU model run successfully completed
# 2024-03-26 23:50:47,135 - INFO - Running CircularEconomy model
# 2024-03-26 23:50:47,135 - INFO - Running CircularEconomy model
# 2024-03-26 23:50:47,135 - INFO - Running CircularEconomy model
# 2024-03-26 23:50:47,239 - INFO - CircularEconomy model run successfully completed
# 2024-03-26 23:50:47,239 - INFO - CircularEconomy model run successfully completed
# 2024-03-26 23:50:47,239 - INFO - CircularEconomy model run successfully completed
# 2024-03-26 23:50:47,241 - INFO - Running IPPU model
# 2024-03-26 23:50:47,241 - INFO - Running IPPU model
# 2024-03-26 23:50:47,241 - INFO - Running IPPU model
# 2024-03-26 23:50:47,409 - INFO - IPPU model run successfully completed
# 2024-03-26 23:50:47,409 - INFO - IPPU model run successfully completed
# 2024-03-26 23:50:47,409 - INFO - IPPU model run successfully completed
# 2024-03-26 23:50:47,411 - INFO - Running Energy model (NonElectricEnergy without Fugitive Emissions)
# 2024-03-26 23:50:47,411 - INFO - Running Energy model (NonElectricEnergy without Fugitive Emissions)
# 2024-03-26 23:50:47,411 - INFO - Running Energy model (NonElectricEnergy without Fugitive Emissions)
# 2024-03-26 23:50:47,461 - DEBUG - Missing elasticity information found in 'project_energy_consumption_by_fuel_from_effvars': using specified future demands.
# 2024-03-26 23:50:47,461 - DEBUG - Missing elasticity information found in 'project_energy_consumption_by_fuel_from_effvars': using specified future demands.
# 2024-03-26 23:50:47,461 - DEBUG - Missing elasticity information found in 'project_energy_consumption_by_fuel_from_effvars': using specified future demands.
# 2024-03-26 23:50:47,654 - INFO - NonElectricEnergy without Fugitive Emissions model run successfully completed
# 2024-03-26 23:50:47,654 - INFO - NonElectricEnergy without Fugitive Emissions model run successfully completed
# 2024-03-26 23:50:47,654 - INFO - NonElectricEnergy without Fugitive Emissions model run successfully completed
# 2024-03-26 23:50:47,656 - INFO - Running Energy (Fugitive Emissions)
# 2024-03-26 23:50:47,656 - INFO - Running Energy (Fugitive Emissions)
# 2024-03-26 23:50:47,656 - INFO - Running Energy (Fugitive Emissions)
# 2024-03-26 23:50:47,706 - ERROR - Error running Fugitive Emissions from Energy model:
#             Unable to extract variable Total Energy Demand by Fuel in extract_model_variable: unsupported operand type(s) for -: 'list' and 'list'
#
# 2024-03-26 23:50:47,706 - ERROR - Error running Fugitive Emissions from Energy model:
#             Unable to extract variable Total Energy Demand by Fuel in extract_model_variable: unsupported operand type(s) for -: 'list' and 'list'
#
# 2024-03-26 23:50:47,706 - ERROR - Error running Fugitive Emissions from Energy model:
#             Unable to extract variable Total Energy Demand by Fuel in extract_model_variable: unsupported operand type(s) for -: 'list' and 'list'
#
# 2024-03-26 23:50:47,708 - INFO - Appending Socioeconomic outputs
# 2024-03-26 23:50:47,708 - INFO - Appending Socioeconomic outputs
# 2024-03-26 23:50:47,708 - INFO - Appending Socioeconomic outputs
# 2024-03-26 23:50:47,730 - INFO - Socioeconomic outputs successfully appended.
# 2024-03-26 23:50:47,730 - INFO - Socioeconomic outputs successfully appended.
# 2024-03-26 23:50:47,730 - INFO - Socioeconomic outputs successfully appended.

# %%
df_out[
    ["time_period"] + 
    [x for x in df_out.columns if x.startswith("emission_co2e_subsector_total_frst")]
].plot.area(x = "time_period")
# Out:
# <AxesSubplot: xlabel='time_period'>

# %%
df_out["emission_co2e_subsector_total_frst"].sum()
# Out:
# -4898.248765938248

# %%
df_out2["emission_co2e_subsector_total_frst"].sum()
# Out:
# -6524.812590157492

# %%
df_out2[
    ["time_period"] + 
    [x for x in df_out2.columns if x.startswith("emission_co2e_subsector_total_frst")]
].plot.area(x = "time_period")
# Out:
# <AxesSubplot: xlabel='time_period'>

# %%
df_out[
    ["time_period"] + 
    [x for x in df_out.columns if x.startswith("emission_co2e_subsector")]
].plot.area(x = "time_period")
# Out:
# <AxesSubplot: xlabel='time_period'>

# %%
df_out[
    ["time_period"] + 
    [x for x in df_out.columns if x.startswith("emission_co2e_ch4_lvst")]

].plot.area(x = "time_period")
# Out:
# <AxesSubplot: xlabel='time_period'>

# %%
df_input_new[
    ["time_period"] + 
    [x for x in df_input_new.columns if ("export" in x) and ("agrc" in x)]
].plot.area(x = "time_period")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df_input_new[
#       2     ["time_period"] +
#       3     [x for x in df_input_new.columns if ("export" in x) and ("agrc" in x)]
#       4 ].plot.area(x = "time_period")
#
# NameError: name 'df_input_new' is not defined

# %%
df_out[
    ["time_period"] + 
    [x for x in df_out.columns if ("area_lndu" in x) & ("conversion" not in x) and ("improved" not in x)]
].plot.area(x = "time_period")
# Out:
# <AxesSubplot: xlabel='time_period'>

# %%
# read in FAO data
def get_faostat_data(
    dir_faostat: str, 
    nm: str,
    encode: str = "ISO-8859-1"
) -> pd.DataFrame:
    
    fp_read = os.path.join(dir_faostat, nm, f"{nm}.csv")
    sf.check_path(fp_read)
    
    df_ret = pd.read_csv(
        fp_read, 
        encoding = encode
    )
    
    return df_ret

fp = "/Users/jsyme/Documents/Projects/FY21/SWCHE131_1000/Data/ingestion/FAOSTAT/Inputs_LandUse_E_All_Data_(Normalized)/Inputs_LandUse_E_All_Data_(Normalized).csv"


df_lndu = get_faostat_data(
    os.path.dirname(os.path.dirname(fp)),
    "Inputs_LandUse_E_All_Data_(Normalized)"
)

df_lndu[
    df_lndu["Area"].isin(["India"])
    & df_lndu["Year"].isin([2017])
    
];

# %% [markdown]
# ##  Note on projection method:
#  - gdp is in line
#     https://www.goldmansachs.com/intelligence/pages/how-india-could-rise-to-the-worlds-second-biggest-economy.html
# - so is population
#     https://www.google.com/search?q=india+peak+population+projections&client=safari&sca_esv=591800476&source=hp&ei=WQaAZb3vJJHmkPIPmca5oA4&iflsig=AO6bgOgAAAAAZYAUab9TA-ChfCJOB9NZyBS8uSOqE5UY&oq=india+peak+population+p&gs_lp=Egdnd3Mtd2l6IhdpbmRpYSBwZWFrIHBvcHVsYXRpb24gcCoCCAAyBRAAGIAEMgsQABiABBiKBRiGAzILEAAYgAQYigUYhgMyCxAAGIAEGIoFGIYDSK8oUABYryFwAHgAkAEDmAGlAqAB_-wHCAg4QLhiABBixAxjHARjRA8ICBhAAGBYYHg&sclient=gws-wiz

# %%
def project_vector(
    vec_in: pd.Series,
) -> np.ndarray:
    """
    vec_in: vector of data to project forward. Assumes that 0 growth needs
        to be overwritten
    """
    
    v = np.array(vec_in)
    rates = v[1:]/v[0:-1]
    w = np.where(rates != 1.0)[0]
    
    # get historical
    rates_historical = rates[w]
    
    # project continuously
    rates_proj = rates_historical.copy()
    n = len(rates) - len(w)
    
    for i in range(n):
        val = sf.project_from_array(
             np.array([rates_proj]).transpose(),
            max_lookback = None,
        )
        
        rates_proj = np.insert(
            rates_proj, 
            len(rates_proj), 
            val
        )
    
    # add a one and multiply cumulative growth
    rates_proj = np.insert(
        rates_proj,
        0,
        1.0
    )
    
    vec_new = v[0]*np.cumprod(rates_proj)
    
    return vec_new



modvars = [
    sisepuede.models.model_socioeconomic.modvar_gnrl_subpop,
    sisepuede.models.model_socioeconomic.modvar_econ_gdp,
]

fields = sum(
    [sisepuede.model_attributes.build_variable_fields(x) for x in modvars],
    []
)

for field in fields:
    vec = project_vector(df_input[field])
    df_input[field] = vec

# %%
# get data frame mapping variables to new variable trajectory groups
df_new_vargroups = pd.read_csv("/Users/jsyme/Documents/Projects/FY21/SWCHE131_1000/experiments_and_analysis/remapping_of_variable_groups_in_intensity_runs_10_12.csv")
(
    df_new_vargroups
    .rename(
        columns = dict(
            (x, x.lower().strip().replace(" ", "_"))
            for x in ["Variable Specification", "new group"]
        ),
        inplace = True,
    )
)

field_vs = "variable_specification"
field_variable = "variable"
field_new_group = "new_group"
field_tg = "variable_trajectory_group"
df_new_vargroups = (
    df_new_vargroups[[field_vs, field_new_group]]
    .rename(columns = {field_vs: field_variable})
)

# build dictionary
dict_var_to_ng = sf.build_dict(df_new_vargroups[[field_variable, field_new_group]])
dict_ng_to_tg = sorted(list(set(df_new_vargroups[field_new_group])))
dict_ng_to_tg = dict(
    (x, i + 1)
    for i, x in enumerate(dict_ng_to_tg)
)

dict_var_to_tg = {}

dfg = (
    df_new_vargroups
    .groupby([field_new_group])
)

i = 1
for ng, df in dfg:
    
    trajgroup = dict_ng_to_tg.get(ng)
    dict_var_to_tg.update(
        dict(
            (x, trajgroup) for x in list(df[field_variable])
        )
    )
    
    i += 1


# update field out
df_new_vargroups[field_tg] = df_new_vargroups[field_variable].apply(dict_var_to_tg.get)
df_new_vargroups.drop([field_new_group], axis = 1, inplace = True)

"""
df_trajgroup_assignments = sa.model_attributes.build_variable_dataframe_by_sector(
    None, 
    df_trajgroup = df_new_vargroups, 
    include_time_periods = False,
    include_simplex_group_as_trajgroup = True
)
""";

# %%
importlib.reload(sfs)
# Out:
# <module 'sisepuede_file_structure' from '/Users/jsyme/Documents/Projects/git_jbus/sisepuede/python/sisepuede_file_structure.py'>

# %%
##### importlib.reload(ma)
importlib.reload(sf)
importlib.reload(ing)
importlib.reload(tbg)
importlib.reload(tba)
importlib.reload(dta)
importlib.reload(dtc)
importlib.reload(tbe)
importlib.reload(dte)
importlib.reload(dtr)



regions_run = ["india"]
year_0_ramp = 2025
field_region = sisepuede.key_region #"nation"
#regions_run = regions


# reduce inputs
df_input = df_input[
    df_input[field_region].isin(regions_run)
].reset_index(drop = True)


warnings.filterwarnings("ignore")

if True:
    # set some parameters (WILL SET TO READ FROM A CONFIG OR STRATEGY DEFINITION FILE)
    dict_config_te = {
        "categories_entc_max_investment_ramp": [
            "pp_hydropower"
            #"pp_nuclear"
        ],
        "categories_entc_renewable": [
            "pp_geothermal",
            "pp_hydropower",
            "pp_ocean",
            "pp_solar",
            "pp_wind"
        ],
        "categories_inen_high_heat": [
            "cement", 
            "chemicals", 
            "glass", 
            "lime_and_carbonite", 
            "metals"
        ],
        "dict_entc_renewable_target_msp": {
            "pp_solar": 0.15,
            "pp_geothermal": 0.1,
            "pp_wind": 0.15
        },
        "frac_inen_high_temp_elec_hydg": 0.5*0.45,
        "frac_inen_low_temp_elec": 0.95*0.45,
        "n_tp_ramp": None,
        "vir_renewable_cap_delta_frac": 0.0075,
        "vir_renewable_cap_max_frac": 0.125,
        "year_0_ramp": year_0_ramp
    }


    transformations_integrated = dtr.TransformationsIntegrated(
        dict_config_te,
        baseline_with_plur = False, # SET TO TRUE TO ALLOW THE BASELINE TO INCLUDE PLUR (NULLIFIES THE WITH PLUR STRAT)
        df_input = df_input,
        field_region = field_region,
        logger = logger,
        regions = regions_run,
    )
# Out:
# 2024-03-27 00:22:04,287 - INFO - Successfully initialized Analysis ID 'sisepuede_run_2024-03-27T00:22:04.287665'
# 2024-03-27 00:22:04,287 - INFO - Successfully initialized Analysis ID 'sisepuede_run_2024-03-27T00:22:04.287665'
# 2024-03-27 00:22:04,289 - INFO - Verification of SISEPUEDE directory structure completed successfully with 0 errors.
# 2024-03-27 00:22:04,289 - INFO - Verification of SISEPUEDE directory structure completed successfully with 0 errors.
# MISSIONSEARCHNOTE: As of 2023-10-06, there is a temporary solution implemeted in ModelAttributes.get_variable_to_simplex_group_dictionary() to ensure that transition probability rows are enforced on a simplex.
#
# FIX THIS ASAP TO DERIVE PROPERLY.
# 2024-03-27 00:22:05,515 - INFO - NemoMod reference file checks completed successfully.
# 2024-03-27 00:22:05,515 - INFO - NemoMod reference file checks completed successfully.
# 2024-03-27 00:22:05,517 - INFO - Successfully initialized SISEPUEDEFileStructure.
# 2024-03-27 00:22:05,517 - INFO - Successfully initialized SISEPUEDEFileStructure.
# 2024-03-27 00:22:05,526 - INFO - Initializing BaseInputDatabase
# 2024-03-27 00:22:05,526 - INFO - Initializing BaseInputDatabase

# %%
df_input.to_csv(
    sa.fp_csv_tmp_inputs,
    index = None,
    encoding = "UTF-8"
)

# %%
    
strategy_codes_keep = [
    "BASE",
    "LNDU:PLUR",
    "PFLO:BETTER_BASE",
    "PFLO:CHANGE_CONSUMPTION",
    "PFLO:SUPPLY_SIDE_TECH",
    "PFLO:ALL_NO_STOPPING_DEFORESTATION_PLUR",
    "PFLO:ALL_PLUR",
    "LNDU:PLUR_INDIA_CC",
    "PFLO:INDIA_CCDR_PLUR",
    "PFLO:INDIA_CCDR_PLUR_INDIA_CC",
    "PFLO:ALL_PLUR_INDIA_CC"
]
strategies_keep = get_strategies_from_codes(strategy_codes_keep)

if True:
    dict_transformations = transformations_integrated.build_strategies_to_templates(
        df_trajgroup = df_new_vargroups, # passed to input_template.template_from_inputs()
        include_simplex_group_as_trajgroup = True, # passed to input_template.template_from_inputs()
        return_q = False,
        strategies = strategies_keep,
        regions = sisepuede.regions
    )
# Out:
# 2024-03-27 00:24:52,170 - INFO - Starting build of 10 strategies in 1 regions...
# 2024-03-27 00:24:52,170 - INFO - Starting build of 10 strategies in 1 regions...
# 2024-03-27 00:24:52,188 - INFO - Starting build for region india
# 2024-03-27 00:24:52,188 - INFO - Starting build for region india
# 2024-03-27 00:24:52,209 - INFO - 	Successfully built transformation strategy_id = 1015 ('LNDU: Partial land use reallocation') in 0.02 seconds.
# 2024-03-27 00:24:52,209 - INFO - 	Successfully built transformation strategy_id = 1015 ('LNDU: Partial land use reallocation') in 0.02 seconds.
# 2024-03-27 00:24:55,939 - INFO - 	Successfully built transformation strategy_id = 5001 ('PFLO: Better baseline') in 0.18 seconds.
# 2024-03-27 00:24:55,939 - INFO - 	Successfully built transformation strategy_id = 5001 ('PFLO: Better baseline') in 0.18 seconds.
# 2024-03-27 00:24:59,418 - INFO - 	Successfully built transformation strategy_id = 5004 ('PFLO: Change consumer behavior') in 0.17 seconds.
# 2024-03-27 00:24:59,418 - INFO - 	Successfully built transformation strategy_id = 5004 ('PFLO: Change consumer behavior') in 0.17 seconds.
# 2024-03-27 00:25:03,683 - INFO - 	Successfully built transformation strategy_id = 5006 ('PFLO: Supply side technologies and transformations') in 0.82 seconds.
# 2024-03-27 00:25:03,683 - INFO - 	Successfully built transformation strategy_id = 5006 ('PFLO: Supply side technologies and transformations') in 0.82 seconds.
# 2024-03-27 00:25:08,188 - INFO - 	Successfully built transformation strategy_id = 5007 ('PFLO: All transformations without stopping deforestation and partial land use reallocation') in 1.12 seconds.
# 2024-03-27 00:25:08,188 - INFO - 	Successfully built transformation strategy_id = 5007 ('PFLO: All transformations without stopping deforestation and partial land use reallocation') in 1.12 seconds.
# 2024-03-27 00:25:12,655 - INFO - 	Successfully built transformation strategy_id = 5009 ('PFLO: All transformations with partial land use reallocation') in 1.21 seconds.
# 2024-03-27 00:25:12,655 - INFO - 	Successfully built transformation strategy_id = 5009 ('PFLO: All transformations with partial land use reallocation') in 1.21 seconds.
# 2024-03-27 00:25:16,054 - INFO - 	Successfully built transformation strategy_id = 6001 ('LNDU: Partial land use reallocation with India Climate Change') in 0.09 seconds.
# 2024-03-27 00:25:16,054 - INFO - 	Successfully built transformation strategy_id = 6001 ('LNDU: Partial land use reallocation with India Climate Change') in 0.09 seconds.
# 2024-03-27 00:25:20,230 - INFO - 	Successfully built transformation strategy_id = 6002 ('LNDU: India CCDR') in 1.05 seconds.
# 2024-03-27 00:25:20,230 - INFO - 	Successfully built transformation strategy_id = 6002 ('LNDU: India CCDR') in 1.05 seconds.
# 2024-03-27 00:25:24,892 - INFO - 	Successfully built transformation strategy_id = 6003 ('PFLO: India CCDR and India Climate Change Impacts') in 1.08 seconds.
# 2024-03-27 00:25:24,892 - INFO - 	Successfully built transformation strategy_id = 6003 ('PFLO: India CCDR and India Climate Change Impacts') in 1.08 seconds.
# 2024-03-27 00:25:29,594 - INFO - 	Successfully built transformation strategy_id = 6004 ('PFLO: All transformations with partial land use reallocation and India Climate Change Impacts') in 1.27 seconds.
# 2024-03-27 00:25:29,594 - INFO - 	Successfully built transformation strategy_id = 6004 ('PFLO: All transformations with partial land use reallocation and India Climate Change Impacts') in 1.27 seconds.
# 2024-03-27 00:25:33,066 - INFO - Exporting 'af' template in region india to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/india/model_input_variables_india_af_calibrated.xlsx
# 2024-03-27 00:25:33,066 - INFO - Exporting 'af' template in region india to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/india/model_input_variables_india_af_calibrated.xlsx
# 2024-03-27 00:25:35,376 - INFO - Exporting 'ce' template in region india to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/india/model_input_variables_india_ce_calibrated.xlsx
# 2024-03-27 00:25:35,376 - INFO - Exporting 'ce' template in region india to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/india/model_input_variables_india_ce_calibrated.xlsx
# 2024-03-27 00:25:35,864 - INFO - Exporting 'en' template in region india to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/india/model_input_variables_india_en_calibrated.xlsx
# 2024-03-27 00:25:35,864 - INFO - Exporting 'en' template in region india to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/india/model_input_variables_india_en_calibrated.xlsx
# 2024-03-27 00:25:39,247 - INFO - Exporting 'ip' template in region india to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/india/model_input_variables_india_ip_calibrated.xlsx
# 2024-03-27 00:25:39,247 - INFO - Exporting 'ip' template in region india to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/india/model_input_variables_india_ip_calibrated.xlsx
# 2024-03-27 00:25:39,674 - INFO - Exporting 'se' template in region india to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/india/model_input_variables_india_se_calibrated.xlsx
# 2024-03-27 00:25:39,674 - INFO - Exporting 'se' template in region india to /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/ingestion/calibrated/india/model_input_variables_india_se_calibrated.xlsx
# 2024-03-27 00:25:39,777 - INFO - Templates build for region india complete.
#
#
# 2024-03-27 00:25:39,777 - INFO - Templates build for region india complete.
#
#
# 2024-03-27 00:25:39,778 - INFO - Integrated transformations build complete in 47.61 seconds.
# 2024-03-27 00:25:39,778 - INFO - Integrated transformations build complete in 47.61 seconds.

# %%
sisepuede = ssp.SISEPUEDE(
    "calibrated",
    initialize_as_dummy = False,
    regions = ["india"],
    try_exogenous_xl_types_in_variable_specification = True,
)
# Out:
# MISSIONSEARCHNOTE: As of 2023-10-06, there is a temporary solution implemeted in ModelAttributes.get_variable_to_simplex_group_dictionary() to ensure that transition probability rows are enforced on a simplex.
#
# FIX THIS ASAP TO DERIVE PROPERLY.
# 2024-03-27 00:25:49,525 - INFO - Successfully initialized SISEPUEDEFileStructure.
# 2024-03-27 00:25:49,525 - INFO - Successfully initialized SISEPUEDEFileStructure.
# 2024-03-27 00:25:49,525 - INFO - Successfully initialized SISEPUEDEFileStructure.
# 2024-03-27 00:25:49,525 - INFO - Successfully initialized SISEPUEDEFileStructure.
# 2024-03-27 00:25:49,530 - WARNING - Missing key dict_dimensional_keys: key time_series not found. Tables that rely on the time_series will not have index checking.
# 2024-03-27 00:25:49,530 - WARNING - Missing key dict_dimensional_keys: key time_series not found. Tables that rely on the time_series will not have index checking.
# 2024-03-27 00:25:49,530 - WARNING - Missing key dict_dimensional_keys: key time_series not found. Tables that rely on the time_series will not have index checking.
# 2024-03-27 00:25:49,530 - WARNING - Missing key dict_dimensional_keys: key time_series not found. Tables that rely on the time_series will not have index checking.
# 2024-03-27 00:25:49,532 - INFO - 	Setting export engine to 'sqlite'.
# 2024-03-27 00:25:49,532 - INFO - 	Setting export engine to 'sqlite'.
# 2024-03-27 00:25:49,532 - INFO - 	Setting export engine to 'sqlite'.
# 2024-03-27 00:25:49,532 - INFO - 	Setting export engine to 'sqlite'.
# 2024-03-27 00:25:49,548 - WARNING - No index fields defined. Index field values will not be checked when writing to tables.
# 2024-03-27 00:25:49,548 - WARNING - No index fields defined. Index field values will not be checked when writing to tables.
# 2024-03-27 00:25:49,548 - WARNING - No index fields defined. Index field values will not be checked when writing to tables.
# 2024-03-27 00:25:49,548 - WARNING - No index fields defined. Index field values will not be checked when writing to tables.
# 2024-03-27 00:25:49,550 - INFO - Successfully instantiated table ANALYSIS_METADATA
# 2024-03-27 00:25:49,550 - INFO - Successfully instantiated table ANALYSIS_METADATA
# 2024-03-27 00:25:49,550 - INFO - Successfully instantiated table ANALYSIS_METADATA
# 2024-03-27 00:25:49,550 - INFO - Successfully instantiated table ANALYSIS_METADATA
# 2024-03-27 00:25:49,554 - WARNING - No index fields found in ATTRIBUTE_DESIGN. Initializing index fields.
# 2024-03-27 00:25:49,554 - WARNING - No index fields found in ATTRIBUTE_DESIGN. Initializing index fields.
# 2024-03-27 00:25:49,554 - WARNING - No index fields found in ATTRIBUTE_DESIGN. Initializing index fields.
# 2024-03-27 00:25:49,554 - WARNING - No index fields found in ATTRIBUTE_DESIGN. Initializing index fields.
# 2024-03-27 00:25:49,556 - INFO - Successfully instantiated table ATTRIBUTE_DESIGN
# 2024-03-27 00:25:49,556 - INFO - Successfully instantiated table ATTRIBUTE_DESIGN
# 2024-03-27 00:25:49,556 - INFO - Successfully instantiated table ATTRIBUTE_DESIGN
# 2024-03-27 00:25:49,556 - INFO - Successfully instantiated table ATTRIBUTE_DESIGN
# 2024-03-27 00:25:49,560 - WARNING - No index fields found in ATTRIBUTE_LHC_SAMPLES_EXOGENOUS_UNCERTAINTIES. Initializing index fields.
# 2024-03-27 00:25:49,560 - WARNING - No index fields found in ATTRIBUTE_LHC_SAMPLES_EXOGENOUS_UNCERTAINTIES. Initializing index fields.
# 2024-03-27 00:25:49,560 - WARNING - No index fields found in ATTRIBUTE_LHC_SAMPLES_EXOGENOUS_UNCERTAINTIES. Initializing index fields.
# 2024-03-27 00:25:49,560 - WARNING - No index fields found in ATTRIBUTE_LHC_SAMPLES_EXOGENOUS_UNCERTAINTIES. Initializing index fields.
# 2024-03-27 00:25:49,562 - INFO - Successfully instantiated table ATTRIBUTE_LHC_SAMPLES_EXOGENOUS_UNCERTAINTIES
# 2024-03-27 00:25:49,562 - INFO - Successfully instantiated table ATTRIBUTE_LHC_SAMPLES_EXOGENOUS_UNCERTAINTIES
# 2024-03-27 00:25:49,562 - INFO - Successfully instantiated table ATTRIBUTE_LHC_SAMPLES_EXOGENOUS_UNCERTAINTIES
# 2024-03-27 00:25:49,562 - INFO - Successfully instantiated table ATTRIBUTE_LHC_SAMPLES_EXOGENOUS_UNCERTAINTIES
# 2024-03-27 00:25:49,567 - WARNING - No index fields found in ATTRIBUTE_LHC_SAMPLES_LEVER_EFFECTS. Initializing index fields.
# 2024-03-27 00:25:49,567 - WARNING - No index fields found in ATTRIBUTE_LHC_SAMPLES_LEVER_EFFECTS. Initializing index fields.
# 2024-03-27 00:25:49,567 - WARNING - No index fields found in ATTRIBUTE_LHC_SAMPLES_LEVER_EFFECTS. Initializing index fields.
# 2024-03-27 00:25:49,567 - WARNING - No index fields found in ATTRIBUTE_LHC_SAMPLES_LEVER_EFFECTS. Initializing index fields.
# 2024-03-27 00:25:49,571 - INFO - Successfully instantiated table ATTRIBUTE_LHC_SAMPLES_LEVER_EFFECTS
# 2024-03-27 00:25:49,571 - INFO - Successfully instantiated table ATTRIBUTE_LHC_SAMPLES_LEVER_EFFECTS
# 2024-03-27 00:25:49,571 - INFO - Successfully instantiated table ATTRIBUTE_LHC_SAMPLES_LEVER_EFFECTS
# 2024-03-27 00:25:49,571 - INFO - Successfully instantiated table ATTRIBUTE_LHC_SAMPLES_LEVER_EFFECTS
# 2024-03-27 00:25:49,575 - WARNING - No index fields found in ATTRIBUTE_PRIMARY. Initializing index fields.
# 2024-03-27 00:25:49,575 - WARNING - No index fields found in ATTRIBUTE_PRIMARY. Initializing index fields.
# 2024-03-27 00:25:49,575 - WARNING - No index fields found in ATTRIBUTE_PRIMARY. Initializing index fields.
# 2024-03-27 00:25:49,575 - WARNING - No index fields found in ATTRIBUTE_PRIMARY. Initializing index fields.
# 2024-03-27 00:25:49,578 - INFO - Successfully instantiated table ATTRIBUTE_PRIMARY
# 2024-03-27 00:25:49,578 - INFO - Successfully instantiated table ATTRIBUTE_PRIMARY
# 2024-03-27 00:25:49,578 - INFO - Successfully instantiated table ATTRIBUTE_PRIMARY
# 2024-03-27 00:25:49,578 - INFO - Successfully instantiated table ATTRIBUTE_PRIMARY
# 2024-03-27 00:25:49,583 - WARNING - No index fields found in ATTRIBUTE_STRATEGY. Initializing index fields.
# 2024-03-27 00:25:49,583 - WARNING - No index fields found in ATTRIBUTE_STRATEGY. Initializing index fields.
# 2024-03-27 00:25:49,583 - WARNING - No index fields found in ATTRIBUTE_STRATEGY. Initializing index fields.
# 2024-03-27 00:25:49,583 - WARNING - No index fields found in ATTRIBUTE_STRATEGY. Initializing index fields.
# 2024-03-27 00:25:49,587 - INFO - Successfully instantiated table ATTRIBUTE_STRATEGY
# 2024-03-27 00:25:49,587 - INFO - Successfully instantiated table ATTRIBUTE_STRATEGY
# 2024-03-27 00:25:49,587 - INFO - Successfully instantiated table ATTRIBUTE_STRATEGY
# 2024-03-27 00:25:49,587 - INFO - Successfully instantiated table ATTRIBUTE_STRATEGY
# 2024-03-27 00:25:49,591 - WARNING - No index fields found in MODEL_BASE_INPUT_DATABASE. Initializing index fields.
# 2024-03-27 00:25:49,591 - WARNING - No index fields found in MODEL_BASE_INPUT_DATABASE. Initializing index fields.
# 2024-03-27 00:25:49,591 - WARNING - No index fields found in MODEL_BASE_INPUT_DATABASE. Initializing index fields.
# 2024-03-27 00:25:49,591 - WARNING - No index fields found in MODEL_BASE_INPUT_DATABASE. Initializing index fields.
# 2024-03-27 00:25:49,594 - INFO - Successfully instantiated table MODEL_BASE_INPUT_DATABASE
# 2024-03-27 00:25:49,594 - INFO - Successfully instantiated table MODEL_BASE_INPUT_DATABASE
# 2024-03-27 00:25:49,594 - INFO - Successfully instantiated table MODEL_BASE_INPUT_DATABASE
# 2024-03-27 00:25:49,594 - INFO - Successfully instantiated table MODEL_BASE_INPUT_DATABASE
# 2024-03-27 00:25:49,598 - WARNING - No index fields found in MODEL_INPUT. Initializing index fields.
# 2024-03-27 00:25:49,598 - WARNING - No index fields found in MODEL_INPUT. Initializing index fields.
# 2024-03-27 00:25:49,598 - WARNING - No index fields found in MODEL_INPUT. Initializing index fields.
# 2024-03-27 00:25:49,598 - WARNING - No index fields found in MODEL_INPUT. Initializing index fields.
# 2024-03-27 00:25:49,600 - INFO - Successfully instantiated table MODEL_INPUT
# 2024-03-27 00:25:49,600 - INFO - Successfully instantiated table MODEL_INPUT
# 2024-03-27 00:25:49,600 - INFO - Successfully instantiated table MODEL_INPUT
# 2024-03-27 00:25:49,600 - INFO - Successfully instantiated table MODEL_INPUT
# 2024-03-27 00:25:49,604 - WARNING - No index fields found in MODEL_OUTPUT. Initializing index fields.
# 2024-03-27 00:25:49,604 - WARNING - No index fields found in MODEL_OUTPUT. Initializing index fields.
# 2024-03-27 00:25:49,604 - WARNING - No index fields found in MODEL_OUTPUT. Initializing index fields.
# 2024-03-27 00:25:49,604 - WARNING - No index fields found in MODEL_OUTPUT. Initializing index fields.
# 2024-03-27 00:25:49,606 - INFO - Successfully instantiated table MODEL_OUTPUT
# 2024-03-27 00:25:49,606 - INFO - Successfully instantiated table MODEL_OUTPUT
# 2024-03-27 00:25:49,606 - INFO - Successfully instantiated table MODEL_OUTPUT
# 2024-03-27 00:25:49,606 - INFO - Successfully instantiated table MODEL_OUTPUT
# 2024-03-27 00:25:49,609 - INFO - SISEPUEDEOutputDatabase successfully initialized IterativeDatabase.
# 2024-03-27 00:25:49,609 - INFO - SISEPUEDEOutputDatabase successfully initialized IterativeDatabase.
# 2024-03-27 00:25:49,609 - INFO - SISEPUEDEOutputDatabase successfully initialized IterativeDatabase.
# 2024-03-27 00:25:49,609 - INFO - SISEPUEDEOutputDatabase successfully initialized IterativeDatabase.
# 2024-03-27 00:25:49,611 - INFO - Successfully initialized database with:
# 	type:	sqlite
# 	analysis id:	sisepuede_run_2024-03-27T00:25:48.341387
# 	fp_base_output:	/Users/jsyme/Documents/Projects/git_jbus/sisepuede/out/sisepuede_run_2024-03-27T00;25;48.341387/sisepuede_run_2024-03-27T00;25;48.341387_output_database
# 2024-03-27 00:25:49,611 - INFO - Successfully initialized database with:
# 	type:	sqlite
# 	analysis id:	sisepuede_run_2024-03-27T00:25:48.341387
# 	fp_base_output:	/Users/jsyme/Documents/Projects/git_jbus/sisepuede/out/sisepuede_run_2024-03-27T00;25;48.341387/sisepuede_run_2024-03-27T00;25;48.341387_output_database
# 2024-03-27 00:25:49,611 - INFO - Successfully initialized database with:
# 	type:	sqlite
# 	analysis id:	sisepuede_run_2024-03-27T00:25:48.341387
# 	fp_base_output:	/Users/jsyme/Documents/Projects/git_jbus/sisepuede/out/sisepuede_run_2024-03-27T00;25;48.341387/sisepuede_run_2024-03-27T00;25;48.341387_output_database
# 2024-03-27 00:25:49,611 - INFO - Successfully initialized database with:
# 	type:	sqlite
# 	analysis id:	sisepuede_run_2024-03-27T00:25:48.341387
# 	fp_base_output:	/Users/jsyme/Documents/Projects/git_jbus/sisepuede/out/sisepuede_run_2024-03-27T00;25;48.341387/sisepuede_run_2024-03-27T00;25;48.341387_output_database
# 2024-03-27 00:25:49,613 - INFO - Running SISEPUEDE under template data mode 'calibrated'.
# 2024-03-27 00:25:49,613 - INFO - Running SISEPUEDE under template data mode 'calibrated'.
# 2024-03-27 00:25:49,613 - INFO - Running SISEPUEDE under template data mode 'calibrated'.
# 2024-03-27 00:25:49,613 - INFO - Running SISEPUEDE under template data mode 'calibrated'.
# 2024-03-27 00:25:49,615 - INFO - Initializing BaseInputDatabase
# 2024-03-27 00:25:49,615 - INFO - Initializing BaseInputDatabase
# 2024-03-27 00:25:49,615 - INFO - Initializing BaseInputDatabase
# 2024-03-27 00:25:49,615 - INFO - Initializing BaseInputDatabase
# 2024-03-27 00:25:53,137 - INFO - Initializing FutureTrajectories
# 2024-03-27 00:25:53,137 - INFO - Initializing FutureTrajectories
# 2024-03-27 00:25:53,137 - INFO - Initializing FutureTrajectories
# 2024-03-27 00:25:53,137 - INFO - Initializing FutureTrajectories
# 2024-03-27 00:26:02,575 - INFO - Instantiating 1476 sampling units.
# 2024-03-27 00:26:02,575 - INFO - Instantiating 1476 sampling units.
# 2024-03-27 00:26:02,575 - INFO - Instantiating 1476 sampling units.
# 2024-03-27 00:26:02,575 - INFO - Instantiating 1476 sampling units.
# 2024-03-27 00:26:02,655 - INFO - Iteration 0 complete.
# 2024-03-27 00:26:02,655 - INFO - Iteration 0 complete.
# 2024-03-27 00:26:02,655 - INFO - Iteration 0 complete.
# 2024-03-27 00:26:02,655 - INFO - Iteration 0 complete.
# 2024-03-27 00:26:15,664 - INFO - Iteration 250 complete.
# 2024-03-27 00:26:15,664 - INFO - Iteration 250 complete.
# 2024-03-27 00:26:15,664 - INFO - Iteration 250 complete.
# 2024-03-27 00:26:15,664 - INFO - Iteration 250 complete.
# 2024-03-27 00:26:22,650 - INFO - Iteration 500 complete.
# 2024-03-27 00:26:22,650 - INFO - Iteration 500 complete.
# 2024-03-27 00:26:22,650 - INFO - Iteration 500 complete.
# 2024-03-27 00:26:22,650 - INFO - Iteration 500 complete.
# 2024-03-27 00:26:30,013 - INFO - Iteration 750 complete.
# 2024-03-27 00:26:30,013 - INFO - Iteration 750 complete.
# 2024-03-27 00:26:30,013 - INFO - Iteration 750 complete.
# 2024-03-27 00:26:30,013 - INFO - Iteration 750 complete.
# 2024-03-27 00:26:36,868 - INFO - Iteration 1000 complete.
# 2024-03-27 00:26:36,868 - INFO - Iteration 1000 complete.
# 2024-03-27 00:26:36,868 - INFO - Iteration 1000 complete.
# 2024-03-27 00:26:36,868 - INFO - Iteration 1000 complete.
# 2024-03-27 00:26:43,652 - INFO - Iteration 1250 complete.
# 2024-03-27 00:26:43,652 - INFO - Iteration 1250 complete.
# 2024-03-27 00:26:43,652 - INFO - Iteration 1250 complete.
# 2024-03-27 00:26:43,652 - INFO - Iteration 1250 complete.
# 2024-03-27 00:26:50,351 - INFO - 	1476 sampling units complete in 47.77 seconds.
# 2024-03-27 00:26:50,351 - INFO - 	1476 sampling units complete in 47.77 seconds.
# 2024-03-27 00:26:50,351 - INFO - 	1476 sampling units complete in 47.77 seconds.
# 2024-03-27 00:26:50,351 - INFO - 	1476 sampling units complete in 47.77 seconds.
# 2024-03-27 00:26:51,358 - INFO - 	FutureTrajectories for 'india' complete.
# 2024-03-27 00:26:51,358 - INFO - 	FutureTrajectories for 'india' complete.
# 2024-03-27 00:26:51,358 - INFO - 	FutureTrajectories for 'india' complete.
# 2024-03-27 00:26:51,358 - INFO - 	FutureTrajectories for 'india' complete.
# 2024-03-27 00:26:51,362 - INFO - Initializing LHSDesign
# 2024-03-27 00:26:51,362 - INFO - Initializing LHSDesign
# 2024-03-27 00:26:51,362 - INFO - Initializing LHSDesign
# 2024-03-27 00:26:51,362 - INFO - Initializing LHSDesign
# 2024-03-27 00:26:51,364 - INFO - LHSDesign.fields_factors_l reset successful.
# 2024-03-27 00:26:51,364 - INFO - LHSDesign.fields_factors_l reset successful.
# 2024-03-27 00:26:51,364 - INFO - LHSDesign.fields_factors_l reset successful.
# 2024-03-27 00:26:51,364 - INFO - LHSDesign.fields_factors_l reset successful.
# 2024-03-27 00:26:51,366 - INFO - LHSDesign.fields_factors_x reset successful.
# 2024-03-27 00:26:51,366 - INFO - LHSDesign.fields_factors_x reset successful.
# 2024-03-27 00:26:51,366 - INFO - LHSDesign.fields_factors_x reset successful.
# 2024-03-27 00:26:51,366 - INFO - LHSDesign.fields_factors_x reset successful.
# 2024-03-27 00:26:51,402 - INFO - 	LHSDesign for region 'india' complete.
# 2024-03-27 00:26:51,402 - INFO - 	LHSDesign for region 'india' complete.
# 2024-03-27 00:26:51,402 - INFO - 	LHSDesign for region 'india' complete.
# 2024-03-27 00:26:51,402 - INFO - 	LHSDesign for region 'india' complete.
# 2024-03-27 00:26:51,405 - INFO - Generating primary keys (values of primary_id)...
# 2024-03-27 00:26:51,405 - INFO - Generating primary keys (values of primary_id)...
# 2024-03-27 00:26:51,405 - INFO - Generating primary keys (values of primary_id)...
# 2024-03-27 00:26:51,405 - INFO - Generating primary keys (values of primary_id)...
# 2024-03-27 00:26:51,407 - INFO - Successfully initialized SISEPUEDEExperimentalManager.
# 2024-03-27 00:26:51,407 - INFO - Successfully initialized SISEPUEDEExperimentalManager.
# 2024-03-27 00:26:51,407 - INFO - Successfully initialized SISEPUEDEExperimentalManager.
# 2024-03-27 00:26:51,407 - INFO - Successfully initialized SISEPUEDEExperimentalManager.
# 2024-03-27 00:26:51,423 - INFO - Successfully initialized NemoMod temporary database path as /Users/jsyme/Documents/Projects/git_jbus/sisepuede/tmp/nemomod_intermediate_database.sqlite.
# 2024-03-27 00:26:51,423 - INFO - Successfully initialized NemoMod temporary database path as /Users/jsyme/Documents/Projects/git_jbus/sisepuede/tmp/nemomod_intermediate_database.sqlite.
# 2024-03-27 00:26:51,423 - INFO - Successfully initialized NemoMod temporary database path as /Users/jsyme/Documents/Projects/git_jbus/sisepuede/tmp/nemomod_intermediate_database.sqlite.
# 2024-03-27 00:26:51,423 - INFO - Successfully initialized NemoMod temporary database path as /Users/jsyme/Documents/Projects/git_jbus/sisepuede/tmp/nemomod_intermediate_database.sqlite.
# 2024-03-27 00:26:51,425 - INFO - Set Julia directory for modules and environment to '/Users/jsyme/Documents/Projects/git_jbus/sisepuede/julia'.
# 2024-03-27 00:26:51,425 - INFO - Set Julia directory for modules and environment to '/Users/jsyme/Documents/Projects/git_jbus/sisepuede/julia'.
# 2024-03-27 00:26:51,425 - INFO - Set Julia directory for modules and environment to '/Users/jsyme/Documents/Projects/git_jbus/sisepuede/julia'.
# 2024-03-27 00:26:51,425 - INFO - Set Julia directory for modules and environment to '/Users/jsyme/Documents/Projects/git_jbus/sisepuede/julia'.
# 2024-03-27 00:26:51,581 - INFO - Successfully read NemoMod input table data from /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/nemo_mod/SpecifiedDemandProfile.csv
# 2024-03-27 00:26:51,581 - INFO - Successfully read NemoMod input table data from /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/nemo_mod/SpecifiedDemandProfile.csv
# 2024-03-27 00:26:51,581 - INFO - Successfully read NemoMod input table data from /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/nemo_mod/SpecifiedDemandProfile.csv
# 2024-03-27 00:26:51,581 - INFO - Successfully read NemoMod input table data from /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/nemo_mod/SpecifiedDemandProfile.csv
# 2024-03-27 00:26:51,597 - INFO - Successfully read NemoMod input table data from /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/nemo_mod/CapacityFactor.csv
# 2024-03-27 00:26:51,597 - INFO - Successfully read NemoMod input table data from /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/nemo_mod/CapacityFactor.csv
# 2024-03-27 00:26:51,597 - INFO - Successfully read NemoMod input table data from /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/nemo_mod/CapacityFactor.csv
# 2024-03-27 00:26:51,597 - INFO - Successfully read NemoMod input table data from /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/nemo_mod/CapacityFactor.csv
# 2024-03-27 00:26:51,750 - INFO - Calling Julia API...
# 2024-03-27 00:26:51,750 - INFO - Calling Julia API...
# 2024-03-27 00:26:51,750 - INFO - Calling Julia API...
# 2024-03-27 00:26:51,750 - INFO - Calling Julia API...
# 2024-03-27 00:27:12,880 - DEBUG - 	Successfully activated Julia with compiled_modules = False
# 2024-03-27 00:27:12,880 - DEBUG - 	Successfully activated Julia with compiled_modules = False
# 2024-03-27 00:27:12,880 - DEBUG - 	Successfully activated Julia with compiled_modules = False
# 2024-03-27 00:27:12,880 - DEBUG - 	Successfully activated Julia with compiled_modules = False
# 2024-03-27 00:27:12,888 - DEBUG - 	Successfully imported julia.Base
# 2024-03-27 00:27:12,888 - DEBUG - 	Successfully imported julia.Base
# 2024-03-27 00:27:12,888 - DEBUG - 	Successfully imported julia.Base
# 2024-03-27 00:27:12,888 - DEBUG - 	Successfully imported julia.Base
# 2024-03-27 00:27:12,890 - DEBUG - 	Successfully imported julia.Main
# 2024-03-27 00:27:12,890 - DEBUG - 	Successfully imported julia.Main
# 2024-03-27 00:27:12,890 - DEBUG - 	Successfully imported julia.Main
# 2024-03-27 00:27:12,890 - DEBUG - 	Successfully imported julia.Main
# 2024-03-27 00:27:13,006 - DEBUG - 	Successfully imported julia.Pkg
# 2024-03-27 00:27:13,006 - DEBUG - 	Successfully imported julia.Pkg
# 2024-03-27 00:27:13,006 - DEBUG - 	Successfully imported julia.Pkg
# 2024-03-27 00:27:13,006 - DEBUG - 	Successfully imported julia.Pkg
# 2024-03-27 00:27:13,628 - DEBUG - 	Available Packages:
# 		'GLPK'
# 		 'HiGHS'
# 		 'CxxWrap'
# 		 'Graphs'
# 		 'ExcelReaders'
# 		 'Juniper'
# 		 'FLoops'
# 		 'DataStructures'
# 		 'SimulatedAnnealing'
# 		 'DataFrames'
# 		 'PlotlyJS'
# 		 'MLJ'
# 		 'QuickHeaps'
# 		 'Distributions'
# 		 'SQLite'
# 		 'Clp'
# 		 'Karnak'
# 		 'LatinHypercubeSampling'
# 		 'ScikitLearn'
# 		 'LazySets'
# 		 'Metal'
# 		 'SCIP'
# 		 'GLMakie'
# 		 'DistributedArrays'
# 		 'Gurobi'
# 		 'AlphaVantage'
# 		 'CSV'
# 		 'Revise'
# 		 'StructArrays'
# 		 'Random'
# 		 'BenchmarkTools'
# 		 'Conda'
# 		 'Shapefile'
# 		 'PyCall'
# 		 'StatsBase'
# 		 'IJulia'
# 		 'Flux'
# 		 'Plots'
# 		 'GeoInterface'
# 		 'XLSX'
# 		 'Cbc'
# 		 'MathOptInterface'
# 		 'GLM'
# 		 'CUDA'
# 		 'Statistics'
# 		 'LightGraphs'
# 		 'HypothesisTests'
# 		 'JuMP'
# 		 'NetworkLayout'
# 		 'Ipopt'
# 		 'LaTeXStrings'
# 		 'SharedArrays'
# 		 'CairoMakie'
# 		 'StaticGraphs'
# 		 'MultivariateStats'
# 		 'DecisionTree'
# 		 'GraphMakie'
# 		 'WebIO'
# 		 'AbstractTrees'
# 		 'Cxx'
# 2024-03-27 00:27:13,628 - DEBUG - 	Available Packages:
# 		'GLPK'
# 		 'HiGHS'
# 		 'CxxWrap'
# 		 'Graphs'
# 		 'ExcelReaders'
# 		 'Juniper'
# 		 'FLoops'
# 		 'DataStructures'
# 		 'SimulatedAnnealing'
# 		 'DataFrames'
# 		 'PlotlyJS'
# 		 'MLJ'
# 		 'QuickHeaps'
# 		 'Distributions'
# 		 'SQLite'
# 		 'Clp'
# 		 'Karnak'
# 		 'LatinHypercubeSampling'
# 		 'ScikitLearn'
# 		 'LazySets'
# 		 'Metal'
# 		 'SCIP'
# 		 'GLMakie'
# 		 'DistributedArrays'
# 		 'Gurobi'
# 		 'AlphaVantage'
# 		 'CSV'
# 		 'Revise'
# 		 'StructArrays'
# 		 'Random'
# 		 'BenchmarkTools'
# 		 'Conda'
# 		 'Shapefile'
# 		 'PyCall'
# 		 'StatsBase'
# 		 'IJulia'
# 		 'Flux'
# 		 'Plots'
# 		 'GeoInterface'
# 		 'XLSX'
# 		 'Cbc'
# 		 'MathOptInterface'
# 		 'GLM'
# 		 'CUDA'
# 		 'Statistics'
# 		 'LightGraphs'
# 		 'HypothesisTests'
# 		 'JuMP'
# 		 'NetworkLayout'
# 		 'Ipopt'
# 		 'LaTeXStrings'
# 		 'SharedArrays'
# 		 'CairoMakie'
# 		 'StaticGraphs'
# 		 'MultivariateStats'
# 		 'DecisionTree'
# 		 'GraphMakie'
# 		 'WebIO'
# 		 'AbstractTrees'
# 		 'Cxx'
# 2024-03-27 00:27:13,628 - DEBUG - 	Available Packages:
# 		'GLPK'
# 		 'HiGHS'
# 		 'CxxWrap'
# 		 'Graphs'
# 		 'ExcelReaders'
# 		 'Juniper'
# 		 'FLoops'
# 		 'DataStructures'
# 		 'SimulatedAnnealing'
# 		 'DataFrames'
# 		 'PlotlyJS'
# 		 'MLJ'
# 		 'QuickHeaps'
# 		 'Distributions'
# 		 'SQLite'
# 		 'Clp'
# 		 'Karnak'
# 		 'LatinHypercubeSampling'
# 		 'ScikitLearn'
# 		 'LazySets'
# 		 'Metal'
# 		 'SCIP'
# 		 'GLMakie'
# 		 'DistributedArrays'
# 		 'Gurobi'
# 		 'AlphaVantage'
# 		 'CSV'
# 		 'Revise'
# 		 'StructArrays'
# 		 'Random'
# 		 'BenchmarkTools'
# 		 'Conda'
# 		 'Shapefile'
# 		 'PyCall'
# 		 'StatsBase'
# 		 'IJulia'
# 		 'Flux'
# 		 'Plots'
# 		 'GeoInterface'
# 		 'XLSX'
# 		 'Cbc'
# 		 'MathOptInterface'
# 		 'GLM'
# 		 'CUDA'
# 		 'Statistics'
# 		 'LightGraphs'
# 		 'HypothesisTests'
# 		 'JuMP'
# 		 'NetworkLayout'
# 		 'Ipopt'
# 		 'LaTeXStrings'
# 		 'SharedArrays'
# 		 'CairoMakie'
# 		 'StaticGraphs'
# 		 'MultivariateStats'
# 		 'DecisionTree'
# 		 'GraphMakie'
# 		 'WebIO'
# 		 'AbstractTrees'
# 		 'Cxx'
# 2024-03-27 00:27:13,628 - DEBUG - 	Available Packages:
# 		'GLPK'
# 		 'HiGHS'
# 		 'CxxWrap'
# 		 'Graphs'
# 		 'ExcelReaders'
# 		 'Juniper'
# 		 'FLoops'
# 		 'DataStructures'
# 		 'SimulatedAnnealing'
# 		 'DataFrames'
# 		 'PlotlyJS'
# 		 'MLJ'
# 		 'QuickHeaps'
# 		 'Distributions'
# 		 'SQLite'
# 		 'Clp'
# 		 'Karnak'
# 		 'LatinHypercubeSampling'
# 		 'ScikitLearn'
# 		 'LazySets'
# 		 'Metal'
# 		 'SCIP'
# 		 'GLMakie'
# 		 'DistributedArrays'
# 		 'Gurobi'
# 		 'AlphaVantage'
# 		 'CSV'
# 		 'Revise'
# 		 'StructArrays'
# 		 'Random'
# 		 'BenchmarkTools'
# 		 'Conda'
# 		 'Shapefile'
# 		 'PyCall'
# 		 'StatsBase'
# 		 'IJulia'
# 		 'Flux'
# 		 'Plots'
# 		 'GeoInterface'
# 		 'XLSX'
# 		 'Cbc'
# 		 'MathOptInterface'
# 		 'GLM'
# 		 'CUDA'
# 		 'Statistics'
# 		 'LightGraphs'
# 		 'HypothesisTests'
# 		 'JuMP'
# 		 'NetworkLayout'
# 		 'Ipopt'
# 		 'LaTeXStrings'
# 		 'SharedArrays'
# 		 'CairoMakie'
# 		 'StaticGraphs'
# 		 'MultivariateStats'
# 		 'DecisionTree'
# 		 'GraphMakie'
# 		 'WebIO'
# 		 'AbstractTrees'
# 		 'Cxx'
# 2024-03-27 00:27:14,255 - INFO - Successfully activated Julia environment at '/Users/jsyme/Documents/Projects/git_jbus/sisepuede/julia'
#   Activating project at `~/Documents/Projects/git_jbus/sisepuede/julia`
# 2024-03-27 00:27:14,255 - INFO - Successfully activated Julia environment at '/Users/jsyme/Documents/Projects/git_jbus/sisepuede/julia'
# 2024-03-27 00:27:14,255 - INFO - Successfully activated Julia environment at '/Users/jsyme/Documents/Projects/git_jbus/sisepuede/julia'
# 2024-03-27 00:27:14,255 - INFO - Successfully activated Julia environment at '/Users/jsyme/Documents/Projects/git_jbus/sisepuede/julia'
# 2024-03-27 00:28:32,206 - INFO - Successfully initialized JuMP optimizer from solver module HiGHS.
# 2024-03-27 00:28:32,206 - INFO - Successfully initialized JuMP optimizer from solver module HiGHS.
# 2024-03-27 00:28:32,206 - INFO - Successfully initialized JuMP optimizer from solver module HiGHS.
# 2024-03-27 00:28:32,206 - INFO - Successfully initialized JuMP optimizer from solver module HiGHS.
# 2024-03-27 00:28:32,248 - INFO - Successfully initialized SISEPUEDEModels.
# 2024-03-27 00:28:32,248 - INFO - Successfully initialized SISEPUEDEModels.
# 2024-03-27 00:28:32,248 - INFO - Successfully initialized SISEPUEDEModels.
# 2024-03-27 00:28:32,248 - INFO - Successfully initialized SISEPUEDEModels.
# 2024-03-27 00:28:32,290 - INFO - Table ANALYSIS_METADATA successfully written to database.
# 2024-03-27 00:28:32,290 - INFO - Table ANALYSIS_METADATA successfully written to database.
# 2024-03-27 00:28:32,290 - INFO - Table ANALYSIS_METADATA successfully written to database.
# 2024-03-27 00:28:32,290 - INFO - Table ANALYSIS_METADATA successfully written to database.
# 2024-03-27 00:28:32,310 - INFO - Table ATTRIBUTE_DESIGN successfully written to database.
# 2024-03-27 00:28:32,310 - INFO - Table ATTRIBUTE_DESIGN successfully written to database.
# 2024-03-27 00:28:32,310 - INFO - Table ATTRIBUTE_DESIGN successfully written to database.
# 2024-03-27 00:28:32,310 - INFO - Table ATTRIBUTE_DESIGN successfully written to database.
# 2024-03-27 00:28:32,329 - INFO - Table ATTRIBUTE_STRATEGY successfully written to database.
# 2024-03-27 00:28:32,329 - INFO - Table ATTRIBUTE_STRATEGY successfully written to database.
# 2024-03-27 00:28:32,329 - INFO - Table ATTRIBUTE_STRATEGY successfully written to database.
# 2024-03-27 00:28:32,329 - INFO - Table ATTRIBUTE_STRATEGY successfully written to database.
# 2024-03-27 00:28:33,486 - INFO - Table MODEL_BASE_INPUT_DATABASE successfully written to database.
# 2024-03-27 00:28:33,486 - INFO - Table MODEL_BASE_INPUT_DATABASE successfully written to database.
# 2024-03-27 00:28:33,486 - INFO - Table MODEL_BASE_INPUT_DATABASE successfully written to database.
# 2024-03-27 00:28:33,486 - INFO - Table MODEL_BASE_INPUT_DATABASE successfully written to database.

# %%
dict_filt = {
    "future_id": [0],
    "design_id": [0], 
    "strategy_id": [0, 1015, 5009, 6001, 6002, 6003, 6004]#strategies_keep#[0, 1014, 5001, 5004, 5006, 5007, 5009]
}


dict_primary_keys_out = sisepuede(
    dict_filt,
    chunk_size = 2,
    include_electricity_in_energy = True,
    reinitialize_output_table_on_verification_failure = True,
    #regions = ["mexico"],
    thresholds = (10**(-5), 10**4.5),
)
# Out:
# 2024-03-27 00:38:29,458 - INFO -
# ***	STARTING REGION india	***
#
# 2024-03-27 00:38:29,458 - INFO -
# ***	STARTING REGION india	***
#
# 2024-03-27 00:38:29,458 - INFO -
# ***	STARTING REGION india	***
#
# 2024-03-27 00:38:29,458 - INFO -
# ***	STARTING REGION india	***
#
# 2024-03-27 00:38:38,616 - INFO - Trying run primary_id = 0 in region india
# 2024-03-27 00:38:38,616 - INFO - Trying run primary_id = 0 in region india
# 2024-03-27 00:38:38,616 - INFO - Trying run primary_id = 0 in region india
# 2024-03-27 00:38:38,616 - INFO - Trying run primary_id = 0 in region india
# 2024-03-27 00:38:38,619 - INFO - Running AFOLU model
# 2024-03-27 00:38:38,619 - INFO - Running AFOLU model
# 2024-03-27 00:38:38,619 - INFO - Running AFOLU model
# 2024-03-27 00:38:38,619 - INFO - Running AFOLU model
# 2024-03-27 00:38:39,050 - INFO - AFOLU model run successfully completed
# 2024-03-27 00:38:39,050 - INFO - AFOLU model run successfully completed
# 2024-03-27 00:38:39,050 - INFO - AFOLU model run successfully completed
# 2024-03-27 00:38:39,050 - INFO - AFOLU model run successfully completed
# 2024-03-27 00:38:39,052 - INFO - Running CircularEconomy model
# 2024-03-27 00:38:39,052 - INFO - Running CircularEconomy model
# 2024-03-27 00:38:39,052 - INFO - Running CircularEconomy model
# 2024-03-27 00:38:39,052 - INFO - Running CircularEconomy model
# 2024-03-27 00:38:39,162 - INFO - CircularEconomy model run successfully completed
# 2024-03-27 00:38:39,162 - INFO - CircularEconomy model run successfully completed
# 2024-03-27 00:38:39,162 - INFO - CircularEconomy model run successfully completed
# 2024-03-27 00:38:39,162 - INFO - CircularEconomy model run successfully completed
# 2024-03-27 00:38:39,164 - INFO - Running IPPU model
# 2024-03-27 00:38:39,164 - INFO - Running IPPU model
# 2024-03-27 00:38:39,164 - INFO - Running IPPU model
# 2024-03-27 00:38:39,164 - INFO - Running IPPU model
# 2024-03-27 00:38:39,356 - INFO - IPPU model run successfully completed
# 2024-03-27 00:38:39,356 - INFO - IPPU model run successfully completed
# 2024-03-27 00:38:39,356 - INFO - IPPU model run successfully completed
# 2024-03-27 00:38:39,356 - INFO - IPPU model run successfully completed
# 2024-03-27 00:38:39,358 - INFO - Running Energy model (NonElectricEnergy without Fugitive Emissions)
# 2024-03-27 00:38:39,358 - INFO - Running Energy model (NonElectricEnergy without Fugitive Emissions)
# 2024-03-27 00:38:39,358 - INFO - Running Energy model (NonElectricEnergy without Fugitive Emissions)
# 2024-03-27 00:38:39,358 - INFO - Running Energy model (NonElectricEnergy without Fugitive Emissions)
# 2024-03-27 00:38:39,407 - DEBUG - Missing elasticity information found in 'project_energy_consumption_by_fuel_from_effvars': using specified future demands.
# 2024-03-27 00:38:39,407 - DEBUG - Missing elasticity information found in 'project_energy_consumption_by_fuel_from_effvars': using specified future demands.
# 2024-03-27 00:38:39,407 - DEBUG - Missing elasticity information found in 'project_energy_consumption_by_fuel_from_effvars': using specified future demands.
# 2024-03-27 00:38:39,407 - DEBUG - Missing elasticity information found in 'project_energy_consumption_by_fuel_from_effvars': using specified future demands.
# 2024-03-27 00:38:39,635 - INFO - NonElectricEnergy without Fugitive Emissions model run successfully completed
# 2024-03-27 00:38:39,635 - INFO - NonElectricEnergy without Fugitive Emissions model run successfully completed
# 2024-03-27 00:38:39,635 - INFO - NonElectricEnergy without Fugitive Emissions model run successfully completed
# 2024-03-27 00:38:39,635 - INFO - NonElectricEnergy without Fugitive Emissions model run successfully completed
# 2024-03-27 00:38:39,637 - INFO - Running Energy model (Electricity and Fuel Production: trying to call Julia)
# 2024-03-27 00:38:39,637 - INFO - Running Energy model (Electricity and Fuel Production: trying to call Julia)
# 2024-03-27 00:38:39,637 - INFO - Running Energy model (Electricity and Fuel Production: trying to call Julia)
# 2024-03-27 00:38:39,637 - INFO - Running Energy model (Electricity and Fuel Production: trying to call Julia)
# 2024-27-Mar 00:38:42.837 Started modeling scenario.
# 2024-27-Mar 00:44:45.087 Finished modeling scenario.
# ┌ Warning: Model period activity upper limits for technologies (TotalTechnologyModelPeriodActivityUpperLimit parameter) are not enforced when modeling selected years.
# └ @ NemoMod ~/.julia/packages/NemoMod/d2ky8/src/scenario_calculation.jl:464
# ┌ Warning: Model period emission limits (ModelPeriodEmissionLimit parameter) are not enforced when modeling selected years.
# └ @ NemoMod ~/.julia/packages/NemoMod/d2ky8/src/scenario_calculation.jl:6181
# 2024-03-27 00:44:45,677 - INFO - NemoMod ran successfully with the following status: <PyCall.jlwrap OPTIMAL>
# 2024-03-27 00:44:45,677 - INFO - NemoMod ran successfully with the following status: <PyCall.jlwrap OPTIMAL>
# 2024-03-27 00:44:45,677 - INFO - NemoMod ran successfully with the following status: <PyCall.jlwrap OPTIMAL>
# 2024-03-27 00:44:45,677 - INFO - NemoMod ran successfully with the following status: <PyCall.jlwrap OPTIMAL>
# 2024-03-27 00:44:45,733 - INFO - ElectricEnergy model run successfully completed
# 2024-03-27 00:44:45,733 - INFO - ElectricEnergy model run successfully completed
# 2024-03-27 00:44:45,733 - INFO - ElectricEnergy model run successfully completed
# 2024-03-27 00:44:45,733 - INFO - ElectricEnergy model run successfully completed
# 2024-03-27 00:44:45,736 - INFO - Running Energy (Fugitive Emissions)
# 2024-03-27 00:44:45,736 - INFO - Running Energy (Fugitive Emissions)
# 2024-03-27 00:44:45,736 - INFO - Running Energy (Fugitive Emissions)
# 2024-03-27 00:44:45,736 - INFO - Running Energy (Fugitive Emissions)
# 2024-03-27 00:44:45,857 - INFO - Fugitive Emissions from Energy model run successfully completed
# 2024-03-27 00:44:45,857 - INFO - Fugitive Emissions from Energy model run successfully completed
# 2024-03-27 00:44:45,857 - INFO - Fugitive Emissions from Energy model run successfully completed
# 2024-03-27 00:44:45,857 - INFO - Fugitive Emissions from Energy model run successfully completed
# 2024-03-27 00:44:45,861 - INFO - Appending Socioeconomic outputs
# 2024-03-27 00:44:45,861 - INFO - Appending Socioeconomic outputs
# 2024-03-27 00:44:45,861 - INFO - Appending Socioeconomic outputs
# 2024-03-27 00:44:45,861 - INFO - Appending Socioeconomic outputs
# 2024-03-27 00:44:45,887 - INFO - Socioeconomic outputs successfully appended.
# 2024-03-27 00:44:45,887 - INFO - Socioeconomic outputs successfully appended.
# 2024-03-27 00:44:45,887 - INFO - Socioeconomic outputs successfully appended.
# 2024-03-27 00:44:45,887 - INFO - Socioeconomic outputs successfully appended.
# 2024-03-27 00:44:45,907 - INFO - Model run for primary_id = 0 successfully completed in 367.29 seconds (n_tries = 1).
# 2024-03-27 00:44:45,907 - INFO - Model run for primary_id = 0 successfully completed in 367.29 seconds (n_tries = 1).
# 2024-03-27 00:44:45,907 - INFO - Model run for primary_id = 0 successfully completed in 367.29 seconds (n_tries = 1).
# 2024-03-27 00:44:45,907 - INFO - Model run for primary_id = 0 successfully completed in 367.29 seconds (n_tries = 1).
# 2024-03-27 00:44:45,984 - INFO - Trying run primary_id = 15015 in region india
# 2024-03-27 00:44:45,984 - INFO - Trying run primary_id = 15015 in region india
# 2024-03-27 00:44:45,984 - INFO - Trying run primary_id = 15015 in region india
# 2024-03-27 00:44:45,984 - INFO - Trying run primary_id = 15015 in region india
# 2024-03-27 00:44:45,987 - INFO - Running AFOLU model
# 2024-03-27 00:44:45,987 - INFO - Running AFOLU model
# 2024-03-27 00:44:45,987 - INFO - Running AFOLU model
# 2024-03-27 00:44:45,987 - INFO - Running AFOLU model
# 2024-03-27 00:44:46,443 - INFO - AFOLU model run successfully completed
# 2024-03-27 00:44:46,443 - INFO - AFOLU model run successfully completed
# 2024-03-27 00:44:46,443 - INFO - AFOLU model run successfully completed
# 2024-03-27 00:44:46,443 - INFO - AFOLU model run successfully completed
# 2024-03-27 00:44:47,465 - INFO - Running CircularEconomy model
# 2024-03-27 00:44:47,465 - INFO - Running CircularEconomy model
# 2024-03-27 00:44:47,465 - INFO - Running CircularEconomy model
# 2024-03-27 00:44:47,465 - INFO - Running CircularEconomy model
# 2024-03-27 00:44:47,613 - INFO - CircularEconomy model run successfully completed
# 2024-03-27 00:44:47,613 - INFO - CircularEconomy model run successfully completed
# 2024-03-27 00:44:47,613 - INFO - CircularEconomy model run successfully completed
# 2024-03-27 00:44:47,613 - INFO - CircularEconomy model run successfully completed
# 2024-03-27 00:44:47,616 - INFO - Running IPPU model
# 2024-03-27 00:44:47,616 - INFO - Running IPPU model
# 2024-03-27 00:44:47,616 - INFO - Running IPPU model
# 2024-03-27 00:44:47,616 - INFO - Running IPPU model
# 2024-03-27 00:44:47,790 - INFO - IPPU model run successfully completed
# 2024-03-27 00:44:47,790 - INFO - IPPU model run successfully completed
# 2024-03-27 00:44:47,790 - INFO - IPPU model run successfully completed
# 2024-03-27 00:44:47,790 - INFO - IPPU model run successfully completed
# 2024-03-27 00:44:47,792 - INFO - Running Energy model (NonElectricEnergy without Fugitive Emissions)
# 2024-03-27 00:44:47,792 - INFO - Running Energy model (NonElectricEnergy without Fugitive Emissions)
# 2024-03-27 00:44:47,792 - INFO - Running Energy model (NonElectricEnergy without Fugitive Emissions)
# 2024-03-27 00:44:47,792 - INFO - Running Energy model (NonElectricEnergy without Fugitive Emissions)
# 2024-03-27 00:44:47,838 - DEBUG - Missing elasticity information found in 'project_energy_consumption_by_fuel_from_effvars': using specified future demands.
# 2024-03-27 00:44:47,838 - DEBUG - Missing elasticity information found in 'project_energy_consumption_by_fuel_from_effvars': using specified future demands.
# 2024-03-27 00:44:47,838 - DEBUG - Missing elasticity information found in 'project_energy_consumption_by_fuel_from_effvars': using specified future demands.
# 2024-03-27 00:44:47,838 - DEBUG - Missing elasticity information found in 'project_energy_consumption_by_fuel_from_effvars': using specified future demands.
# 2024-03-27 00:44:48,042 - INFO - NonElectricEnergy without Fugitive Emissions model run successfully completed
# 2024-03-27 00:44:48,042 - INFO - NonElectricEnergy without Fugitive Emissions model run successfully completed
# 2024-03-27 00:44:48,042 - INFO - NonElectricEnergy without Fugitive Emissions model run successfully completed
# 2024-03-27 00:44:48,042 - INFO - NonElectricEnergy without Fugitive Emissions model run successfully completed
# 2024-03-27 00:44:48,044 - INFO - Running Energy model (Electricity and Fuel Production: trying to call Julia)
# 2024-03-27 00:44:48,044 - INFO - Running Energy model (Electricity and Fuel Production: trying to call Julia)
# 2024-03-27 00:44:48,044 - INFO - Running Energy model (Electricity and Fuel Production: trying to call Julia)
# 2024-03-27 00:44:48,044 - INFO - Running Energy model (Electricity and Fuel Production: trying to call Julia)
# 2024-27-Mar 00:44:50.644 Started modeling scenario.
# 2024-27-Mar 00:50:53.799 Finished modeling scenario.
# ┌ Warning: Model period activity upper limits for technologies (TotalTechnologyModelPeriodActivityUpperLimit parameter) are not enforced when modeling selected years.
# └ @ NemoMod ~/.julia/packages/NemoMod/d2ky8/src/scenario_calculation.jl:464
# ┌ Warning: Model period emission limits (ModelPeriodEmissionLimit parameter) are not enforced when modeling selected years.
# └ @ NemoMod ~/.julia/packages/NemoMod/d2ky8/src/scenario_calculation.jl:6181
# 2024-03-27 00:50:54,375 - INFO - NemoMod ran successfully with the following status: <PyCall.jlwrap OPTIMAL>
# 2024-03-27 00:50:54,375 - INFO - NemoMod ran successfully with the following status: <PyCall.jlwrap OPTIMAL>
# 2024-03-27 00:50:54,375 - INFO - NemoMod ran successfully with the following status: <PyCall.jlwrap OPTIMAL>
# 2024-03-27 00:50:54,375 - INFO - NemoMod ran successfully with the following status: <PyCall.jlwrap OPTIMAL>
# 2024-03-27 00:50:54,436 - INFO - ElectricEnergy model run successfully completed
# 2024-03-27 00:50:54,436 - INFO - ElectricEnergy model run successfully completed
# 2024-03-27 00:50:54,436 - INFO - ElectricEnergy model run successfully completed
# 2024-03-27 00:50:54,436 - INFO - ElectricEnergy model run successfully completed
# 2024-03-27 00:50:54,439 - INFO - Running Energy (Fugitive Emissions)
# 2024-03-27 00:50:54,439 - INFO - Running Energy (Fugitive Emissions)
# 2024-03-27 00:50:54,439 - INFO - Running Energy (Fugitive Emissions)
# 2024-03-27 00:50:54,439 - INFO - Running Energy (Fugitive Emissions)
# 2024-03-27 00:50:54,526 - INFO - Fugitive Emissions from Energy model run successfully completed
# 2024-03-27 00:50:54,526 - INFO - Fugitive Emissions from Energy model run successfully completed
# 2024-03-27 00:50:54,526 - INFO - Fugitive Emissions from Energy model run successfully completed
# 2024-03-27 00:50:54,526 - INFO - Fugitive Emissions from Energy model run successfully completed
# 2024-03-27 00:50:54,528 - INFO - Appending Socioeconomic outputs
# 2024-03-27 00:50:54,528 - INFO - Appending Socioeconomic outputs
# 2024-03-27 00:50:54,528 - INFO - Appending Socioeconomic outputs
# 2024-03-27 00:50:54,528 - INFO - Appending Socioeconomic outputs
# 2024-03-27 00:50:54,550 - INFO - Socioeconomic outputs successfully appended.
# 2024-03-27 00:50:54,550 - INFO - Socioeconomic outputs successfully appended.
# 2024-03-27 00:50:54,550 - INFO - Socioeconomic outputs successfully appended.
# 2024-03-27 00:50:54,550 - INFO - Socioeconomic outputs successfully appended.
# 2024-03-27 00:50:54,562 - INFO - Model run for primary_id = 15015 successfully completed in 368.58 seconds (n_tries = 1).
# 2024-03-27 00:50:54,562 - INFO - Model run for primary_id = 15015 successfully completed in 368.58 seconds (n_tries = 1).
# 2024-03-27 00:50:54,562 - INFO - Model run for primary_id = 15015 successfully completed in 368.58 seconds (n_tries = 1).
# 2024-03-27 00:50:54,562 - INFO - Model run for primary_id = 15015 successfully completed in 368.58 seconds (n_tries = 1).
# 2024-03-27 00:50:56,895 - INFO - Table MODEL_OUTPUT successfully written to database.
# 2024-03-27 00:50:56,895 - INFO - Table MODEL_OUTPUT successfully written to database.
# 2024-03-27 00:50:56,895 - INFO - Table MODEL_OUTPUT successfully written to database.
# 2024-03-27 00:50:56,895 - INFO - Table MODEL_OUTPUT successfully written to database.
# 2024-03-27 00:50:57,047 - INFO - Trying run primary_id = 128128 in region india
# 2024-03-27 00:50:57,047 - INFO - Trying run primary_id = 128128 in region india
# 2024-03-27 00:50:57,047 - INFO - Trying run primary_id = 128128 in region india
# 2024-03-27 00:50:57,047 - INFO - Trying run primary_id = 128128 in region india
# 2024-03-27 00:50:57,048 - INFO - Running AFOLU model
# 2024-03-27 00:50:57,048 - INFO - Running AFOLU model
# 2024-03-27 00:50:57,048 - INFO - Running AFOLU model
# 2024-03-27 00:50:57,048 - INFO - Running AFOLU model
# 2024-03-27 00:50:57,439 - INFO - AFOLU model run successfully completed
# 2024-03-27 00:50:57,439 - INFO - AFOLU model run successfully completed
# 2024-03-27 00:50:57,439 - INFO - AFOLU model run successfully completed
# 2024-03-27 00:50:57,439 - INFO - AFOLU model run successfully completed
# 2024-03-27 00:50:57,442 - INFO - Running CircularEconomy model
# 2024-03-27 00:50:57,442 - INFO - Running CircularEconomy model
# 2024-03-27 00:50:57,442 - INFO - Running CircularEconomy model
# 2024-03-27 00:50:57,442 - INFO - Running CircularEconomy model
# 2024-03-27 00:50:57,548 - INFO - CircularEconomy model run successfully completed
# 2024-03-27 00:50:57,548 - INFO - CircularEconomy model run successfully completed
# 2024-03-27 00:50:57,548 - INFO - CircularEconomy model run successfully completed
# 2024-03-27 00:50:57,548 - INFO - CircularEconomy model run successfully completed
# 2024-03-27 00:50:57,550 - INFO - Running IPPU model
# 2024-03-27 00:50:57,550 - INFO - Running IPPU model
# 2024-03-27 00:50:57,550 - INFO - Running IPPU model
# 2024-03-27 00:50:57,550 - INFO - Running IPPU model
# 2024-03-27 00:50:57,706 - INFO - IPPU model run successfully completed
# 2024-03-27 00:50:57,706 - INFO - IPPU model run successfully completed
# 2024-03-27 00:50:57,706 - INFO - IPPU model run successfully completed
# 2024-03-27 00:50:57,706 - INFO - IPPU model run successfully completed
# 2024-03-27 00:50:57,708 - INFO - Running Energy model (NonElectricEnergy without Fugitive Emissions)
# 2024-03-27 00:50:57,708 - INFO - Running Energy model (NonElectricEnergy without Fugitive Emissions)
# 2024-03-27 00:50:57,708 - INFO - Running Energy model (NonElectricEnergy without Fugitive Emissions)
# 2024-03-27 00:50:57,708 - INFO - Running Energy model (NonElectricEnergy without Fugitive Emissions)
# 2024-03-27 00:50:57,752 - DEBUG - Missing elasticity information found in 'project_energy_consumption_by_fuel_from_effvars': using specified future demands.
# 2024-03-27 00:50:57,752 - DEBUG - Missing elasticity information found in 'project_energy_consumption_by_fuel_from_effvars': using specified future demands.
# 2024-03-27 00:50:57,752 - DEBUG - Missing elasticity information found in 'project_energy_consumption_by_fuel_from_effvars': using specified future demands.
# 2024-03-27 00:50:57,752 - DEBUG - Missing elasticity information found in 'project_energy_consumption_by_fuel_from_effvars': using specified future demands.
# 2024-03-27 00:50:57,945 - INFO - NonElectricEnergy without Fugitive Emissions model run successfully completed
# 2024-03-27 00:50:57,945 - INFO - NonElectricEnergy without Fugitive Emissions model run successfully completed
# 2024-03-27 00:50:57,945 - INFO - NonElectricEnergy without Fugitive Emissions model run successfully completed
# 2024-03-27 00:50:57,945 - INFO - NonElectricEnergy without Fugitive Emissions model run successfully completed
# 2024-03-27 00:50:57,950 - INFO - Running Energy model (Electricity and Fuel Production: trying to call Julia)
# 2024-03-27 00:50:57,950 - INFO - Running Energy model (Electricity and Fuel Production: trying to call Julia)
# 2024-03-27 00:50:57,950 - INFO - Running Energy model (Electricity and Fuel Production: trying to call Julia)
# 2024-03-27 00:50:57,950 - INFO - Running Energy model (Electricity and Fuel Production: trying to call Julia)
# 2024-27-Mar 00:51:00.865 Started modeling scenario.
# 2024-27-Mar 01:01:35.848 Finished modeling scenario.
# ┌ Warning: Model period activity upper limits for technologies (TotalTechnologyModelPeriodActivityUpperLimit parameter) are not enforced when modeling selected years.
# └ @ NemoMod ~/.julia/packages/NemoMod/d2ky8/src/scenario_calculation.jl:464
# ┌ Warning: Model period emission limits (ModelPeriodEmissionLimit parameter) are not enforced when modeling selected years.
# └ @ NemoMod ~/.julia/packages/NemoMod/d2ky8/src/scenario_calculation.jl:6181
# 2024-03-27 01:01:36,582 - INFO - NemoMod ran successfully with the following status: <PyCall.jlwrap OPTIMAL>
# 2024-03-27 01:01:36,582 - INFO - NemoMod ran successfully with the following status: <PyCall.jlwrap OPTIMAL>
# 2024-03-27 01:01:36,582 - INFO - NemoMod ran successfully with the following status: <PyCall.jlwrap OPTIMAL>
# 2024-03-27 01:01:36,582 - INFO - NemoMod ran successfully with the following status: <PyCall.jlwrap OPTIMAL>
# 2024-03-27 01:01:36,666 - INFO - ElectricEnergy model run successfully completed
# 2024-03-27 01:01:36,666 - INFO - ElectricEnergy model run successfully completed
# 2024-03-27 01:01:36,666 - INFO - ElectricEnergy model run successfully completed
# 2024-03-27 01:01:36,666 - INFO - ElectricEnergy model run successfully completed
# 2024-03-27 01:01:36,668 - INFO - Running Energy (Fugitive Emissions)
# 2024-03-27 01:01:36,668 - INFO - Running Energy (Fugitive Emissions)
# 2024-03-27 01:01:36,668 - INFO - Running Energy (Fugitive Emissions)
# 2024-03-27 01:01:36,668 - INFO - Running Energy (Fugitive Emissions)
# 2024-03-27 01:01:36,756 - INFO - Fugitive Emissions from Energy model run successfully completed
# 2024-03-27 01:01:36,756 - INFO - Fugitive Emissions from Energy model run successfully completed
# 2024-03-27 01:01:36,756 - INFO - Fugitive Emissions from Energy model run successfully completed
# 2024-03-27 01:01:36,756 - INFO - Fugitive Emissions from Energy model run successfully completed
# 2024-03-27 01:01:36,760 - INFO - Appending Socioeconomic outputs
# 2024-03-27 01:01:36,760 - INFO - Appending Socioeconomic outputs
# 2024-03-27 01:01:36,760 - INFO - Appending Socioeconomic outputs
# 2024-03-27 01:01:36,760 - INFO - Appending Socioeconomic outputs
# 2024-03-27 01:01:36,779 - INFO - Socioeconomic outputs successfully appended.
# 2024-03-27 01:01:36,779 - INFO - Socioeconomic outputs successfully appended.
# 2024-03-27 01:01:36,779 - INFO - Socioeconomic outputs successfully appended.
# 2024-03-27 01:01:36,779 - INFO - Socioeconomic outputs successfully appended.
# 2024-03-27 01:01:36,793 - INFO - Model run for primary_id = 128128 successfully completed in 639.74 seconds (n_tries = 1).
# 2024-03-27 01:01:36,793 - INFO - Model run for primary_id = 128128 successfully completed in 639.74 seconds (n_tries = 1).
# 2024-03-27 01:01:36,793 - INFO - Model run for primary_id = 128128 successfully completed in 639.74 seconds (n_tries = 1).
# 2024-03-27 01:01:36,793 - INFO - Model run for primary_id = 128128 successfully completed in 639.74 seconds (n_tries = 1).
# 2024-03-27 01:01:36,907 - INFO - Trying run primary_id = 145145 in region india
# 2024-03-27 01:01:36,907 - INFO - Trying run primary_id = 145145 in region india
# 2024-03-27 01:01:36,907 - INFO - Trying run primary_id = 145145 in region india
# 2024-03-27 01:01:36,907 - INFO - Trying run primary_id = 145145 in region india
# 2024-03-27 01:01:36,920 - INFO - Running AFOLU model
# 2024-03-27 01:01:36,920 - INFO - Running AFOLU model
# 2024-03-27 01:01:36,920 - INFO - Running AFOLU model
# 2024-03-27 01:01:36,920 - INFO - Running AFOLU model
# 2024-03-27 01:01:37,535 - INFO - AFOLU model run successfully completed
# 2024-03-27 01:01:37,535 - INFO - AFOLU model run successfully completed
# 2024-03-27 01:01:37,535 - INFO - AFOLU model run successfully completed
# 2024-03-27 01:01:37,535 - INFO - AFOLU model run successfully completed
# 2024-03-27 01:01:37,538 - INFO - Running CircularEconomy model
# 2024-03-27 01:01:37,538 - INFO - Running CircularEconomy model
# 2024-03-27 01:01:37,538 - INFO - Running CircularEconomy model
# 2024-03-27 01:01:37,538 - INFO - Running CircularEconomy model
# 2024-03-27 01:01:37,655 - INFO - CircularEconomy model run successfully completed
# 2024-03-27 01:01:37,655 - INFO - CircularEconomy model run successfully completed
# 2024-03-27 01:01:37,655 - INFO - CircularEconomy model run successfully completed
# 2024-03-27 01:01:37,655 - INFO - CircularEconomy model run successfully completed
# 2024-03-27 01:01:37,657 - INFO - Running IPPU model
# 2024-03-27 01:01:37,657 - INFO - Running IPPU model
# 2024-03-27 01:01:37,657 - INFO - Running IPPU model
# 2024-03-27 01:01:37,657 - INFO - Running IPPU model
# 2024-03-27 01:01:37,833 - INFO - IPPU model run successfully completed
# 2024-03-27 01:01:37,833 - INFO - IPPU model run successfully completed
# 2024-03-27 01:01:37,833 - INFO - IPPU model run successfully completed
# 2024-03-27 01:01:37,833 - INFO - IPPU model run successfully completed
# 2024-03-27 01:01:37,835 - INFO - Running Energy model (NonElectricEnergy without Fugitive Emissions)
# 2024-03-27 01:01:37,835 - INFO - Running Energy model (NonElectricEnergy without Fugitive Emissions)
# 2024-03-27 01:01:37,835 - INFO - Running Energy model (NonElectricEnergy without Fugitive Emissions)
# 2024-03-27 01:01:37,835 - INFO - Running Energy model (NonElectricEnergy without Fugitive Emissions)
# 2024-03-27 01:01:37,878 - DEBUG - Missing elasticity information found in 'project_energy_consumption_by_fuel_from_effvars': using specified future demands.
# 2024-03-27 01:01:37,878 - DEBUG - Missing elasticity information found in 'project_energy_consumption_by_fuel_from_effvars': using specified future demands.
# 2024-03-27 01:01:37,878 - DEBUG - Missing elasticity information found in 'project_energy_consumption_by_fuel_from_effvars': using specified future demands.
# 2024-03-27 01:01:37,878 - DEBUG - Missing elasticity information found in 'project_energy_consumption_by_fuel_from_effvars': using specified future demands.
# 2024-03-27 01:01:38,084 - INFO - NonElectricEnergy without Fugitive Emissions model run successfully completed
# 2024-03-27 01:01:38,084 - INFO - NonElectricEnergy without Fugitive Emissions model run successfully completed
# 2024-03-27 01:01:38,084 - INFO - NonElectricEnergy without Fugitive Emissions model run successfully completed
# 2024-03-27 01:01:38,084 - INFO - NonElectricEnergy without Fugitive Emissions model run successfully completed
# 2024-03-27 01:01:38,086 - INFO - Running Energy model (Electricity and Fuel Production: trying to call Julia)
# 2024-03-27 01:01:38,086 - INFO - Running Energy model (Electricity and Fuel Production: trying to call Julia)
# 2024-03-27 01:01:38,086 - INFO - Running Energy model (Electricity and Fuel Production: trying to call Julia)
# 2024-03-27 01:01:38,086 - INFO - Running Energy model (Electricity and Fuel Production: trying to call Julia)
# 2024-27-Mar 01:01:41.451 Started modeling scenario.
# 2024-27-Mar 01:07:41.742 Finished modeling scenario.
# ┌ Warning: Model period activity upper limits for technologies (TotalTechnologyModelPeriodActivityUpperLimit parameter) are not enforced when modeling selected years.
# └ @ NemoMod ~/.julia/packages/NemoMod/d2ky8/src/scenario_calculation.jl:464
# ┌ Warning: Model period emission limits (ModelPeriodEmissionLimit parameter) are not enforced when modeling selected years.
# └ @ NemoMod ~/.julia/packages/NemoMod/d2ky8/src/scenario_calculation.jl:6181
# 2024-03-27 01:07:42,323 - INFO - NemoMod ran successfully with the following status: <PyCall.jlwrap OPTIMAL>
# 2024-03-27 01:07:42,323 - INFO - NemoMod ran successfully with the following status: <PyCall.jlwrap OPTIMAL>
# 2024-03-27 01:07:42,323 - INFO - NemoMod ran successfully with the following status: <PyCall.jlwrap OPTIMAL>
# 2024-03-27 01:07:42,323 - INFO - NemoMod ran successfully with the following status: <PyCall.jlwrap OPTIMAL>
# 2024-03-27 01:07:42,392 - INFO - ElectricEnergy model run successfully completed
# 2024-03-27 01:07:42,392 - INFO - ElectricEnergy model run successfully completed
# 2024-03-27 01:07:42,392 - INFO - ElectricEnergy model run successfully completed
# 2024-03-27 01:07:42,392 - INFO - ElectricEnergy model run successfully completed
# 2024-03-27 01:07:42,394 - INFO - Running Energy (Fugitive Emissions)
# 2024-03-27 01:07:42,394 - INFO - Running Energy (Fugitive Emissions)
# 2024-03-27 01:07:42,394 - INFO - Running Energy (Fugitive Emissions)
# 2024-03-27 01:07:42,394 - INFO - Running Energy (Fugitive Emissions)
# 2024-03-27 01:07:42,500 - INFO - Fugitive Emissions from Energy model run successfully completed
# 2024-03-27 01:07:42,500 - INFO - Fugitive Emissions from Energy model run successfully completed
# 2024-03-27 01:07:42,500 - INFO - Fugitive Emissions from Energy model run successfully completed
# 2024-03-27 01:07:42,500 - INFO - Fugitive Emissions from Energy model run successfully completed
# 2024-03-27 01:07:42,502 - INFO - Appending Socioeconomic outputs
# 2024-03-27 01:07:42,502 - INFO - Appending Socioeconomic outputs
# 2024-03-27 01:07:42,502 - INFO - Appending Socioeconomic outputs
# 2024-03-27 01:07:42,502 - INFO - Appending Socioeconomic outputs
# 2024-03-27 01:07:42,529 - INFO - Socioeconomic outputs successfully appended.
# 2024-03-27 01:07:42,529 - INFO - Socioeconomic outputs successfully appended.
# 2024-03-27 01:07:42,529 - INFO - Socioeconomic outputs successfully appended.
# 2024-03-27 01:07:42,529 - INFO - Socioeconomic outputs successfully appended.
# 2024-03-27 01:07:42,546 - INFO - Model run for primary_id = 145145 successfully completed in 365.64 seconds (n_tries = 1).
# 2024-03-27 01:07:42,546 - INFO - Model run for primary_id = 145145 successfully completed in 365.64 seconds (n_tries = 1).
# 2024-03-27 01:07:42,546 - INFO - Model run for primary_id = 145145 successfully completed in 365.64 seconds (n_tries = 1).
# 2024-03-27 01:07:42,546 - INFO - Model run for primary_id = 145145 successfully completed in 365.64 seconds (n_tries = 1).
# 2024-03-27 01:07:44,935 - INFO - Table MODEL_OUTPUT successfully appended to database.
# 2024-03-27 01:07:44,935 - INFO - Table MODEL_OUTPUT successfully appended to database.
# 2024-03-27 01:07:44,935 - INFO - Table MODEL_OUTPUT successfully appended to database.
# 2024-03-27 01:07:44,935 - INFO - Table MODEL_OUTPUT successfully appended to database.
# 2024-03-27 01:07:44,989 - INFO - Trying run primary_id = 146146 in region india
# 2024-03-27 01:07:44,989 - INFO - Trying run primary_id = 146146 in region india
# 2024-03-27 01:07:44,989 - INFO - Trying run primary_id = 146146 in region india
# 2024-03-27 01:07:44,989 - INFO - Trying run primary_id = 146146 in region india
# 2024-03-27 01:07:44,990 - INFO - Running AFOLU model
# 2024-03-27 01:07:44,990 - INFO - Running AFOLU model
# 2024-03-27 01:07:44,990 - INFO - Running AFOLU model
# 2024-03-27 01:07:44,990 - INFO - Running AFOLU model
# 2024-03-27 01:07:45,372 - INFO - AFOLU model run successfully completed
# 2024-03-27 01:07:45,372 - INFO - AFOLU model run successfully completed
# 2024-03-27 01:07:45,372 - INFO - AFOLU model run successfully completed
# 2024-03-27 01:07:45,372 - INFO - AFOLU model run successfully completed
# 2024-03-27 01:07:45,375 - INFO - Running CircularEconomy model
# 2024-03-27 01:07:45,375 - INFO - Running CircularEconomy model
# 2024-03-27 01:07:45,375 - INFO - Running CircularEconomy model
# 2024-03-27 01:07:45,375 - INFO - Running CircularEconomy model
# 2024-03-27 01:07:45,481 - INFO - CircularEconomy model run successfully completed
# 2024-03-27 01:07:45,481 - INFO - CircularEconomy model run successfully completed
# 2024-03-27 01:07:45,481 - INFO - CircularEconomy model run successfully completed
# 2024-03-27 01:07:45,481 - INFO - CircularEconomy model run successfully completed
# 2024-03-27 01:07:45,483 - INFO - Running IPPU model
# 2024-03-27 01:07:45,483 - INFO - Running IPPU model
# 2024-03-27 01:07:45,483 - INFO - Running IPPU model
# 2024-03-27 01:07:45,483 - INFO - Running IPPU model
# 2024-03-27 01:07:45,642 - INFO - IPPU model run successfully completed
# 2024-03-27 01:07:45,642 - INFO - IPPU model run successfully completed
# 2024-03-27 01:07:45,642 - INFO - IPPU model run successfully completed
# 2024-03-27 01:07:45,642 - INFO - IPPU model run successfully completed
# 2024-03-27 01:07:45,645 - INFO - Running Energy model (NonElectricEnergy without Fugitive Emissions)
# 2024-03-27 01:07:45,645 - INFO - Running Energy model (NonElectricEnergy without Fugitive Emissions)
# 2024-03-27 01:07:45,645 - INFO - Running Energy model (NonElectricEnergy without Fugitive Emissions)
# 2024-03-27 01:07:45,645 - INFO - Running Energy model (NonElectricEnergy without Fugitive Emissions)
# 2024-03-27 01:07:45,690 - DEBUG - Missing elasticity information found in 'project_energy_consumption_by_fuel_from_effvars': using specified future demands.
# 2024-03-27 01:07:45,690 - DEBUG - Missing elasticity information found in 'project_energy_consumption_by_fuel_from_effvars': using specified future demands.
# 2024-03-27 01:07:45,690 - DEBUG - Missing elasticity information found in 'project_energy_consumption_by_fuel_from_effvars': using specified future demands.
# 2024-03-27 01:07:45,690 - DEBUG - Missing elasticity information found in 'project_energy_consumption_by_fuel_from_effvars': using specified future demands.
# 2024-03-27 01:07:45,879 - INFO - NonElectricEnergy without Fugitive Emissions model run successfully completed
# 2024-03-27 01:07:45,879 - INFO - NonElectricEnergy without Fugitive Emissions model run successfully completed
# 2024-03-27 01:07:45,879 - INFO - NonElectricEnergy without Fugitive Emissions model run successfully completed
# 2024-03-27 01:07:45,879 - INFO - NonElectricEnergy without Fugitive Emissions model run successfully completed
# 2024-03-27 01:07:45,881 - INFO - Running Energy model (Electricity and Fuel Production: trying to call Julia)
# 2024-03-27 01:07:45,881 - INFO - Running Energy model (Electricity and Fuel Production: trying to call Julia)
# 2024-03-27 01:07:45,881 - INFO - Running Energy model (Electricity and Fuel Production: trying to call Julia)
# 2024-03-27 01:07:45,881 - INFO - Running Energy model (Electricity and Fuel Production: trying to call Julia)
# ┌ Warning: Model period activity upper limits for technologies (TotalTechnologyModelPeriodActivityUpperLimit parameter) are not enforced when modeling selected years.
# └ @ NemoMod ~/.julia/packages/NemoMod/d2ky8/src/scenario_calculation.jl:464
# ┌ Warning: Model period emission limits (ModelPeriodEmissionLimit parameter) are not enforced when modeling selected years.
# └ @ NemoMod ~/.julia/packages/NemoMod/d2ky8/src/scenario_calculation.jl:6181
# 2024-03-27 01:23:22,879 - ERROR - Error running ElectricEnergy model: 'NoneType' object is not subscriptable
# 2024-03-27 01:23:22,879 - ERROR - Error running ElectricEnergy model: 'NoneType' object is not subscriptable
# 2024-03-27 01:23:22,879 - ERROR - Error running ElectricEnergy model: 'NoneType' object is not subscriptable
# 2024-03-27 01:23:22,879 - ERROR - Error running ElectricEnergy model: 'NoneType' object is not subscriptable
# 2024-03-27 01:23:23,017 - INFO - Running Energy (Fugitive Emissions)
# 2024-27-Mar 01:07:48.877 Started modeling scenario.
# 2024-27-Mar 01:23:22.676 Solver did not find an optimal solution for model. No results will be saved to database.
# 2024-27-Mar 01:23:22.748 Finished modeling scenario.
# 2024-03-27 01:23:23,017 - INFO - Running Energy (Fugitive Emissions)
# 2024-03-27 01:23:23,017 - INFO - Running Energy (Fugitive Emissions)
# 2024-03-27 01:23:23,017 - INFO - Running Energy (Fugitive Emissions)
# 2024-03-27 01:23:23,131 - ERROR - Error running Fugitive Emissions from Energy model:
#             Unable to extract variable Total Energy Demand by Fuel in extract_model_variable: unsupported operand type(s) for -: 'list' and 'list'
#
# 2024-03-27 01:23:23,131 - ERROR - Error running Fugitive Emissions from Energy model:
#             Unable to extract variable Total Energy Demand by Fuel in extract_model_variable: unsupported operand type(s) for -: 'list' and 'list'
#
# 2024-03-27 01:23:23,131 - ERROR - Error running Fugitive Emissions from Energy model:
#             Unable to extract variable Total Energy Demand by Fuel in extract_model_variable: unsupported operand type(s) for -: 'list' and 'list'
#
# 2024-03-27 01:23:23,131 - ERROR - Error running Fugitive Emissions from Energy model:
#             Unable to extract variable Total Energy Demand by Fuel in extract_model_variable: unsupported operand type(s) for -: 'list' and 'list'
#
# 2024-03-27 01:23:23,136 - INFO - Appending Socioeconomic outputs
# 2024-03-27 01:23:23,136 - INFO - Appending Socioeconomic outputs
# 2024-03-27 01:23:23,136 - INFO - Appending Socioeconomic outputs
# 2024-03-27 01:23:23,136 - INFO - Appending Socioeconomic outputs
# 2024-03-27 01:23:23,178 - INFO - Socioeconomic outputs successfully appended.
# 2024-03-27 01:23:23,178 - INFO - Socioeconomic outputs successfully appended.
# 2024-03-27 01:23:23,178 - INFO - Socioeconomic outputs successfully appended.
# 2024-03-27 01:23:23,178 - INFO - Socioeconomic outputs successfully appended.
# 2024-03-27 01:23:23,204 - INFO - Model run for primary_id = 146146 successfully completed in 938.21 seconds (n_tries = 1).
# 2024-03-27 01:23:23,204 - INFO - Model run for primary_id = 146146 successfully completed in 938.21 seconds (n_tries = 1).
# 2024-03-27 01:23:23,204 - INFO - Model run for primary_id = 146146 successfully completed in 938.21 seconds (n_tries = 1).
# 2024-03-27 01:23:23,204 - INFO - Model run for primary_id = 146146 successfully completed in 938.21 seconds (n_tries = 1).
# 2024-03-27 01:23:23,259 - INFO - Trying run primary_id = 147147 in region india
# 2024-03-27 01:23:23,259 - INFO - Trying run primary_id = 147147 in region india
# 2024-03-27 01:23:23,259 - INFO - Trying run primary_id = 147147 in region india
# 2024-03-27 01:23:23,259 - INFO - Trying run primary_id = 147147 in region india
# 2024-03-27 01:23:23,266 - INFO - Running AFOLU model
# 2024-03-27 01:23:23,266 - INFO - Running AFOLU model
# 2024-03-27 01:23:23,266 - INFO - Running AFOLU model
# 2024-03-27 01:23:23,266 - INFO - Running AFOLU model
# 2024-03-27 01:23:23,884 - INFO - AFOLU model run successfully completed
# 2024-03-27 01:23:23,884 - INFO - AFOLU model run successfully completed
# 2024-03-27 01:23:23,884 - INFO - AFOLU model run successfully completed
# 2024-03-27 01:23:23,884 - INFO - AFOLU model run successfully completed
# 2024-03-27 01:23:23,887 - INFO - Running CircularEconomy model
# 2024-03-27 01:23:23,887 - INFO - Running CircularEconomy model
# 2024-03-27 01:23:23,887 - INFO - Running CircularEconomy model
# 2024-03-27 01:23:23,887 - INFO - Running CircularEconomy model
# 2024-03-27 01:23:24,029 - INFO - CircularEconomy model run successfully completed
# 2024-03-27 01:23:24,029 - INFO - CircularEconomy model run successfully completed
# 2024-03-27 01:23:24,029 - INFO - CircularEconomy model run successfully completed
# 2024-03-27 01:23:24,029 - INFO - CircularEconomy model run successfully completed
# 2024-03-27 01:23:24,031 - INFO - Running IPPU model
# 2024-03-27 01:23:24,031 - INFO - Running IPPU model
# 2024-03-27 01:23:24,031 - INFO - Running IPPU model
# 2024-03-27 01:23:24,031 - INFO - Running IPPU model
# 2024-03-27 01:23:24,232 - INFO - IPPU model run successfully completed
# 2024-03-27 01:23:24,232 - INFO - IPPU model run successfully completed
# 2024-03-27 01:23:24,232 - INFO - IPPU model run successfully completed
# 2024-03-27 01:23:24,232 - INFO - IPPU model run successfully completed
# 2024-03-27 01:23:24,234 - INFO - Running Energy model (NonElectricEnergy without Fugitive Emissions)
# 2024-03-27 01:23:24,234 - INFO - Running Energy model (NonElectricEnergy without Fugitive Emissions)
# 2024-03-27 01:23:24,234 - INFO - Running Energy model (NonElectricEnergy without Fugitive Emissions)
# 2024-03-27 01:23:24,234 - INFO - Running Energy model (NonElectricEnergy without Fugitive Emissions)
# 2024-03-27 01:23:24,285 - DEBUG - Missing elasticity information found in 'project_energy_consumption_by_fuel_from_effvars': using specified future demands.
# 2024-03-27 01:23:24,285 - DEBUG - Missing elasticity information found in 'project_energy_consumption_by_fuel_from_effvars': using specified future demands.
# 2024-03-27 01:23:24,285 - DEBUG - Missing elasticity information found in 'project_energy_consumption_by_fuel_from_effvars': using specified future demands.
# 2024-03-27 01:23:24,285 - DEBUG - Missing elasticity information found in 'project_energy_consumption_by_fuel_from_effvars': using specified future demands.
# 2024-03-27 01:23:24,517 - INFO - NonElectricEnergy without Fugitive Emissions model run successfully completed
# 2024-03-27 01:23:24,517 - INFO - NonElectricEnergy without Fugitive Emissions model run successfully completed
# 2024-03-27 01:23:24,517 - INFO - NonElectricEnergy without Fugitive Emissions model run successfully completed
# 2024-03-27 01:23:24,517 - INFO - NonElectricEnergy without Fugitive Emissions model run successfully completed
# 2024-03-27 01:23:24,520 - INFO - Running Energy model (Electricity and Fuel Production: trying to call Julia)
# 2024-03-27 01:23:24,520 - INFO - Running Energy model (Electricity and Fuel Production: trying to call Julia)
# 2024-03-27 01:23:24,520 - INFO - Running Energy model (Electricity and Fuel Production: trying to call Julia)
# 2024-03-27 01:23:24,520 - INFO - Running Energy model (Electricity and Fuel Production: trying to call Julia)
# ┌ Warning: Model period activity upper limits for technologies (TotalTechnologyModelPeriodActivityUpperLimit parameter) are not enforced when modeling selected years.
# └ @ NemoMod ~/.julia/packages/NemoMod/d2ky8/src/scenario_calculation.jl:464
# ┌ Warning: Model period emission limits (ModelPeriodEmissionLimit parameter) are not enforced when modeling selected years.
# └ @ NemoMod ~/.julia/packages/NemoMod/d2ky8/src/scenario_calculation.jl:6181
# 2024-27-Mar 01:23:27.942 Started modeling scenario.
# 2024-27-Mar 01:36:26.927 Finished modeling scenario.
# 2024-03-27 01:36:27,530 - INFO - NemoMod ran successfully with the following status: <PyCall.jlwrap OPTIMAL>
# 2024-03-27 01:36:27,530 - INFO - NemoMod ran successfully with the following status: <PyCall.jlwrap OPTIMAL>
# 2024-03-27 01:36:27,530 - INFO - NemoMod ran successfully with the following status: <PyCall.jlwrap OPTIMAL>
# 2024-03-27 01:36:27,530 - INFO - NemoMod ran successfully with the following status: <PyCall.jlwrap OPTIMAL>
# 2024-03-27 01:36:27,594 - INFO - ElectricEnergy model run successfully completed
# 2024-03-27 01:36:27,594 - INFO - ElectricEnergy model run successfully completed
# 2024-03-27 01:36:27,594 - INFO - ElectricEnergy model run successfully completed
# 2024-03-27 01:36:27,594 - INFO - ElectricEnergy model run successfully completed
# 2024-03-27 01:36:27,597 - INFO - Running Energy (Fugitive Emissions)
# 2024-03-27 01:36:27,597 - INFO - Running Energy (Fugitive Emissions)
# 2024-03-27 01:36:27,597 - INFO - Running Energy (Fugitive Emissions)
# 2024-03-27 01:36:27,597 - INFO - Running Energy (Fugitive Emissions)
# 2024-03-27 01:36:27,718 - INFO - Fugitive Emissions from Energy model run successfully completed
# 2024-03-27 01:36:27,718 - INFO - Fugitive Emissions from Energy model run successfully completed
# 2024-03-27 01:36:27,718 - INFO - Fugitive Emissions from Energy model run successfully completed
# 2024-03-27 01:36:27,718 - INFO - Fugitive Emissions from Energy model run successfully completed
# 2024-03-27 01:36:27,722 - INFO - Appending Socioeconomic outputs
# 2024-03-27 01:36:27,722 - INFO - Appending Socioeconomic outputs
# 2024-03-27 01:36:27,722 - INFO - Appending Socioeconomic outputs
# 2024-03-27 01:36:27,722 - INFO - Appending Socioeconomic outputs
# 2024-03-27 01:36:27,750 - INFO - Socioeconomic outputs successfully appended.
# 2024-03-27 01:36:27,750 - INFO - Socioeconomic outputs successfully appended.
# 2024-03-27 01:36:27,750 - INFO - Socioeconomic outputs successfully appended.
# 2024-03-27 01:36:27,750 - INFO - Socioeconomic outputs successfully appended.
# 2024-03-27 01:36:27,786 - INFO - Model run for primary_id = 147147 successfully completed in 784.52 seconds (n_tries = 1).
# 2024-03-27 01:36:27,786 - INFO - Model run for primary_id = 147147 successfully completed in 784.52 seconds (n_tries = 1).
# 2024-03-27 01:36:27,786 - INFO - Model run for primary_id = 147147 successfully completed in 784.52 seconds (n_tries = 1).
# 2024-03-27 01:36:27,786 - INFO - Model run for primary_id = 147147 successfully completed in 784.52 seconds (n_tries = 1).
# 2024-03-27 01:36:30,114 - INFO - Table MODEL_OUTPUT successfully appended to database.
# 2024-03-27 01:36:30,114 - INFO - Table MODEL_OUTPUT successfully appended to database.
# 2024-03-27 01:36:30,114 - INFO - Table MODEL_OUTPUT successfully appended to database.
# 2024-03-27 01:36:30,114 - INFO - Table MODEL_OUTPUT successfully appended to database.
# 2024-03-27 01:36:30,148 - INFO - Trying run primary_id = 148148 in region india
# 2024-03-27 01:36:30,148 - INFO - Trying run primary_id = 148148 in region india
# 2024-03-27 01:36:30,148 - INFO - Trying run primary_id = 148148 in region india
# 2024-03-27 01:36:30,148 - INFO - Trying run primary_id = 148148 in region india
# 2024-03-27 01:36:30,150 - INFO - Running AFOLU model
# 2024-03-27 01:36:30,150 - INFO - Running AFOLU model
# 2024-03-27 01:36:30,150 - INFO - Running AFOLU model
# 2024-03-27 01:36:30,150 - INFO - Running AFOLU model
# 2024-03-27 01:36:30,607 - INFO - AFOLU model run successfully completed
# 2024-03-27 01:36:30,607 - INFO - AFOLU model run successfully completed
# 2024-03-27 01:36:30,607 - INFO - AFOLU model run successfully completed
# 2024-03-27 01:36:30,607 - INFO - AFOLU model run successfully completed
# 2024-03-27 01:36:30,610 - INFO - Running CircularEconomy model
# 2024-03-27 01:36:30,610 - INFO - Running CircularEconomy model
# 2024-03-27 01:36:30,610 - INFO - Running CircularEconomy model
# 2024-03-27 01:36:30,610 - INFO - Running CircularEconomy model
# 2024-03-27 01:36:30,727 - INFO - CircularEconomy model run successfully completed
# 2024-03-27 01:36:30,727 - INFO - CircularEconomy model run successfully completed
# 2024-03-27 01:36:30,727 - INFO - CircularEconomy model run successfully completed
# 2024-03-27 01:36:30,727 - INFO - CircularEconomy model run successfully completed
# 2024-03-27 01:36:30,729 - INFO - Running IPPU model
# 2024-03-27 01:36:30,729 - INFO - Running IPPU model
# 2024-03-27 01:36:30,729 - INFO - Running IPPU model
# 2024-03-27 01:36:30,729 - INFO - Running IPPU model
# 2024-03-27 01:36:30,914 - INFO - IPPU model run successfully completed
# 2024-03-27 01:36:30,914 - INFO - IPPU model run successfully completed
# 2024-03-27 01:36:30,914 - INFO - IPPU model run successfully completed
# 2024-03-27 01:36:30,914 - INFO - IPPU model run successfully completed
# 2024-03-27 01:36:30,916 - INFO - Running Energy model (NonElectricEnergy without Fugitive Emissions)
# 2024-03-27 01:36:30,916 - INFO - Running Energy model (NonElectricEnergy without Fugitive Emissions)
# 2024-03-27 01:36:30,916 - INFO - Running Energy model (NonElectricEnergy without Fugitive Emissions)
# 2024-03-27 01:36:30,916 - INFO - Running Energy model (NonElectricEnergy without Fugitive Emissions)
# 2024-03-27 01:36:30,967 - DEBUG - Missing elasticity information found in 'project_energy_consumption_by_fuel_from_effvars': using specified future demands.
# 2024-03-27 01:36:30,967 - DEBUG - Missing elasticity information found in 'project_energy_consumption_by_fuel_from_effvars': using specified future demands.
# 2024-03-27 01:36:30,967 - DEBUG - Missing elasticity information found in 'project_energy_consumption_by_fuel_from_effvars': using specified future demands.
# 2024-03-27 01:36:30,967 - DEBUG - Missing elasticity information found in 'project_energy_consumption_by_fuel_from_effvars': using specified future demands.
# 2024-03-27 01:36:31,179 - INFO - NonElectricEnergy without Fugitive Emissions model run successfully completed
# 2024-03-27 01:36:31,179 - INFO - NonElectricEnergy without Fugitive Emissions model run successfully completed
# 2024-03-27 01:36:31,179 - INFO - NonElectricEnergy without Fugitive Emissions model run successfully completed
# 2024-03-27 01:36:31,179 - INFO - NonElectricEnergy without Fugitive Emissions model run successfully completed
# 2024-03-27 01:36:31,181 - INFO - Running Energy model (Electricity and Fuel Production: trying to call Julia)
# 2024-03-27 01:36:31,181 - INFO - Running Energy model (Electricity and Fuel Production: trying to call Julia)
# 2024-03-27 01:36:31,181 - INFO - Running Energy model (Electricity and Fuel Production: trying to call Julia)
# 2024-03-27 01:36:31,181 - INFO - Running Energy model (Electricity and Fuel Production: trying to call Julia)
# 2024-27-Mar 01:36:33.969 Started modeling scenario.
# 2024-27-Mar 01:46:49.500 Finished modeling scenario.
# ┌ Warning: Model period activity upper limits for technologies (TotalTechnologyModelPeriodActivityUpperLimit parameter) are not enforced when modeling selected years.
# └ @ NemoMod ~/.julia/packages/NemoMod/d2ky8/src/scenario_calculation.jl:464
# ┌ Warning: Model period emission limits (ModelPeriodEmissionLimit parameter) are not enforced when modeling selected years.
# └ @ NemoMod ~/.julia/packages/NemoMod/d2ky8/src/scenario_calculation.jl:6181
# 2024-03-27 01:46:49,926 - INFO - NemoMod ran successfully with the following status: <PyCall.jlwrap OPTIMAL>
# 2024-03-27 01:46:49,926 - INFO - NemoMod ran successfully with the following status: <PyCall.jlwrap OPTIMAL>
# 2024-03-27 01:46:49,926 - INFO - NemoMod ran successfully with the following status: <PyCall.jlwrap OPTIMAL>
# 2024-03-27 01:46:49,926 - INFO - NemoMod ran successfully with the following status: <PyCall.jlwrap OPTIMAL>
# 2024-03-27 01:46:49,969 - INFO - ElectricEnergy model run successfully completed
# 2024-03-27 01:46:49,969 - INFO - ElectricEnergy model run successfully completed
# 2024-03-27 01:46:49,969 - INFO - ElectricEnergy model run successfully completed
# 2024-03-27 01:46:49,969 - INFO - ElectricEnergy model run successfully completed
# 2024-03-27 01:46:49,972 - INFO - Running Energy (Fugitive Emissions)
# 2024-03-27 01:46:49,972 - INFO - Running Energy (Fugitive Emissions)
# 2024-03-27 01:46:49,972 - INFO - Running Energy (Fugitive Emissions)
# 2024-03-27 01:46:49,972 - INFO - Running Energy (Fugitive Emissions)
# 2024-03-27 01:46:50,045 - INFO - Fugitive Emissions from Energy model run successfully completed
# 2024-03-27 01:46:50,045 - INFO - Fugitive Emissions from Energy model run successfully completed
# 2024-03-27 01:46:50,045 - INFO - Fugitive Emissions from Energy model run successfully completed
# 2024-03-27 01:46:50,045 - INFO - Fugitive Emissions from Energy model run successfully completed
# 2024-03-27 01:46:50,048 - INFO - Appending Socioeconomic outputs
# 2024-03-27 01:46:50,048 - INFO - Appending Socioeconomic outputs
# 2024-03-27 01:46:50,048 - INFO - Appending Socioeconomic outputs
# 2024-03-27 01:46:50,048 - INFO - Appending Socioeconomic outputs
# 2024-03-27 01:46:50,067 - INFO - Socioeconomic outputs successfully appended.
# 2024-03-27 01:46:50,067 - INFO - Socioeconomic outputs successfully appended.
# 2024-03-27 01:46:50,067 - INFO - Socioeconomic outputs successfully appended.
# 2024-03-27 01:46:50,067 - INFO - Socioeconomic outputs successfully appended.
# 2024-03-27 01:46:50,078 - INFO - Model run for primary_id = 148148 successfully completed in 619.93 seconds (n_tries = 1).
# 2024-03-27 01:46:50,078 - INFO - Model run for primary_id = 148148 successfully completed in 619.93 seconds (n_tries = 1).
# 2024-03-27 01:46:50,078 - INFO - Model run for primary_id = 148148 successfully completed in 619.93 seconds (n_tries = 1).
# 2024-03-27 01:46:50,078 - INFO - Model run for primary_id = 148148 successfully completed in 619.93 seconds (n_tries = 1).
# 2024-03-27 01:46:50,080 - INFO -
# ***	 REGION india COMPLETE	***
#
# 2024-03-27 01:46:50,080 - INFO -
# ***	 REGION india COMPLETE	***
#
# 2024-03-27 01:46:50,080 - INFO -
# ***	 REGION india COMPLETE	***
#
# 2024-03-27 01:46:50,080 - INFO -
# ***	 REGION india COMPLETE	***
#
# 2024-03-27 01:46:50,718 - INFO - Table MODEL_OUTPUT successfully appended to database.
# 2024-03-27 01:46:50,718 - INFO - Table MODEL_OUTPUT successfully appended to database.
# 2024-03-27 01:46:50,718 - INFO - Table MODEL_OUTPUT successfully appended to database.
# 2024-03-27 01:46:50,718 - INFO - Table MODEL_OUTPUT successfully appended to database.
# 2024-03-27 01:46:50,738 - INFO - Table ATTRIBUTE_PRIMARY successfully written to database.
# 2024-03-27 01:46:50,738 - INFO - Table ATTRIBUTE_PRIMARY successfully written to database.
# 2024-03-27 01:46:50,738 - INFO - Table ATTRIBUTE_PRIMARY successfully written to database.
# 2024-03-27 01:46:50,738 - INFO - Table ATTRIBUTE_PRIMARY successfully written to database.

# %%
df_out = sisepuede.read_output(None)

# %%
df_out["primary_id"].unique()
# Out:
# array([     0,  15015, 128128, 145145, 146146, 147147, 148148])

# %%
fields_plot = [x for x in df_out.columns if x.startswith("emission_co2e_subsector_total")]
fields_plot = [x for x in fields_plot if ("agrc" in x) | ("lndu" in x) | ("frst" in x) | ("lvst" in x) | ("lsmm" in x) | ("soil" in x)]
field_x = "time_period"

df_out[
    df_out[sisepuede.key_primary].isin([146146])
][
    [field_x] + fields_plot
].plot.area(x = field_x)
# Out:
# <AxesSubplot: xlabel='time_period'>

# %%
def plot_stack(
    df: pd.DataFrame,
    fields: pd.DataFrame, 
    field_x: Union[str, None] = None,
) -> Union['matplotlib.Plot', None]:
    """
    plt.plot.area() cannot handle negative trajctories.
    
    Function Arguments
    ------------------
    - df: data frame to pull data from
    - fields: fields to plot

    Keyword Arguments
    ----------------- 
    - x: optional field `x` in data frame to use for x axis
    """
    
    # check fields
    fields = [x for x in df.columns if x in fields]
    if len(fields) == 0:
        return None
    
    field_x = field_x if field_x in df.columns else None
    fields = (
        [x for x in fields if x != field_x] + [field_x]
        if field_x is not None
        else fields
    )
    
    
    df_plot = df[felds].copy()
    
    # 
    for k in fields:
        if x == field_x:
            continue
        
        
        vec = np.array(df_plot[k])
        bnds = (0, np.inf) if (vec[-1] >= 0) else (-np.inf, 0)
        if (max(vec) > 0) and (min(vec) < 0):
            k0 = f"{k}_positive"
            k1 = f"{k}_negative"
            
            df_out[k0] = sf.vec_bounds(np.array(df_out[k]), (0, np.inf))
            df_out[k1] = sf.vec_bounds(np.array(df_out[k]), (-np.inf, 0))
            df_out.drop([k], axis = 1, inplace = True)
            flds = flds + [k0, k1]
            flds = [x for x in flds if x != k]
            
        else:
            df_out[k] = sf.vec_bounds(np.array(df_out[k]), bnds)

# %%
flds = [
    x for x in df_out.columns 
    if True
        & ("area_lndu" in x) 
        & ("conversion" not in x)
        & ("improved" not in x)
]

flds = [
    x for x in df_out.columns if x.startswith("emission_co2e_subsector")
]

df_out[
    df_out["primary_id"].isin([125125])
][
    ["time_period"] + flds
].plot(x = "time_period")
# Out:
# <AxesSubplot: xlabel='time_period'>

# %%
df_out["primary_id"].unique()
# Out:
# array([ 14014, 125125, 127127])

# %%
"totalvalue_enfu_fuel_consumed_entc_fuel_other" in df_out.columns
# Out:
# True

# %%
sisepuede.odpt_primary.get_indexing_dataframe(
    key_values = list(df_out[sisepuede.key_primary].unique())
)
# Out:
#    primary_id  design_id  strategy_id  future_id
# 0       14014          0         1014          0
# 1      125125          0         5007          0
# 2      127127          0         5009          0

# %%
# 3008, 3009, 303
strat_id, strat_id_intervention = 1014, 5009# 0, 5009
future_id, future_id_intervention = 0, 0#875
design_id = 0

# set dictionaries
dict_filt = {
    sisepuede.key_design: design_id,
    sisepuede.key_future: future_id,
    sisepuede.key_strategy: strat_id,
}
dict_filt_intervention = {
    sisepuede.key_design: design_id,
    sisepuede.key_future: future_id_intervention,
    sisepuede.key_strategy: strat_id_intervention,
}
# update if any are missing
for k, val in dict_filt.items():
    if k not in dict_filt.keys():
        dict_filt.update({k: val[0]})
    if k not in dict_filt_intervention.keys():
        dict_filt_intervention.update({k: val[0]})
        


primary_id = sisepuede.odpt_primary.get_key_value(**dict_filt)
df_filt = df_out[
    df_out[sisepuede.key_primary].isin([primary_id])
]
df_in_filt = sisepuede.generate_scenario_database_from_primary_key(primary_id)

        
        
primary_id_intervention = sisepuede.odpt_primary.get_key_value(**dict_filt_intervention)
df_filt_intervention = df_out[
    df_out[sisepuede.key_primary].isin([primary_id_intervention])
]
df_in_filt_intervention = sisepuede.generate_scenario_database_from_primary_key(primary_id_intervention)




############################
###                      ###
###    BEGIN PLOTTING    ###
###                      ###
############################

fig, ax = plt.subplots(2, 1, figsize = (15, 15))
#ax[0].set_ylim(-150, 350)
#ax[0].set_ylim(0, 900)
#ax[1].set_ylim(0, 900)

palette_func = plt.cm.tab20#plt.cm.hsv

flds = [sisepuede.key_time_period]
if False:
    flds += [
        x for x in df_filt.columns 
        if x.startswith("emission_co2e_subsector_total") 
        and (
            False
            or ("ccsq" in x) 
            or ("entc" in x)
            or ("enfu" in x)
            or ("fgtv" in x)
            or ("inen" in x)
            or ("scoe" in x)
            or ("trns" in x)
        )
    ]
    
if False:
    flds += [
        x for x in df_filt.columns 
        if x.startswith("emission_co2e_subsector_total") 
        and (
            #True
            ("agrc" in x)
            or ("frst" in x)
            or ("lndu" in x)
            or ("lsmm" in x)
            or ("lvst" in x)
            or ("soil" in x)
            #("entc" in x) 
            #or ("scoe" in x)
            #or ("lsmm" in x)
            #or ("soil" in x)
            #or ("frst" in x)
            #or ("lndu" in x)
        )
    ]
    
if False:
    flds = [x for x in flds if "trns" in x]
    
if True:
    flds += [
        x for x in df_filt.columns 
        if x.startswith("emission_co2e_") 
        and (
            True
            #and ("lvst" in x)
            #or ("fgtv" in x)
            #and ("subsector_total" not in x)
            and ("subsector_total" in x)
            and 
            (
                True
                #("lvst" in x)
                #or ("lsmm" in x)
                #or ("soil" in x)
            )
        )
    ]

if False:
    flds += [
        x for x in df_filt.columns 
        if x.startswith("energy_demand_enfu_") 
        and (
            True
            #("entc" in x)
            #or ("fgtv" in x)
            #("inen" in x)
            & ("subsector" in x)
            & ("electricity" in x)
        )
    ]

if False:
    #flds = [x for x in df_filt.columns if x.startswith("energy_demand_enfu") and ("total" in x) and ("subsector" not in x)]# and (("natural_gas" in x) or ("crude" in x) or ("electricity" in x) or ("hydrogen" in x))]
    cat = "rail_passenger"
    pre = "energy_consumption_trns"
    fld_ignore = f"{pre}_{cat}"
    flds = [sisepuede.key_time_period] + [x for x in df_filt.columns if x.startswith(pre) and (cat in x) and (x != fld_ignore)]
    #flds = [x for x in df_filt.columns if x.startswith("passenger_distance")]

add_total = True
plot_from_modvar = False

if True:

    # AFOLU
    modvar_plot = sisepuede.models.model_afolu.modvar_lndu_area_by_cat
    #modvar_plot = sisepuede.models.model_afolu.modvar_lndu_area_converted_from_type
    #modvar_plot = sisepuede.models.model_afolu.modvar_lndu_area_by_cat
    #modvar_plot = sisepuede.models.model_afolu.modvar_soil_emissions_co2_urea
    #modvar_plot = sisepuede.models.model_afolu.modvar_lvst_pop
    #modvar_plot = sisepuede.models.model_afolu.modvar_lvst_adjusted_equivalent_exports

    #modvar_plot = sisepuede.models.model_afolu.modvar_frst_emissions_co2_sequestration
    #modvar_plot = sisepuede.models.model_afolu.modvar_lndu_emissions_conv
    #modvar_plot = sisepuede.models.model_afolu.modvar_lvst_emissions_ch4_ef
    #modvar_plot = sisepuede.models.model_afolu.modvar_lsmm_emissions_ch4
    
    
    # ENERGY
    #modvar_plot = sisepuede.models.model_electricity.modvar_entc_nemomod_emissions_co2_mne
    #modvar_plot = sisepuede.models.model_electricity.modvar_entc_nemomod_production_by_technology
    #modvar_plot = sisepuede.models.model_energy.modvar_trns_energy_consumption_total
    #modvar_plot = sisepuede.models.model_energy.modvar_trns_passenger_distance_traveled
    #modvar_plot = sisepuede.models.model_energy.modvar_trns_passenger_distance_traveled
    #modvar_plot = sisepuede.models.model_energy.modvar_trde_demand_pkm
    #modvar_plot = sisepuede.models.model_energy.modvar_trns_mass_distance_traveled
    #modvar_plot = sisepuede.models.model_energy.modvar_fgtv_emissions_ch4
    #modvar_plot = sisepuede.models.model_energy.modvar_enfu_exports_fuel_adjusted
    #modvar_plot = sisepuede.models.model_energy.modvar_enfu_energy_demand_by_fuel_total
    #modvar_plot = sisepuede.models.model_energy.modvar_enfu_energy_demand_by_fuel_trns
    #modvar_plot = sisepuede.models.model_electricity.modvar_entc_nemomod_production_by_technology
    #modvar_plot = sisepuede.models.model_energy.modvar_fgtv_emissions_ch4
    #modvar_plot = sisepuede.models.model_energy.modvar_trns_vehicle_distance_traveled_electricity
    
    #IPPU
    #modvar_plot = sisepuede.models.model_ippu.modvar_ippu_qty_total_production
    
    
    
    # NO INTERVENTION
    
    df = sisepuede.model_attributes.extract_model_variable(
        df_filt,
        modvar_plot
    )
    df = pd.concat([df_filt[[sisepuede.key_time_period]].reset_index(drop = True), df], axis = 1)
    df = df[[x for x in df.columns if ("nuclear" not in x) and ("crude" not in x)]]
    df = df_filt[flds] if (not plot_from_modvar) else df
    if len(df) > 0:
        for k in df.columns:
            vec = np.array(df[k])
            bnds = (0, np.inf) if (vec[-1] >= 0) else (-np.inf, 0)
            if (max(vec) > 0) and (min(vec) < 0):
                k0 = f"{k}_positive"
                k1 = f"{k}_negative"
                df[k0] = sf.vec_bounds(np.array(df[k]), (0, np.inf))
                df[k1] = sf.vec_bounds(np.array(df[k]), (-np.inf, 0))
                df.drop([k], axis = 1, inplace = True)
            else:
                df[k] = sf.vec_bounds(np.array(df[k]), bnds)
    
    m, n = df.shape
    colors = [palette_func(x/n) for x in range(n)]
    
    alpha = 1 if not add_total else 0.75
    df.plot.area(x = sisepuede.key_time_period, ax = ax[0], color = colors, alpha = alpha)
    if add_total:
        df["total"] = df.drop([sisepuede.key_time_period], axis = 1).sum(axis = 1)
        df[[sisepuede.key_time_period, "total"]].plot(x = sisepuede.key_time_period, ax = ax[0], color = "black", linewidth = 5)
    df_plot_noint = df.copy()
        
        
    # INTERVENTION
    
    df = sisepuede.model_attributes.extract_model_variable(
        df_filt_intervention,
        modvar_plot
    )
    df = pd.concat([df_filt_intervention[[sisepuede.key_time_period]].reset_index(drop = True), df], axis = 1)
    df = df[[x for x in df.columns if ("nuclear" not in x) and ("crude" not in x)]]
    df = df_filt_intervention[flds] if (not plot_from_modvar) else df
    
    if False:
        # UNCOMMENT TO USE DIFF
        vec = np.array(df[sisepuede.key_time_period])
        flds = [x for x in df.columns if (x != sisepuede.key_time_period)]
        df = pd.DataFrame(np.array(df_filt_intervention[flds]) - np.array(df_filt[flds]), columns = flds)
        df[sisepuede.key_time_period] = vec

    
    
    for k in df.columns:
        vec = np.array(df[k])
        bnds = (0, np.inf) if (vec[-1] >= 0) else (-np.inf, 0)
        if (max(vec) > 0) and (min(vec) < 0):
            k0 = f"{k}_positive"
            k1 = f"{k}_negative"
            df[k0] = sf.vec_bounds(np.array(df[k]), (0, np.inf))
            df[k1] = sf.vec_bounds(np.array(df[k]), (-np.inf, 0))
            df.drop([k], axis = 1, inplace = True)
        else:
            df[k] = sf.vec_bounds(np.array(df[k]), bnds)
    
    m, n = df.shape
    colors = [palette_func(x/n) for x in range(n)]
    
    alpha = 1 if not add_total else 0.75
    df.plot.area(x = sisepuede.key_time_period, ax = ax[1], color = colors, alpha = alpha)
    if add_total:
        df["total"] = df.drop([sisepuede.key_time_period], axis = 1).sum(axis = 1)
        df[[sisepuede.key_time_period, "total"]].plot(x = sisepuede.key_time_period, ax = ax[1], color = "black", linewidth = 5)
    df_plot_int = df.copy()
    #df.plot(ax = ax[1], color = colors)

# %% [markdown]
# ##  Export Output

# %%
all_primaries = sorted(list(df_out[sisepuede.key_primary].unique()))
region = "india" 
df_in = []

for primary in all_primaries: 
    df_in_filt = sisepuede.generate_scenario_database_from_primary_key(primary)
    df_in.append(df_in_filt.get(region))

df_in = pd.concat(df_in, axis = 0).reset_index(drop = True)


df_export = pd.merge(
    df_out,
    df_in,
    how = "left",
)





# check output directory 
dir_pkg = os.path.join(sisepuede.file_struct.dir_out, f"sisepuede_summary_results_run_{sisepuede.id_fs_safe}")
os.makedirs(dir_pkg) if not os.path.exists(dir_pkg) else None

for tab in ["ATTRIBUTE_STRATEGY"]:
    sisepuede.database.db.read_table(tab).to_csv(
        os.path.join(dir_pkg, f"{tab}.csv"),
        index = None,
        encoding = "UTF-8"
    )


df_primary = sisepuede.odpt_primary.get_indexing_dataframe(sorted(list(df_out[sisepuede.key_primary].unique())))
df_primary.to_csv(
    os.path.join(dir_pkg, f"ATTRIBUTE_PRIMARY.csv"),
    index = None,
    encoding = "UTF-8"
)

df_export.to_csv(
    os.path.join(dir_pkg, f"sisepuede_results_{sisepuede.id_fs_safe}_WIDE_INPUTS_OUTPUTS.csv"),
    index = None,
    encoding = "UTF-8"
)

# %% [markdown]
# ######

# %%
#127127

# %%
attr = sisepuede.model_attributes.get_dimensional_attribute_table("strategy_id")
attr.table
# Out:
#      strategy_id                                           strategy  \
# 0              0                                       Baseline NDP
# 1           1001                          AGRC: All transformations
# 2           1002  AGRC: All transformations with partial land us...
# 3           1003                             AGRC: Decrease Exports
# 4           1004              AGRC: Expand conservation agriculture
# ..           ...                                                ...
# 144         5025                                PFLO:Placeholder 10
# 145         6001  LNDU: Partial land use reallocation with India...
# 146         6002                                   LNDU: India CCDR
# 147         6003  PFLO: India CCDR and India Climate Change Impacts
# 148         6004  PFLO: All transformations with partial land us...
#
#                          strategy_code  baseline_strategy_id  \
# 0                                 BASE                     1
# 1                             AGRC:ALL                     0
# 2                        AGRC:ALL_PLUR                     0
# 3                     AGRC:DEC_EXPORTS                     0
# 4    AGRC:INC_CONSERVATION_AGRICULTURE                     0
# ..                                 ...                   ...
# 144                PFLO:PLACEHOLDER_10                     0
# 145                 LNDU:PLUR_INDIA_CC                     0
# 146               PFLO:INDIA_CCDR_PLUR                     0
# 147      PFLO:INDIA_CCDR_PLUR_INDIA_CC                     0
# 148             PFLO:ALL_PLUR_INDIA_CC                     0
#
#                                            description
# 0    Base assumptions to which all transformations ...
# 1                     All agricultural transformations
# 2                     All agricultural transformations
# 3    Decrease agricultural exports by 50% (relative...
# 4     | Decrease soil organic carbon loss in cropla...
# ..                                                 ...
# 144                                        placeholder
# 145  Set land use reallocation factor to 0.5 + Indi...
# 146      India CCDR with partial land use reallocation
# 147  India CCDR with partial land use reallocation ...
# 148  All transformations with partial land use real...
#
# [149 rows x 5 columns]

# %%
df_out2 = df_out.copy()
df_out2["emission_net"] = df_out[
    [
        x for x in df_out2.columns if x.startswith("emission_co2e_subsector_total") and 
        not (
            ("agrc" in x)
            | ("frst" in x)
            | ("lndu" in x)
            | ("lsmm" in x)
            | ("lvst" in x)
            | ("soil" in x)
            | ("trww" in x)
            | ("waso" in x)
        )
    ]
].sum(axis = 1)

df_out2[
    df_out2["time_period"].isin([55])
][["primary_id", "emission_net"]]
# Out:
#      primary_id  emission_net
# 55            0  40214.375888
# 111       15015  40264.384793
# 167      128128   3803.189006
# 223      145145  40254.306723
# 279      146146   3106.451220
# 335      147147   3803.392910
# 391      148148   3803.189006

# %%
df_in[
    df_in["time_period"].isin([55])
][["primary_id"] + [x for x in df_in.columns if ("pij_lndu" in x) and ("to_forests_secondary" in x)]]

df_out[
    df_out["time_period"].isin([55])
][["primary_id"] + [x for x in df_out.columns if ("area_lndu" in x) and ("conversion" not in x)]]
# Out:
#      primary_id  area_lndu_croplands  area_lndu_forests_mangroves  \
# 55            0         2.190563e+08                408034.014776
# 111       15015         1.917691e+08                388288.635201
# 167      128128         1.295011e+08                940002.951584
# 223      145145         2.145855e+08                142133.073929
# 279      146146         1.298366e+08                732739.861903
# 335      147147         1.463751e+08                718290.243514
# 391      148148         1.295011e+08                940002.951584
#
#      area_lndu_forests_primary  area_lndu_forests_secondary  \
# 55                4.330919e+07                 1.077599e+07
# 111               4.333450e+07                 1.379003e+07
# 167               4.406678e+07                 8.992782e+07
# 223               4.297631e+07                 1.110249e+07
# 279               4.348851e+07                 2.468455e+07
# 335               4.348837e+07                 2.220797e+07
# 391               4.406678e+07                 8.992782e+07
#
#      area_lndu_grasslands  area_lndu_improved_croplands  \
# 55           3.662490e+07                  1.244177e+06
# 111          6.120232e+07                  1.033634e+06
# 167          5.041479e+07                  7.485206e+07
# 223          5.257869e+07                  1.150501e+06
# 279          6.244391e+07                  7.497848e+07
# 335          6.239727e+07                  8.461878e+07
# 391          5.041479e+07                  7.485206e+07
#
#      area_lndu_improved_grasslands  area_lndu_other  area_lndu_settlements  \
# 55                    1.086187e+06     8.626576e+06           3.120415e+06
# 111                   1.815081e+06     6.381355e+06           3.161770e+06
# 167                   2.889956e+06     4.939666e+06           3.003835e+06
# 223                   1.559329e+06     1.983809e+06           3.052113e+06
# 279                   1.851903e+06     2.738185e+07           3.289982e+06
# 335                   1.850520e+06     2.176591e+07           3.287818e+06
# 391                   2.889956e+06     4.939666e+06           3.003835e+06
#
#      area_lndu_wetlands
# 55         6.804617e+06
# 111        8.698652e+06
# 167        5.931978e+06
# 223        2.304920e+06
# 279        3.686783e+07
# 335        2.848524e+07
# 391        5.931978e+06

# %%
df_out[
    df_out["time_period"].isin([55])
    & df_out["primary_id"].isin([128128, 146146])
][["primary_id", "emission_co2e_subsector_total_lndu"]]
# Out:
#      primary_id  emission_co2e_subsector_total_lndu
# 167      128128                           16.281109
# 279      146146                          103.069201

# %%
fields_show = ["emission_co2e_ch4_trww_treated_septic_treatment"]
fields_show = [x for x in df_out.columns if ("aerobic" in x) & ("trww" in x) & ("ch4" in x)]
fields_show = [x for x in df_out.columns if ("biogas" in x) & ("gasrecovered" in x)]

df_out[
    df_out[sisepuede.key_time_period].isin([30, 55])
    # df_out[sisepuede.key_primary].isin([14014])
][
    [
        sisepuede.key_primary,
        sisepuede.key_time_period
    ] + fields_show
]
# Out:
#      primary_id  time_period  \
# 30        14014           30
# 55        14014           55
# 86       125125           30
# 111      125125           55
# 142      127127           30
# 167      127127           55
#
#      gasrecovered_lsmm_biogass_anaerobic_digester_tonne  \
# 30                                        2.254492e+05
# 55                                        2.793731e+05
# 86                                        1.366658e+07
# 111                                       4.921871e+07
# 142                                       1.366475e+07
# 167                                       4.921380e+07
#
#      gasrecovered_trww_biogas_tonne  gasrecovered_waso_biogas_anaerobic_tonne  \
# 30                     0.000000e+00                              6.091981e+05
# 55                     0.000000e+00                              6.813399e+05
# 86                     4.237610e+07                              4.126837e+06
# 111                    3.079372e+08                              7.734657e+06
# 142                    4.237610e+07                              4.126837e+06
# 167                    3.079372e+08                              7.734657e+06
#
#      gasrecovered_waso_biogas_landfills_tonne
# 30                               0.000000e+00
# 55                               0.000000e+00
# 86                               7.819183e+07
# 111                              4.085389e+08
# 142                              7.819183e+07
# 167                              4.085389e+08

# %%
(
    pd.DataFrame(
        df_out[[x for x in df_out.columns if ("emission_co2e_ch4" in x)]].iloc[55]
    )
    .sort_values(by = [55], ascending = False)
    .iloc[0:25]
)
# Out:
#                                                              55
# emission_co2e_ch4_fgtv_fuel_coal                    3011.662475
# emission_co2e_ch4_waso_open_dump_chemical_indus...   543.264980
# emission_co2e_ch4_trww_untreated_no_sewerage_tr...   293.537161
# emission_co2e_ch4_lvst_entferm_cattle_dairy          290.279579
# emission_co2e_ch4_waso_open_dump_food                268.112914
# emission_co2e_ch4_lvst_entferm_buffalo               266.042279
# emission_co2e_ch4_lvst_entferm_cattle_nondairy       195.673535
# emission_co2e_ch4_fgtv_fuel_natural_gas              155.153632
# emission_co2e_ch4_agrc_anaerobicdom_rice              90.185943
# emission_co2e_ch4_trww_treated_secondary_anaero...    56.654791
# emission_co2e_ch4_lsmm_liquid_slurry                  48.817354
# emission_co2e_ch4_fgtv_fuel_oil                       43.901301
# emission_co2e_ch4_waso_open_dump_paper                36.346304
# emission_co2e_ch4_lvst_entferm_goats                  34.399062
# emission_co2e_ch4_trns_road_light                     32.956525
# emission_co2e_ch4_lndu_wetlands                       21.720970
# emission_co2e_ch4_inen_other_product_manufacturing    18.953931
# emission_co2e_ch4_lsmm_anaerobic_lagoon               18.672539
# emission_co2e_ch4_lvst_entferm_sheep                  16.692954
# emission_co2e_ch4_trww_treated_latrine_improved...    11.039048
# emission_co2e_ch4_waso_incineration                    9.602760
# emission_co2e_ch4_ippu_production_chemicals            9.215134
# emission_co2e_ch4_ippu_production_plastic              9.042047
# emission_co2e_ch4_trns_road_heavy_freight              6.501553
# emission_co2e_ch4_trww_treated_septic_treatment        6.023147

# %%
fields_show = ["emission_co2e_ch4_trww_treated_septic_treatment"]
fields_show = [x for x in df_out.columns if ("aerobic" in x) & ("trww" in x) & ("ch4" in x)]

df_out[
    df_out[sisepuede.key_time_period].isin([30, 55])
    # df_out[sisepuede.key_primary].isin([14014])
][
    [
        sisepuede.key_primary,
        sisepuede.key_time_period
    ] + fields_show
]
# Out:
#      primary_id  time_period  \
# 30        14014           30
# 55        14014           55
# 86       125125           30
# 111      125125           55
# 142      127127           30
# 167      127127           55
#
#      emission_co2e_ch4_trww_treated_advanced_aerobic_treatment  \
# 30                                            0.000553
# 55                                            0.000932
# 86                                            0.089262
# 111                                           0.051700
# 142                                           0.089262
# 167                                           0.051700
#
#      emission_co2e_ch4_trww_treated_advanced_anaerobic_treatment  \
# 30                                            0.110616
# 55                                            0.186364
# 86                                           37.714248
# 111                                          25.330606
# 142                                          37.714248
# 167                                          25.330606
#
#      emission_co2e_ch4_trww_treated_secondary_aerobic_treatment  \
# 30                                            0.252205
# 55                                            0.424911
# 86                                            0.191767
# 111                                           0.065754
# 142                                           0.191767
# 167                                           0.065754
#
#      emission_co2e_ch4_trww_treated_secondary_anaerobic_treatment
# 30                                           33.627295
# 55                                           56.654791
# 86                                           25.568878
# 111                                           8.767185
# 142                                          25.568878
# 167                                           8.767185

# %%
df_out[
    df_out[sisepuede.key_time_period].isin([30, 55])
    # df_out[sisepuede.key_primary].isin([14014])
][
    [
        sisepuede.key_primary,
        sisepuede.key_time_period,
        "emission_co2e_subsector_total_waso"
    ]
]
# Out:
#      primary_id  time_period  emission_co2e_subsector_total_waso
# 30        14014           30                          719.136109
# 55        14014           55                         1241.724910
# 86       125125           30                          454.798159
# 111      125125           55                          253.280416
# 142      127127           30                          454.798159
# 167      127127           55                          253.280416
