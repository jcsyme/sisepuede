# %% [markdown]
# # Work with transformations in a notebook

# %%
import importlib # needed so that we can reload packages
import matplotlib.pyplot as plt
import os, os.path
import numpy as np
import pandas as pd
import pathlib
import sys
import time
from typing import Union
import warnings
warnings.filterwarnings("ignore")

# add SISEPUEDE to path
dir_py = pathlib.Path(os.path.realpath(".")).parents[0].joinpath("python")
if str(dir_py) not in sys.path:
    sys.path.append(str(dir_py))

# import the define_transformations objects
import define_transformations_afolu as dta
import define_transformations_circular_economy as dtc
import define_transformations_energy as dte
import define_transformations_ippu as dti
import define_transformations_integrated as dtr

# get other SISEPUEDE objects
import sisepuede as ssp
import sisepuede_file_structure as sfs
import sisepuede_models as sm
import support_classes as sc
import support_functions as sf

#import transformations_base_afolu as tba
#mport transformations_base_circular_economy as tbc
#import transformations_base_energy as tbe
#import transformations_base_general as tbg
#import transformations_base_ippu as tbi

# %% [markdown]
# ##  Initialize the SISEPUEDE class to get data from existing templates
# - see ``?SISEPUEDE`` for more information on initialization arguments
# - You can initialize as a dummy to avoid marginal setup time for Julia, but we may want to run with it at some point

# %%
sisepuede = ssp.SISEPUEDE(
    "calibrated",
    initialize_as_dummy = False, # no connection to Julia is initialized if set to True
    regions = ["peru"],
    try_exogenous_xl_types_in_variable_specification = True,
)
# Out:
# 2024-05-17 11:44:46,464 - INFO - Successfully initialized SISEPUEDEFileStructure.
# 2024-05-17 11:44:46,464 - INFO - Successfully initialized SISEPUEDEFileStructure.
# 2024-05-17 11:44:46,468 - WARNING - Missing key dict_dimensional_keys: key time_series not found. Tables that rely on the time_series will not have index checking.
# 2024-05-17 11:44:46,468 - WARNING - Missing key dict_dimensional_keys: key time_series not found. Tables that rely on the time_series will not have index checking.
# 2024-05-17 11:44:46,469 - INFO - 	Setting export engine to 'sqlite'.
# 2024-05-17 11:44:46,469 - INFO - 	Setting export engine to 'sqlite'.
# 2024-05-17 11:44:46,472 - WARNING - No index fields defined. Index field values will not be checked when writing to tables.
# 2024-05-17 11:44:46,472 - WARNING - No index fields defined. Index field values will not be checked when writing to tables.
# 2024-05-17 11:44:46,473 - INFO - Successfully instantiated table ANALYSIS_METADATA
# 2024-05-17 11:44:46,473 - INFO - Successfully instantiated table ANALYSIS_METADATA
# 2024-05-17 11:44:46,475 - WARNING - No index fields found in ATTRIBUTE_DESIGN. Initializing index fields.
# 2024-05-17 11:44:46,475 - WARNING - No index fields found in ATTRIBUTE_DESIGN. Initializing index fields.
# 2024-05-17 11:44:46,475 - INFO - Successfully instantiated table ATTRIBUTE_DESIGN
# 2024-05-17 11:44:46,475 - INFO - Successfully instantiated table ATTRIBUTE_DESIGN
# 2024-05-17 11:44:46,477 - WARNING - No index fields found in ATTRIBUTE_LHC_SAMPLES_EXOGENOUS_UNCERTAINTIES. Initializing index fields.
# 2024-05-17 11:44:46,477 - WARNING - No index fields found in ATTRIBUTE_LHC_SAMPLES_EXOGENOUS_UNCERTAINTIES. Initializing index fields.
# 2024-05-17 11:44:46,478 - INFO - Successfully instantiated table ATTRIBUTE_LHC_SAMPLES_EXOGENOUS_UNCERTAINTIES
# 2024-05-17 11:44:46,478 - INFO - Successfully instantiated table ATTRIBUTE_LHC_SAMPLES_EXOGENOUS_UNCERTAINTIES
# 2024-05-17 11:44:46,479 - WARNING - No index fields found in ATTRIBUTE_LHC_SAMPLES_LEVER_EFFECTS. Initializing index fields.
# 2024-05-17 11:44:46,479 - WARNING - No index fields found in ATTRIBUTE_LHC_SAMPLES_LEVER_EFFECTS. Initializing index fields.
# 2024-05-17 11:44:46,481 - INFO - Successfully instantiated table ATTRIBUTE_LHC_SAMPLES_LEVER_EFFECTS
# 2024-05-17 11:44:46,481 - INFO - Successfully instantiated table ATTRIBUTE_LHC_SAMPLES_LEVER_EFFECTS
# MISSIONSEARCHNOTE: As of 2023-10-06, there is a temporary solution implemeted in ModelAttributes.get_variable_to_simplex_group_dictionary() to ensure that transition probability rows are enforced on a simplex.
#
# FIX THIS ASAP TO DERIVE PROPERLY.
# 2024-05-17 11:44:46,482 - WARNING - No index fields found in ATTRIBUTE_PRIMARY. Initializing index fields.
# 2024-05-17 11:44:46,482 - WARNING - No index fields found in ATTRIBUTE_PRIMARY. Initializing index fields.
# 2024-05-17 11:44:46,484 - INFO - Successfully instantiated table ATTRIBUTE_PRIMARY
# 2024-05-17 11:44:46,484 - INFO - Successfully instantiated table ATTRIBUTE_PRIMARY
# 2024-05-17 11:44:46,485 - WARNING - No index fields found in ATTRIBUTE_STRATEGY. Initializing index fields.
# 2024-05-17 11:44:46,485 - WARNING - No index fields found in ATTRIBUTE_STRATEGY. Initializing index fields.
# 2024-05-17 11:44:46,487 - INFO - Successfully instantiated table ATTRIBUTE_STRATEGY
# 2024-05-17 11:44:46,487 - INFO - Successfully instantiated table ATTRIBUTE_STRATEGY
# 2024-05-17 11:44:46,488 - WARNING - No index fields found in MODEL_BASE_INPUT_DATABASE. Initializing index fields.
# 2024-05-17 11:44:46,488 - WARNING - No index fields found in MODEL_BASE_INPUT_DATABASE. Initializing index fields.
# 2024-05-17 11:44:46,489 - INFO - Successfully instantiated table MODEL_BASE_INPUT_DATABASE
# 2024-05-17 11:44:46,489 - INFO - Successfully instantiated table MODEL_BASE_INPUT_DATABASE
# 2024-05-17 11:44:46,490 - WARNING - No index fields found in MODEL_INPUT. Initializing index fields.
# 2024-05-17 11:44:46,490 - WARNING - No index fields found in MODEL_INPUT. Initializing index fields.
# 2024-05-17 11:44:46,491 - INFO - Successfully instantiated table MODEL_INPUT
# 2024-05-17 11:44:46,491 - INFO - Successfully instantiated table MODEL_INPUT
# 2024-05-17 11:44:46,493 - WARNING - No index fields found in MODEL_OUTPUT. Initializing index fields.
# 2024-05-17 11:44:46,493 - WARNING - No index fields found in MODEL_OUTPUT. Initializing index fields.
# 2024-05-17 11:44:46,494 - INFO - Successfully instantiated table MODEL_OUTPUT
# 2024-05-17 11:44:46,494 - INFO - Successfully instantiated table MODEL_OUTPUT
# 2024-05-17 11:44:46,495 - INFO - SISEPUEDEOutputDatabase successfully initialized IterativeDatabase.
# 2024-05-17 11:44:46,495 - INFO - SISEPUEDEOutputDatabase successfully initialized IterativeDatabase.
# 2024-05-17 11:44:46,497 - INFO - Successfully initialized database with:
# 	type:	sqlite
# 	analysis id:	sisepuede_run_2024-05-17T11:44:45.480237
# 	fp_base_output:	/Users/jsyme/Documents/Projects/git_jbus/sisepuede/out/sisepuede_run_2024-05-17T11;44;45.480237/sisepuede_run_2024-05-17T11;44;45.480237_output_database
# 2024-05-17 11:44:46,497 - INFO - Successfully initialized database with:
# 	type:	sqlite
# 	analysis id:	sisepuede_run_2024-05-17T11:44:45.480237
# 	fp_base_output:	/Users/jsyme/Documents/Projects/git_jbus/sisepuede/out/sisepuede_run_2024-05-17T11;44;45.480237/sisepuede_run_2024-05-17T11;44;45.480237_output_database
# 2024-05-17 11:44:46,498 - INFO - Running SISEPUEDE under template data mode 'calibrated'.
# 2024-05-17 11:44:46,498 - INFO - Running SISEPUEDE under template data mode 'calibrated'.
# 2024-05-17 11:44:46,499 - INFO - Initializing BaseInputDatabase
# 2024-05-17 11:44:46,499 - INFO - Initializing BaseInputDatabase
# 2024-05-17 11:44:48,234 - INFO - Initializing FutureTrajectories
# 2024-05-17 11:44:48,234 - INFO - Initializing FutureTrajectories
# 2024-05-17 11:44:55,268 - INFO - Instantiating 1392 sampling units.
# 2024-05-17 11:44:55,268 - INFO - Instantiating 1392 sampling units.
# 2024-05-17 11:44:55,342 - INFO - Iteration 0 complete.
# 2024-05-17 11:44:55,342 - INFO - Iteration 0 complete.
# 2024-05-17 11:45:10,252 - INFO - Iteration 250 complete.
# 2024-05-17 11:45:10,252 - INFO - Iteration 250 complete.
# 2024-05-17 11:45:17,063 - INFO - Iteration 500 complete.
# 2024-05-17 11:45:17,063 - INFO - Iteration 500 complete.
# 2024-05-17 11:45:23,596 - INFO - Iteration 750 complete.
# 2024-05-17 11:45:23,596 - INFO - Iteration 750 complete.
# 2024-05-17 11:45:30,681 - INFO - Iteration 1000 complete.
# 2024-05-17 11:45:30,681 - INFO - Iteration 1000 complete.
# 2024-05-17 11:45:37,641 - INFO - Iteration 1250 complete.
# 2024-05-17 11:45:37,641 - INFO - Iteration 1250 complete.
# 2024-05-17 11:45:41,420 - INFO - 	1392 sampling units complete in 46.15 seconds.
# 2024-05-17 11:45:41,420 - INFO - 	1392 sampling units complete in 46.15 seconds.
# 2024-05-17 11:45:41,428 - INFO - 	FutureTrajectories for 'peru' complete.
# 2024-05-17 11:45:41,428 - INFO - 	FutureTrajectories for 'peru' complete.
# 2024-05-17 11:45:41,430 - INFO - Initializing LHSDesign
# 2024-05-17 11:45:41,430 - INFO - Initializing LHSDesign
# 2024-05-17 11:45:41,431 - INFO - LHSDesign.fields_factors_l reset successful.
# 2024-05-17 11:45:41,431 - INFO - LHSDesign.fields_factors_l reset successful.
# 2024-05-17 11:45:41,432 - INFO - LHSDesign.fields_factors_x reset successful.
# 2024-05-17 11:45:41,432 - INFO - LHSDesign.fields_factors_x reset successful.
# 2024-05-17 11:45:41,456 - INFO - 	LHSDesign for region 'peru' complete.
# 2024-05-17 11:45:41,456 - INFO - 	LHSDesign for region 'peru' complete.
# 2024-05-17 11:45:41,457 - INFO - Generating primary keys (values of primary_id)...
# 2024-05-17 11:45:41,457 - INFO - Generating primary keys (values of primary_id)...
# 2024-05-17 11:45:41,459 - INFO - Successfully initialized SISEPUEDEExperimentalManager.
# 2024-05-17 11:45:41,459 - INFO - Successfully initialized SISEPUEDEExperimentalManager.
# 2024-05-17 11:45:41,463 - INFO - Successfully initialized NemoMod temporary database path as /Users/jsyme/Documents/Projects/git_jbus/sisepuede/tmp/nemomod_intermediate_database.sqlite.
# 2024-05-17 11:45:41,463 - INFO - Successfully initialized NemoMod temporary database path as /Users/jsyme/Documents/Projects/git_jbus/sisepuede/tmp/nemomod_intermediate_database.sqlite.
# 2024-05-17 11:45:41,464 - INFO - Set Julia directory for modules and environment to '/Users/jsyme/Documents/Projects/git_jbus/sisepuede/julia'.
# 2024-05-17 11:45:41,464 - INFO - Set Julia directory for modules and environment to '/Users/jsyme/Documents/Projects/git_jbus/sisepuede/julia'.
# 2024-05-17 11:45:41,621 - INFO - Successfully read NemoMod input table data from /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/nemo_mod/CapacityFactor.csv
# 2024-05-17 11:45:41,621 - INFO - Successfully read NemoMod input table data from /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/nemo_mod/CapacityFactor.csv
# 2024-05-17 11:45:41,630 - INFO - Successfully read NemoMod input table data from /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/nemo_mod/SpecifiedDemandProfile.csv
# 2024-05-17 11:45:41,630 - INFO - Successfully read NemoMod input table data from /Users/jsyme/Documents/Projects/git_jbus/sisepuede/ref/nemo_mod/SpecifiedDemandProfile.csv
# 2024-05-17 11:45:41,764 - INFO - Calling Julia API...
# 2024-05-17 11:45:41,764 - INFO - Calling Julia API...
# 2024-05-17 11:46:05,620 - DEBUG - 	Successfully activated Julia with compiled_modules = False
# 2024-05-17 11:46:05,620 - DEBUG - 	Successfully activated Julia with compiled_modules = False
# 2024-05-17 11:46:05,626 - DEBUG - 	Successfully imported julia.Base
# 2024-05-17 11:46:05,626 - DEBUG - 	Successfully imported julia.Base
# 2024-05-17 11:46:05,627 - DEBUG - 	Successfully imported julia.Main
# 2024-05-17 11:46:05,627 - DEBUG - 	Successfully imported julia.Main
# 2024-05-17 11:46:05,732 - DEBUG - 	Successfully imported julia.Pkg
# 2024-05-17 11:46:05,732 - DEBUG - 	Successfully imported julia.Pkg
# 2024-05-17 11:46:06,382 - DEBUG - 	Available Packages:
# 		'GLPK'
# 		 'HiGHS'
# 		 'CxxWrap'
# 		 'Graphs'
# 		 'IterativeHeaps'
# 		 'ExcelReaders'
# 		 'Juniper'
# 		 'FLoops'
# 		 'DataStructures'
# 		 'GeoInterfaceRecipes'
# 		 'DataFrames'
# 		 'PlotlyJS'
# 		 'MLJ'
# 		 'QuickHeaps'
# 		 'Distributions'
# 		 'SQLite'
# 		 'Clp'
# 		 'Karnak'
# 		 'TimerOutputs'
# 		 'LatinHypercubeSampling'
# 		 'ScikitLearn'
# 		 'LazySets'
# 		 'Metal'
# 		 'SCIP'
# 		 'GLMakie'
# 		 'DistributedArrays'
# 		 'Gurobi'
# 		 'AlphaVantage'
# 		 'CSV'
# 		 'Revise'
# 		 'StructArrays'
# 		 'Random'
# 		 'BenchmarkTools'
# 		 'Suppressor'
# 		 'Conda'
# 		 'Shapefile'
# 		 'Symbolics'
# 		 'PyCall'
# 		 'StatsBase'
# 		 'IJulia'
# 		 'Flux'
# 		 'Plots'
# 		 'GeoInterface'
# 		 'XLSX'
# 		 'Cbc'
# 		 'MathOptInterface'
# 		 'GLM'
# 		 'CUDA'
# 		 'Statistics'
# 		 'LightGraphs'
# 		 'HypothesisTests'
# 		 'JuMP'
# 		 'NetworkLayout'
# 		 'Ipopt'
# 		 'LaTeXStrings'
# 		 'SharedArrays'
# 		 'CairoMakie'
# 		 'StaticGraphs'
# 		 'MultivariateStats'
# 		 'DecisionTree'
# 		 'GraphMakie'
# 		 'WebIO'
# 		 'AbstractTrees'
# 		 'Cxx'
# 2024-05-17 11:46:06,382 - DEBUG - 	Available Packages:
# 		'GLPK'
# 		 'HiGHS'
# 		 'CxxWrap'
# 		 'Graphs'
# 		 'IterativeHeaps'
# 		 'ExcelReaders'
# 		 'Juniper'
# 		 'FLoops'
# 		 'DataStructures'
# 		 'GeoInterfaceRecipes'
# 		 'DataFrames'
# 		 'PlotlyJS'
# 		 'MLJ'
# 		 'QuickHeaps'
# 		 'Distributions'
# 		 'SQLite'
# 		 'Clp'
# 		 'Karnak'
# 		 'TimerOutputs'
# 		 'LatinHypercubeSampling'
# 		 'ScikitLearn'
# 		 'LazySets'
# 		 'Metal'
# 		 'SCIP'
# 		 'GLMakie'
# 		 'DistributedArrays'
# 		 'Gurobi'
# 		 'AlphaVantage'
# 		 'CSV'
# 		 'Revise'
# 		 'StructArrays'
# 		 'Random'
# 		 'BenchmarkTools'
# 		 'Suppressor'
# 		 'Conda'
# 		 'Shapefile'
# 		 'Symbolics'
# 		 'PyCall'
# 		 'StatsBase'
# 		 'IJulia'
# 		 'Flux'
# 		 'Plots'
# 		 'GeoInterface'
# 		 'XLSX'
# 		 'Cbc'
# 		 'MathOptInterface'
# 		 'GLM'
# 		 'CUDA'
# 		 'Statistics'
# 		 'LightGraphs'
# 		 'HypothesisTests'
# 		 'JuMP'
# 		 'NetworkLayout'
# 		 'Ipopt'
# 		 'LaTeXStrings'
# 		 'SharedArrays'
# 		 'CairoMakie'
# 		 'StaticGraphs'
# 		 'MultivariateStats'
# 		 'DecisionTree'
# 		 'GraphMakie'
# 		 'WebIO'
# 		 'AbstractTrees'
# 		 'Cxx'
# 2024-05-17 11:46:07,063 - INFO - Successfully activated Julia environment at '/Users/jsyme/Documents/Projects/git_jbus/sisepuede/julia'
#   Activating project at `~/Documents/Projects/git_jbus/sisepuede/julia`
# 2024-05-17 11:46:07,063 - INFO - Successfully activated Julia environment at '/Users/jsyme/Documents/Projects/git_jbus/sisepuede/julia'
# 2024-05-17 11:47:29,113 - INFO - Successfully initialized JuMP optimizer from solver module HiGHS.
# 2024-05-17 11:47:29,113 - INFO - Successfully initialized JuMP optimizer from solver module HiGHS.
# 2024-05-17 11:47:29,159 - INFO - Successfully initialized SISEPUEDEModels.
# 2024-05-17 11:47:29,159 - INFO - Successfully initialized SISEPUEDEModels.
# 2024-05-17 11:47:29,186 - INFO - Table ANALYSIS_METADATA successfully written to database.
# 2024-05-17 11:47:29,186 - INFO - Table ANALYSIS_METADATA successfully written to database.
# 2024-05-17 11:47:29,199 - INFO - Table ATTRIBUTE_DESIGN successfully written to database.
# 2024-05-17 11:47:29,199 - INFO - Table ATTRIBUTE_DESIGN successfully written to database.
# 2024-05-17 11:47:29,211 - INFO - Table ATTRIBUTE_STRATEGY successfully written to database.
# 2024-05-17 11:47:29,211 - INFO - Table ATTRIBUTE_STRATEGY successfully written to database.
# 2024-05-17 11:47:29,789 - INFO - Table MODEL_BASE_INPUT_DATABASE successfully written to database.
# 2024-05-17 11:47:29,789 - INFO - Table MODEL_BASE_INPUT_DATABASE successfully written to database.

# %% [markdown]
# # Now, generate a baseline input dataframe to work from
# - You can use what you want; `sisepuede.baseline_strategy` stores the id for baseline strategy, but you may want to compare to another baseline

# %%
primary_base = sisepuede.odpt_primary.get_key_value(
    **{
        "design_id": 0,
        "future_id": 0,
        "strategy_id": 1015 # Land Use with PLUR
    }
)
df_in = sisepuede.generate_scenario_database_from_primary_key(primary_base);
df_in = df_in.get("peru")

# %% [markdown]
# ###  Let's do some evaluation without leveraging the entire SISEPUEDE framwork--just using the models
# - we can read a data frame and return a dataframe
# - we can also interact with transformations in the notebook and evaluate how they work together

# %%
mod = sisepuede.models

# %% [markdown]
# ##  Now lets's think about some transformations
# - Currently, some configuration pieces relevant to transformations have to be set in a dictionary. **This is soon changing**, but you can see below  how to instantiate a transformations object

# %%
year_0_ramp = 2025

# set some parameters (WILL SET TO READ FROM A CONFIG OR STRATEGY DEFINITION FILE)
dict_config_te = {
    "categories_entc_max_investment_ramp": [
        "pp_hydropower"
        #"pp_nuclear"
    ],
    "categories_entc_renewable": [
        "pp_geothermal",
        "pp_hydropower",
        "pp_ocean",
        "pp_solar",
        "pp_wind"
    ],
    "categories_inen_high_heat": [
        "cement", 
        "chemicals", 
        "glass", 
        "lime_and_carbonite", 
        "metals"
    ],
    "dict_entc_renewable_target_msp": {
        "pp_solar": 0.15,
        "pp_geothermal": 0.1,
        "pp_wind": 0.15
    },
    "frac_inen_high_temp_elec_hydg": 0.5*0.45,
    "frac_inen_low_temp_elec": 0.95*0.45,
    "n_tp_ramp": None,
    "vir_renewable_cap_delta_frac": 0.0075,
    "vir_renewable_cap_max_frac": 0.125,
    "year_0_ramp": year_0_ramp
}


transformations_integrated = dtr.TransformationsIntegrated(
    dict_config_te,
    baseline_with_plur = False, # SET TO TRUE TO ALLOW THE BASELINE TO INCLUDE PLUR (NULLIFIES THE WITH PLUR STRAT)
    df_input = df_in,
    field_region = sisepuede.key_region,
    regions = sisepuede.regions,
)
# Out:
# MISSIONSEARCHNOTE: As of 2023-10-06, there is a temporary solution implemeted in ModelAttributes.get_variable_to_simplex_group_dictionary() to ensure that transition probability rows are enforced on a simplex.
#
# FIX THIS ASAP TO DERIVE PROPERLY.
